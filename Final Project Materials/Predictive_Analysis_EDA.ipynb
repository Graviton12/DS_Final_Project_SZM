# %% [markdown]
# # **Predictive Analysis - Predicting Earth-Like Similarity in Exoplanets: Exploratory Data Analysis**

# %%
# Importing
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# loading dataset
df = pd.read_excel('/content/drive/MyDrive/Exoplanet /exoplanet_habitability_data.xlsx')

# %%
# Viewing the first 5 rows of the dataset
df.head()
# Out:
#     pl_name hostname  default_flag  sy_snum  sy_pnum  discoverymethod  \
# 0  11 Com b   11 Com             1        2        1  Radial Velocity
# 1  11 Com b   11 Com             0        2        1  Radial Velocity
# 2  11 Com b   11 Com             0        2        1  Radial Velocity
# 3  11 UMi b   11 UMi             0        1        1  Radial Velocity
# 4  11 UMi b   11 UMi             1        1        1  Radial Velocity
#
#    disc_year                           disc_facility              soltype  \
# 0       2007                        Xinglong Station  Published Confirmed
# 1       2007                        Xinglong Station  Published Confirmed
# 2       2007                        Xinglong Station  Published Confirmed
# 3       2009  Thueringer Landessternwarte Tautenburg  Published Confirmed
# 4       2009  Thueringer Landessternwarte Tautenburg  Published Confirmed
#
#    pl_controv_flag  ... sy_vmagerr2  sy_kmag  sy_kmagerr1  sy_kmagerr2  \
# 0                0  ...      -0.023    2.282        0.346       -0.346
# 1                0  ...      -0.023    2.282        0.346       -0.346
# 2                0  ...      -0.023    2.282        0.346       -0.346
# 3                0  ...      -0.005    1.939        0.270       -0.270
# 4                0  ...      -0.005    1.939        0.270       -0.270
#
#    sy_gaiamag  sy_gaiamagerr1  sy_gaiamagerr2  rowupdate  pl_pubdate  \
# 0     4.44038        0.003848       -0.003848 2023-09-19     2023-08
# 1     4.44038        0.003848       -0.003848 2014-05-14     2008-01
# 2     4.44038        0.003848       -0.003848 2014-07-23     2011-08
# 3     4.56216        0.003903       -0.003903 2018-04-25     2009-10
# 4     4.56216        0.003903       -0.003903 2018-09-04     2017-03
#
#    releasedate
# 0   2023-09-19
# 1   2014-05-14
# 2   2014-07-23
# 3   2014-05-14
# 4   2018-09-06
#
# [5 rows x 92 columns]

# %%
# viewing dataset information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39235 entries, 0 to 39234
# Data columns (total 92 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pl_name          39235 non-null  object
#  1   hostname         39235 non-null  object
#  2   default_flag     39235 non-null  int64
#  3   sy_snum          39235 non-null  int64
#  4   sy_pnum          39235 non-null  int64
#  5   discoverymethod  39235 non-null  object
#  6   disc_year        39235 non-null  int64
#  7   disc_facility    39235 non-null  object
#  8   soltype          39235 non-null  object
#  9   pl_controv_flag  39235 non-null  int64
#  10  pl_refname       39235 non-null  object
#  11  pl_orbper        35942 non-null  float64
#  12  pl_orbpererr1    34256 non-null  float64
#  13  pl_orbpererr2    34255 non-null  float64
#  14  pl_orbperlim     35942 non-null  float64
#  15  pl_orbsmax       21968 non-null  float64
#  16  pl_orbsmaxerr1   7499 non-null   float64
#  17  pl_orbsmaxerr2   7498 non-null   float64
#  18  pl_orbsmaxlim    24754 non-null  float64
#  19  pl_rade          27053 non-null  float64
#  20  pl_radeerr1      26323 non-null  float64
#  21  pl_radeerr2      26323 non-null  float64
#  22  pl_radelim       29798 non-null  float64
#  23  pl_radj          27053 non-null  float64
#  24  pl_radjerr1      26323 non-null  float64
#  25  pl_radjerr2      26323 non-null  float64
#  26  pl_radjlim       27053 non-null  float64
#  27  pl_bmasse        7112 non-null   float64
#  28  pl_bmasseerr1    6452 non-null   float64
#  29  pl_bmasseerr2    6452 non-null   float64
#  30  pl_bmasselim     7112 non-null   float64
#  31  pl_bmassj        7111 non-null   float64
#  32  pl_bmassjerr1    6446 non-null   float64
#  33  pl_bmassjerr2    6446 non-null   float64
#  34  pl_bmassjlim     7111 non-null   float64
#  35  pl_bmassprov     7112 non-null   object
#  36  pl_orbeccen      18729 non-null  float64
#  37  pl_orbeccenerr1  3732 non-null   float64
#  38  pl_orbeccenerr2  3731 non-null   float64
#  39  pl_orbeccenlim   21472 non-null  float64
#  40  pl_insol         17124 non-null  float64
#  41  pl_insolerr1     15787 non-null  float64
#  42  pl_insolerr2     15787 non-null  float64
#  43  pl_insollim      22182 non-null  float64
#  44  pl_eqt           17215 non-null  float64
#  45  pl_eqterr1       2548 non-null   float64
#  46  pl_eqterr2       2548 non-null   float64
#  47  pl_eqtlim        19958 non-null  float64
#  48  ttv_flag         39235 non-null  int64
#  49  st_refname       38834 non-null  object
#  50  st_spectype      2901 non-null   object
#  51  st_teff          35743 non-null  float64
#  52  st_tefferr1      34981 non-null  float64
#  53  st_tefferr2      34721 non-null  float64
#  54  st_tefflim       35743 non-null  float64
#  55  st_rad           35978 non-null  float64
#  56  st_raderr1       30430 non-null  float64
#  57  st_raderr2       30277 non-null  float64
#  58  st_radlim        35978 non-null  float64
#  59  st_mass          33126 non-null  float64
#  60  st_masserr1      27704 non-null  float64
#  61  st_masserr2      27549 non-null  float64
#  62  st_masslim       33133 non-null  float64
#  63  st_met           24786 non-null  float64
#  64  st_meterr1       24113 non-null  float64
#  65  st_meterr2       24113 non-null  float64
#  66  st_metlim        27097 non-null  float64
#  67  st_metratio      24589 non-null  object
#  68  st_logg          30455 non-null  float64
#  69  st_loggerr1      25151 non-null  float64
#  70  st_loggerr2      25150 non-null  float64
#  71  st_logglim       30455 non-null  float64
#  72  sy_refname       39235 non-null  object
#  73  rastr            39235 non-null  object
#  74  ra               39235 non-null  float64
#  75  decstr           39235 non-null  object
#  76  dec              39235 non-null  float64
#  77  sy_dist          38389 non-null  float64
#  78  sy_disterr1      37532 non-null  float64
#  79  sy_disterr2      37532 non-null  float64
#  80  sy_vmag          38433 non-null  float64
#  81  sy_vmagerr1      38420 non-null  float64
#  82  sy_vmagerr2      38419 non-null  float64
#  83  sy_kmag          38424 non-null  float64
#  84  sy_kmagerr1      38182 non-null  float64
#  85  sy_kmagerr2      38182 non-null  float64
#  86  sy_gaiamag       38134 non-null  float64
#  87  sy_gaiamagerr1   38134 non-null  float64
#  88  sy_gaiamagerr2   38134 non-null  float64
#  89  rowupdate        39234 non-null  datetime64[ns]
#  90  pl_pubdate       39235 non-null  object
#  91  releasedate      39235 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), float64(70), int64(6), object(14)
# memory usage: 27.5+ MB

# %%
# looking at statistics of dataset
df.describe()
# Out:
#        default_flag       sy_snum       sy_pnum     disc_year  \
# count  39235.000000  39235.000000  39235.000000  39235.000000
# mean       0.154734      1.085281      1.918389   2015.536281
# min        0.000000      1.000000      1.000000   1992.000000
# 25%        0.000000      1.000000      1.000000   2014.000000
# 50%        0.000000      1.000000      1.000000   2016.000000
# 75%        0.000000      1.000000      2.000000   2016.000000
# max        1.000000      4.000000      8.000000   2026.000000
# std        0.361656      0.308527      1.238380      4.006345
#
#        pl_controv_flag     pl_orbper  pl_orbpererr1  pl_orbpererr2  \
# count     39235.000000  3.594200e+04   3.425600e+04   3.425500e+04
# mean          0.003109  1.217103e+04   1.408216e+04  -3.318888e+03
# min           0.000000  9.070629e-02   0.000000e+00  -1.000000e+08
# 25%           0.000000  4.385364e+00   8.000000e-06  -2.000000e-04
# 50%           0.000000  1.033116e+01   3.812000e-05  -3.817000e-05
# 75%           0.000000  2.662946e+01   2.000000e-04  -8.000000e-06
# max           1.000000  4.020000e+08   4.700000e+08   0.000000e+00
# std           0.055677  2.121667e+06   2.539574e+06   5.415493e+05
#
#        pl_orbperlim    pl_orbsmax  ...   sy_vmagerr1   sy_vmagerr2  \
# count  35942.000000  21968.000000  ...  38420.000000  38419.000000
# mean      -0.000250      4.727418  ...      0.115940     -0.116524
# min       -1.000000      0.004400  ...      0.001000    -12.270000
# 25%        0.000000      0.054500  ...      0.046000     -0.137000
# 50%        0.000000      0.100735  ...      0.092000     -0.092000
# 75%        0.000000      0.219012  ...      0.137000     -0.046000
# max        1.000000  19000.000000  ...     11.000000     -0.001000
# std        0.020428    180.936826  ...      0.150125      0.179291
#
#             sy_kmag   sy_kmagerr1   sy_kmagerr2    sy_gaiamag  sy_gaiamagerr1  \
# count  38424.000000  38182.000000  38182.000000  38134.000000    38134.000000
# mean      11.529683      0.034920     -0.034440     13.319203        0.000520
# min       -3.044000      0.011000    -11.140000      2.364310        0.000112
# 25%       10.649000      0.020000     -0.033000     12.303100        0.000253
# 50%       12.234000      0.024000     -0.024000     13.951700        0.000353
# 75%       13.145000      0.033000     -0.020000     15.027600        0.000507
# max       35.330000      9.995000     -0.011000     20.186100        0.063232
# std        2.332455      0.185057      0.176456      2.364615        0.001092
#
#        sy_gaiamagerr2                      rowupdate  \
# count    38134.000000                          39234
# mean        -0.000520  2018-04-08 01:13:22.141000192
# min         -0.063232            2013-10-28 00:00:00
# 25%         -0.000507            2015-08-25 00:00:00
# 50%         -0.000353            2017-05-08 00:00:00
# 75%         -0.000253            2019-06-24 00:00:00
# max         -0.000112            2026-01-08 00:00:00
# std          0.001092                            NaN
#
#                          releasedate
# count                          39235
# mean   2018-02-20 05:57:30.715534592
# min              2013-10-28 00:00:00
# 25%              2015-02-26 00:00:00
# 50%              2017-05-08 00:00:00
# 75%              2019-04-18 00:00:00
# max              2026-01-08 00:00:00
# std                              NaN
#
# [8 rows x 78 columns]

# %%
# Viewing the number of rows and columns
df.shape # 39,235 rows and 92 columns
# Out:
# (39235, 92)

# %%
# Viewing columns
df.columns
# Out:
# Index(['pl_name', 'hostname', 'default_flag', 'sy_snum', 'sy_pnum',
#        'discoverymethod', 'disc_year', 'disc_facility', 'soltype',
#        'pl_controv_flag', 'pl_refname', 'pl_orbper', 'pl_orbpererr1',
#        'pl_orbpererr2', 'pl_orbperlim', 'pl_orbsmax', 'pl_orbsmaxerr1',
#        'pl_orbsmaxerr2', 'pl_orbsmaxlim', 'pl_rade', 'pl_radeerr1',
#        'pl_radeerr2', 'pl_radelim', 'pl_radj', 'pl_radjerr1', 'pl_radjerr2',
#        'pl_radjlim', 'pl_bmasse', 'pl_bmasseerr1', 'pl_bmasseerr2',
#        'pl_bmasselim', 'pl_bmassj', 'pl_bmassjerr1', 'pl_bmassjerr2',
#        'pl_bmassjlim', 'pl_bmassprov', 'pl_orbeccen', 'pl_orbeccenerr1',
#        'pl_orbeccenerr2', 'pl_orbeccenlim', 'pl_insol', 'pl_insolerr1',
#        'pl_insolerr2', 'pl_insollim', 'pl_eqt', 'pl_eqterr1', 'pl_eqterr2',
#        'pl_eqtlim', 'ttv_flag', 'st_refname', 'st_spectype', 'st_teff',
#        'st_tefferr1', 'st_tefferr2', 'st_tefflim', 'st_rad', 'st_raderr1',
#        'st_raderr2', 'st_radlim', 'st_mass', 'st_masserr1', 'st_masserr2',
#        'st_masslim', 'st_met', 'st_meterr1', 'st_meterr2', 'st_metlim',
#        'st_metratio', 'st_logg', 'st_loggerr1', 'st_loggerr2', 'st_logglim',
#        'sy_refname', 'rastr', 'ra', 'decstr', 'dec', 'sy_dist', 'sy_disterr1',
#        'sy_disterr2', 'sy_vmag', 'sy_vmagerr1', 'sy_vmagerr2', 'sy_kmag',
#        'sy_kmagerr1', 'sy_kmagerr2', 'sy_gaiamag', 'sy_gaiamagerr1',
#        'sy_gaiamagerr2', 'rowupdate', 'pl_pubdate', 'releasedate'],
#       dtype='object')

# %% [markdown]
# ## **Initial Data Preprocessing**

# %% [markdown]
# ### Deleting and Renaming Columns

# %%
# dropping uneeded columns
df.drop(['sy_pnum', 'pl_refname', 'pl_orbpererr1', 'pl_orbpererr2', 'pl_orbperlim', 'pl_orbsmaxerr1', 'pl_orbsmaxerr2', 'pl_orbsmaxlim',
         'pl_radeerr1', 'pl_radeerr2', 'pl_radelim', 'pl_radjerr1', 'pl_radjerr2', 'pl_radjlim', 'pl_bmasseerr1', 'pl_bmasseerr2',
         'pl_bmasselim', 'pl_bmassjerr1', 'pl_bmassjerr2', 'pl_bmassjlim', 'pl_bmassprov', 'pl_orbeccenerr1', 'pl_orbeccenerr2',
         'pl_orbeccenlim', 'pl_insol', 'pl_insolerr1', 'pl_insolerr2', 'pl_insollim', 'pl_eqterr1', 'pl_eqterr2', 'pl_eqtlim', 'ttv_flag', 'st_refname',
         'st_tefferr1', 'st_tefferr2', 'st_tefflim', 'st_raderr1', 'st_raderr2', 'st_radlim', 'st_masserr1', 'st_masserr2', 'st_masslim',
         'st_meterr1', 'st_meterr2', 'st_metlim', 'st_metratio', 'st_loggerr1', 'st_loggerr2', 'st_logglim', 'sy_refname', 'rastr', 'ra', 'decstr', 'dec',
         'sy_disterr1', 'sy_disterr2', 'sy_vmagerr1', 'sy_vmagerr2', 'sy_kmagerr1', 'sy_kmagerr2', 'sy_gaiamagerr1', 'sy_gaiamagerr2', 'rowupdate', 'pl_pubdate',
         'releasedate', 'sy_vmag', 'sy_kmag', 'sy_gaiamag'], axis=1, inplace=True)

# %%
# Checking if the columns were dropped
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39235 entries, 0 to 39234
# Data columns (total 24 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pl_name          39235 non-null  object
#  1   hostname         39235 non-null  object
#  2   default_flag     39235 non-null  int64
#  3   sy_snum          39235 non-null  int64
#  4   discoverymethod  39235 non-null  object
#  5   disc_year        39235 non-null  int64
#  6   disc_facility    39235 non-null  object
#  7   soltype          39235 non-null  object
#  8   pl_controv_flag  39235 non-null  int64
#  9   pl_orbper        35942 non-null  float64
#  10  pl_orbsmax       21968 non-null  float64
#  11  pl_rade          27053 non-null  float64
#  12  pl_radj          27053 non-null  float64
#  13  pl_bmasse        7112 non-null   float64
#  14  pl_bmassj        7111 non-null   float64
#  15  pl_orbeccen      18729 non-null  float64
#  16  pl_eqt           17215 non-null  float64
#  17  st_spectype      2901 non-null   object
#  18  st_teff          35743 non-null  float64
#  19  st_rad           35978 non-null  float64
#  20  st_mass          33126 non-null  float64
#  21  st_met           24786 non-null  float64
#  22  st_logg          30455 non-null  float64
#  23  sy_dist          38389 non-null  float64
# dtypes: float64(14), int64(4), object(6)
# memory usage: 7.2+ MB

# %%
# renaming columns
df = df.rename(columns={
    'pl_name': 'planet_name',
    'hostname': 'host_star_name',
    'st_spectype': 'spectral_type',
    'sy_snum': 'star_number_per_system',
    'discoverymethod': 'discovery_method',
    'disc_year': 'year_of_discovery',
    'disc_facility': 'discovery_facility',
    'soltype': 'solution_type',
    'pl_orbper': 'orbital_period_day',
    'pl_orbsmax': 'orbit_semi_major_axis_au',
    'pl_rade': 'planet_rad_earth_rad',
    'pl_radj': 'planet_rad_jupiter_rad',
    'pl_bmasse': 'planet_mass_earth_mass',
    'pl_bmassj': 'planet_mass_jupiter_mass',
    'pl_orbeccen': 'orbital_eccentricity',
    'pl_eqt': 'planet_equil_temp_k',
    'st_teff': 'stellar_effective_temp_k',
    'st_rad': 'stellar_rad_solar_rad',
    'st_mass': 'stellar_mass_solar_mass',
    'st_met': 'stellar_metallicity',
    'st_logg': 'stellar_surf_grav',
    'sy_dist': 'distance_parsec'
})

# %%
# checking if columns were renamed
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39235 entries, 0 to 39234
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   planet_name               39235 non-null  object
#  1   host_star_name            39235 non-null  object
#  2   default_flag              39235 non-null  int64
#  3   star_number_per_system    39235 non-null  int64
#  4   discovery_method          39235 non-null  object
#  5   year_of_discovery         39235 non-null  int64
#  6   discovery_facility        39235 non-null  object
#  7   solution_type             39235 non-null  object
#  8   pl_controv_flag           39235 non-null  int64
#  9   orbital_period_day        35942 non-null  float64
#  10  orbit_semi_major_axis_au  21968 non-null  float64
#  11  planet_rad_earth_rad      27053 non-null  float64
#  12  planet_rad_jupiter_rad    27053 non-null  float64
#  13  planet_mass_earth_mass    7112 non-null   float64
#  14  planet_mass_jupiter_mass  7111 non-null   float64
#  15  orbital_eccentricity      18729 non-null  float64
#  16  planet_equil_temp_k       17215 non-null  float64
#  17  spectral_type             2901 non-null   object
#  18  stellar_effective_temp_k  35743 non-null  float64
#  19  stellar_rad_solar_rad     35978 non-null  float64
#  20  stellar_mass_solar_mass   33126 non-null  float64
#  21  stellar_metallicity       24786 non-null  float64
#  22  stellar_surf_grav         30455 non-null  float64
#  23  distance_parsec           38389 non-null  float64
# dtypes: float64(14), int64(4), object(6)
# memory usage: 7.2+ MB

# %% [markdown]
# ### Checking for outliers

# %% [markdown]
# #### Outlier Detection Algorithm
# * Creating an outlier detection algorithm to identify which entries are potential outliers for a given exoplanet per column

# %%
# Determining all numerical columns in DataFrame
numerical_columns = df.select_dtypes(include=[np.number]).columns
numerical_columns
# Out:
# Index(['default_flag', 'star_number_per_system', 'year_of_discovery',
#        'pl_controv_flag', 'orbital_period_day', 'orbit_semi_major_axis_au',
#        'planet_rad_earth_rad', 'planet_rad_jupiter_rad',
#        'planet_mass_earth_mass', 'planet_mass_jupiter_mass',
#        'orbital_eccentricity', 'planet_equil_temp_k',
#        'stellar_effective_temp_k', 'stellar_rad_solar_rad',
#        'stellar_mass_solar_mass', 'stellar_metallicity', 'stellar_surf_grav',
#        'distance_parsec'],
#       dtype='object')

# %%
# Creating copy of DataFrame
exoplanets = df.copy()

# Function to determine the z-score using Population Standard Deviation (ddof=0)
def flag_outliers_zscore(series, threshold=3):
    # Calculate mean and population std dev (ddof=0)
    # We use dropna() to ensure missing values don't interfere with the calculation
    clean_series = series.dropna()
    if len(clean_series) < 3:
        return pd.Series([False] * len(series), index=series.index)

    mean = clean_series.mean()
    # population standard deviation
    std_dev = clean_series.std(ddof=0)

    # Lowered guard to 0.01 so stellar parameters aren't skipped
    if std_dev <= 0.01:
        return pd.Series([False] * len(series), index=series.index)

    # Compute the z-score
    z_scores = (series - mean) / std_dev
    return abs(z_scores) > threshold

# Function to flag outliers
def flag_outliers_for_column_zscore(df, column_name, threshold=3):
    # Group by planet name (ensure this matches your column name, e.g., 'pl_name')
    grouped = df.groupby("planet_name")

    for group_name, group_data in grouped:
        outlier_flags = flag_outliers_zscore(group_data[column_name], threshold)
        df.loc[group_data.index, column_name + '_outlier'] = outlier_flags

# Get numerical columns
numerical_columns = exoplanets.select_dtypes(include=[np.number]).columns

# Define sensitive columns that need a lower threshold to catch outliers
sensitive_columns = ['stellar_mass_solar_mass', 'stellar_rad_solar_rad']

# Apply the detection
for column_name in numerical_columns:
    if column_name in sensitive_columns:
        # Use threshold=1.0 for stellar mass and radius
        flag_outliers_for_column_zscore(exoplanets, column_name, threshold=1.0)
    else:
        # Use threshold=3.0 for all other numerical columns
        flag_outliers_for_column_zscore(exoplanets, column_name, threshold=3.0)

# Verification check for Kepler-452 b
print(exoplanets[exoplanets['planet_name'] == 'Kepler-452 b'][['default_flag', 'planet_name', 'stellar_mass_solar_mass', 'stellar_mass_solar_mass_outlier']])
# Out:
#        default_flag   planet_name  stellar_mass_solar_mass  \
# 27463             0  Kepler-452 b                      NaN
# 27464             0  Kepler-452 b                    1.022
# 27465             0  Kepler-452 b                    0.892
# 27466             0  Kepler-452 b                    1.030
# 27467             1  Kepler-452 b                    1.037
# 27468             0  Kepler-452 b                    0.870
#
#       stellar_mass_solar_mass_outlier
# 27463                           False
# 27464                           False
# 27465                            True
# 27466                           False
# 27467                           False
# 27468                            True

# %%
# Create an empty list to store outlier dictionaries
all_outliers_data = []

# Loop over all outlier columns (which are all numerical columns)
for column in numerical_columns:
    outlier_col = column + "_outlier"

    # Filter rows where the outlier flag is True
    outliers = exoplanets[exoplanets[outlier_col] == True]

    # For each outlier, create a dictionary and add it to the list
    for idx, row in outliers.iterrows():
        all_outliers_data.append({
            "planet_name": row["planet_name"],
            "column": column,
            "value": row[column]
        })

# Create the DataFrame from the list of dictionaries after the loop
outlier_summary = pd.DataFrame(all_outliers_data)

# Display all outliers
print(outlier_summary)
# Out:
#         planet_name             column  value
# 0          55 Cnc b       default_flag   1.00
# 1          55 Cnc d       default_flag   1.00
# 2          55 Cnc e       default_flag   1.00
# 3          AU Mic b       default_flag   1.00
# 4         CoRoT-2 b       default_flag   1.00
# ...             ...                ...    ...
# 23146   Kepler-23 d  stellar_surf_grav   3.97
# 23147  Kepler-428 b  stellar_surf_grav   4.67
# 23148   Kepler-43 b  stellar_surf_grav   4.54
# 23149   Kepler-44 b  stellar_surf_grav   4.48
# 23150    Kepler-6 b  stellar_surf_grav   4.42
#
# [23151 rows x 3 columns]

# %% [markdown]
# 23,151 entries flagged as an outlier

# %%
# If a row with default_flag == 1 has entry flagged as outlier (true), this entry should still be kept and thus, will be changed to false
outlier_cols = [col for col in exoplanets.columns if col.endswith('_outlier')]

rows_with_outliers = exoplanets[
    (exoplanets["default_flag"] == 1) &
    (exoplanets[outlier_cols].any(axis=1))
]

print(
    rows_with_outliers[
        ["default_flag", "planet_name"] + outlier_cols
    ]
)
# Out:
#        default_flag planet_name default_flag_outlier  \
# 0                 1    11 Com b                False
# 4                 1    11 UMi b                False
# 17                1  16 Cyg B b                False
# 85                1    55 Cnc b                 True
# 91                1    55 Cnc c                False
# ...             ...         ...                  ...
# 39196             1   rho CrB c                False
# 39201             1   tau Boo b                False
# 39215             1   ups And b                False
# 39221             1   ups And c                False
# 39227             1   ups And d                False
#
#       star_number_per_system_outlier year_of_discovery_outlier  \
# 0                              False                     False
# 4                              False                     False
# 17                             False                     False
# 85                             False                     False
# 91                             False                     False
# ...                              ...                       ...
# 39196                          False                     False
# 39201                          False                     False
# 39215                          False                     False
# 39221                          False                     False
# 39227                          False                     False
#
#       pl_controv_flag_outlier orbital_period_day_outlier  \
# 0                       False                      False
# 4                       False                      False
# 17                      False                      False
# 85                      False                      False
# 91                      False                      False
# ...                       ...                        ...
# 39196                   False                      False
# 39201                   False                      False
# 39215                   False                      False
# 39221                   False                      False
# 39227                   False                      False
#
#       orbit_semi_major_axis_au_outlier planet_rad_earth_rad_outlier  \
# 0                                False                        False
# 4                                False                        False
# 17                               False                        False
# 85                               False                        False
# 91                               False                        False
# ...                                ...                          ...
# 39196                            False                        False
# 39201                            False                        False
# 39215                            False                        False
# 39221                            False                        False
# 39227                            False                        False
#
#       planet_rad_jupiter_rad_outlier planet_mass_earth_mass_outlier  \
# 0                              False                          False
# 4                              False                          False
# 17                             False                          False
# 85                             False                          False
# 91                             False                          False
# ...                              ...                            ...
# 39196                          False                          False
# 39201                          False                          False
# 39215                          False                          False
# 39221                          False                          False
# 39227                          False                          False
#
#       planet_mass_jupiter_mass_outlier orbital_eccentricity_outlier  \
# 0                                False                        False
# 4                                False                        False
# 17                               False                        False
# 85                               False                        False
# 91                               False                        False
# ...                                ...                          ...
# 39196                            False                        False
# 39201                            False                        False
# 39215                            False                        False
# 39221                            False                        False
# 39227                            False                        False
#
#       planet_equil_temp_k_outlier stellar_effective_temp_k_outlier  \
# 0                           False                            False
# 4                           False                            False
# 17                          False                            False
# 85                          False                            False
# 91                          False                            False
# ...                           ...                              ...
# 39196                       False                            False
# 39201                       False                            False
# 39215                       False                            False
# 39221                       False                            False
# 39227                       False                            False
#
#       stellar_rad_solar_rad_outlier stellar_mass_solar_mass_outlier  \
# 0                             False                            True
# 4                             False                            True
# 17                            False                            True
# 85                            False                            True
# 91                            False                            True
# ...                             ...                             ...
# 39196                         False                            True
# 39201                          True                           False
# 39215                          True                           False
# 39221                          True                           False
# 39227                          True                           False
#
#       stellar_metallicity_outlier stellar_surf_grav_outlier  \
# 0                           False                     False
# 4                           False                     False
# 17                          False                     False
# 85                          False                     False
# 91                          False                     False
# ...                           ...                       ...
# 39196                       False                     False
# 39201                       False                     False
# 39215                       False                     False
# 39221                       False                     False
# 39227                       False                     False
#
#       distance_parsec_outlier
# 0                       False
# 4                       False
# 17                      False
# 85                      False
# 91                      False
# ...                       ...
# 39196                   False
# 39201                   False
# 39215                   False
# 39221                   False
# 39227                   False
#
# [2594 rows x 20 columns]

# %% [markdown]
# 2,549 defautl flag rows have at least one outlier entry. These outlier entries must be overidden

# %%
# Manually overiding the entries within default flag == 1 rows to be False
exoplanets.loc[
    exoplanets["default_flag"] == 1,
    outlier_cols
] = False

# %% [markdown]
# #### Outlier Visualizer
# * Automatically diplaying the entries flagged as outliers for a given exoplanet per column

# %%
# Create an empty list to store outlier dictionaries
all_outliers_data = []

# Loop over all outlier columns (which are all numerical columns)
for column in numerical_columns:
    outlier_col = column + "_outlier"

    # Filter rows where the outlier flag is True
    outliers = exoplanets[exoplanets[outlier_col] == True]

    # For each outlier, create a dictionary and add it to the list
    for idx, row in outliers.iterrows():
        all_outliers_data.append({
            "planet_name": row["planet_name"],
            "column": column,
            "value": row[column]
        })

# Create the DataFrame from the list of dictionaries after the loop
outlier_summary = pd.DataFrame(all_outliers_data)

# Display all outliers
print(outlier_summary)
# Out:
#         planet_name              column        value
# 0          55 Cnc b  orbital_period_day    14.465314
# 1       HD 106315 c  orbital_period_day  1221.270977
# 2           K2-19 c  orbital_period_day    23.814860
# 3           K2-32 b  orbital_period_day    17.975860
# 4      Kepler-117 b  orbital_period_day    50.790364
# ...             ...                 ...          ...
# 19564   Kepler-23 d   stellar_surf_grav     3.970000
# 19565  Kepler-428 b   stellar_surf_grav     4.670000
# 19566   Kepler-43 b   stellar_surf_grav     4.540000
# 19567   Kepler-44 b   stellar_surf_grav     4.480000
# 19568    Kepler-6 b   stellar_surf_grav     4.420000
#
# [19569 rows x 3 columns]

# %% [markdown]
# 19,569 entries now flagged as an outlier

# %%
# List of planets we want to visualize
selected_planets = ["55 Cnc b"] # HD 106315 c

# Loop over each outlier in the summary
for _, outlier in outlier_summary.iterrows():
    planet = outlier["planet_name"]
    column = outlier["column"]

    # Only process if the planet is in your selected list
    if planet in selected_planets:
        print(f"\nAll entries for planet '{planet}' in column '{column}':")

        # Filter the DataFrame for this planet
        planet_data = exoplanets[exoplanets["planet_name"] == planet].copy()

        # Keep only the planet_name and the column with the outlier
        planet_data = planet_data[["default_flag", "planet_name", column]]

        # Style function to highlight the outlier
        def highlight_outlier(val):
            if val == outlier["value"]:
                return 'background-color: yellow; font-weight: bold'
            else:
                return ''

        # Display with styling
        display(planet_data.style.applymap(highlight_outlier, subset=[column]))
# Out:
# All entries for planet '55 Cnc b' in column 'orbital_period_day':
# <style type="text/css">
# #T_54695_row1_col2 {
#   background-color: yellow;
#   font-weight: bold;
# }
# </style>
# <table id="T_54695" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_54695_level0_col0" class="col_heading level0 col0" >default_flag</th>
#       <th id="T_54695_level0_col1" class="col_heading level0 col1" >planet_name</th>
#       <th id="T_54695_level0_col2" class="col_heading level0 col2" >orbital_period_day</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_54695_level0_row0" class="row_heading level0 row0" >75</th>
#       <td id="T_54695_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_54695_row0_col1" class="data row0 col1" >55 Cnc b</td>
#       <td id="T_54695_row0_col2" class="data row0 col2" >14.647000</td>
#     </tr>
#     <tr>
#       <th id="T_54695_level0_row1" class="row_heading level0 row1" >76</th>
#       <td id="T_54695_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_54695_row1_col1" class="data row1 col1" >55 Cnc b</td>
#       <td id="T_54695_row1_col2" class="data row1 col2" >14.465314</td>
#     </tr>
#     <tr>
#       <th id="T_54695_level0_row2" class="row_heading level0 row2" >77</th>
#       <td id="T_54695_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_54695_row2_col1" class="data row2 col1" >55 Cnc b</td>
#       <td id="T_54695_row2_col2" class="data row2 col2" >14.653000</td>
#     </tr>
#     <tr>
#       <th id="T_54695_level0_row3" class="row_heading level0 row3" >78</th>
#       <td id="T_54695_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_54695_row3_col1" class="data row3 col1" >55 Cnc b</td>
#       <td id="T_54695_row3_col2" class="data row3 col2" >14.651520</td>
#     </tr>
#     <tr>
#       <th id="T_54695_level0_row4" class="row_heading level0 row4" >79</th>
#       <td id="T_54695_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_54695_row4_col1" class="data row4 col1" >55 Cnc b</td>
#       <td id="T_54695_row4_col2" class="data row4 col2" >14.651620</td>
#     </tr>
#     <tr>
#       <th id="T_54695_level0_row5" class="row_heading level0 row5" >80</th>
#       <td id="T_54695_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_54695_row5_col1" class="data row5 col1" >55 Cnc b</td>
#       <td id="T_54695_row5_col2" class="data row5 col2" >14.651000</td>
#     </tr>
#     <tr>
#       <th id="T_54695_level0_row6" class="row_heading level0 row6" >81</th>
#       <td id="T_54695_row6_col0" class="data row6 col0" >0</td>
#       <td id="T_54695_row6_col1" class="data row6 col1" >55 Cnc b</td>
#       <td id="T_54695_row6_col2" class="data row6 col2" >14.651260</td>
#     </tr>
#     <tr>
#       <th id="T_54695_level0_row7" class="row_heading level0 row7" >82</th>
#       <td id="T_54695_row7_col0" class="data row7 col0" >0</td>
#       <td id="T_54695_row7_col1" class="data row7 col1" >55 Cnc b</td>
#       <td id="T_54695_row7_col2" class="data row7 col2" >14.651710</td>
#     </tr>
#     <tr>
#       <th id="T_54695_level0_row8" class="row_heading level0 row8" >83</th>
#       <td id="T_54695_row8_col0" class="data row8 col0" >0</td>
#       <td id="T_54695_row8_col1" class="data row8 col1" >55 Cnc b</td>
#       <td id="T_54695_row8_col2" class="data row8 col2" >14.651600</td>
#     </tr>
#     <tr>
#       <th id="T_54695_level0_row9" class="row_heading level0 row9" >84</th>
#       <td id="T_54695_row9_col0" class="data row9 col0" >0</td>
#       <td id="T_54695_row9_col1" class="data row9 col1" >55 Cnc b</td>
#       <td id="T_54695_row9_col2" class="data row9 col2" >14.600000</td>
#     </tr>
#     <tr>
#       <th id="T_54695_level0_row10" class="row_heading level0 row10" >85</th>
#       <td id="T_54695_row10_col0" class="data row10 col0" >1</td>
#       <td id="T_54695_row10_col1" class="data row10 col1" >55 Cnc b</td>
#       <td id="T_54695_row10_col2" class="data row10 col2" >14.651552</td>
#     </tr>
#     <tr>
#       <th id="T_54695_level0_row11" class="row_heading level0 row11" >86</th>
#       <td id="T_54695_row11_col0" class="data row11 col0" >0</td>
#       <td id="T_54695_row11_col1" class="data row11 col1" >55 Cnc b</td>
#       <td id="T_54695_row11_col2" class="data row11 col2" >14.648000</td>
#     </tr>
#     <tr>
#       <th id="T_54695_level0_row12" class="row_heading level0 row12" >87</th>
#       <td id="T_54695_row12_col0" class="data row12 col0" >0</td>
#       <td id="T_54695_row12_col1" class="data row12 col1" >55 Cnc b</td>
#       <td id="T_54695_row12_col2" class="data row12 col2" >14.670000</td>
#     </tr>
#   </tbody>
# </table>
# All entries for planet '55 Cnc b' in column 'stellar_mass_solar_mass':
# <style type="text/css">
# #T_705b2_row7_col2 {
#   background-color: yellow;
#   font-weight: bold;
# }
# </style>
# <table id="T_705b2" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_705b2_level0_col0" class="col_heading level0 col0" >default_flag</th>
#       <th id="T_705b2_level0_col1" class="col_heading level0 col1" >planet_name</th>
#       <th id="T_705b2_level0_col2" class="col_heading level0 col2" >stellar_mass_solar_mass</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_705b2_level0_row0" class="row_heading level0 row0" >75</th>
#       <td id="T_705b2_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_705b2_row0_col1" class="data row0 col1" >55 Cnc b</td>
#       <td id="T_705b2_row0_col2" class="data row0 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_705b2_level0_row1" class="row_heading level0 row1" >76</th>
#       <td id="T_705b2_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_705b2_row1_col1" class="data row1 col1" >55 Cnc b</td>
#       <td id="T_705b2_row1_col2" class="data row1 col2" >0.900000</td>
#     </tr>
#     <tr>
#       <th id="T_705b2_level0_row2" class="row_heading level0 row2" >77</th>
#       <td id="T_705b2_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_705b2_row2_col1" class="data row2 col1" >55 Cnc b</td>
#       <td id="T_705b2_row2_col2" class="data row2 col2" >0.950000</td>
#     </tr>
#     <tr>
#       <th id="T_705b2_level0_row3" class="row_heading level0 row3" >78</th>
#       <td id="T_705b2_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_705b2_row3_col1" class="data row3 col1" >55 Cnc b</td>
#       <td id="T_705b2_row3_col2" class="data row3 col2" >0.950000</td>
#     </tr>
#     <tr>
#       <th id="T_705b2_level0_row4" class="row_heading level0 row4" >79</th>
#       <td id="T_705b2_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_705b2_row4_col1" class="data row4 col1" >55 Cnc b</td>
#       <td id="T_705b2_row4_col2" class="data row4 col2" >0.900000</td>
#     </tr>
#     <tr>
#       <th id="T_705b2_level0_row5" class="row_heading level0 row5" >80</th>
#       <td id="T_705b2_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_705b2_row5_col1" class="data row5 col1" >55 Cnc b</td>
#       <td id="T_705b2_row5_col2" class="data row5 col2" >0.900000</td>
#     </tr>
#     <tr>
#       <th id="T_705b2_level0_row6" class="row_heading level0 row6" >81</th>
#       <td id="T_705b2_row6_col0" class="data row6 col0" >0</td>
#       <td id="T_705b2_row6_col1" class="data row6 col1" >55 Cnc b</td>
#       <td id="T_705b2_row6_col2" class="data row6 col2" >0.900000</td>
#     </tr>
#     <tr>
#       <th id="T_705b2_level0_row7" class="row_heading level0 row7" >82</th>
#       <td id="T_705b2_row7_col0" class="data row7 col0" >0</td>
#       <td id="T_705b2_row7_col1" class="data row7 col1" >55 Cnc b</td>
#       <td id="T_705b2_row7_col2" class="data row7 col2" >0.974708</td>
#     </tr>
#     <tr>
#       <th id="T_705b2_level0_row8" class="row_heading level0 row8" >83</th>
#       <td id="T_705b2_row8_col0" class="data row8 col0" >0</td>
#       <td id="T_705b2_row8_col1" class="data row8 col1" >55 Cnc b</td>
#       <td id="T_705b2_row8_col2" class="data row8 col2" >0.905000</td>
#     </tr>
#     <tr>
#       <th id="T_705b2_level0_row9" class="row_heading level0 row9" >84</th>
#       <td id="T_705b2_row9_col0" class="data row9 col0" >0</td>
#       <td id="T_705b2_row9_col1" class="data row9 col1" >55 Cnc b</td>
#       <td id="T_705b2_row9_col2" class="data row9 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_705b2_level0_row10" class="row_heading level0 row10" >85</th>
#       <td id="T_705b2_row10_col0" class="data row10 col0" >1</td>
#       <td id="T_705b2_row10_col1" class="data row10 col1" >55 Cnc b</td>
#       <td id="T_705b2_row10_col2" class="data row10 col2" >1.015000</td>
#     </tr>
#     <tr>
#       <th id="T_705b2_level0_row11" class="row_heading level0 row11" >86</th>
#       <td id="T_705b2_row11_col0" class="data row11 col0" >0</td>
#       <td id="T_705b2_row11_col1" class="data row11 col1" >55 Cnc b</td>
#       <td id="T_705b2_row11_col2" class="data row11 col2" >0.850000</td>
#     </tr>
#     <tr>
#       <th id="T_705b2_level0_row12" class="row_heading level0 row12" >87</th>
#       <td id="T_705b2_row12_col0" class="data row12 col0" >0</td>
#       <td id="T_705b2_row12_col1" class="data row12 col1" >55 Cnc b</td>
#       <td id="T_705b2_row12_col2" class="data row12 col2" >0.950000</td>
#     </tr>
#   </tbody>
# </table>
# All entries for planet '55 Cnc b' in column 'stellar_mass_solar_mass':
# <style type="text/css">
# #T_16336_row11_col2 {
#   background-color: yellow;
#   font-weight: bold;
# }
# </style>
# <table id="T_16336" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_16336_level0_col0" class="col_heading level0 col0" >default_flag</th>
#       <th id="T_16336_level0_col1" class="col_heading level0 col1" >planet_name</th>
#       <th id="T_16336_level0_col2" class="col_heading level0 col2" >stellar_mass_solar_mass</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_16336_level0_row0" class="row_heading level0 row0" >75</th>
#       <td id="T_16336_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_16336_row0_col1" class="data row0 col1" >55 Cnc b</td>
#       <td id="T_16336_row0_col2" class="data row0 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_16336_level0_row1" class="row_heading level0 row1" >76</th>
#       <td id="T_16336_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_16336_row1_col1" class="data row1 col1" >55 Cnc b</td>
#       <td id="T_16336_row1_col2" class="data row1 col2" >0.900000</td>
#     </tr>
#     <tr>
#       <th id="T_16336_level0_row2" class="row_heading level0 row2" >77</th>
#       <td id="T_16336_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_16336_row2_col1" class="data row2 col1" >55 Cnc b</td>
#       <td id="T_16336_row2_col2" class="data row2 col2" >0.950000</td>
#     </tr>
#     <tr>
#       <th id="T_16336_level0_row3" class="row_heading level0 row3" >78</th>
#       <td id="T_16336_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_16336_row3_col1" class="data row3 col1" >55 Cnc b</td>
#       <td id="T_16336_row3_col2" class="data row3 col2" >0.950000</td>
#     </tr>
#     <tr>
#       <th id="T_16336_level0_row4" class="row_heading level0 row4" >79</th>
#       <td id="T_16336_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_16336_row4_col1" class="data row4 col1" >55 Cnc b</td>
#       <td id="T_16336_row4_col2" class="data row4 col2" >0.900000</td>
#     </tr>
#     <tr>
#       <th id="T_16336_level0_row5" class="row_heading level0 row5" >80</th>
#       <td id="T_16336_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_16336_row5_col1" class="data row5 col1" >55 Cnc b</td>
#       <td id="T_16336_row5_col2" class="data row5 col2" >0.900000</td>
#     </tr>
#     <tr>
#       <th id="T_16336_level0_row6" class="row_heading level0 row6" >81</th>
#       <td id="T_16336_row6_col0" class="data row6 col0" >0</td>
#       <td id="T_16336_row6_col1" class="data row6 col1" >55 Cnc b</td>
#       <td id="T_16336_row6_col2" class="data row6 col2" >0.900000</td>
#     </tr>
#     <tr>
#       <th id="T_16336_level0_row7" class="row_heading level0 row7" >82</th>
#       <td id="T_16336_row7_col0" class="data row7 col0" >0</td>
#       <td id="T_16336_row7_col1" class="data row7 col1" >55 Cnc b</td>
#       <td id="T_16336_row7_col2" class="data row7 col2" >0.974708</td>
#     </tr>
#     <tr>
#       <th id="T_16336_level0_row8" class="row_heading level0 row8" >83</th>
#       <td id="T_16336_row8_col0" class="data row8 col0" >0</td>
#       <td id="T_16336_row8_col1" class="data row8 col1" >55 Cnc b</td>
#       <td id="T_16336_row8_col2" class="data row8 col2" >0.905000</td>
#     </tr>
#     <tr>
#       <th id="T_16336_level0_row9" class="row_heading level0 row9" >84</th>
#       <td id="T_16336_row9_col0" class="data row9 col0" >0</td>
#       <td id="T_16336_row9_col1" class="data row9 col1" >55 Cnc b</td>
#       <td id="T_16336_row9_col2" class="data row9 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_16336_level0_row10" class="row_heading level0 row10" >85</th>
#       <td id="T_16336_row10_col0" class="data row10 col0" >1</td>
#       <td id="T_16336_row10_col1" class="data row10 col1" >55 Cnc b</td>
#       <td id="T_16336_row10_col2" class="data row10 col2" >1.015000</td>
#     </tr>
#     <tr>
#       <th id="T_16336_level0_row11" class="row_heading level0 row11" >86</th>
#       <td id="T_16336_row11_col0" class="data row11 col0" >0</td>
#       <td id="T_16336_row11_col1" class="data row11 col1" >55 Cnc b</td>
#       <td id="T_16336_row11_col2" class="data row11 col2" >0.850000</td>
#     </tr>
#     <tr>
#       <th id="T_16336_level0_row12" class="row_heading level0 row12" >87</th>
#       <td id="T_16336_row12_col0" class="data row12 col0" >0</td>
#       <td id="T_16336_row12_col1" class="data row12 col1" >55 Cnc b</td>
#       <td id="T_16336_row12_col2" class="data row12 col2" >0.950000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Outlier Removal Algorithm
# * Automatically remove the entries flagged as outliers

# %%
# Make a copy of the DataFrame
exoplanets_cleaned = exoplanets.copy()

# Loop over all outlier columns (which are numerical columns)
for column in numerical_columns:
    outlier_col = column + "_outlier"

    # Set the outlier entries to NaN (remove the entry) but do not remove the row
    exoplanets_cleaned.loc[exoplanets_cleaned[outlier_col] == True, column] = pd.NA

# Drop the '_outlier' columns now that they are no longer needed
outlier_cols = [col + "_outlier" for col in numerical_columns]
exoplanets_cleaned = exoplanets_cleaned.drop(columns=outlier_cols)

# Display the cleaned DataFrame
print(exoplanets_cleaned)
# Out:
#       planet_name host_star_name  default_flag  star_number_per_system  \
# 0        11 Com b         11 Com           1.0                     2.0
# 1        11 Com b         11 Com           0.0                     2.0
# 2        11 Com b         11 Com           0.0                     2.0
# 3        11 UMi b         11 UMi           0.0                     1.0
# 4        11 UMi b         11 UMi           1.0                     1.0
# ...           ...            ...           ...                     ...
# 39230   ups And d        ups And           0.0                     2.0
# 39231   ups Leo b        ups Leo           1.0                     1.0
# 39232    xi Aql b         xi Aql           0.0                     1.0
# 39233    xi Aql b         xi Aql           0.0                     1.0
# 39234    xi Aql b         xi Aql           1.0                     1.0
#
#       discovery_method  year_of_discovery  \
# 0      Radial Velocity             2007.0
# 1      Radial Velocity             2007.0
# 2      Radial Velocity             2007.0
# 3      Radial Velocity             2009.0
# 4      Radial Velocity             2009.0
# ...                ...                ...
# 39230  Radial Velocity             1999.0
# 39231  Radial Velocity             2021.0
# 39232  Radial Velocity             2007.0
# 39233  Radial Velocity             2007.0
# 39234  Radial Velocity             2007.0
#
#                            discovery_facility        solution_type  \
# 0                            Xinglong Station  Published Confirmed
# 1                            Xinglong Station  Published Confirmed
# 2                            Xinglong Station  Published Confirmed
# 3      Thueringer Landessternwarte Tautenburg  Published Confirmed
# 4      Thueringer Landessternwarte Tautenburg  Published Confirmed
# ...                                       ...                  ...
# 39230                  Multiple Observatories  Published Confirmed
# 39231       Okayama Astrophysical Observatory  Published Confirmed
# 39232       Okayama Astrophysical Observatory  Published Confirmed
# 39233       Okayama Astrophysical Observatory  Published Confirmed
# 39234       Okayama Astrophysical Observatory  Published Confirmed
#
#        pl_controv_flag  orbital_period_day  ...  planet_mass_jupiter_mass  \
# 0                  0.0           323.21000  ...                    15.464
# 1                  0.0           326.03000  ...                    19.400
# 2                  0.0                 NaN  ...                    17.100
# 3                  0.0           516.22000  ...                    10.500
# 4                  0.0           516.21997  ...                    14.740
# ...                ...                 ...  ...                       ...
# 39230              0.0          1278.10000  ...                     4.130
# 39231              0.0           385.20000  ...                     0.510
# 39232              0.0                 NaN  ...                     2.020
# 39233              0.0           136.75000  ...                     2.800
# 39234              0.0           136.97000  ...                     1.941
#
#        orbital_eccentricity  planet_equil_temp_k  spectral_type  \
# 0                     0.238                  NaN         G8 III
# 1                     0.231                  NaN         G8 III
# 2                       NaN                  NaN            NaN
# 3                     0.080                  NaN         K4 III
# 4                     0.080                  NaN            NaN
# ...                     ...                  ...            ...
# 39230                 0.267                  NaN            NaN
# 39231                 0.320                  NaN         G9 III
# 39232                   NaN                  NaN            NaN
# 39233                 0.000                  NaN            NaN
# 39234                 0.059                  NaN         K0 III
#
#        stellar_effective_temp_k  stellar_rad_solar_rad  \
# 0                       4874.00               13.76000
# 1                       4742.00               19.00000
# 2                           NaN                    NaN
# 3                       4340.00               24.08000
# 4                       4213.00               29.79000
# ...                         ...                    ...
# 39230                   6105.51                1.63649
# 39231                   4836.00               11.22000
# 39232                       NaN                    NaN
# 39233                   4780.00               12.00000
# 39234                   4841.00               10.86000
#
#        stellar_mass_solar_mass stellar_metallicity  stellar_surf_grav  \
# 0                         2.09             -0.2600            2.45000
# 1                         2.70             -0.3500            2.31000
# 2                         2.60                 NaN                NaN
# 3                         1.80              0.0400            1.60000
# 4                         2.78             -0.0200            1.93000
# ...                        ...                 ...                ...
# 39230                      NaN              0.1014            4.07094
# 39231                     1.48             -0.2000            2.46000
# 39232                      NaN                 NaN                NaN
# 39233                      NaN             -0.2050            2.66000
# 39234                     1.74             -0.1100            2.61000
#
#        distance_parsec
# 0              93.1846
# 1              93.1846
# 2              93.1846
# 3             125.3210
# 4             125.3210
# ...                ...
# 39230          13.4054
# 39231          52.5973
# 39232          56.1858
# 39233          56.1858
# 39234          56.1858
#
# [39235 rows x 24 columns]

# %%
exoplanets_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39235 entries, 0 to 39234
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   planet_name               39235 non-null  object
#  1   host_star_name            39235 non-null  object
#  2   default_flag              39235 non-null  float64
#  3   star_number_per_system    39235 non-null  float64
#  4   discovery_method          39235 non-null  object
#  5   year_of_discovery         39235 non-null  float64
#  6   discovery_facility        39235 non-null  object
#  7   solution_type             39235 non-null  object
#  8   pl_controv_flag           39235 non-null  float64
#  9   orbital_period_day        35927 non-null  float64
#  10  orbit_semi_major_axis_au  21968 non-null  float64
#  11  planet_rad_earth_rad      27037 non-null  float64
#  12  planet_rad_jupiter_rad    27040 non-null  float64
#  13  planet_mass_earth_mass    7110 non-null   float64
#  14  planet_mass_jupiter_mass  7110 non-null   float64
#  15  orbital_eccentricity      18727 non-null  float64
#  16  planet_equil_temp_k       17215 non-null  float64
#  17  spectral_type             2901 non-null   object
#  18  stellar_effective_temp_k  35700 non-null  float64
#  19  stellar_rad_solar_rad     25413 non-null  float64
#  20  stellar_mass_solar_mass   24229 non-null  float64
#  21  stellar_metallicity       24783 non-null  float64
#  22  stellar_surf_grav         30443 non-null  float64
#  23  distance_parsec           38389 non-null  float64
# dtypes: float64(18), object(6)
# memory usage: 7.2+ MB

# %% [markdown]
# ### Unconfirmed Exoplanet Removal

# %%
# filtering our uncomfirmed exoplanets
exoplanets_filtered = exoplanets_cleaned[exoplanets_cleaned['solution_type'] != 'TESS Project Candidate']
exoplanets_filtered
# Out:
#       planet_name host_star_name  default_flag  star_number_per_system  \
# 0        11 Com b         11 Com           1.0                     2.0
# 1        11 Com b         11 Com           0.0                     2.0
# 2        11 Com b         11 Com           0.0                     2.0
# 3        11 UMi b         11 UMi           0.0                     1.0
# 4        11 UMi b         11 UMi           1.0                     1.0
# ...           ...            ...           ...                     ...
# 39230   ups And d        ups And           0.0                     2.0
# 39231   ups Leo b        ups Leo           1.0                     1.0
# 39232    xi Aql b         xi Aql           0.0                     1.0
# 39233    xi Aql b         xi Aql           0.0                     1.0
# 39234    xi Aql b         xi Aql           1.0                     1.0
#
#       discovery_method  year_of_discovery  \
# 0      Radial Velocity             2007.0
# 1      Radial Velocity             2007.0
# 2      Radial Velocity             2007.0
# 3      Radial Velocity             2009.0
# 4      Radial Velocity             2009.0
# ...                ...                ...
# 39230  Radial Velocity             1999.0
# 39231  Radial Velocity             2021.0
# 39232  Radial Velocity             2007.0
# 39233  Radial Velocity             2007.0
# 39234  Radial Velocity             2007.0
#
#                            discovery_facility        solution_type  \
# 0                            Xinglong Station  Published Confirmed
# 1                            Xinglong Station  Published Confirmed
# 2                            Xinglong Station  Published Confirmed
# 3      Thueringer Landessternwarte Tautenburg  Published Confirmed
# 4      Thueringer Landessternwarte Tautenburg  Published Confirmed
# ...                                       ...                  ...
# 39230                  Multiple Observatories  Published Confirmed
# 39231       Okayama Astrophysical Observatory  Published Confirmed
# 39232       Okayama Astrophysical Observatory  Published Confirmed
# 39233       Okayama Astrophysical Observatory  Published Confirmed
# 39234       Okayama Astrophysical Observatory  Published Confirmed
#
#        pl_controv_flag  orbital_period_day  ...  planet_mass_jupiter_mass  \
# 0                  0.0           323.21000  ...                    15.464
# 1                  0.0           326.03000  ...                    19.400
# 2                  0.0                 NaN  ...                    17.100
# 3                  0.0           516.22000  ...                    10.500
# 4                  0.0           516.21997  ...                    14.740
# ...                ...                 ...  ...                       ...
# 39230              0.0          1278.10000  ...                     4.130
# 39231              0.0           385.20000  ...                     0.510
# 39232              0.0                 NaN  ...                     2.020
# 39233              0.0           136.75000  ...                     2.800
# 39234              0.0           136.97000  ...                     1.941
#
#        orbital_eccentricity  planet_equil_temp_k  spectral_type  \
# 0                     0.238                  NaN         G8 III
# 1                     0.231                  NaN         G8 III
# 2                       NaN                  NaN            NaN
# 3                     0.080                  NaN         K4 III
# 4                     0.080                  NaN            NaN
# ...                     ...                  ...            ...
# 39230                 0.267                  NaN            NaN
# 39231                 0.320                  NaN         G9 III
# 39232                   NaN                  NaN            NaN
# 39233                 0.000                  NaN            NaN
# 39234                 0.059                  NaN         K0 III
#
#        stellar_effective_temp_k  stellar_rad_solar_rad  \
# 0                       4874.00               13.76000
# 1                       4742.00               19.00000
# 2                           NaN                    NaN
# 3                       4340.00               24.08000
# 4                       4213.00               29.79000
# ...                         ...                    ...
# 39230                   6105.51                1.63649
# 39231                   4836.00               11.22000
# 39232                       NaN                    NaN
# 39233                   4780.00               12.00000
# 39234                   4841.00               10.86000
#
#        stellar_mass_solar_mass stellar_metallicity  stellar_surf_grav  \
# 0                         2.09             -0.2600            2.45000
# 1                         2.70             -0.3500            2.31000
# 2                         2.60                 NaN                NaN
# 3                         1.80              0.0400            1.60000
# 4                         2.78             -0.0200            1.93000
# ...                        ...                 ...                ...
# 39230                      NaN              0.1014            4.07094
# 39231                     1.48             -0.2000            2.46000
# 39232                      NaN                 NaN                NaN
# 39233                      NaN             -0.2050            2.66000
# 39234                     1.74             -0.1100            2.61000
#
#        distance_parsec
# 0              93.1846
# 1              93.1846
# 2              93.1846
# 3             125.3210
# 4             125.3210
# ...                ...
# 39230          13.4054
# 39231          52.5973
# 39232          56.1858
# 39233          56.1858
# 39234          56.1858
#
# [37943 rows x 24 columns]

# %%
# checking if rows were filtered out
print(f'orignal dataset dimensions: {exoplanets_cleaned.shape}')
print(f'filtered dataset dimesions: {exoplanets_filtered.shape}')
# Out:
# orignal dataset dimensions: (39235, 24)
# filtered dataset dimesions: (37943, 24)

# %%
# deleting solution_type column
del exoplanets_filtered['solution_type']
# deleting default_flag column
del exoplanets_filtered['pl_controv_flag']

# %%
exoplanets_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37943 entries, 0 to 39234
# Data columns (total 22 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   planet_name               37943 non-null  object
#  1   host_star_name            37943 non-null  object
#  2   default_flag              37943 non-null  float64
#  3   star_number_per_system    37943 non-null  float64
#  4   discovery_method          37943 non-null  object
#  5   year_of_discovery         37943 non-null  float64
#  6   discovery_facility        37943 non-null  object
#  7   orbital_period_day        34656 non-null  float64
#  8   orbit_semi_major_axis_au  21968 non-null  float64
#  9   planet_rad_earth_rad      25756 non-null  float64
#  10  planet_rad_jupiter_rad    25759 non-null  float64
#  11  planet_mass_earth_mass    7110 non-null   float64
#  12  planet_mass_jupiter_mass  7110 non-null   float64
#  13  orbital_eccentricity      18727 non-null  float64
#  14  planet_equil_temp_k       15929 non-null  float64
#  15  spectral_type             2901 non-null   object
#  16  stellar_effective_temp_k  34408 non-null  float64
#  17  stellar_rad_solar_rad     24453 non-null  float64
#  18  stellar_mass_solar_mass   24229 non-null  float64
#  19  stellar_metallicity       24783 non-null  float64
#  20  stellar_surf_grav         29163 non-null  float64
#  21  distance_parsec           37102 non-null  float64
# dtypes: float64(17), object(5)
# memory usage: 6.7+ MB

# %% [markdown]
# ### Duplicate Row Reduction Algorithm

# %%
# import stats from scipy to calculate mode
from scipy import stats

# creating function to get the mode of a series
# this custom mode function can help avoid a KeyError: 0
# this error can occur if the serires that is passed in the mode function is empty or there is is an isue accessing the mode_value
def mode(series):
    # handling a series if it is empty (contains null values)
    if series.empty:
        # return a null value if the series is empty
        return np.nan
    # compute mode result which is the most frequent value (mode) of the series
    mode_value = series.mode()
    # checking if mode result is empty
    if mode_value.empty:
        # return a null value if mode result result is empty
        return np.nan
    # if there are multple modes, ensuring first element is picked and if there is only one mode, then only that mode is picked
    return mode_value.iloc[0]

# %%
# Creating copy of dataset
new_exoplanets_filtered = exoplanets_filtered.copy()

numeric_cols = [
    'orbital_period_day',
    'orbit_semi_major_axis_au',
    'planet_rad_earth_rad',
    'planet_mass_earth_mass',
    'planet_rad_jupiter_rad',
    'planet_mass_jupiter_mass',
    'orbital_eccentricity',
    'planet_equil_temp_k',
    'stellar_effective_temp_k',
    'stellar_rad_solar_rad',
    'stellar_mass_solar_mass',
    'stellar_metallicity',
    'stellar_surf_grav',
    'distance_parsec'
]

THRESHOLD = 0.15   # 15% deviation allowed (this can be fine tuned)

def aggregate_planet(group):

    result = {}

    # ---------- NON-NUMERIC (mode) ----------
    categorical_cols = [
        'host_star_name',
        'star_number_per_system',
        'discovery_method',
        'year_of_discovery',
        'discovery_facility',
        'spectral_type'
    ]

    for col in categorical_cols:
        result[col] = mode(group[col])

    # ---------- DEFAULT ROW ----------
    default_rows = group[group['default_flag'] == 1]

    if not default_rows.empty:
        default_row = default_rows.iloc[0]
    else:
        default_row = None

    # ---------- NUMERIC COLUMNS ----------
    for col in numeric_cols:

        mean_val = group[col].mean()

        if default_row is not None and pd.notna(default_row[col]):

            default_val = default_row[col]

            # avoid division by zero
            if default_val != 0:
                rel_diff = abs(mean_val - default_val) / abs(default_val)
            else:
                rel_diff = abs(mean_val - default_val)

            # choose value
            if rel_diff > THRESHOLD:
                result[col] = default_val
            else:
                result[col] = mean_val
        else:
            result[col] = mean_val

    # keep the mean for the defautl flag
    result['default_flag'] = group['default_flag'].mean()

    return pd.Series(result)

# %%
# group by the name of exoplanet (group the values in the column by the planet_name)
# .agg(custom_aggregation) performs the spefic aggreagtion function within custom_aggregation for each column
# using .reset_index() to reset the index of new_exoplanets_filtered2
# planet_name is converted to the index of the new_exoplanets_filtered2 so .reset_index() coverts planet_name back into a column, creating default integer index
new_exoplanets_filtered2 = (
    new_exoplanets_filtered
    .groupby('planet_name')
    .apply(aggregate_planet)
    .reset_index()
)

# %%
# delete the default flag column
del new_exoplanets_filtered2['default_flag']

# %%
new_exoplanets_filtered2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6071 entries, 0 to 6070
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   planet_name               6071 non-null   object
#  1   host_star_name            6071 non-null   object
#  2   star_number_per_system    6071 non-null   float64
#  3   discovery_method          6071 non-null   object
#  4   year_of_discovery         6071 non-null   float64
#  5   discovery_facility        6071 non-null   object
#  6   spectral_type             1908 non-null   object
#  7   orbital_period_day        5753 non-null   float64
#  8   orbit_semi_major_axis_au  5762 non-null   float64
#  9   planet_rad_earth_rad      4559 non-null   float64
#  10  planet_mass_earth_mass    3180 non-null   float64
#  11  planet_rad_jupiter_rad    4559 non-null   float64
#  12  planet_mass_jupiter_mass  3180 non-null   float64
#  13  orbital_eccentricity      5168 non-null   float64
#  14  planet_equil_temp_k       4438 non-null   float64
#  15  stellar_effective_temp_k  5605 non-null   float64
#  16  stellar_rad_solar_rad     5465 non-null   float64
#  17  stellar_mass_solar_mass   6031 non-null   float64
#  18  stellar_metallicity       5362 non-null   float64
#  19  stellar_surf_grav         5422 non-null   float64
#  20  distance_parsec           5948 non-null   float64
# dtypes: float64(16), object(5)
# memory usage: 996.2+ KB

# %%
# Viewing the percentage of missing value for each column
missing_percentage = (new_exoplanets_filtered2.isnull().sum() / len(new_exoplanets_filtered2))
((missing_percentage * 100).sort_values(ascending=False)).map(lambda x: f"{x:.2f}%")
# Out:
# spectral_type               68.57%
# planet_mass_earth_mass      47.62%
# planet_mass_jupiter_mass    47.62%
# planet_equil_temp_k         26.90%
# planet_rad_jupiter_rad      24.91%
# planet_rad_earth_rad        24.91%
# orbital_eccentricity        14.87%
# stellar_metallicity         11.68%
# stellar_surf_grav           10.69%
# stellar_rad_solar_rad        9.98%
# stellar_effective_temp_k     7.68%
# orbital_period_day           5.24%
# orbit_semi_major_axis_au     5.09%
# distance_parsec              2.03%
# stellar_mass_solar_mass      0.66%
# year_of_discovery            0.00%
# host_star_name               0.00%
# planet_name                  0.00%
# discovery_method             0.00%
# star_number_per_system       0.00%
# discovery_facility           0.00%
# dtype: object

# %%
# columns to show
columns_to_show = [
    "planet_name",
    "host_star_name",
    "spectral_type",
    "star_number_per_system",
    "orbital_period_day",
    "orbit_semi_major_axis_au",
    "planet_rad_earth_rad",
    "planet_mass_earth_mass",
    "planet_rad_jupiter_rad",
    "planet_mass_jupiter_mass",
    "orbital_eccentricity",
    "planet_equil_temp_k",
    "stellar_effective_temp_k",
    "stellar_rad_solar_rad",
    "stellar_mass_solar_mass",
    "stellar_surf_grav"
]

# %%
# viewing row for kepler-452 b
new_exoplanets_filtered2[new_exoplanets_filtered2['planet_name'] == 'Kepler-452 b'][columns_to_show]
# Out:
#        planet_name host_star_name spectral_type  star_number_per_system  \
# 4115  Kepler-452 b     Kepler-452            G2                     1.0
#
#       orbital_period_day  orbit_semi_major_axis_au  planet_rad_earth_rad  \
# 4115          384.844831                  1.009733                  1.63
#
#       planet_mass_earth_mass  planet_rad_jupiter_rad  \
# 4115                     NaN                0.145419
#
#       planet_mass_jupiter_mass  orbital_eccentricity  planet_equil_temp_k  \
# 4115                       NaN                   0.0                235.0
#
#       stellar_effective_temp_k  stellar_rad_solar_rad  \
# 4115               5687.166667               1.099285
#
#       stellar_mass_solar_mass  stellar_surf_grav
# 4115                 1.029667            4.44555

# %%
# viewing row for Kepler-22 b
new_exoplanets_filtered2[new_exoplanets_filtered2['planet_name'] == 'Kepler-22 b'][columns_to_show]
# Out:
#       planet_name host_star_name spectral_type  star_number_per_system  \
# 3508  Kepler-22 b      Kepler-22          G5 V                     1.0
#
#       orbital_period_day  orbit_semi_major_axis_au  planet_rad_earth_rad  \
# 3508          289.863821                  0.829829              2.191111
#
#       planet_mass_earth_mass  planet_rad_jupiter_rad  \
# 3508                     9.1                0.195441
#
#       planet_mass_jupiter_mass  orbital_eccentricity  planet_equil_temp_k  \
# 3508                  0.028632                  0.72           264.142857
#
#       stellar_effective_temp_k  stellar_rad_solar_rad  \
# 3508               5589.090909               0.881097
#
#       stellar_mass_solar_mass  stellar_surf_grav
# 3508                 0.951875           4.478131

# %%
# viewing row for Kepler-1636 b
new_exoplanets_filtered2[new_exoplanets_filtered2['planet_name'] == 'Kepler-1636 b'][columns_to_show]
# Out:
#         planet_name host_star_name spectral_type  star_number_per_system  \
# 2968  Kepler-1636 b    Kepler-1636           NaN                     1.0
#
#       orbital_period_day  orbit_semi_major_axis_au  planet_rad_earth_rad  \
# 2968          425.479746                  1.146428              3.471333
#
#       planet_mass_earth_mass  planet_rad_jupiter_rad  \
# 2968                     NaN                0.309692
#
#       planet_mass_jupiter_mass  orbital_eccentricity  planet_equil_temp_k  \
# 2968                       NaN                   0.0                248.0
#
#       stellar_effective_temp_k  stellar_rad_solar_rad  \
# 2968               5828.501429                  1.065
#
#       stellar_mass_solar_mass  stellar_surf_grav
# 2968                   1.0896            4.39989

# %%
# Checking if rows were successfully reduced
print(f'New filtered dataset dimensions: {new_exoplanets_filtered2.shape}')
# Out:
# New filtered dataset dimensions: (6071, 21)

# %%
# Saving this new DataFrame
#new_exoplanets_filtered2.to_csv('filtered_2026_dataset_new_final.csv', index=False)

# %% [markdown]
# ## **Data Preprocessing for Filtered Dataset**

# %%
# Importing
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# loading dataset
new_exoplanets_filtered2 = pd.read_csv('/content/drive/MyDrive/Exoplanet /filtered_2026_dataset_new_final.csv')

# %%
# Viewing the statistics of the dataset
new_exoplanets_filtered2.describe()
# Out:
#        star_number_per_system  year_of_discovery  orbital_period_day  \
# count             6071.000000        6071.000000        5.753000e+03
# mean                 1.103772        2016.878109        7.439539e+04
# std                  0.342638           4.900489        5.302515e+06
# min                  1.000000        1992.000000        9.070629e-02
# 25%                  1.000000        2014.000000        4.347403e+00
# 50%                  1.000000        2016.000000        1.109864e+01
# 75%                  1.000000        2021.000000        3.979222e+01
# max                  4.000000        2026.000000        4.020000e+08
#
#        orbit_semi_major_axis_au  planet_rad_earth_rad  planet_mass_earth_mass  \
# count               5762.000000           4559.000000             3180.000000
# mean                  15.683308              4.471483              736.638867
# std                  351.054583              4.981039             1470.769786
# min                    0.004400              0.296555                0.017500
# 25%                    0.052301              1.620143               11.601899
# 50%                    0.101554              2.431636              154.305833
# 75%                    0.303543              4.113411              650.058065
# max                19000.000000             87.205870             9614.309312
#
#        planet_rad_jupiter_rad  planet_mass_jupiter_mass  orbital_eccentricity  \
# count             4559.000000               3180.000000           5168.000000
# mean                 0.398967                  2.318232              0.079579
# std                  0.444423                  4.628212              0.151067
# min                  0.026454                  0.000055              0.000000
# 25%                  0.144596                  0.036536              0.000000
# 50%                  0.217170                  0.485667              0.000000
# 75%                  0.366943                  2.045350              0.092000
# max                  7.780000                 30.250000              0.948000
#
#        planet_equil_temp_k  stellar_effective_temp_k  stellar_rad_solar_rad  \
# count          4438.000000                5605.00000            5465.000000
# mean            907.461345                5411.81116               1.499202
# std             460.185186                1764.17497               3.881452
# min              50.000000                 415.00000               0.012300
# 25%             566.850000                4920.00000               0.773858
# 50%             811.425000                5561.70000               0.954822
# 75%            1166.475000                5908.05000               1.243600
# max            4050.000000               57000.00000              88.475000
#
#        stellar_mass_solar_mass  stellar_metallicity  stellar_surf_grav  \
# count              6031.000000          5362.000000        5422.000000
# mean                  0.937058             0.006227           4.370520
# std                   0.408025             0.184792           0.438663
# min                   0.009400            -1.000000           0.541000
# 25%                   0.772437            -0.090000           4.287276
# 50%                   0.946000             0.011056           4.439900
# 75%                   1.082708             0.119750           4.565387
# max                  10.940000             0.600000           8.070000
#
#        distance_parsec
# count      5948.000000
# mean        707.049160
# std        1185.291954
# min           1.301190
# 25%         102.144000
# 50%         384.757000
# 75%         839.274250
# max        8240.000000

# %% [markdown]
# ### Assessing Null Values

# %%
# Viewing the percentage of missing value for each column
missing_percentage = (new_exoplanets_filtered2.isnull().sum() / len(new_exoplanets_filtered2))
((missing_percentage * 100).sort_values(ascending=False)).map(lambda x: f"{x:.2f}%")
# Out:
# spectral_type               68.57%
# planet_mass_earth_mass      47.62%
# planet_mass_jupiter_mass    47.62%
# planet_equil_temp_k         26.90%
# planet_rad_jupiter_rad      24.91%
# planet_rad_earth_rad        24.91%
# orbital_eccentricity        14.87%
# stellar_metallicity         11.68%
# stellar_surf_grav           10.69%
# stellar_rad_solar_rad        9.98%
# stellar_effective_temp_k     7.68%
# orbital_period_day           5.24%
# orbit_semi_major_axis_au     5.09%
# distance_parsec              2.03%
# stellar_mass_solar_mass      0.66%
# year_of_discovery            0.00%
# host_star_name               0.00%
# planet_name                  0.00%
# discovery_method             0.00%
# star_number_per_system       0.00%
# discovery_facility           0.00%
# dtype: object

# %%
# Viewing the information of the new DataFrame
new_exoplanets_filtered2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6071 entries, 0 to 6070
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   planet_name               6071 non-null   object
#  1   host_star_name            6071 non-null   object
#  2   star_number_per_system    6071 non-null   float64
#  3   discovery_method          6071 non-null   object
#  4   year_of_discovery         6071 non-null   float64
#  5   discovery_facility        6071 non-null   object
#  6   spectral_type             1908 non-null   object
#  7   orbital_period_day        5753 non-null   float64
#  8   orbit_semi_major_axis_au  5762 non-null   float64
#  9   planet_rad_earth_rad      4559 non-null   float64
#  10  planet_mass_earth_mass    3180 non-null   float64
#  11  planet_rad_jupiter_rad    4559 non-null   float64
#  12  planet_mass_jupiter_mass  3180 non-null   float64
#  13  orbital_eccentricity      5168 non-null   float64
#  14  planet_equil_temp_k       4438 non-null   float64
#  15  stellar_effective_temp_k  5605 non-null   float64
#  16  stellar_rad_solar_rad     5465 non-null   float64
#  17  stellar_mass_solar_mass   6031 non-null   float64
#  18  stellar_metallicity       5362 non-null   float64
#  19  stellar_surf_grav         5422 non-null   float64
#  20  distance_parsec           5948 non-null   float64
# dtypes: float64(16), object(5)
# memory usage: 996.2+ KB

# %% [markdown]
# #### Missing Stellar Mass Imputation (Kepler's Third Law Method)
# * Imputing the missing value for stellar mass using Kepler's Third Law Equations

# %%
# viewing a row which has missing stellar mass but the orbital semi major axis and orbital period is known
new_exoplanets_filtered2[new_exoplanets_filtered2["stellar_mass_solar_mass"].isna() & new_exoplanets_filtered2["orbit_semi_major_axis_au"].notna() & new_exoplanets_filtered2["orbital_period_day"].notna()]
# Out:
#          planet_name host_star_name  star_number_per_system  \
# 99          CI Tau c         CI Tau                     1.0
# 221         GJ 163 b         GJ 163                     1.0
# 222         GJ 163 c         GJ 163                     1.0
# 223         GJ 163 d         GJ 163                     1.0
# 1132      HD 47186 c       HD 47186                     1.0
# 2923    Kepler-160 d     Kepler-160                     1.0
# 4923  MXB 1658-298 b   MXB 1658-298                     2.0
# 5230      TOI-1422 c       TOI-1422                     1.0
#
#                discovery_method  year_of_discovery  \
# 99              Radial Velocity             2024.0
# 221             Radial Velocity             2013.0
# 222             Radial Velocity             2013.0
# 223             Radial Velocity             2013.0
# 1132            Radial Velocity             2008.0
# 2923  Transit Timing Variations             2020.0
# 4923  Eclipse Timing Variations             2017.0
# 5230            Radial Velocity             2025.0
#
#                       discovery_facility spectral_type  orbital_period_day  \
# 99                Multiple Observatories           NaN            25.20000
# 221                 La Silla Observatory           NaN             8.63182
# 222                 La Silla Observatory           NaN            25.63058
# 223                 La Silla Observatory           NaN           603.95116
# 1132                La Silla Observatory           NaN          1353.60000
# 2923                              Kepler           NaN            30.00000
# 4923              Multiple Observatories           NaN           760.00000
# 5230  Roque de los Muchachos Observatory          G2 V            34.56330
#
#       orbit_semi_major_axis_au  planet_rad_earth_rad  ...  \
# 99                      0.1700                   NaN  ...
# 221                     0.0607                   NaN  ...
# 222                     0.1254                   NaN  ...
# 223                     1.0304                   NaN  ...
# 1132                    2.3950                   NaN  ...
# 2923                    0.1700                   NaN  ...
# 4923                    1.6130                   NaN  ...
# 5230                    0.2050                  2.61  ...
#
#       planet_rad_jupiter_rad  planet_mass_jupiter_mass  orbital_eccentricity  \
# 99                       NaN                  3.600000                 0.580
# 221                      NaN                  0.033351                 0.073
# 222                      NaN                  0.021395                 0.099
# 223                      NaN                  0.092502                 0.373
# 1132                     NaN                  0.350610                 0.249
# 2923                     NaN                  0.314634                   NaN
# 4923                     NaN                 23.700000                   NaN
# 5230                0.232849                  0.044049                 0.200
#
#       planet_equil_temp_k  stellar_effective_temp_k  stellar_rad_solar_rad  \
# 99                    NaN                       NaN                    NaN
# 221                   NaN                       NaN                    NaN
# 222                   NaN                       NaN                    NaN
# 223                   NaN                       NaN                    NaN
# 1132                  NaN                       NaN                    NaN
# 2923                  NaN                    5471.0                  1.118
# 4923                  NaN                       NaN                    NaN
# 5230                628.0                       NaN                    NaN
#
#       stellar_mass_solar_mass  stellar_metallicity  stellar_surf_grav  \
# 99                        NaN                  NaN                NaN
# 221                       NaN                  NaN                NaN
# 222                       NaN                  NaN                NaN
# 223                       NaN                  NaN                NaN
# 1132                      NaN                  NaN                NaN
# 2923                      NaN                  NaN                NaN
# 4923                      NaN                  NaN                NaN
# 5230                      NaN                  NaN                NaN
#
#       distance_parsec
# 99           157.9980
# 221           15.1285
# 222           15.1285
# 223           15.1285
# 1132          37.4574
# 2923         937.0130
# 4923              NaN
# 5230         155.1410
#
# [8 rows x 21 columns]

# %%
# focusing on specfiic rows for futher viewing: planet name, host star name, spectral tyoe, stellar mass, obirtal semi major axis, and orbtial period
cols_to_show = [
    "planet_name",
    "host_star_name",
    "spectral_type",
    "stellar_mass_solar_mass",
    "orbit_semi_major_axis_au",
    "orbital_period_day"
]

filtered_rows = new_exoplanets_filtered2[
    new_exoplanets_filtered2["stellar_mass_solar_mass"].isna() &
    new_exoplanets_filtered2["orbit_semi_major_axis_au"].notna() &
    new_exoplanets_filtered2["orbital_period_day"].notna()
][cols_to_show]

filtered_rows
# Out:
#          planet_name host_star_name spectral_type  stellar_mass_solar_mass  \
# 99          CI Tau c         CI Tau           NaN                      NaN
# 221         GJ 163 b         GJ 163           NaN                      NaN
# 222         GJ 163 c         GJ 163           NaN                      NaN
# 223         GJ 163 d         GJ 163           NaN                      NaN
# 1132      HD 47186 c       HD 47186           NaN                      NaN
# 2923    Kepler-160 d     Kepler-160           NaN                      NaN
# 4923  MXB 1658-298 b   MXB 1658-298           NaN                      NaN
# 5230      TOI-1422 c       TOI-1422          G2 V                      NaN
#
#       orbit_semi_major_axis_au  orbital_period_day
# 99                      0.1700            25.20000
# 221                     0.0607             8.63182
# 222                     0.1254            25.63058
# 223                     1.0304           603.95116
# 1132                    2.3950          1353.60000
# 2923                    0.1700            30.00000
# 4923                    1.6130           760.00000
# 5230                    0.2050            34.56330

# %%
# For: Ms = (a^3)/(T^2) where a is the orbital semi major axis, T is the orbital period, and Ms is the stellar mass in terms of the Sun's mass (normalized)

# Constants and convertion factors
# the orbital_period will be converted from earth days to earth years
days_to_years = 1 / 365.25

# Create a boolean mask (series of TRUE and FALSE per row) to avoid division by zero or missing inputs
# Each row must be TRUE for all (no missing orbital semi major axis data, no missing orbital period data, all orbital period data greater than zero)
valid_inputs = (
    # For all orbital semi major axis (distance between star and planet) entries not missing and
    new_exoplanets_filtered2["orbit_semi_major_axis_au"].notna() &
    # For all orbital period (time it takes the planet to orbit its star) entries not missing and
    new_exoplanets_filtered2["orbital_period_day"].notna() &
    # For all orbital period entries greater than (but never equal to) zero
    (new_exoplanets_filtered2["orbital_period_day"] > 0)
)

# Mask of rows to be modified for the stellar mass column where the stellar mass entry is missing TRUE and satisfies the valid inputs TRUE
mask = new_exoplanets_filtered2["stellar_mass_solar_mass"].isna() & valid_inputs

# For the specific rows in stellar mass with missing mass entry, apply the mask
new_exoplanets_filtered2.loc[mask, "stellar_mass_solar_mass"] = (
    new_exoplanets_filtered2.loc[mask, "orbit_semi_major_axis_au"]**3
    / (new_exoplanets_filtered2.loc[mask, "orbital_period_day"]*days_to_years)**2
)

# %%
# checking if the number of missing values decreased
missing_percentage = (new_exoplanets_filtered2.isnull().sum() / len(new_exoplanets_filtered2))
((missing_percentage * 100).sort_values(ascending=False)).map(lambda x: f"{x:.2f}%")
# Out:
# spectral_type               68.57%
# planet_mass_earth_mass      47.62%
# planet_mass_jupiter_mass    47.62%
# planet_equil_temp_k         26.90%
# planet_rad_jupiter_rad      24.91%
# planet_rad_earth_rad        24.91%
# orbital_eccentricity        14.87%
# stellar_metallicity         11.68%
# stellar_surf_grav           10.69%
# stellar_rad_solar_rad        9.98%
# stellar_effective_temp_k     7.68%
# orbital_period_day           5.24%
# orbit_semi_major_axis_au     5.09%
# distance_parsec              2.03%
# stellar_mass_solar_mass      0.53%
# year_of_discovery            0.00%
# host_star_name               0.00%
# planet_name                  0.00%
# discovery_method             0.00%
# star_number_per_system       0.00%
# discovery_facility           0.00%
# dtype: object

# %%
# viewing planet TOI-1422 c to verify imputation values align with physical theory
new_exoplanets_filtered2[new_exoplanets_filtered2["planet_name"] == "TOI-1422 c"][cols_to_show]
# Out:
#      planet_name host_star_name spectral_type  stellar_mass_solar_mass  \
# 5230  TOI-1422 c       TOI-1422          G2 V                 0.962081
#
#       orbit_semi_major_axis_au  orbital_period_day
# 5230                     0.205             34.5633

# %% [markdown]
# #### Missing Stellar Mass Imputation (Law of Universal Gravitation Method)
# * Imputing the missing value for stellar mass using the Law of Universal Gravitaion

# %%
# viewing a row which has missing stellar mass but stellar surface gravity is known and stellar radius is known
new_exoplanets_filtered2[new_exoplanets_filtered2["stellar_mass_solar_mass"].isna() & new_exoplanets_filtered2["stellar_surf_grav"].notna() & new_exoplanets_filtered2["stellar_rad_solar_rad"].notna()]
# Out:
#           planet_name  host_star_name  star_number_per_system  \
# 153  EPIC 201427007 b  EPIC 201427007                     1.0
# 163  EPIC 206024342 c  EPIC 206024342                     1.0
# 164  EPIC 206024342 d  EPIC 206024342                     1.0
# 167  EPIC 206042996 c  EPIC 206042996                     1.0
# 179  EPIC 212624936 b  EPIC 212624936                     1.0
# 180  EPIC 212624936 c  EPIC 212624936                     1.0
# 183  EPIC 220492298 b  EPIC 220492298                     1.0
#
#     discovery_method  year_of_discovery discovery_facility spectral_type  \
# 153          Transit             2021.0                 K2           NaN
# 163          Transit             2021.0                 K2           NaN
# 164          Transit             2021.0                 K2           NaN
# 167          Transit             2021.0                 K2           NaN
# 179          Transit             2021.0                 K2           NaN
# 180          Transit             2021.0                 K2           NaN
# 183          Transit             2021.0                 K2           NaN
#
#      orbital_period_day  orbit_semi_major_axis_au  planet_rad_earth_rad  ...  \
# 153            0.720910                       NaN              1.500000  ...
# 163            0.911666                       NaN              1.303333  ...
# 164           14.642393                       NaN              2.600000  ...
# 167            0.354897                       NaN              1.325000  ...
# 179            0.578657                       NaN              1.200000  ...
# 180           11.812653                       NaN              2.485000  ...
# 183            0.762406                       NaN              0.990000  ...
#
#      planet_rad_jupiter_rad  planet_mass_jupiter_mass  orbital_eccentricity  \
# 153                0.133821                       NaN                   NaN
# 163                0.116113                       NaN                   NaN
# 164                0.231957                       NaN                   NaN
# 167                0.118209                       NaN                   NaN
# 179                0.107057                       NaN                   NaN
# 180                0.221596                       NaN                   NaN
# 183                0.088322                       NaN                   NaN
#
#      planet_equil_temp_k  stellar_effective_temp_k  stellar_rad_solar_rad  \
# 153                  NaN               5633.000000                  0.940
# 163                  NaN               5686.000000                  1.020
# 164                  NaN               5936.666667                  1.020
# 167                  NaN               4003.500000                  0.535
# 179                  NaN               5765.000000                  0.930
# 180                  NaN               5765.000000                  0.939
# 183                  NaN               5620.000000                  0.890
#
#      stellar_mass_solar_mass  stellar_metallicity  stellar_surf_grav  \
# 153                      NaN               -0.053               4.40
# 163                      NaN               -0.220               4.50
# 164                      NaN               -0.220               4.35
# 167                      NaN                0.006               4.80
# 179                      NaN               -0.390               4.40
# 180                      NaN               -0.390               4.40
# 183                      NaN                0.280               4.50
#
#      distance_parsec
# 153          706.391
# 163          369.888
# 164          369.888
# 167          451.769
# 179          561.929
# 180          561.929
# 183          624.512
#
# [7 rows x 21 columns]

# %%
# focusing on specfiic rows for futher viewing: planet name, host star name, spectral type, stellar mass, stellar radius, stellar surface gravity,
# orbital semi major axis, and orbtial period
cols_to_show2 = [
    "planet_name",
    "host_star_name",
    "spectral_type",
    "stellar_mass_solar_mass",
    "stellar_rad_solar_rad",
    "stellar_surf_grav",
    "orbit_semi_major_axis_au",
    "orbital_period_day"
]

filtered_rows = new_exoplanets_filtered2[
    new_exoplanets_filtered2["stellar_mass_solar_mass"].isna() &
    new_exoplanets_filtered2["stellar_rad_solar_rad"].notna() &
    new_exoplanets_filtered2["stellar_surf_grav"].notna()
][cols_to_show2]

filtered_rows
# Out:
#           planet_name  host_star_name spectral_type  stellar_mass_solar_mass  \
# 153  EPIC 201427007 b  EPIC 201427007           NaN                      NaN
# 163  EPIC 206024342 c  EPIC 206024342           NaN                      NaN
# 164  EPIC 206024342 d  EPIC 206024342           NaN                      NaN
# 167  EPIC 206042996 c  EPIC 206042996           NaN                      NaN
# 179  EPIC 212624936 b  EPIC 212624936           NaN                      NaN
# 180  EPIC 212624936 c  EPIC 212624936           NaN                      NaN
# 183  EPIC 220492298 b  EPIC 220492298           NaN                      NaN
#
#      stellar_rad_solar_rad  stellar_surf_grav  orbit_semi_major_axis_au  \
# 153                  0.940               4.40                       NaN
# 163                  1.020               4.50                       NaN
# 164                  1.020               4.35                       NaN
# 167                  0.535               4.80                       NaN
# 179                  0.930               4.40                       NaN
# 180                  0.939               4.40                       NaN
# 183                  0.890               4.50                       NaN
#
#      orbital_period_day
# 153            0.720910
# 163            0.911666
# 164           14.642393
# 167            0.354897
# 179            0.578657
# 180           11.812653
# 183            0.762406

# %%
# For: Ms = (g Rs^(2))/G where g is the stellar surface gravity, Rs is the stellar radius and and G is the gravitational constant

# Constants and conversion factors
G = 6.67430e-11    # m^3 kg^-1 s^-2
M_sun = 1.989e30   # kg
R_sun = 6.96e8     # m

# Valid inputs: stellar radius and surface gravity (log g) known
valid_inputs = (
    new_exoplanets_filtered2["stellar_rad_solar_rad"].notna() &
    new_exoplanets_filtered2["stellar_surf_grav"].notna()
)

# Mask of rows to be modified for the stellar mass column where the stellar mass entry is missing TRUE and satisfies the valid inputs TRUE
mask2 = new_exoplanets_filtered2["stellar_mass_solar_mass"].isna() & valid_inputs

# Convert log(g) [cgs] to g [m/s^2]
g_m_s2 = 10 ** new_exoplanets_filtered2.loc[mask2, "stellar_surf_grav"] / 100

# Convert stellar radius from sun radius to meters
R_m = new_exoplanets_filtered2.loc[mask2, "stellar_rad_solar_rad"] * R_sun

# Compute stellar mass in sun masses
new_exoplanets_filtered2.loc[mask2, "stellar_mass_solar_mass"] = ((g_m_s2 * R_m**2) / G) / M_sun

# %%
# checking if the number of missing values decreased
missing_percentage = (new_exoplanets_filtered2.isnull().sum() / len(new_exoplanets_filtered2))
((missing_percentage * 100).sort_values(ascending=False)).map(lambda x: f"{x:.2f}%")
# Out:
# spectral_type               68.57%
# planet_mass_earth_mass      47.62%
# planet_mass_jupiter_mass    47.62%
# planet_equil_temp_k         26.90%
# planet_rad_jupiter_rad      24.91%
# planet_rad_earth_rad        24.91%
# orbital_eccentricity        14.87%
# stellar_metallicity         11.68%
# stellar_surf_grav           10.69%
# stellar_rad_solar_rad        9.98%
# stellar_effective_temp_k     7.68%
# orbital_period_day           5.24%
# orbit_semi_major_axis_au     5.09%
# distance_parsec              2.03%
# stellar_mass_solar_mass      0.41%
# year_of_discovery            0.00%
# host_star_name               0.00%
# planet_name                  0.00%
# discovery_method             0.00%
# star_number_per_system       0.00%
# discovery_facility           0.00%
# dtype: object

# %%
# viewing planet EPIC 201427007 b to verify imputation values align with physical theory
new_exoplanets_filtered2[new_exoplanets_filtered2["planet_name"] == "EPIC 201427007 b"][cols_to_show2]
# Out:
#           planet_name  host_star_name spectral_type  stellar_mass_solar_mass  \
# 153  EPIC 201427007 b  EPIC 201427007           NaN                 0.809904
#
#      stellar_rad_solar_rad  stellar_surf_grav  orbit_semi_major_axis_au  \
# 153                   0.94                4.4                       NaN
#
#      orbital_period_day
# 153             0.72091

# %%
# Creating a flag column since multiple methods were used to impute stellar mass

# Tf stellar mass exists and was never imputed. it’s labeled as observed
new_exoplanets_filtered2["stellar_mass_imputation_method"] = "observed"
# If the orbital period and semi major axis was not missing and used to impute stellar mass. It's labeled as kepler_third_law_method_orb_per_orb_semi_major_axis
new_exoplanets_filtered2.loc[mask, "stellar_mass_imputation_method"] = "kepler_third_law_method_orb_per_orb_semi_major_axis"
# If the stellar radius and stellar surface gravity was not missing and used to impute stellar mass. It's labeled as law_of_gravition_stellar_rad_surf_grav
new_exoplanets_filtered2.loc[mask2, "stellar_mass_imputation_method"] = "law_of_gravition_stellar_rad_surf_grav"
# If missing values for stellar mass still missing. It's labeled as missing
new_exoplanets_filtered2.loc[
    new_exoplanets_filtered2["stellar_mass_solar_mass"].isna(),
    "stellar_mass_imputation_method"
] = "missing"

# %%
# Check how many times a specifc method was used for imputing missing stellar mass
new_exoplanets_filtered2["stellar_mass_imputation_method"].value_counts()
# Out:
# stellar_mass_imputation_method
# observed                                               6031
# missing                                                  25
# kepler_third_law_method_orb_per_orb_semi_major_axis       8
# law_of_gravition_stellar_rad_surf_grav                    7
# Name: count, dtype: int64

# %%
# Viewing the rows which still have a missing stellar mass
filtered_rows2 = new_exoplanets_filtered2[
    new_exoplanets_filtered2["stellar_mass_solar_mass"].isna()][cols_to_show2]

filtered_rows2 # These rows will most likely be removed as they have substantial missing data in key feature columns
# Out:
#                     planet_name           host_star_name spectral_type  \
# 16    2MASS J03590986+2009361 b  2MASS J03590986+2009361           NaN
# 18    2MASS J11011926-7732383 b  2MASS J11011926-7732383           NaN
# 19    2MASS J11550485-7919108 b  2MASS J11550485-7919108           NaN
# 22    2MASS J21252752-8138278 b  2MASS J21252752-8138278           NaN
# 24    2MASS J22501512+2325342 b  2MASS J22501512+2325342            M3
# 51                     AB Pic b                   AB Pic          K2 V
# 101                    CT Cha b                   CT Cha           NaN
# 197                   G 196-3 b                  G 196-3           NaN
# 658               HD 135344 A b              HD 135344 A          A0 V
# 887                 HD 203030 b                HD 203030          G8 V
# 1037             HD 284149 AB b              HD 284149 A           NaN
# 1108               HD 41004 A b               HD 41004 A           NaN
# 1378                HIP 77900 b                HIP 77900           NaN
# 1398                   HN Peg b                   HN Peg          G0 V
# 1414                   ITG 15 b                 ITG 15 A           NaN
# 1922             KIC 10001893 b             KIC 10001893           NaN
# 1923             KIC 10001893 c             KIC 10001893           NaN
# 1924             KIC 10001893 d             KIC 10001893           NaN
# 4881                  LkCa 15 b                  LkCa 15           NaN
# 4882                  LkCa 15 c                  LkCa 15           NaN
# 5081                   PDS 70 c                   PDS 70           NaN
# 5113                 Ross 458 c                 Ross 458           NaN
# 5116                 SR 12 AB c                 SR 12 AB           NaN
# 5998                 WISPIT 1 b                 WISPIT 1          K4 V
# 5999                 WISPIT 1 c                 WISPIT 1          K4 V
#
#       stellar_mass_solar_mass  stellar_rad_solar_rad  stellar_surf_grav  \
# 16                        NaN                    NaN                NaN
# 18                        NaN                    NaN                NaN
# 19                        NaN                    NaN                NaN
# 22                        NaN                    NaN                NaN
# 24                        NaN                    NaN                NaN
# 51                        NaN                    NaN                NaN
# 101                       NaN                    NaN                NaN
# 197                       NaN                    NaN                NaN
# 658                       NaN                1.50000                NaN
# 887                       NaN                    NaN                NaN
# 1037                      NaN                1.36000                NaN
# 1108                      NaN                    NaN                NaN
# 1378                      NaN                    NaN                NaN
# 1398                      NaN                    NaN                NaN
# 1414                      NaN                    NaN                NaN
# 1922                      NaN                    NaN               5.35
# 1923                      NaN                    NaN               5.35
# 1924                      NaN                    NaN               5.35
# 4881                      NaN                1.60711                NaN
# 4882                      NaN                1.60711                NaN
# 5081                      NaN                    NaN                NaN
# 5113                      NaN                    NaN                NaN
# 5116                      NaN                    NaN                NaN
# 5998                      NaN                    NaN                NaN
# 5999                      NaN                    NaN                NaN
#
#       orbit_semi_major_axis_au  orbital_period_day
# 16                      572.00                 NaN
# 18                      266.00                 NaN
# 19                      587.00                 NaN
# 22                     7493.00                 NaN
# 24                      518.00                 NaN
# 51                      260.00                 NaN
# 101                     440.00                 NaN
# 197                     350.00                 NaN
# 658                      16.50                 NaN
# 887                     487.10                 NaN
# 1037                    431.16                 NaN
# 1108                       NaN           963.00000
# 1378                   3319.00                 NaN
# 1398                    773.00                 NaN
# 1414                    435.00                 NaN
# 1922                       NaN             0.21970
# 1923                       NaN             0.32528
# 1924                       NaN             0.81161
# 4881                     14.70                 NaN
# 4882                     18.60                 NaN
# 5081                     34.25                 NaN
# 5113                   1100.00                 NaN
# 5116                       NaN                 NaN
# 5998                    338.00                 NaN
# 5999                    840.00                 NaN

# %% [markdown]
# #### Missing Orbital Semi Major Axis Imputation
# * Imputing the missing value for orbital semi major axis using Kepler's Third Law Equations

# %%
# focusing on specfiic rows for futher viewing: planet name, host star name, spectral tyoe, stellar mass, obirtal semi major axis, and orbtial period
cols_to_show = [
    "planet_name",
    "host_star_name",
    "spectral_type",
    "stellar_mass_solar_mass",
    "orbit_semi_major_axis_au",
    "orbital_period_day"
]

filtered_rows = new_exoplanets_filtered2[
    new_exoplanets_filtered2["orbit_semi_major_axis_au"].isna() &
    new_exoplanets_filtered2["stellar_mass_solar_mass"].notna() &
    new_exoplanets_filtered2["orbital_period_day"].notna()
][cols_to_show]

filtered_rows
# Out:
#            planet_name  host_star_name spectral_type  stellar_mass_solar_mass  \
# 56            AU Mic d          AU Mic           NaN                   0.5100
# 57            AU Mic e          AU Mic           NaN                   0.6000
# 136          CoRoT-7 d         CoRoT-7          G9 V                   0.9150
# 150         DS Tuc A b        DS Tuc A          G6 V                   0.9845
# 152   EPIC 201238110 b  EPIC 201238110           NaN                   0.4100
# ...                ...             ...           ...                      ...
# 5817        WASP-110 b        WASP-110            G9                   0.8140
# 5830        WASP-126 c        WASP-126           NaN                   1.1200
# 6023  ZTF J1230-2655 b  ZTF J1230-2655           NaN                   0.6460
# 6024  ZTF J1828+2308 b  ZTF J1828+2308           NaN                   0.6100
# 6054          pi Men d        HD 39091           NaN                   1.0700
#
#       orbit_semi_major_axis_au  orbital_period_day
# 56                         NaN           12.735960
# 57                         NaN           33.250000
# 136                        NaN            8.966000
# 150                        NaN            8.138484
# 152                        NaN           28.167600
# ...                        ...                 ...
# 5817                       NaN            3.778401
# 5830                       NaN            7.630000
# 6023                       NaN            0.235978
# 6024                       NaN            0.112007
# 6054                       NaN          124.640000
#
# [298 rows x 6 columns]

# %%
# For: a = (T^2 * Ms)^(1/3) where a is the orbital semi major axis, T is the orbital period, and Ms is the stellar mass in terms of the Sun's mass (normalized)

# Constants and conversion factors
# the orbital_period will be converted from earth days to earth years
days_to_years = 1 / 365.25

# Create a boolean mask (series of TRUE and FALSE per row) to avoid division by zero or missing inputs
# Each row must be TRUE for all (no missing orbital semi major axis data, no missing orbital period data, all orbital period data greater than zero)
valid_inputs = (
    # For all orbital period (time it takes the planet to orbit its star) entries not missing and
    new_exoplanets_filtered2["orbital_period_day"].notna() &
    # For all stellar mass entries not missing
    new_exoplanets_filtered2["stellar_mass_solar_mass"].notna()
)

# Mask of rows to be modified for the stellar mass column where the orbital semi major axis entry is missing TRUE and satisfys the valid inputs TRUE
mask = new_exoplanets_filtered2["orbit_semi_major_axis_au"].isna() & valid_inputs

# For the specific rows in orbital semi major axis with missing mass entry, apply the mask
new_exoplanets_filtered2.loc[mask, "orbit_semi_major_axis_au"] = (
    new_exoplanets_filtered2.loc[mask, "stellar_mass_solar_mass"] * (new_exoplanets_filtered2.loc[mask, "orbital_period_day"] * days_to_years)**2)**(1/3)

# %%
# checking if the number of missing values decreased
missing_percentage = (new_exoplanets_filtered2.isnull().sum() / len(new_exoplanets_filtered2))
((missing_percentage * 100).sort_values(ascending=False)).map(lambda x: f"{x:.2f}%")
# Out:
# spectral_type                     68.57%
# planet_mass_earth_mass            47.62%
# planet_mass_jupiter_mass          47.62%
# planet_equil_temp_k               26.90%
# planet_rad_earth_rad              24.91%
# planet_rad_jupiter_rad            24.91%
# orbital_eccentricity              14.87%
# stellar_metallicity               11.68%
# stellar_surf_grav                 10.69%
# stellar_rad_solar_rad              9.98%
# stellar_effective_temp_k           7.68%
# orbital_period_day                 5.24%
# distance_parsec                    2.03%
# stellar_mass_solar_mass            0.41%
# orbit_semi_major_axis_au           0.18%
# year_of_discovery                  0.00%
# discovery_facility                 0.00%
# star_number_per_system             0.00%
# host_star_name                     0.00%
# planet_name                        0.00%
# discovery_method                   0.00%
# stellar_mass_imputation_method     0.00%
# dtype: object

# %%
# viewing planet EPIC 201427007 b to verify imputation values align with physical theory
new_exoplanets_filtered2[new_exoplanets_filtered2["planet_name"] == "EPIC 201427007 b"][cols_to_show2]
# Out:
#           planet_name  host_star_name spectral_type  stellar_mass_solar_mass  \
# 153  EPIC 201427007 b  EPIC 201427007           NaN                 0.809904
#
#      stellar_rad_solar_rad  stellar_surf_grav  orbit_semi_major_axis_au  \
# 153                   0.94                4.4                  0.014667
#
#      orbital_period_day
# 153             0.72091

# %% [markdown]
# #### Missing Orbital Period Imputation
# * Imputing the missing value for orbital period using Kepler's Third Law Equations

# %%
# focusing on specfiic rows for futher viewing: planet name, host star name, spectral tyoe, stellar mass, orbital semi major axis, and orbtial period
cols_to_show = [
    "planet_name",
    "host_star_name",
    "spectral_type",
    "stellar_mass_solar_mass",
    "orbit_semi_major_axis_au",
    "orbital_period_day"
]

filtered_rows = new_exoplanets_filtered2[
    new_exoplanets_filtered2["orbital_period_day"].isna() &
    new_exoplanets_filtered2["orbit_semi_major_axis_au"].notna() &
    new_exoplanets_filtered2["stellar_mass_solar_mass"].notna()
][cols_to_show]

filtered_rows
# Out:
#                         planet_name               host_star_name  \
# 7           1RXS J160929.1-210524 b        1RXS J160929.1-210524
# 11                         2M0437 b      2MASS J04372171+2651014
# 12     2MASS J01033563-5515561 AB b    2MASS J01033563-5515561 A
# 13        2MASS J01225093-2439505 b      2MASS J01225093-2439505
# 14        2MASS J02192210-3925225 b      2MASS J02192210-3925225
# ...                             ...                          ...
# 5994                  WD 0806-661 b                  WD 0806-661
# 5997  WISEP J121756.91+162640.2 A b  WISEP J121756.91+162640.2 A
# 6000                     WISPIT 2 b                     WISPIT 2
# 6043                      kap And b                      kap And
# 6046                      mu2 Sco b                      mu2 Sco
#
#      spectral_type  stellar_mass_solar_mass  orbit_semi_major_axis_au  \
# 7             K7 V                 0.850000                     330.0
# 11             M V                 0.170000                     118.0
# 12         M5.5/M6                 0.190000                      84.0
# 13          M3.5 V                 0.376592                      52.0
# 14              M6                 0.108000                     156.0
# ...            ...                      ...                       ...
# 5994            DQ                 0.620000                    2500.0
# 5997          T8.5                 0.029000                       8.0
# 6000           NaN                 1.080000                      55.5
# 6043         B9 IV                 2.525000                      58.0
# 6046         B2 IV                 9.100000                     242.4
#
#       orbital_period_day
# 7                    NaN
# 11                   NaN
# 12                   NaN
# 13                   NaN
# 14                   NaN
# ...                  ...
# 5994                 NaN
# 5997                 NaN
# 6000                 NaN
# 6043                 NaN
# 6046                 NaN
#
# [291 rows x 6 columns]

# %%
# For: T = (a^3 * Ms)^(1/2) where a is the orbital semi major axis, T is the orbital period, and Ms is the stellar mass in terms of the Sun's mass (normalized)

# Constants and conversion factors
# the orbital_period will be converted from earth years to earth days
years_to_days = 365.25

# Create a boolean mask (series of TRUE and FALSE per row) to avoid division by zero or missing inputs
# Each row must be TRUE for all (no missing orbital semi major axis data, no missing orbital period data, all orbital period data greater than zero)
valid_inputs = (
    # For all orbital period (time it takes the planet to orbit its star) entries not missing and
    new_exoplanets_filtered2["orbit_semi_major_axis_au"].notna() &
    # For all stellar mass entries not missing and
    new_exoplanets_filtered2["stellar_mass_solar_mass"].notna() &
    # For all stelar mass entries greater than (but never equal to) zero
    (new_exoplanets_filtered2["stellar_mass_solar_mass"] > 0)
)

# Mask of rows to be modified for the stellar mass column where the orbital semi major axis entry is missing TRUE and satisfys the valid inputs TRUE
mask = new_exoplanets_filtered2["orbital_period_day"].isna() & valid_inputs

# Create a boolean mask (series of TRUE and FALSE per row) to avoid division by zero or missing inputs
# Each row must be TRUE for all (no missing orbital semi major axis data, no missing orbital period data, all orbital period data greater than zero)
valid_inputs = (
    # For all orbital semi major axis (distance between planet and its star) entries not missing and
    new_exoplanets_filtered2["orbit_semi_major_axis_au"].notna() &
    # For all stellar mass entries not missing and
    new_exoplanets_filtered2["stellar_mass_solar_mass"].notna() &
    # For all stelar mass entries greater than (but never equal to) zero
    (new_exoplanets_filtered2["stellar_mass_solar_mass"] > 0)
)

# Mask of rows to be modified for the orbital period column where the orbital period entry is missing TRUE and satisfies the valid inputs TRUE
mask = new_exoplanets_filtered2["orbital_period_day"].isna() & valid_inputs

# For the specific rows in orbital period with missing mass entry, apply the mask
new_exoplanets_filtered2.loc[mask, "orbital_period_day"] = (
    (new_exoplanets_filtered2.loc[mask, "orbit_semi_major_axis_au"])**3 / new_exoplanets_filtered2.loc[mask, "stellar_mass_solar_mass"])**(1/3)

# %%
# checking if number of missing values decreased
missing_percentage = (new_exoplanets_filtered2.isnull().sum() / len(new_exoplanets_filtered2))
((missing_percentage * 100).sort_values(ascending=False)).map(lambda x: f"{x:.2f}%")
# Out:
# spectral_type                     68.57%
# planet_mass_earth_mass            47.62%
# planet_mass_jupiter_mass          47.62%
# planet_equil_temp_k               26.90%
# planet_rad_earth_rad              24.91%
# planet_rad_jupiter_rad            24.91%
# orbital_eccentricity              14.87%
# stellar_metallicity               11.68%
# stellar_surf_grav                 10.69%
# stellar_rad_solar_rad              9.98%
# stellar_effective_temp_k           7.68%
# distance_parsec                    2.03%
# orbital_period_day                 0.44%
# stellar_mass_solar_mass            0.41%
# orbit_semi_major_axis_au           0.18%
# year_of_discovery                  0.00%
# discovery_facility                 0.00%
# star_number_per_system             0.00%
# host_star_name                     0.00%
# planet_name                        0.00%
# discovery_method                   0.00%
# stellar_mass_imputation_method     0.00%
# dtype: object

# %%
# viewing planet 2MASS J01033563-5515561 AB b to verify imputation values align with physical theory
new_exoplanets_filtered2[new_exoplanets_filtered2["planet_name"] == "2MASS J01033563-5515561 AB b"][cols_to_show2]
# Out:
#                      planet_name             host_star_name spectral_type  \
# 12  2MASS J01033563-5515561 AB b  2MASS J01033563-5515561 A       M5.5/M6
#
#     stellar_mass_solar_mass  stellar_rad_solar_rad  stellar_surf_grav  \
# 12                     0.19                    NaN                NaN
#
#     orbit_semi_major_axis_au  orbital_period_day
# 12                      84.0          146.114983

# %% [markdown]
# #### Missing Stellar Surface Gravity Imputation
# * Imputing the missing value for stellar surface gravity using the Law of Universal Gravitation

# %%
# For: g = (GMs)/(Rs^(2)) where g is the stellar surface gravity, Rs is the stellar radius and and G is the gravitational constant

# Constants and conversion factors
G = 6.67430e-11    # m^3 kg^-1 s^-2
M_sun = 1.989e30   # kg
R_sun = 6.96e8     # m

# Valid inputs: stellar mass and stellar radius known
valid_inputs = (
    new_exoplanets_filtered2["stellar_mass_solar_mass"].notna() &
    new_exoplanets_filtered2["stellar_rad_solar_rad"].notna() &
    (new_exoplanets_filtered2["stellar_mass_solar_mass"] > 0) &
    (new_exoplanets_filtered2["stellar_rad_solar_rad"] > 0)
)

# Mask of rows to be modified for the stellar surface gravity log(g) [cgs] column where the stellar surface entry is missing TRUE and satisfies the valid inputs TRUE
mask = new_exoplanets_filtered2["stellar_surf_grav"].isna() & valid_inputs

# Convert stellar mass from solar masses to kg
M_kg = new_exoplanets_filtered2.loc[mask, "stellar_mass_solar_mass"] * M_sun

# Convert stellar radius from solar radii to meters
R_m = new_exoplanets_filtered2.loc[mask, "stellar_rad_solar_rad"] * R_sun

# Compute surface gravity in m/s^2
g_m_s2 = G * M_kg / (R_m ** 2)

# Convert m/s^2 → cm/s^2
g_cgs = g_m_s2 * 100

# Store log10(g) (cgs)
new_exoplanets_filtered2.loc[mask, "stellar_surf_grav"] = np.log10(g_cgs)

# %%
# checking if number of missing values decreased
missing_percentage = (new_exoplanets_filtered2.isnull().sum() / len(new_exoplanets_filtered2))
((missing_percentage * 100).sort_values(ascending=False)).map(lambda x: f"{x:.2f}%")
# Out:
# spectral_type                     68.57%
# planet_mass_earth_mass            47.62%
# planet_mass_jupiter_mass          47.62%
# planet_equil_temp_k               26.90%
# planet_rad_earth_rad              24.91%
# planet_rad_jupiter_rad            24.91%
# orbital_eccentricity              14.87%
# stellar_metallicity               11.68%
# stellar_rad_solar_rad              9.98%
# stellar_surf_grav                  8.17%
# stellar_effective_temp_k           7.68%
# distance_parsec                    2.03%
# orbital_period_day                 0.44%
# stellar_mass_solar_mass            0.41%
# orbit_semi_major_axis_au           0.18%
# year_of_discovery                  0.00%
# discovery_facility                 0.00%
# star_number_per_system             0.00%
# host_star_name                     0.00%
# planet_name                        0.00%
# discovery_method                   0.00%
# stellar_mass_imputation_method     0.00%
# dtype: object

# %%
# Viewing the rows which still have a missing stellar surface gravity
filtered_rows3 = new_exoplanets_filtered2[
    new_exoplanets_filtered2["stellar_surf_grav"].isna()][cols_to_show2]

filtered_rows3
# Out:
#                        planet_name             host_star_name spectral_type  \
# 12    2MASS J01033563-5515561 AB b  2MASS J01033563-5515561 A       M5.5/M6
# 15              2MASS J0249-0557 c         2MASS J0249-0557 A          M6 V
# 16       2MASS J03590986+2009361 b    2MASS J03590986+2009361           NaN
# 17       2MASS J04414489+2301513 b    2MASS J04414489+2301513          M8.5
# 18       2MASS J11011926-7732383 b    2MASS J11011926-7732383           NaN
# ...                            ...                        ...           ...
# 6030                     bet Pic c                    bet Pic           NaN
# 6061                     tau Cet e                    tau Cet           NaN
# 6062                     tau Cet f                    tau Cet           NaN
# 6063                     tau Cet g                    tau Cet           NaN
# 6064                     tau Cet h                    tau Cet           NaN
#
#       stellar_mass_solar_mass  stellar_rad_solar_rad  stellar_surf_grav  \
# 12                      0.190                    NaN                NaN
# 15                      0.046                    NaN                NaN
# 16                        NaN                    NaN                NaN
# 17                      0.019                    NaN                NaN
# 18                        NaN                    NaN                NaN
# ...                       ...                    ...                ...
# 6030                    1.795                    NaN                NaN
# 6061                    0.783                    NaN                NaN
# 6062                    0.783                    NaN                NaN
# 6063                    0.783                    NaN                NaN
# 6064                    0.783                    NaN                NaN
#
#       orbit_semi_major_axis_au  orbital_period_day
# 12                      84.000          146.114983
# 15                    1950.000         5442.294019
# 16                     572.000                 NaN
# 17                      15.000           56.213427
# 18                     266.000                 NaN
# ...                        ...                 ...
# 6030                     2.700         1207.593170
# 6061                     0.538          162.870000
# 6062                     1.334          636.130000
# 6063                     0.133           20.000000
# 6064                     0.243           49.410000
#
# [496 rows x 8 columns]

# %% [markdown]
# #### Missing Stellar Effective Temperature Imputation
# * Imputing the missing value for stellar effective temp using Zero-Greenhouse Equilibrium Temperature of Exoplanet Equation

# %%
# Viewing the rows which still have a missing stellar effective temperature
filtered_rows4 = new_exoplanets_filtered2[
    new_exoplanets_filtered2["stellar_effective_temp_k"].isna()]

filtered_rows4
# Out:
#                        planet_name             host_star_name  \
# 12    2MASS J01033563-5515561 AB b  2MASS J01033563-5515561 A
# 15              2MASS J0249-0557 c         2MASS J0249-0557 A
# 16       2MASS J03590986+2009361 b    2MASS J03590986+2009361
# 17       2MASS J04414489+2301513 b    2MASS J04414489+2301513
# 18       2MASS J11011926-7732383 b    2MASS J11011926-7732383
# ...                            ...                        ...
# 6030                     bet Pic c                    bet Pic
# 6061                     tau Cet e                    tau Cet
# 6062                     tau Cet f                    tau Cet
# 6063                     tau Cet g                    tau Cet
# 6064                     tau Cet h                    tau Cet
#
#       star_number_per_system discovery_method  year_of_discovery  \
# 12                       2.0          Imaging             2013.0
# 15                       2.0          Imaging             2018.0
# 16                       1.0          Imaging             2024.0
# 17                       1.0          Imaging             2010.0
# 18                       1.0          Imaging             2024.0
# ...                      ...              ...                ...
# 6030                     1.0  Radial Velocity             2019.0
# 6061                     1.0  Radial Velocity             2017.0
# 6062                     1.0  Radial Velocity             2017.0
# 6063                     1.0  Radial Velocity             2017.0
# 6064                     1.0  Radial Velocity             2017.0
#
#                               discovery_facility spectral_type  \
# 12                           Paranal Observatory       M5.5/M6
# 15                         Mauna Kea Observatory          M6 V
# 16    European Space Agency (ESA) Gaia Satellite           NaN
# 17                        Hubble Space Telescope          M8.5
# 18    European Space Agency (ESA) Gaia Satellite           NaN
# ...                                          ...           ...
# 6030                        La Silla Observatory           NaN
# 6061                      Multiple Observatories           NaN
# 6062                      Multiple Observatories           NaN
# 6063                      Multiple Observatories           NaN
# 6064                      Multiple Observatories           NaN
#
#       orbital_period_day  orbit_semi_major_axis_au  planet_rad_earth_rad  ...  \
# 12            146.114983                    84.000                   NaN  ...
# 15           5442.294019                  1950.000                   NaN  ...
# 16                   NaN                   572.000                   NaN  ...
# 17             56.213427                    15.000                   NaN  ...
# 18                   NaN                   266.000                   NaN  ...
# ...                  ...                       ...                   ...  ...
# 6030         1207.593170                     2.700                   NaN  ...
# 6061          162.870000                     0.538                   NaN  ...
# 6062          636.130000                     1.334                   NaN  ...
# 6063           20.000000                     0.133                   NaN  ...
# 6064           49.410000                     0.243                   NaN  ...
#
#       planet_mass_jupiter_mass  orbital_eccentricity  planet_equil_temp_k  \
# 12                   13.000000                   NaN                  NaN
# 15                   11.600000                   NaN                  NaN
# 16                   18.000000                   NaN               2369.0
# 17                    7.500000                   NaN                  NaN
# 18                   28.000000                   NaN               2677.0
# ...                        ...                   ...                  ...
# 6030                  9.113000                 0.308               1250.0
# 6061                  0.012365                 0.180                  NaN
# 6062                  0.012365                 0.160                  NaN
# 6063                  0.005506                 0.060                  NaN
# 6064                  0.005758                 0.230                  NaN
#
#       stellar_effective_temp_k  stellar_rad_solar_rad  \
# 12                         NaN                    NaN
# 15                         NaN                    NaN
# 16                         NaN                    NaN
# 17                         NaN                    NaN
# 18                         NaN                    NaN
# ...                        ...                    ...
# 6030                       NaN                    NaN
# 6061                       NaN                    NaN
# 6062                       NaN                    NaN
# 6063                       NaN                    NaN
# 6064                       NaN                    NaN
#
#       stellar_mass_solar_mass  stellar_metallicity  stellar_surf_grav  \
# 12                      0.190                  NaN                NaN
# 15                      0.046                  NaN                NaN
# 16                        NaN                  NaN                NaN
# 17                      0.019                  NaN                NaN
# 18                        NaN                  NaN                NaN
# ...                       ...                  ...                ...
# 6030                    1.795                  NaN                NaN
# 6061                    0.783                  NaN                NaN
# 6062                    0.783                  NaN                NaN
# 6063                    0.783                  NaN                NaN
# 6064                    0.783                  NaN                NaN
#
#       distance_parsec  stellar_mass_imputation_method
# 12                NaN                        observed
# 15           66.06130                        observed
# 16          117.43500                         missing
# 17                NaN                        observed
# 18                NaN                         missing
# ...               ...                             ...
# 6030         19.74420                        observed
# 6061          3.60304                        observed
# 6062          3.60304                        observed
# 6063          3.60304                        observed
# 6064          3.60304                        observed
#
# [466 rows x 22 columns]

# %%
# For: T_eff = (T_eq/(1 - A)^(1/4)) * sqrt((2a)/Rs) where Rs is the stellar radius in sun radius and a is the orbital semi major axis (coverted from AU to Solar Radius)
# and T_eff is the stellar effective temperature

# Constants
AU_to_Rsun = 215.032    # 1 AU = 215.032 solar radii
A = 0.5                 # Bond albedo (assumed A = 0.5 neither hihgly reflective nor completely dark)

# Valid inputs: stellar temperature [K], stellar radius [R_sun], semi-major axis [AU]
valid_inputs = (
    new_exoplanets_filtered2["planet_equil_temp_k"].notna() &
    new_exoplanets_filtered2["orbit_semi_major_axis_au"].notna() &
    new_exoplanets_filtered2["stellar_rad_solar_rad"].notna() &
    (new_exoplanets_filtered2["stellar_rad_solar_rad"] > 0) &
    (new_exoplanets_filtered2["orbit_semi_major_axis_au"] > 0)
)

# Mask rows where stellar effective temperature is missing
mask = new_exoplanets_filtered2["stellar_effective_temp_k"].isna() & valid_inputs

# Planetary equilibrium effective temperature already in Kelvin
T_eq = new_exoplanets_filtered2.loc[mask, "planet_equil_temp_k"]

# Convert semi-major axis from AU to sun radius since a/Rs must be dimensionless
a_Rsun = (
    new_exoplanets_filtered2.loc[mask, "orbit_semi_major_axis_au"] * AU_to_Rsun
)

# Stellar radius already in sun radius
Rs = new_exoplanets_filtered2.loc[mask, "stellar_rad_solar_rad"]

# Compute planetary equilibrium temperature [K]
T_eff = (
    T_eq / (1-A)**0.25 * np.sqrt(2 * a_Rsun / Rs)
)

# Store result in Kelvin
T_eff = new_exoplanets_filtered2.loc[mask, "stellar_effective_temp_k"]

# %%
# checking if number of missing values decreased
missing_percentage = (new_exoplanets_filtered2.isnull().sum() / len(new_exoplanets_filtered2))
((missing_percentage * 100).sort_values(ascending=False)).map(lambda x: f"{x:.2f}%")
# Out:
# spectral_type                     68.57%
# planet_mass_earth_mass            47.62%
# planet_mass_jupiter_mass          47.62%
# planet_equil_temp_k               26.90%
# planet_rad_earth_rad              24.91%
# planet_rad_jupiter_rad            24.91%
# orbital_eccentricity              14.87%
# stellar_metallicity               11.68%
# stellar_rad_solar_rad              9.98%
# stellar_surf_grav                  8.17%
# stellar_effective_temp_k           7.68%
# distance_parsec                    2.03%
# orbital_period_day                 0.44%
# stellar_mass_solar_mass            0.41%
# orbit_semi_major_axis_au           0.18%
# year_of_discovery                  0.00%
# discovery_facility                 0.00%
# star_number_per_system             0.00%
# host_star_name                     0.00%
# planet_name                        0.00%
# discovery_method                   0.00%
# stellar_mass_imputation_method     0.00%
# dtype: object

# %% [markdown]
# #### Missing Planet Equilibrium Temperature Imputation
# * Imputing the missing value for plant equilibrium using Zero-Greenhouse Equilibrium Temperature of Exoplanet Equation

# %%
# Viewing the rows which still have a missing planet equilibrium temperature
filtered_rows5 = new_exoplanets_filtered2[
    new_exoplanets_filtered2["planet_equil_temp_k"].isna()]

filtered_rows5
# Out:
#      planet_name host_star_name  star_number_per_system discovery_method  \
# 0       11 Com b         11 Com                     2.0  Radial Velocity
# 1       11 UMi b         11 UMi                     1.0  Radial Velocity
# 2       14 And b         14 And                     1.0  Radial Velocity
# 3       14 Her b         14 Her                     1.0  Radial Velocity
# 4     16 Cyg B b       16 Cyg B                     3.0  Radial Velocity
# ...          ...            ...                     ...              ...
# 6066   ups And b        ups And                     2.0  Radial Velocity
# 6067   ups And c        ups And                     2.0  Radial Velocity
# 6068   ups And d        ups And                     2.0  Radial Velocity
# 6069   ups Leo b        ups Leo                     1.0  Radial Velocity
# 6070    xi Aql b         xi Aql                     1.0  Radial Velocity
#
#       year_of_discovery                      discovery_facility spectral_type  \
# 0                2007.0                        Xinglong Station        G8 III
# 1                2009.0  Thueringer Landessternwarte Tautenburg        K4 III
# 2                2008.0       Okayama Astrophysical Observatory        K0 III
# 3                2002.0                  W. M. Keck Observatory          K0 V
# 4                1996.0                  Multiple Observatories        G2.5 V
# ...                 ...                                     ...           ...
# 6066             1996.0                        Lick Observatory          F8 V
# 6067             1999.0                  Multiple Observatories          F8 V
# 6068             1999.0                  Multiple Observatories          F8 V
# 6069             2021.0       Okayama Astrophysical Observatory        G9 III
# 6070             2007.0       Okayama Astrophysical Observatory        K0 III
#
#       orbital_period_day  orbit_semi_major_axis_au  planet_rad_earth_rad  ...  \
# 0             324.620000                  1.226000                   NaN  ...
# 1             516.219985                  1.526667                   NaN  ...
# 2             186.300000                  0.761667                   NaN  ...
# 3            1766.378417                  2.814750                   NaN  ...
# 4             799.375000                  1.662833                   NaN  ...
# ...                  ...                       ...                   ...  ...
# 6066            4.616229                  0.058895                   NaN  ...
# 6067          240.728533                  0.827712                   NaN  ...
# 6068         1285.346167                  2.528382                   NaN  ...
# 6069          385.200000                  1.180000                   NaN  ...
# 6070          136.860000                  0.628333                   NaN  ...
#
#       planet_mass_jupiter_mass  orbital_eccentricity  planet_equil_temp_k  \
# 0                    17.321333              0.234500                  NaN
# 1                    14.740000              0.080000                  NaN
# 2                     3.853000              0.000000                  NaN
# 3                     8.053000              0.362925                  NaN
# 4                     1.678667              0.676033                  NaN
# ...                        ...                   ...                  ...
# 6066                  0.692086              0.021500                  NaN
# 6067                  1.981000              0.238933                  NaN
# 6068                  4.132000              0.281117                  NaN
# 6069                  0.510000              0.320000                  NaN
# 6070                  1.941000              0.059000                  NaN
#
#       stellar_effective_temp_k  stellar_rad_solar_rad  \
# 0                  4808.000000              13.760000
# 1                  4276.500000              26.935000
# 2                  4850.500000              11.275000
# 3                  5296.985000               0.999085
# 4                  5728.594000               1.129135
# ...                        ...                    ...
# 6066               6137.820000               1.614742
# 6067               6117.093333               1.614742
# 6068               6117.093333               1.614742
# 6069               4836.000000              11.220000
# 6070               4810.500000              11.430000
#
#       stellar_mass_solar_mass  stellar_metallicity  stellar_surf_grav  \
# 0                    2.090000            -0.260000           2.380000
# 1                    2.780000            -0.020000           1.765000
# 2                    1.780000            -0.225000           2.590000
# 3                    0.904000             0.415040           4.418006
# 4                    1.016599             0.056380           4.342293
# ...                       ...                  ...                ...
# 6066                 1.276049             0.110975           4.161529
# 6067                 1.301399             0.117967           4.148705
# 6068                 1.301399             0.117967           4.148705
# 6069                 1.480000            -0.200000           2.460000
# 6070                 1.740000            -0.110000           2.635000
#
#       distance_parsec  stellar_mass_imputation_method
# 0             93.1846                        observed
# 1            125.3210                        observed
# 2             75.4392                        observed
# 3             17.9323                        observed
# 4             21.1397                        observed
# ...               ...                             ...
# 6066          13.4054                        observed
# 6067          13.4054                        observed
# 6068          13.4054                        observed
# 6069          52.5973                        observed
# 6070          56.1858                        observed
#
# [1633 rows x 22 columns]

# %%
# For: T_eq = T_eff * (1 - A)^(1/4) * sqrt(Rs/(2a)) where Rs is the stellar radius in sun radius and a is the orbital semi major axis (coverted from AU to Solar Radius)
# and T_eff is the stellar effective temperature

# Constants
AU_to_Rsun = 215.032    # 1 AU = 215.032 solar radii
A = 0.5                 # Bond albedo (assumed A = 0.5 neither hihgly reflective nor completely dark)

# Valid inputs: stellar temperature [K], stellar radius [R_sun], semi-major axis [AU]
valid_inputs = (
    new_exoplanets_filtered2["stellar_effective_temp_k"].notna() &
    new_exoplanets_filtered2["stellar_rad_solar_rad"].notna() &
    new_exoplanets_filtered2["orbit_semi_major_axis_au"].notna() &
    (new_exoplanets_filtered2["stellar_effective_temp_k"] > 0) &
    (new_exoplanets_filtered2["stellar_rad_solar_rad"] > 0) &
    (new_exoplanets_filtered2["orbit_semi_major_axis_au"] > 0)
)

# Mask rows where planetary equilibrium temperature is missing
mask = new_exoplanets_filtered2["planet_equil_temp_k"].isna() & valid_inputs

# Stellar effective temperature already in Kelvin
T_eff = new_exoplanets_filtered2.loc[mask, "stellar_effective_temp_k"]

# Convert semi-major axis from AU to sun radius since Rs/a must be dimensionless
a_Rsun = (
    new_exoplanets_filtered2.loc[mask, "orbit_semi_major_axis_au"] * AU_to_Rsun
)

# Stellar radius already in sun radius
Rs = new_exoplanets_filtered2.loc[mask, "stellar_rad_solar_rad"]

# Compute planetary equilibrium temperature [K]
T_eq = (
    T_eff *
    (1 - A) ** 0.25 *
    np.sqrt(Rs / (2 * a_Rsun))
)

# Store result in Kelvin
new_exoplanets_filtered2.loc[mask, "planet_equil_temp_k"] = T_eq

# %%
# checking if number of missing values decreased
missing_percentage = (new_exoplanets_filtered2.isnull().sum() / len(new_exoplanets_filtered2))
((missing_percentage * 100).sort_values(ascending=False)).map(lambda x: f"{x:.2f}%")
# Out:
# spectral_type                     68.57%
# planet_mass_earth_mass            47.62%
# planet_mass_jupiter_mass          47.62%
# planet_rad_earth_rad              24.91%
# planet_rad_jupiter_rad            24.91%
# orbital_eccentricity              14.87%
# stellar_metallicity               11.68%
# stellar_rad_solar_rad              9.98%
# planet_equil_temp_k                9.55%
# stellar_surf_grav                  8.17%
# stellar_effective_temp_k           7.68%
# distance_parsec                    2.03%
# orbital_period_day                 0.44%
# stellar_mass_solar_mass            0.41%
# orbit_semi_major_axis_au           0.18%
# year_of_discovery                  0.00%
# discovery_facility                 0.00%
# star_number_per_system             0.00%
# host_star_name                     0.00%
# planet_name                        0.00%
# discovery_method                   0.00%
# stellar_mass_imputation_method     0.00%
# dtype: object

# %%
# viewing planet 11 Com b to verify imputation values align with physical theory
new_exoplanets_filtered2[new_exoplanets_filtered2["planet_name"] == "11 Com b"]
# Out:
#   planet_name host_star_name  star_number_per_system discovery_method  \
# 0    11 Com b         11 Com                     2.0  Radial Velocity
#
#    year_of_discovery discovery_facility spectral_type  orbital_period_day  \
# 0             2007.0   Xinglong Station        G8 III              324.62
#
#    orbit_semi_major_axis_au  planet_rad_earth_rad  ...  \
# 0                     1.226                   NaN  ...
#
#    planet_mass_jupiter_mass  orbital_eccentricity  planet_equil_temp_k  \
# 0                 17.321333                0.2345           653.137165
#
#    stellar_effective_temp_k  stellar_rad_solar_rad  stellar_mass_solar_mass  \
# 0                    4808.0                  13.76                     2.09
#
#    stellar_metallicity  stellar_surf_grav  distance_parsec  \
# 0                -0.26               2.38          93.1846
#
#    stellar_mass_imputation_method
# 0                        observed
#
# [1 rows x 22 columns]

# %% [markdown]
# #### Missing Planet Mass Imputation
# * Imputing the missing value for planetary mass using Transit Method Mass-Radius Estimation

# %%
# Viewing the rows which still have a missing planet mass (in terms of earth)
filtered_rows6 = new_exoplanets_filtered2[
    new_exoplanets_filtered2["planet_mass_earth_mass"].isna()]

filtered_rows6
# Out:
#             planet_name  host_star_name  star_number_per_system  \
# 151   EPIC 201170410.02  EPIC 201170410                     1.0
# 152    EPIC 201238110 b  EPIC 201238110                     1.0
# 153    EPIC 201427007 b  EPIC 201427007                     1.0
# 154    EPIC 201497682 b  EPIC 201497682                     1.0
# 156    EPIC 201615463 c          K2-166                     1.0
# ...                 ...             ...                     ...
# 5750         TOI-880.02         TOI-880                     1.0
# 5752          TOI-904 b         TOI-904                     1.0
# 5753          TOI-904 c         TOI-904                     1.0
# 5755         TOI-907.01         TOI-907                     1.0
# 5758          TOI-913 b         TOI-913                     1.0
#
#      discovery_method  year_of_discovery  \
# 151           Transit             2020.0
# 152           Transit             2019.0
# 153           Transit             2021.0
# 154           Transit             2019.0
# 156           Transit             2019.0
# ...               ...                ...
# 5750          Transit             2024.0
# 5752          Transit             2023.0
# 5753          Transit             2023.0
# 5755          Transit             2024.0
# 5758          Transit             2023.0
#
#                                 discovery_facility spectral_type  \
# 151                                             K2           NaN
# 152                                             K2           NaN
# 153                                             K2           NaN
# 154                                             K2           NaN
# 156                                             K2           NaN
# ...                                            ...           ...
# 5750  Transiting Exoplanet Survey Satellite (TESS)             K
# 5752  Transiting Exoplanet Survey Satellite (TESS)           NaN
# 5753  Transiting Exoplanet Survey Satellite (TESS)           NaN
# 5755  Transiting Exoplanet Survey Satellite (TESS)           NaN
# 5758  Transiting Exoplanet Survey Satellite (TESS)           NaN
#
#       orbital_period_day  orbit_semi_major_axis_au  planet_rad_earth_rad  ...  \
# 151             6.798700                  0.034900              1.047000  ...
# 152            28.167600                  0.134597              2.035000  ...
# 153             0.720910                  0.014667              1.500000  ...
# 154             2.131740                  0.029840              0.692000  ...
# 156             3.804640                  0.048829              1.220000  ...
# ...                  ...                       ...                   ...  ...
# 5750            2.574652                  0.034545              2.483961  ...
# 5752           10.877200                  0.056000              2.426000  ...
# 5753           83.999700                  0.312000              2.167000  ...
# 5755            4.584913                  0.055225              9.615885  ...
# 5758           11.098644                  0.091143              2.452800  ...
#
#       planet_mass_jupiter_mass  orbital_eccentricity  planet_equil_temp_k  \
# 151                        NaN                   0.0           420.477369
# 152                        NaN                   NaN                  NaN
# 153                        NaN                   NaN          1828.565041
# 154                        NaN                   NaN                  NaN
# 156                        NaN                   NaN                  NaN
# ...                        ...                   ...                  ...
# 5750                       NaN                   NaN          1123.985000
# 5752                       NaN                   NaN           429.430000
# 5753                       NaN                   NaN           217.260000
# 5755                       NaN                   NaN          1846.600000
# 5758                       NaN                   NaN           712.010000
#
#       stellar_effective_temp_k  stellar_rad_solar_rad  \
# 151                     3648.0               0.282000
# 152                        NaN               0.374000
# 153                     5633.0               0.940000
# 154                        NaN                    NaN
# 156                        NaN                    NaN
# ...                        ...                    ...
# 5750                    4992.5               0.823500
# 5752                    3770.2               0.527000
# 5753                    3770.2               0.527000
# 5755                    6272.0               2.059789
# 5758                    4969.0               0.732500
#
#       stellar_mass_solar_mass  stellar_metallicity  stellar_surf_grav  \
# 151                  0.287000               -0.048           4.999000
# 152                  0.410000                  NaN           4.904863
# 153                  0.809904               -0.053           4.400000
# 154                  0.780000                  NaN                NaN
# 156                  1.073000                  NaN                NaN
# ...                       ...                  ...                ...
# 5750                 0.837708                0.230           4.525000
# 5752                 0.557000                0.022           4.740056
# 5753                 0.557000                0.022           4.740056
# 5755                 1.069357                  NaN           3.839900
# 5758                 0.820000               -0.133           4.622000
#
#       distance_parsec          stellar_mass_imputation_method
# 151               NaN                                observed
# 152          159.2590                                observed
# 153          706.3910  law_of_gravition_stellar_rad_surf_grav
# 154          253.0260                                observed
# 156          476.8820                                observed
# ...               ...                                     ...
# 5750          60.6679                                observed
# 5752          46.0891                                observed
# 5753          46.0891                                observed
# 5755         312.5290                                observed
# 5758          65.1769                                observed
#
# [2891 rows x 22 columns]

# %%
# Viewing the rows which still have a missing planet mass (in terms of jupiter)
filtered_rows7 = new_exoplanets_filtered2[
    new_exoplanets_filtered2["planet_mass_jupiter_mass"].isna()]

filtered_rows7
# Out:
#             planet_name  host_star_name  star_number_per_system  \
# 151   EPIC 201170410.02  EPIC 201170410                     1.0
# 152    EPIC 201238110 b  EPIC 201238110                     1.0
# 153    EPIC 201427007 b  EPIC 201427007                     1.0
# 154    EPIC 201497682 b  EPIC 201497682                     1.0
# 156    EPIC 201615463 c          K2-166                     1.0
# ...                 ...             ...                     ...
# 5750         TOI-880.02         TOI-880                     1.0
# 5752          TOI-904 b         TOI-904                     1.0
# 5753          TOI-904 c         TOI-904                     1.0
# 5755         TOI-907.01         TOI-907                     1.0
# 5758          TOI-913 b         TOI-913                     1.0
#
#      discovery_method  year_of_discovery  \
# 151           Transit             2020.0
# 152           Transit             2019.0
# 153           Transit             2021.0
# 154           Transit             2019.0
# 156           Transit             2019.0
# ...               ...                ...
# 5750          Transit             2024.0
# 5752          Transit             2023.0
# 5753          Transit             2023.0
# 5755          Transit             2024.0
# 5758          Transit             2023.0
#
#                                 discovery_facility spectral_type  \
# 151                                             K2           NaN
# 152                                             K2           NaN
# 153                                             K2           NaN
# 154                                             K2           NaN
# 156                                             K2           NaN
# ...                                            ...           ...
# 5750  Transiting Exoplanet Survey Satellite (TESS)             K
# 5752  Transiting Exoplanet Survey Satellite (TESS)           NaN
# 5753  Transiting Exoplanet Survey Satellite (TESS)           NaN
# 5755  Transiting Exoplanet Survey Satellite (TESS)           NaN
# 5758  Transiting Exoplanet Survey Satellite (TESS)           NaN
#
#       orbital_period_day  orbit_semi_major_axis_au  planet_rad_earth_rad  ...  \
# 151             6.798700                  0.034900              1.047000  ...
# 152            28.167600                  0.134597              2.035000  ...
# 153             0.720910                  0.014667              1.500000  ...
# 154             2.131740                  0.029840              0.692000  ...
# 156             3.804640                  0.048829              1.220000  ...
# ...                  ...                       ...                   ...  ...
# 5750            2.574652                  0.034545              2.483961  ...
# 5752           10.877200                  0.056000              2.426000  ...
# 5753           83.999700                  0.312000              2.167000  ...
# 5755            4.584913                  0.055225              9.615885  ...
# 5758           11.098644                  0.091143              2.452800  ...
#
#       planet_mass_jupiter_mass  orbital_eccentricity  planet_equil_temp_k  \
# 151                        NaN                   0.0           420.477369
# 152                        NaN                   NaN                  NaN
# 153                        NaN                   NaN          1828.565041
# 154                        NaN                   NaN                  NaN
# 156                        NaN                   NaN                  NaN
# ...                        ...                   ...                  ...
# 5750                       NaN                   NaN          1123.985000
# 5752                       NaN                   NaN           429.430000
# 5753                       NaN                   NaN           217.260000
# 5755                       NaN                   NaN          1846.600000
# 5758                       NaN                   NaN           712.010000
#
#       stellar_effective_temp_k  stellar_rad_solar_rad  \
# 151                     3648.0               0.282000
# 152                        NaN               0.374000
# 153                     5633.0               0.940000
# 154                        NaN                    NaN
# 156                        NaN                    NaN
# ...                        ...                    ...
# 5750                    4992.5               0.823500
# 5752                    3770.2               0.527000
# 5753                    3770.2               0.527000
# 5755                    6272.0               2.059789
# 5758                    4969.0               0.732500
#
#       stellar_mass_solar_mass  stellar_metallicity  stellar_surf_grav  \
# 151                  0.287000               -0.048           4.999000
# 152                  0.410000                  NaN           4.904863
# 153                  0.809904               -0.053           4.400000
# 154                  0.780000                  NaN                NaN
# 156                  1.073000                  NaN                NaN
# ...                       ...                  ...                ...
# 5750                 0.837708                0.230           4.525000
# 5752                 0.557000                0.022           4.740056
# 5753                 0.557000                0.022           4.740056
# 5755                 1.069357                  NaN           3.839900
# 5758                 0.820000               -0.133           4.622000
#
#       distance_parsec          stellar_mass_imputation_method
# 151               NaN                                observed
# 152          159.2590                                observed
# 153          706.3910  law_of_gravition_stellar_rad_surf_grav
# 154          253.0260                                observed
# 156          476.8820                                observed
# ...               ...                                     ...
# 5750          60.6679                                observed
# 5752          46.0891                                observed
# 5753          46.0891                                observed
# 5755         312.5290                                observed
# 5758          65.1769                                observed
#
# [2891 rows x 22 columns]

# %%
# viewing planets with missing mass but known planet radius

cols_to_show3 = [
    "planet_name",
    "planet_mass_earth_mass",
    "planet_rad_earth_rad",
]

filtered_row6 = new_exoplanets_filtered2[
    new_exoplanets_filtered2["planet_mass_earth_mass"].isna() &
    new_exoplanets_filtered2["planet_rad_earth_rad"].notna()
][cols_to_show3]

filtered_row6
# Out:
#             planet_name  planet_mass_earth_mass  planet_rad_earth_rad
# 151   EPIC 201170410.02                     NaN              1.047000
# 152    EPIC 201238110 b                     NaN              2.035000
# 153    EPIC 201427007 b                     NaN              1.500000
# 154    EPIC 201497682 b                     NaN              0.692000
# 156    EPIC 201615463 c                     NaN              1.220000
# ...                 ...                     ...                   ...
# 5750         TOI-880.02                     NaN              2.483961
# 5752          TOI-904 b                     NaN              2.426000
# 5753          TOI-904 c                     NaN              2.167000
# 5755         TOI-907.01                     NaN              9.615885
# 5758          TOI-913 b                     NaN              2.452800
#
# [2884 rows x 3 columns]

# %%
# viewing planets with missing mass but known planet radius

cols_to_show4 = [
    "planet_name",
    "planet_mass_earth_mass",
    "planet_rad_earth_rad",
    "planet_mass_jupiter_mass",
    "planet_rad_jupiter_rad"
]

filtered_row7 = new_exoplanets_filtered2[
    new_exoplanets_filtered2["planet_mass_earth_mass"].isna() &
    new_exoplanets_filtered2["planet_mass_jupiter_mass"].isna() &
    new_exoplanets_filtered2["planet_rad_earth_rad"].notna() &
    new_exoplanets_filtered2["planet_rad_jupiter_rad"].notna()
][cols_to_show4]

filtered_row7
# Out:
#             planet_name  planet_mass_earth_mass  planet_rad_earth_rad  \
# 151   EPIC 201170410.02                     NaN              1.047000
# 152    EPIC 201238110 b                     NaN              2.035000
# 153    EPIC 201427007 b                     NaN              1.500000
# 154    EPIC 201497682 b                     NaN              0.692000
# 156    EPIC 201615463 c                     NaN              1.220000
# ...                 ...                     ...                   ...
# 5750         TOI-880.02                     NaN              2.483961
# 5752          TOI-904 b                     NaN              2.426000
# 5753          TOI-904 c                     NaN              2.167000
# 5755         TOI-907.01                     NaN              9.615885
# 5758          TOI-913 b                     NaN              2.452800
#
#       planet_mass_jupiter_mass  planet_rad_jupiter_rad
# 151                        NaN                0.093407
# 152                        NaN                0.183415
# 153                        NaN                0.133821
# 154                        NaN                0.061736
# 156                        NaN                0.108841
# ...                        ...                     ...
# 5750                       NaN                0.221470
# 5752                       NaN                0.216434
# 5753                       NaN                0.193327
# 5755                       NaN                0.856942
# 5758                       NaN                0.218825
#
# [2884 rows x 5 columns]

# %%
# Define ALL radius ranges (now including Earth-like)
planet_categories = {
    "Earth-like": (0, 1.5),
    "Super-Earth-like": (1.5, 2),
    "Neptune-like": (2, 4),
    "Super-Neptune-like": (4, 6),
    "Saturn-like": (6, 9),
    "Super-Saturn-like": (9, 11),
    "Jupiter-like": (11, 15),
    "Super-Jupiter-like": (15, float("inf"))
}

# Dictionary to store results
mean_radii = {}

# Loop through each category
for category, (lower, upper) in planet_categories.items():

    subset = new_exoplanets_filtered2[
        (new_exoplanets_filtered2["planet_rad_earth_rad"].notna()) &
        (new_exoplanets_filtered2["planet_rad_earth_rad"] > lower) &
        (new_exoplanets_filtered2["planet_rad_earth_rad"] <= upper)
    ]

    # Store mean
    mean_radii[category] = subset["planet_rad_earth_rad"].mean()

    # Print results
    print(f"\n{category}")
    print("Count:", len(subset))
    print("Mean radius:", mean_radii[category])

    # Optional preview
    print(subset[["planet_name", "planet_rad_earth_rad"]].head())
# Out:
# Earth-like
# Count: 937
# Mean radius: 1.167121076131567
#            planet_name  planet_rad_earth_rad
# 151  EPIC 201170410.02              1.047000
# 153   EPIC 201427007 b              1.500000
# 154   EPIC 201497682 b              0.692000
# 155   EPIC 201595106 b              1.367688
# 156   EPIC 201615463 c              1.220000
#
# Super-Earth-like
# Count: 715
# Mean radius: 1.7305391325681365
#           planet_name  planet_rad_earth_rad
# 36           55 Cnc e              1.962000
# 134         CoRoT-7 b              1.652507
# 162  EPIC 206024342 b              1.570000
# 166  EPIC 206042996 b              1.700000
# 173  EPIC 212297394 b              1.544333
#
# Neptune-like
# Count: 1747
# Mean radius: 2.675131652635472
#           planet_name  planet_rad_earth_rad
# 55           AU Mic c              2.850674
# 66        BD+20 594 b              2.387841
# 118        CoRoT-24 b              3.700000
# 152  EPIC 201238110 b              2.035000
# 164  EPIC 206024342 d              2.600000
#
# Super-Neptune-like
# Count: 200
# Mean radius: 4.815818243388744
#           planet_name  planet_rad_earth_rad
# 54           AU Mic b              4.105036
# 116        CoRoT-22 b              4.880000
# 119        CoRoT-24 c              5.000000
# 150        DS Tuc A b              5.665000
# 172  EPIC 211945201 b              5.998128
#
# Saturn-like
# Count: 141
# Mean radius: 7.445359731096349
#     planet_name  planet_rad_earth_rad
# 128  CoRoT-32 b              6.389130
# 137   CoRoT-8 b              6.924577
# 283  GJ 414 A c              8.400000
# 381  HAT-P-26 b              6.900975
# 435   HATS-12 b              7.760000
#
# Super-Saturn-like
# Count: 137
# Mean radius: 10.129956993139484
#     planet_name  planet_rad_earth_rad
# 103  CoRoT-10 b             10.763466
# 113  CoRoT-20 b             10.761750
# 123  CoRoT-28 b             10.704595
# 124  CoRoT-29 b             10.088100
# 371  HAT-P-18 b             10.973626
#
# Jupiter-like
# Count: 459
# Mean radius: 12.876860942198219
#                    planet_name  planet_rad_earth_rad
# 13   2MASS J01225093-2439505 b             11.209000
# 74                BD+60 1417 b             14.683765
# 100               COCONUTS-2 b             12.441969
# 106                 CoRoT-13 b             11.291211
# 107                 CoRoT-14 b             11.949524
#
# Super-Jupiter-like
# Count: 223
# Mean radius: 18.250524080458682
#                   planet_name  planet_rad_earth_rad
# 7     1RXS J160929.1-210524 b             18.647000
# 14  2MASS J02192210-3925225 b             16.140960
# 84               BD-14 3065 b             21.590000
# 95               CD-35 2722 b             17.373920
# 97           CFHTWIR-Oph 98 b             20.848704

# %%
# For Mp = Rp^(1.3) where Rp is the planet radius and Mp is the planet (For Earth-Like where Rp <= 1.5)
# For Mp = Rp^(2.44) where Rp is the planet radius and Mp is the planet (For Super-Earth-Like where 1.5 < Rp <= 2)
# For Mp = Rp^(1.9) where Rp is the planet radius and Mp is the planet (For Neptune-Like where 2 < Rp <= 4)
# For Mp = Rp^(2.61) where Rp is the planet radius and Mp is the planet (For Super-Neptune-Like where 4 < Rp <= 6)
# For Mp = Rp^(2.37) where Rp is the planet radius and Mp is the planet (For Saturn-Like where 6 < Rp <= 9)
# For Mp = Rp^(2.63) where Rp is the planet radius and Mp is the planet (For Super-Saturn-Like where 9 < Rp <= 11)
# For Mp = Rp^(2.63) where Rp is the planet radius and Mp is the planet (For Jupiter-Like where 11 < Rp <= 15)
# For Mp = Rp^(2.31) where Rp is the planet radius and Mp is the planet (For Super-Jupiter-Like where Rp > 15)

# Valid inputs
valid_inputs_earth_like = (
    new_exoplanets_filtered2["planet_rad_earth_rad"].notna() &
    (new_exoplanets_filtered2["planet_rad_earth_rad"] > 0) &
    (new_exoplanets_filtered2["planet_rad_earth_rad"] <= 1.5)
)
valid_inputs_super_earth_like = (
    new_exoplanets_filtered2["planet_rad_earth_rad"].notna() &
    (new_exoplanets_filtered2["planet_rad_earth_rad"] > 0) &
    (new_exoplanets_filtered2["planet_rad_earth_rad"] > 1.5) &
    (new_exoplanets_filtered2["planet_rad_earth_rad"] <= 2)
)
valid_inputs_neptune_like = (
    new_exoplanets_filtered2["planet_rad_earth_rad"].notna() &
    (new_exoplanets_filtered2["planet_rad_earth_rad"] > 0) &
    (new_exoplanets_filtered2["planet_rad_earth_rad"] > 2) &
    (new_exoplanets_filtered2["planet_rad_earth_rad"] <= 4)
)
valid_inputs_super_neptune_like = (
    new_exoplanets_filtered2["planet_rad_earth_rad"].notna() &
    (new_exoplanets_filtered2["planet_rad_earth_rad"] > 0) &
    (new_exoplanets_filtered2["planet_rad_earth_rad"] > 4) &
    (new_exoplanets_filtered2["planet_rad_earth_rad"] <= 6)
)
valid_inputs_saturn_like = (
    new_exoplanets_filtered2["planet_rad_earth_rad"].notna() &
    (new_exoplanets_filtered2["planet_rad_earth_rad"] > 0) &
    (new_exoplanets_filtered2["planet_rad_earth_rad"] > 6) &
    (new_exoplanets_filtered2["planet_rad_earth_rad"] <= 9)
)
valid_inputs_super_saturn_like = (
    new_exoplanets_filtered2["planet_rad_earth_rad"].notna() &
    (new_exoplanets_filtered2["planet_rad_earth_rad"] > 0) &
    (new_exoplanets_filtered2["planet_rad_earth_rad"] > 9) &
    (new_exoplanets_filtered2["planet_rad_earth_rad"] <= 11)
)
valid_inputs_jupiter_like = (
    new_exoplanets_filtered2["planet_rad_earth_rad"].notna() &
    (new_exoplanets_filtered2["planet_rad_earth_rad"] > 0) &
    (new_exoplanets_filtered2["planet_rad_earth_rad"] > 11) &
    (new_exoplanets_filtered2["planet_rad_earth_rad"] <= 15)
)
valid_inputs_super_jupiter_like = (
    new_exoplanets_filtered2["planet_rad_earth_rad"].notna() &
    (new_exoplanets_filtered2["planet_rad_earth_rad"] > 0) &
    (new_exoplanets_filtered2["planet_rad_earth_rad"] > 15)
)


# Mask rows where planet mass is missing for earth like
mask_earth_like = new_exoplanets_filtered2["planet_mass_earth_mass"].isna() & valid_inputs_earth_like
# Mask rows where planet mass is missing for super earth like
mask_super_earth_like = new_exoplanets_filtered2["planet_mass_earth_mass"].isna() & valid_inputs_super_earth_like
# Mask rows where planet mass is missing for neptune like
mask_neptune_like = new_exoplanets_filtered2["planet_mass_earth_mass"].isna() & valid_inputs_neptune_like
# Mask rows where planet mass is missing for super-neptune like
mask_super_neptune_like = new_exoplanets_filtered2["planet_mass_earth_mass"].isna() & valid_inputs_super_neptune_like
# Mask rows where planet mass is missing for saturn like
mask_saturn_like = new_exoplanets_filtered2["planet_mass_earth_mass"].isna() & valid_inputs_saturn_like
# Mask rows where planet mass is missing for super-saturn like
mask_super_saturn_like = new_exoplanets_filtered2["planet_mass_earth_mass"].isna() & valid_inputs_super_saturn_like
# Mask rows where planet mass is missing for jupiter like
mask_jupiter_like = new_exoplanets_filtered2["planet_mass_earth_mass"].isna() & valid_inputs_jupiter_like
# Mask rows where planet mass is missing for super-jupiter like
mask_super_jupiter_like = new_exoplanets_filtered2["planet_mass_earth_mass"].isna() & valid_inputs_super_jupiter_like


# imputing missing planet mass for earth like
new_exoplanets_filtered2.loc[mask_earth_like, "planet_mass_earth_mass"] = new_exoplanets_filtered2.loc[mask_earth_like, "planet_rad_earth_rad"]**1.3
# imputing missing planet mass for super earth like
new_exoplanets_filtered2.loc[mask_super_earth_like, "planet_mass_earth_mass"] = new_exoplanets_filtered2.loc[mask_super_earth_like, "planet_rad_earth_rad"]**2.44
# imputing missing planet mass for neptune like
new_exoplanets_filtered2.loc[mask_neptune_like, "planet_mass_earth_mass"] = new_exoplanets_filtered2.loc[mask_neptune_like, "planet_rad_earth_rad"]**1.9
# imputing missing planet mass for super neptune like
new_exoplanets_filtered2.loc[mask_super_neptune_like, "planet_mass_earth_mass"] = new_exoplanets_filtered2.loc[mask_super_neptune_like, "planet_rad_earth_rad"]**2.61
# imputing missing planet mass for saturn like
new_exoplanets_filtered2.loc[mask_saturn_like, "planet_mass_earth_mass"] = new_exoplanets_filtered2.loc[mask_saturn_like, "planet_rad_earth_rad"]**2.37
# imputing missing planet mass for super saturn like
new_exoplanets_filtered2.loc[mask_super_saturn_like, "planet_mass_earth_mass"] = new_exoplanets_filtered2.loc[mask_super_saturn_like, "planet_rad_earth_rad"]**2.63
# imputing missing planet mass for jupiter like
new_exoplanets_filtered2.loc[mask_jupiter_like, "planet_mass_earth_mass"] = new_exoplanets_filtered2.loc[mask_jupiter_like, "planet_rad_earth_rad"]**2.63
# imputing missing planet mass for super jupiter like
new_exoplanets_filtered2.loc[mask_super_jupiter_like, "planet_mass_earth_mass"] = new_exoplanets_filtered2.loc[mask_super_jupiter_like, "planet_rad_earth_rad"]**2.31

# %%
# checking if number of missing values decreased
missing_percentage = (new_exoplanets_filtered2.isnull().sum() / len(new_exoplanets_filtered2))
((missing_percentage * 100).sort_values(ascending=False)).map(lambda x: f"{x:.2f}%")
# Out:
# spectral_type                     68.57%
# planet_mass_jupiter_mass          47.62%
# planet_rad_earth_rad              24.91%
# planet_rad_jupiter_rad            24.91%
# orbital_eccentricity              14.87%
# stellar_metallicity               11.68%
# stellar_rad_solar_rad              9.98%
# planet_equil_temp_k                9.55%
# stellar_surf_grav                  8.17%
# stellar_effective_temp_k           7.68%
# distance_parsec                    2.03%
# orbital_period_day                 0.44%
# stellar_mass_solar_mass            0.41%
# orbit_semi_major_axis_au           0.18%
# planet_mass_earth_mass             0.12%
# year_of_discovery                  0.00%
# discovery_facility                 0.00%
# star_number_per_system             0.00%
# host_star_name                     0.00%
# planet_name                        0.00%
# discovery_method                   0.00%
# stellar_mass_imputation_method     0.00%
# dtype: object

# %% [markdown]
# #### Missing Planet Radius Imputation
# * Imputing the missing value for planet radius using mputing the missing value for planetary mass using Transit Method Mass-Radius Estimation

# %%
# viewing planets with missing mass but known planet radius

cols_to_show4 = [
    "planet_name",
    "planet_mass_earth_mass",
    "planet_rad_earth_rad",
]

filtered_row6 = new_exoplanets_filtered2[
    new_exoplanets_filtered2["planet_rad_earth_rad"].isna() &
    new_exoplanets_filtered2["planet_mass_earth_mass"].notna()
][cols_to_show4]

filtered_row6
# Out:
#      planet_name  planet_mass_earth_mass  planet_rad_earth_rad
# 0       11 Com b             5505.066162                   NaN
# 1       11 UMi b             4684.814200                   NaN
# 2       14 And b             1224.550434                   NaN
# 3       14 Her b             2559.472162                   NaN
# 4     16 Cyg B b              533.514528                   NaN
# ...          ...                     ...                   ...
# 6066   ups And b              219.960419                   NaN
# 6067   ups And c              629.595000                   NaN
# 6068   ups And d             1313.220000                   NaN
# 6069   ups Leo b              162.092488                   NaN
# 6070    xi Aql b              616.904938                   NaN
#
# [1505 rows x 3 columns]

# %%
# For Rp = Mp^(1/2.09) where Rp is the planet radius and Mp is the planet mass

# Valid inputs
valid_inputs = (
    new_exoplanets_filtered2["planet_mass_earth_mass"].notna() &
    (new_exoplanets_filtered2["planet_mass_earth_mass"] > 0)
)

# Mask rows where planet rad is missing
mask = new_exoplanets_filtered2["planet_rad_earth_rad"].isna() & valid_inputs

# imputing missing planet rad
new_exoplanets_filtered2.loc[mask, "planet_rad_earth_rad"] = new_exoplanets_filtered2.loc[mask, "planet_mass_earth_mass"]**(1/2.09)

# %%
# checking if number of missing values decreased
missing_percentage = (new_exoplanets_filtered2.isnull().sum() / len(new_exoplanets_filtered2))
((missing_percentage * 100).sort_values(ascending=False)).map(lambda x: f"{x:.2f}%")
# Out:
# spectral_type                     68.57%
# planet_mass_jupiter_mass          47.62%
# planet_rad_jupiter_rad            24.91%
# orbital_eccentricity              14.87%
# stellar_metallicity               11.68%
# stellar_rad_solar_rad              9.98%
# planet_equil_temp_k                9.55%
# stellar_surf_grav                  8.17%
# stellar_effective_temp_k           7.68%
# distance_parsec                    2.03%
# orbital_period_day                 0.44%
# stellar_mass_solar_mass            0.41%
# orbit_semi_major_axis_au           0.18%
# planet_rad_earth_rad               0.12%
# planet_mass_earth_mass             0.12%
# year_of_discovery                  0.00%
# discovery_facility                 0.00%
# star_number_per_system             0.00%
# host_star_name                     0.00%
# planet_name                        0.00%
# discovery_method                   0.00%
# stellar_mass_imputation_method     0.00%
# dtype: object

# %%
# viewing planet 11 Com b to verify imputation values align with physical theory
new_exoplanets_filtered2[new_exoplanets_filtered2["planet_name"] == "11 Com b"]
# Out:
#   planet_name host_star_name  star_number_per_system discovery_method  \
# 0    11 Com b         11 Com                     2.0  Radial Velocity
#
#    year_of_discovery discovery_facility spectral_type  orbital_period_day  \
# 0             2007.0   Xinglong Station        G8 III              324.62
#
#    orbit_semi_major_axis_au  planet_rad_earth_rad  ...  \
# 0                     1.226             61.636581  ...
#
#    planet_mass_jupiter_mass  orbital_eccentricity  planet_equil_temp_k  \
# 0                 17.321333                0.2345           653.137165
#
#    stellar_effective_temp_k  stellar_rad_solar_rad  stellar_mass_solar_mass  \
# 0                    4808.0                  13.76                     2.09
#
#    stellar_metallicity  stellar_surf_grav  distance_parsec  \
# 0                -0.26               2.38          93.1846
#
#    stellar_mass_imputation_method
# 0                        observed
#
# [1 rows x 22 columns]

# %% [markdown]
# ### Computing Columns Relavent for Analysis

# %% [markdown]
# #### Creating Stellar Luminosity Column
# * Using the Stefan-Boltzmann Formula

# %%
# For Ls = Rs^(2) * Teff_s^(4) where Ls is the stellar luminosity (in terms of sun's luminosity), Rs is the stellar radius (in terms of sun;s radius), and
# Ts is the stellar effective surface temperature (in terms of sun's effective surface temperature)

# Constants and conversion factors
# sun's effective surface temperature in Kelvin [K]
Teff_sun = 5778 #K

# valid calculation if stellar radius and stellar effective temperature is known
mask_lum = (
    new_exoplanets_filtered2["stellar_rad_solar_rad"].notna() &
    new_exoplanets_filtered2["stellar_effective_temp_k"].notna()
)

# converting the stellar effective surface temperature in Kelvin to Sun's effective surface temperature in Kelvin
Teff_s = new_exoplanets_filtered2.loc[mask, "stellar_effective_temp_k"] / Teff_sun

new_exoplanets_filtered2.loc[mask_lum, "stellar_luminosity_solar_lum"] = (
    new_exoplanets_filtered2.loc[mask_lum, "stellar_rad_solar_rad"]**2 *
    (new_exoplanets_filtered2.loc[mask_lum, "stellar_effective_temp_k"] / Teff_sun)**4
)

# fill remaining rows with NaN (pandas does this by default)
new_exoplanets_filtered2["stellar_luminosity_solar_lum"] = new_exoplanets_filtered2["stellar_luminosity_solar_lum"].astype(float)

# %%
# checking new column is added for kepler 452 b
new_exoplanets_filtered2[new_exoplanets_filtered2["planet_name"] == "Kepler-452 b"]
# Out:
#        planet_name host_star_name  star_number_per_system discovery_method  \
# 4115  Kepler-452 b     Kepler-452                     1.0          Transit
#
#       year_of_discovery discovery_facility spectral_type  orbital_period_day  \
# 4115             2015.0             Kepler            G2          384.844831
#
#       orbit_semi_major_axis_au  planet_rad_earth_rad  ...  \
# 4115                  1.009733                  1.63  ...
#
#       orbital_eccentricity  planet_equil_temp_k  stellar_effective_temp_k  \
# 4115                   0.0                235.0               5687.166667
#
#       stellar_rad_solar_rad  stellar_mass_solar_mass  stellar_metallicity  \
# 4115               1.099285                 1.029667                 0.21
#
#       stellar_surf_grav  distance_parsec  stellar_mass_imputation_method  \
# 4115            4.44555          551.727                        observed
#
#       stellar_luminosity_solar_lum
# 4115                      1.134212
#
# [1 rows x 23 columns]

# %% [markdown]
# #### Creating Planet Radial Velocity Column
# * Using Planet Radial Velocity Formula

# %%
# For: v_orb = sqrt(G * Ms / a), expressed in units of Earth's orbital velocity
# Ms = stellar mass [M_sun], a = semi-major axis [AU]

# Constants
G = 6.67430e-11        # m^3 kg^-1 s^-2
M_sun = 1.98847e30     # kg
AU = 1.495978707e11    # m
v_earth_km_s = 29.78   # Earth's orbital velocity in km/s

# valid calculation if stellar mass and semi-major axis are known
mask_vel = (
    new_exoplanets_filtered2["stellar_mass_solar_mass"].notna() &
    new_exoplanets_filtered2["orbit_semi_major_axis_au"].notna()
)

# convert to SI units
M_star = new_exoplanets_filtered2.loc[mask_vel, "stellar_mass_solar_mass"] * M_sun
a_m = new_exoplanets_filtered2.loc[mask_vel, "orbit_semi_major_axis_au"] * AU

# compute orbital velocity [m/s]
v_orb_m_s = np.sqrt(G * M_star / a_m)

# convert to km/s
v_orb_km_s = v_orb_m_s / 1e3

# convert to Earth orbital velocity units
v_orb_earth_units = v_orb_km_s / v_earth_km_s

# store result in new column
new_exoplanets_filtered2.loc[mask_vel, "planet_orbital_velocity"] = v_orb_earth_units

# ensure column is float
new_exoplanets_filtered2["planet_orbital_velocity"] = new_exoplanets_filtered2["planet_orbital_velocity"].astype(float)

# %%
# checking new column is added for kepler 452 b
new_exoplanets_filtered2[new_exoplanets_filtered2["planet_name"] == "Kepler-452 b"]
# Out:
#        planet_name host_star_name  star_number_per_system discovery_method  \
# 4115  Kepler-452 b     Kepler-452                     1.0          Transit
#
#       year_of_discovery discovery_facility spectral_type  orbital_period_day  \
# 4115             2015.0             Kepler            G2          384.844831
#
#       orbit_semi_major_axis_au  planet_rad_earth_rad  ...  \
# 4115                  1.009733                  1.63  ...
#
#       planet_equil_temp_k  stellar_effective_temp_k  stellar_rad_solar_rad  \
# 4115                235.0               5687.166667               1.099285
#
#       stellar_mass_solar_mass  stellar_metallicity  stellar_surf_grav  \
# 4115                 1.029667                 0.21            4.44555
#
#       distance_parsec  stellar_mass_imputation_method  \
# 4115          551.727                        observed
#
#       stellar_luminosity_solar_lum  planet_orbital_velocity
# 4115                      1.134212                 1.009997
#
# [1 rows x 24 columns]

# %% [markdown]
# ### Spectral Type Column Imputation

# %%
# checking if number of missing values decreased
missing_percentage = (new_exoplanets_filtered2.isnull().sum() / len(new_exoplanets_filtered2))
((missing_percentage * 100).sort_values(ascending=False)).map(lambda x: f"{x:.2f}%")
# Out:
# spectral_type                     68.57%
# planet_mass_jupiter_mass          47.62%
# planet_rad_jupiter_rad            24.91%
# orbital_eccentricity              14.87%
# stellar_metallicity               11.68%
# stellar_luminosity_solar_lum      10.38%
# stellar_rad_solar_rad              9.98%
# planet_equil_temp_k                9.55%
# stellar_surf_grav                  8.17%
# stellar_effective_temp_k           7.68%
# distance_parsec                    2.03%
# planet_orbital_velocity            0.51%
# orbital_period_day                 0.44%
# stellar_mass_solar_mass            0.41%
# orbit_semi_major_axis_au           0.18%
# planet_mass_earth_mass             0.12%
# planet_rad_earth_rad               0.12%
# discovery_facility                 0.00%
# year_of_discovery                  0.00%
# discovery_method                   0.00%
# host_star_name                     0.00%
# planet_name                        0.00%
# star_number_per_system             0.00%
# stellar_mass_imputation_method     0.00%
# dtype: object

# %% [markdown]
# #### Main Sequence (V) Spectral Type Imputation:

# %%
# Create a mask for Main Sequence (V) calculation constraints where stellar effective temperature, stellar mass, stellar radius, and stellar luminsoty must be known
mask_star_calculation = (
    new_exoplanets_filtered2["stellar_effective_temp_k"].notna() &
    new_exoplanets_filtered2["stellar_mass_solar_mass"].notna() &
    new_exoplanets_filtered2["stellar_rad_solar_rad"].notna() &
    new_exoplanets_filtered2["stellar_luminosity_solar_lum"].notna()
)

# %%
# Impute for Type O Main Sequence (V) Star:

# Create mask for Type O Main Sequence (V) stars
mask_OV = (
    (new_exoplanets_filtered2["stellar_effective_temp_k"] >= 30000) &
    (new_exoplanets_filtered2["stellar_mass_solar_mass"] >= 16) &
    (new_exoplanets_filtered2["stellar_rad_solar_rad"] >= 6.6) &
    (new_exoplanets_filtered2["stellar_luminosity_solar_lum"] >= 30000)
)

# Impute only where spectral_type is missing
new_exoplanets_filtered2.loc[
    new_exoplanets_filtered2["spectral_type"].isna() & mask_star_calculation & mask_OV,
    "spectral_type"
] = "OV"

# checking if OV was added
(new_exoplanets_filtered2["spectral_type"] == "OV").sum()
# Out:
# np.int64(0)

# %%
# Impute for Type B Main Sequence (V) Star:

# Create mask for Type B Main Sequence (V) stars
mask_BV = (
    (new_exoplanets_filtered2["stellar_effective_temp_k"] >= 10000) & (new_exoplanets_filtered2["stellar_effective_temp_k"] < 30000) &
    (new_exoplanets_filtered2["stellar_mass_solar_mass"] >= 2.1) & (new_exoplanets_filtered2["stellar_mass_solar_mass"] < 16) &
    (new_exoplanets_filtered2["stellar_rad_solar_rad"] >= 1.8) & (new_exoplanets_filtered2["stellar_rad_solar_rad"] < 6.6) &
    (new_exoplanets_filtered2["stellar_luminosity_solar_lum"] >= 25) & (new_exoplanets_filtered2["stellar_luminosity_solar_lum"] < 30000)
)

# Impute only where spectral_type is missing
new_exoplanets_filtered2.loc[
    new_exoplanets_filtered2["spectral_type"].isna() & mask_star_calculation & mask_BV,
    "spectral_type"
] = "BV"

# checking if BV was added
(new_exoplanets_filtered2["spectral_type"] == "BV").sum()
# Out:
# np.int64(0)

# %%
# Impute for Type A Main Sequence (V) Star:

# Create mask for Type A Main Sequence (V) stars
mask_AV = (
    (new_exoplanets_filtered2["stellar_effective_temp_k"] >= 7500) & (new_exoplanets_filtered2["stellar_effective_temp_k"] < 10000) &
    (new_exoplanets_filtered2["stellar_mass_solar_mass"] >= 1.4) & (new_exoplanets_filtered2["stellar_mass_solar_mass"] < 2.2) &
    (new_exoplanets_filtered2["stellar_rad_solar_rad"] >= 1.4) & (new_exoplanets_filtered2["stellar_rad_solar_rad"] < 2.5) &
    (new_exoplanets_filtered2["stellar_luminosity_solar_lum"] >= 5) & (new_exoplanets_filtered2["stellar_luminosity_solar_lum"] < 25)
)

# Impute only where spectral_type is missing
new_exoplanets_filtered2.loc[
    new_exoplanets_filtered2["spectral_type"].isna() & mask_star_calculation & mask_AV,
    "spectral_type"
] = "AV"

# checking if AV was added
(new_exoplanets_filtered2["spectral_type"] == "AV").sum()
# Out:
# np.int64(10)

# %%
# Impute for Type F Main Sequence (V) Star:

# Create mask for Type F Main Sequence (V) stars
mask_FV = (
    (new_exoplanets_filtered2["stellar_effective_temp_k"] >= 6000) & (new_exoplanets_filtered2["stellar_effective_temp_k"] < 7500) &
    (new_exoplanets_filtered2["stellar_mass_solar_mass"] >= 0.8) & (new_exoplanets_filtered2["stellar_mass_solar_mass"] < 1.45) &
    (new_exoplanets_filtered2["stellar_rad_solar_rad"] >= 0.8) & (new_exoplanets_filtered2["stellar_rad_solar_rad"] < 2.2) &
    (new_exoplanets_filtered2["stellar_luminosity_solar_lum"] >= 0.9) & (new_exoplanets_filtered2["stellar_luminosity_solar_lum"] < 6.2)
)

# Impute only where spectral_type is missing
new_exoplanets_filtered2.loc[
    new_exoplanets_filtered2["spectral_type"].isna() & mask_star_calculation & mask_FV,
    "spectral_type"
] = "FV"

# checking if FV was added
(new_exoplanets_filtered2["spectral_type"] == "FV").sum()
# Out:
# np.int64(690)

# %%
# Impute for Type G Main Sequence (V) Star (Sun-Like star):

# Create mask for Type G Main Sequence (V) stars
mask_GV = (
    (new_exoplanets_filtered2["stellar_effective_temp_k"] >= 5200) & (new_exoplanets_filtered2["stellar_effective_temp_k"] < 6000) &
    (new_exoplanets_filtered2["stellar_mass_solar_mass"] >= 0) & (new_exoplanets_filtered2["stellar_mass_solar_mass"] < 1.4) &
    (new_exoplanets_filtered2["stellar_rad_solar_rad"] >= 0) & (new_exoplanets_filtered2["stellar_rad_solar_rad"] < 2.3) &
    (new_exoplanets_filtered2["stellar_luminosity_solar_lum"] >= 0) & (new_exoplanets_filtered2["stellar_luminosity_solar_lum"] < 3.7)
)

# Impute only where spectral_type is missing
new_exoplanets_filtered2.loc[
    new_exoplanets_filtered2["spectral_type"].isna() & mask_star_calculation & mask_GV,
    "spectral_type"
] = "GV"

# checking if GV was added
(new_exoplanets_filtered2["spectral_type"] == "GV").sum()
# Out:
# np.int64(1910)

# %%
# Impute for Type K Main Sequence (V) Star:

# Create mask for Type K Main Sequence (V) stars
mask_KV = (
    (new_exoplanets_filtered2["stellar_effective_temp_k"] >= 3600) & (new_exoplanets_filtered2["stellar_effective_temp_k"] < 5200) &
    (new_exoplanets_filtered2["stellar_mass_solar_mass"] >= 0.16) & (new_exoplanets_filtered2["stellar_mass_solar_mass"] < 1.1) &
    (new_exoplanets_filtered2["stellar_rad_solar_rad"] >= 0.17) & (new_exoplanets_filtered2["stellar_rad_solar_rad"] < 1.5) &
    (new_exoplanets_filtered2["stellar_luminosity_solar_lum"] >= 0) & (new_exoplanets_filtered2["stellar_luminosity_solar_lum"] < 0.9)
)

# Impute only where spectral_type is missing
new_exoplanets_filtered2.loc[
    new_exoplanets_filtered2["spectral_type"].isna() & mask_star_calculation & mask_KV,
    "spectral_type"
] = "KV"

# checking if KV was added
(new_exoplanets_filtered2["spectral_type"] == "KV").sum()
# Out:
# np.int64(886)

# %%
# Impute for Type M Main Sequence (V) Star:

# Create mask for Type M Main Sequence (V) stars
mask_MV = (
    (new_exoplanets_filtered2["stellar_effective_temp_k"] >= 2500) & (new_exoplanets_filtered2["stellar_effective_temp_k"] < 3700) &
    (new_exoplanets_filtered2["stellar_mass_solar_mass"] < 0.58) &
    (new_exoplanets_filtered2["stellar_rad_solar_rad"] < 0.63) &
    (new_exoplanets_filtered2["stellar_luminosity_solar_lum"] >= 0) & (new_exoplanets_filtered2["stellar_luminosity_solar_lum"] < 0.08)
)

# Impute only where spectral_type is missing
new_exoplanets_filtered2.loc[
    new_exoplanets_filtered2["spectral_type"].isna() & mask_star_calculation & mask_MV,
    "spectral_type"
] = "MV"

# checking if MV was added
(new_exoplanets_filtered2["spectral_type"] == "MV").sum()
# Out:
# np.int64(80)

# %% [markdown]
# #### Sub Giant (IV) Spectral Type Imputation:

# %%
# Impute for Type B Sub Giant (IV) Star:

# Create mask for Type B Sub Giant (IV) stars
mask_BIV = (
    (new_exoplanets_filtered2["stellar_effective_temp_k"] >= 10000) & (new_exoplanets_filtered2["stellar_effective_temp_k"] < 30000) &
    (new_exoplanets_filtered2["stellar_mass_solar_mass"] >= 3) & (new_exoplanets_filtered2["stellar_mass_solar_mass"] < 16) &
    (new_exoplanets_filtered2["stellar_rad_solar_rad"] >= 3) & (new_exoplanets_filtered2["stellar_rad_solar_rad"] < 10) &
    (new_exoplanets_filtered2["stellar_luminosity_solar_lum"] >= 100) & (new_exoplanets_filtered2["stellar_luminosity_solar_lum"] < 20000)
)

# Impute only where spectral_type is missing
new_exoplanets_filtered2.loc[
    new_exoplanets_filtered2["spectral_type"].isna() & mask_star_calculation & mask_BIV,
    "spectral_type"
] = "BIV"

# checking if AIV was added
(new_exoplanets_filtered2["spectral_type"] == "BIV").sum()
# Out:
# np.int64(0)

# %%
# Impute for Type A Sub Giant (IV) Star:

# Create mask for Type A Sub Giant (IV) stars
mask_AIV = (
    (new_exoplanets_filtered2["stellar_effective_temp_k"] >= 7500) & (new_exoplanets_filtered2["stellar_effective_temp_k"] < 10000) &
    (new_exoplanets_filtered2["stellar_mass_solar_mass"] >= 1.5) & (new_exoplanets_filtered2["stellar_mass_solar_mass"] < 3) &
    (new_exoplanets_filtered2["stellar_rad_solar_rad"] >= 2) & (new_exoplanets_filtered2["stellar_rad_solar_rad"] < 4) &
    (new_exoplanets_filtered2["stellar_luminosity_solar_lum"] >= 10) & (new_exoplanets_filtered2["stellar_luminosity_solar_lum"] < 60)
)

# Impute only where spectral_type is missing
new_exoplanets_filtered2.loc[
    new_exoplanets_filtered2["spectral_type"].isna() & mask_star_calculation & mask_AIV,
    "spectral_type"
] = "AIV"

# checking if AIV was added
(new_exoplanets_filtered2["spectral_type"] == "AIV").sum()
# Out:
# np.int64(0)

# %%
# Impute for Type F Sub Giant (IV) Star:

# Create mask for Type F Sub Giant (IV) stars
mask_FIV = (
    (new_exoplanets_filtered2["stellar_effective_temp_k"] >= 6000) & (new_exoplanets_filtered2["stellar_effective_temp_k"] < 7500) &
    (new_exoplanets_filtered2["stellar_mass_solar_mass"] >= 1.2) & (new_exoplanets_filtered2["stellar_mass_solar_mass"] < 2) &
    (new_exoplanets_filtered2["stellar_rad_solar_rad"] >= 1.2) & (new_exoplanets_filtered2["stellar_rad_solar_rad"] < 5) &
    (new_exoplanets_filtered2["stellar_luminosity_solar_lum"] >= 4) & (new_exoplanets_filtered2["stellar_luminosity_solar_lum"] < 20)
)

# Impute only where spectral_type is missing
new_exoplanets_filtered2.loc[
    new_exoplanets_filtered2["spectral_type"].isna() & mask_star_calculation & mask_FIV,
    "spectral_type"
] = "FIV"

# checking if AIV was added
(new_exoplanets_filtered2["spectral_type"] == "FIV").sum()
# Out:
# np.int64(53)

# %%
# Impute for Type G Sub Giant (IV) Star:

# Create mask for Type G Sub Giant (IV) stars
mask_GIV = (
    (new_exoplanets_filtered2["stellar_effective_temp_k"] >= 5200) & (new_exoplanets_filtered2["stellar_effective_temp_k"] < 6000) &
    (new_exoplanets_filtered2["stellar_mass_solar_mass"] >= 1) & (new_exoplanets_filtered2["stellar_mass_solar_mass"] < 1.6) &
    (new_exoplanets_filtered2["stellar_rad_solar_rad"] >= 1.45) & (new_exoplanets_filtered2["stellar_rad_solar_rad"] < 6) &
    (new_exoplanets_filtered2["stellar_luminosity_solar_lum"] >= 2) & (new_exoplanets_filtered2["stellar_luminosity_solar_lum"] < 10)
)

# Impute only where spectral_type is missing
new_exoplanets_filtered2.loc[
    new_exoplanets_filtered2["spectral_type"].isna() & mask_star_calculation & mask_GIV,
    "spectral_type"
] = "GIV"

# checking if AIV was added
(new_exoplanets_filtered2["spectral_type"] == "GIV").sum()
# Out:
# np.int64(16)

# %%
# Impute for Type K Sub Giant (IV) Star:

# Create mask for Type K Sub Giant (IV) stars
mask_KIV = (
    (new_exoplanets_filtered2["stellar_effective_temp_k"] >= 3700) & (new_exoplanets_filtered2["stellar_effective_temp_k"] < 5200) &
    (new_exoplanets_filtered2["stellar_mass_solar_mass"] >= 0.8) & (new_exoplanets_filtered2["stellar_mass_solar_mass"] < 2.6) &
    (new_exoplanets_filtered2["stellar_rad_solar_rad"] >= 1.5) & (new_exoplanets_filtered2["stellar_rad_solar_rad"] < 8) &
    (new_exoplanets_filtered2["stellar_luminosity_solar_lum"] >= 1) & (new_exoplanets_filtered2["stellar_luminosity_solar_lum"] < 25)
)

# Impute only where spectral_type is missing
new_exoplanets_filtered2.loc[
    new_exoplanets_filtered2["spectral_type"].isna() & mask_star_calculation & mask_KIV,
    "spectral_type"
] = "KIV"

# checking if AIV was added
(new_exoplanets_filtered2["spectral_type"] == "KIV").sum()
# Out:
# np.int64(68)

# %% [markdown]
# #### Giant (III) Spectral Type Imputation:

# %%
# Impute for Type O Giant (III) Star:

# Create mask for Type O Giant (III) stars
mask_OIII = (
    (new_exoplanets_filtered2["stellar_effective_temp_k"] >= 30000) &
    (new_exoplanets_filtered2["stellar_mass_solar_mass"] >= 20) &
    (new_exoplanets_filtered2["stellar_rad_solar_rad"] >= 15) &
    (new_exoplanets_filtered2["stellar_luminosity_solar_lum"] >= 100000)
)

# Impute only where spectral_type is missing
new_exoplanets_filtered2.loc[
    new_exoplanets_filtered2["spectral_type"].isna() & mask_star_calculation & mask_OIII,
    "spectral_type"
] = "OIII"

# checking if OIII was added
(new_exoplanets_filtered2["spectral_type"] == "OIII").sum()
# Out:
# np.int64(0)

# %%
# Impute for Type B Giant (III) Star:

# Create mask for Type B Giant (III) stars
mask_BIII = (
    (new_exoplanets_filtered2["stellar_effective_temp_k"] >= 10000) & (new_exoplanets_filtered2["stellar_effective_temp_k"] < 30000) &
    (new_exoplanets_filtered2["stellar_mass_solar_mass"] >= 5) & (new_exoplanets_filtered2["stellar_mass_solar_mass"] < 20) &
    (new_exoplanets_filtered2["stellar_rad_solar_rad"] >= 5) & (new_exoplanets_filtered2["stellar_rad_solar_rad"] < 20) &
    (new_exoplanets_filtered2["stellar_luminosity_solar_lum"] >= 1000) & (new_exoplanets_filtered2["stellar_luminosity_solar_lum"] < 100000)
)

# Impute only where spectral_type is missing
new_exoplanets_filtered2.loc[
    new_exoplanets_filtered2["spectral_type"].isna() & mask_star_calculation & mask_BIII,
    "spectral_type"
] = "BIII"

# checking if BIII was added
(new_exoplanets_filtered2["spectral_type"] == "BIII").sum()
# Out:
# np.int64(0)

# %%
# Impute for Type A Giant (III) Star:

# Create mask for Type A Giant (III) stars
mask_AIII = (
    (new_exoplanets_filtered2["stellar_effective_temp_k"] >= 7000) & (new_exoplanets_filtered2["stellar_effective_temp_k"] < 10000) &
    (new_exoplanets_filtered2["stellar_mass_solar_mass"] >= 2) & (new_exoplanets_filtered2["stellar_mass_solar_mass"] < 5) &
    (new_exoplanets_filtered2["stellar_rad_solar_rad"] >= 5) & (new_exoplanets_filtered2["stellar_rad_solar_rad"] < 15) &
    (new_exoplanets_filtered2["stellar_luminosity_solar_lum"] >= 50) & (new_exoplanets_filtered2["stellar_luminosity_solar_lum"] < 500)
)

# Impute only where spectral_type is missing
new_exoplanets_filtered2.loc[
    new_exoplanets_filtered2["spectral_type"].isna() & mask_star_calculation & mask_AIII,
    "spectral_type"
] = "AIII"

# checking if AIII was added
(new_exoplanets_filtered2["spectral_type"] == "AIII").sum()
# Out:
# np.int64(0)

# %%
# Impute for Type F Giant (III) Star:

# Create mask for Type F Giant (III) stars
mask_FIII = (
    (new_exoplanets_filtered2["stellar_effective_temp_k"] >=6000) & (new_exoplanets_filtered2["stellar_effective_temp_k"] < 7000) &
    (new_exoplanets_filtered2["stellar_mass_solar_mass"] >= 1.5) & (new_exoplanets_filtered2["stellar_mass_solar_mass"] < 3) &
    (new_exoplanets_filtered2["stellar_rad_solar_rad"] >= 5) & (new_exoplanets_filtered2["stellar_rad_solar_rad"] < 20) &
    (new_exoplanets_filtered2["stellar_luminosity_solar_lum"] >= 20) & (new_exoplanets_filtered2["stellar_luminosity_solar_lum"] < 200)
)

# Impute only where spectral_type is missing
new_exoplanets_filtered2.loc[
    new_exoplanets_filtered2["spectral_type"].isna() & mask_star_calculation & mask_FIII,
    "spectral_type"
] = "FIII"

# checking if FIII was added
(new_exoplanets_filtered2["spectral_type"] == "FIII").sum()
# Out:
# np.int64(0)

# %%
# Impute for Type G Giant (III) Star:

# Create mask for Type G Giant (III) stars
mask_GIII = (
    (new_exoplanets_filtered2["stellar_effective_temp_k"] >=5000) & (new_exoplanets_filtered2["stellar_effective_temp_k"] < 6000) &
    (new_exoplanets_filtered2["stellar_mass_solar_mass"] >= 0) & (new_exoplanets_filtered2["stellar_mass_solar_mass"] < 3) &
    (new_exoplanets_filtered2["stellar_rad_solar_rad"] >= 8) & (new_exoplanets_filtered2["stellar_rad_solar_rad"] < 30) &
    (new_exoplanets_filtered2["stellar_luminosity_solar_lum"] >= 30) & (new_exoplanets_filtered2["stellar_luminosity_solar_lum"] < 300)
)

# Impute only where spectral_type is missing
new_exoplanets_filtered2.loc[
    new_exoplanets_filtered2["spectral_type"].isna() & mask_star_calculation & mask_GIII,
    "spectral_type"
] = "GIII"

# checking if GIII was added
(new_exoplanets_filtered2["spectral_type"] == "GIII").sum()
# Out:
# np.int64(0)

# %%
# Impute for Type K Giant (III) Star:

# Create mask for Type K Giant (III) stars
mask_KIII = (
    (new_exoplanets_filtered2["stellar_effective_temp_k"] >=3900) & (new_exoplanets_filtered2["stellar_effective_temp_k"] < 5000) &
    (new_exoplanets_filtered2["stellar_mass_solar_mass"] >= 0) & (new_exoplanets_filtered2["stellar_mass_solar_mass"] < 3.8) &
    (new_exoplanets_filtered2["stellar_rad_solar_rad"] >= 8) & (new_exoplanets_filtered2["stellar_rad_solar_rad"] < 51) &
    (new_exoplanets_filtered2["stellar_luminosity_solar_lum"] >= 30) & (new_exoplanets_filtered2["stellar_luminosity_solar_lum"] < 930)
)

# Impute only where spectral_type is missing
new_exoplanets_filtered2.loc[
    new_exoplanets_filtered2["spectral_type"].isna() & mask_star_calculation & mask_KIII,
    "spectral_type"
] = "KIII"

# checking if KIII was added
(new_exoplanets_filtered2["spectral_type"] == "KIII").sum()
# Out:
# np.int64(23)

# %%
# Impute for Type M Giant (III) Star:

# Create mask for Type M Giant (III) stars
mask_MIII = (
    (new_exoplanets_filtered2["stellar_effective_temp_k"] >=2800) & (new_exoplanets_filtered2["stellar_effective_temp_k"] < 3900) &
    (new_exoplanets_filtered2["stellar_mass_solar_mass"] >= 1) & (new_exoplanets_filtered2["stellar_mass_solar_mass"] < 5) &
    (new_exoplanets_filtered2["stellar_rad_solar_rad"] >= 20) & (new_exoplanets_filtered2["stellar_rad_solar_rad"] < 200) &
    (new_exoplanets_filtered2["stellar_luminosity_solar_lum"] >= 3) & (new_exoplanets_filtered2["stellar_luminosity_solar_lum"] < 30)
)

# Impute only where spectral_type is missing
new_exoplanets_filtered2.loc[
    new_exoplanets_filtered2["spectral_type"].isna() & mask_star_calculation & mask_MIII,
    "spectral_type"
] = "MIII"

# checking if MIII was added
(new_exoplanets_filtered2["spectral_type"] == "MIII").sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### White Dwarf (WD) Spectral Type Imputation:

# %%
# Impute for White Dwarf (WD) Star:

# Create mask for White Dwarf (WD) stars
mask_WD = (
    (new_exoplanets_filtered2["stellar_effective_temp_k"] >= 4700) & (new_exoplanets_filtered2["stellar_effective_temp_k"] < 16000) &
    (new_exoplanets_filtered2["stellar_mass_solar_mass"] < 0.7) &
    (new_exoplanets_filtered2["stellar_rad_solar_rad"] < 0.016) &
    (new_exoplanets_filtered2["stellar_luminosity_solar_lum"] < 0.01)
)

# Impute only where spectral_type is missing
new_exoplanets_filtered2.loc[
    new_exoplanets_filtered2["spectral_type"].isna() & mask_star_calculation & mask_WD,
    "spectral_type"
] = "WD"

# checking if MIII was added
(new_exoplanets_filtered2["spectral_type"] == "WD").sum()
# Out:
# np.int64(7)

# %%
cols_to_show6 = [
    "host_star_name",
    "spectral_type",
    "star_number_per_system",
    "stellar_effective_temp_k",
    "stellar_mass_solar_mass",
    "stellar_rad_solar_rad",
    "stellar_luminosity_solar_lum",
    "stellar_mass_imputation_method"
]

# checking which spectral type contains 'WD'
new_exoplanets_filtered2[new_exoplanets_filtered2["spectral_type"].str.contains("WD") == True][cols_to_show6]
# Out:
#           host_star_name spectral_type  star_number_per_system  \
# 1992  KMT-2020-BLG-0414L            WD                     1.0
# 1993  KMT-2020-BLG-0414L            WD                     1.0
# 4957              NN Ser            WD                     2.0
# 4958              NN Ser            WD                     2.0
# 5995         WD 1856+534            WD                     3.0
# 6023      ZTF J1230-2655            WD                     1.0
# 6024      ZTF J1828+2308            WD                     1.0
#
#       stellar_effective_temp_k  stellar_mass_solar_mass  \
# 1992                       NaN                    0.490
# 1993                       NaN                    0.490
# 4957                   57000.0                    0.535
# 4958                   57000.0                    0.535
# 5995                    4710.0                    0.518
# 6023                   10000.0                    0.646
# 6024                   15900.0                    0.610
#
#       stellar_rad_solar_rad  stellar_luminosity_solar_lum  \
# 1992                    NaN                           NaN
# 1993                    NaN                           NaN
# 4957                    NaN                           NaN
# 4958                    NaN                           NaN
# 5995                 0.0131                      0.000076
# 6023                 0.0123                      0.001357
# 6024                 0.0131                      0.009841
#
#      stellar_mass_imputation_method
# 1992                       observed
# 1993                       observed
# 4957                       observed
# 4958                       observed
# 5995                       observed
# 6023                       observed
# 6024                       observed

# %% [markdown]
# #### Sub Dwarf B (sdB) Spectral Type (For Pulsating Stars) Imputation:

# %%
# Impute for Sub Dwarf B (sdB) Pulsating Star:

# Create mask for Sub Dwarf B (sdB) Pulsating Star
mask_sdB = (
    (new_exoplanets_filtered2["stellar_effective_temp_k"] >= 29000) & (new_exoplanets_filtered2["stellar_effective_temp_k"] < 40000) &
    (new_exoplanets_filtered2["stellar_mass_solar_mass"] >= 0.4) & (new_exoplanets_filtered2["stellar_mass_solar_mass"] < 0.6) &
    (new_exoplanets_filtered2["stellar_rad_solar_rad"] >= 0.1) & (new_exoplanets_filtered2["stellar_rad_solar_rad"] < 0.25) &
    (new_exoplanets_filtered2["stellar_luminosity_solar_lum"] >= 23) & (new_exoplanets_filtered2["stellar_luminosity_solar_lum"] < 85)
)

# Impute only where spectral_type is missing
new_exoplanets_filtered2.loc[
    new_exoplanets_filtered2["spectral_type"].isna() & mask_star_calculation & mask_sdB,
    "spectral_type"
] = "sdB"

# checking if sdB was added
(new_exoplanets_filtered2["spectral_type"] == "sdB").sum()
# Out:
# np.int64(6)

# %% [markdown]
# #### HW Virginis (HW Vir) Spectral Type (For Eclipsing Binary Stars) Imputation:

# %%
# Impute for HW Virginis (HW Vir) Eclipsing Binary Star:

# Create mask for HW Virginis (HW Vir) Eclipsing Binary stars
mask_HW_Vir = (
    (new_exoplanets_filtered2["stellar_effective_temp_k"] >= 29000) & (new_exoplanets_filtered2["stellar_effective_temp_k"] < 40000) &
    (new_exoplanets_filtered2["stellar_mass_solar_mass"] >= 0.4) & (new_exoplanets_filtered2["stellar_mass_solar_mass"] < 0.5) &
    (new_exoplanets_filtered2["stellar_rad_solar_rad"] >= 0.1) & (new_exoplanets_filtered2["stellar_rad_solar_rad"] < 0.21) &
    (new_exoplanets_filtered2["stellar_luminosity_solar_lum"] >= 23) & (new_exoplanets_filtered2["stellar_luminosity_solar_lum"] < 85) &
    (new_exoplanets_filtered2["star_number_per_system"] == 2)
)

# Impute only where spectral_type is missing
new_exoplanets_filtered2.loc[
    new_exoplanets_filtered2["spectral_type"].isna() & mask_star_calculation & mask_HW_Vir,
    "spectral_type"
] = "HW Vir"

# checking if HW Vir was added
(new_exoplanets_filtered2["spectral_type"] == "HW Vir").sum()
# Out:
# np.int64(0)

# %%
# checking if imputation successful for spectral type column
missing_percentage = (new_exoplanets_filtered2.isnull().sum() / len(new_exoplanets_filtered2))
((missing_percentage * 100).sort_values(ascending=False)).map(lambda x: f"{x:.2f}%")
# Out:
# planet_mass_jupiter_mass          47.62%
# planet_rad_jupiter_rad            24.91%
# orbital_eccentricity              14.87%
# stellar_metallicity               11.68%
# stellar_luminosity_solar_lum      10.38%
# stellar_rad_solar_rad              9.98%
# planet_equil_temp_k                9.55%
# stellar_surf_grav                  8.17%
# stellar_effective_temp_k           7.68%
# spectral_type                      6.89%
# distance_parsec                    2.03%
# planet_orbital_velocity            0.51%
# orbital_period_day                 0.44%
# stellar_mass_solar_mass            0.41%
# orbit_semi_major_axis_au           0.18%
# planet_mass_earth_mass             0.12%
# planet_rad_earth_rad               0.12%
# discovery_facility                 0.00%
# year_of_discovery                  0.00%
# discovery_method                   0.00%
# host_star_name                     0.00%
# planet_name                        0.00%
# star_number_per_system             0.00%
# stellar_mass_imputation_method     0.00%
# dtype: object

# %% [markdown]
# ### Fixing Inconsistencies within Spectral Type Column

# %%
# Importing
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
#new_exoplanets_filtered2.to_csv('filtered_2026_dataset_new_final2.csv', index=False)

# %%
# loading dataset
new_exoplanets_filtered3 = pd.read_csv('/content/drive/MyDrive/Exoplanet /filtered_2026_dataset_new_final2.csv')

# %% [markdown]
# #### Understanding the dataset now that we have populated the spectral_type column

# %%
# Finding the count of entries in the spectral_type column which contain missing values
total_count = len(new_exoplanets_filtered3['spectral_type'])
non_missing_entries_count = new_exoplanets_filtered3['spectral_type'].count()
missing_entries_count = total_count - non_missing_entries_count

print('The Total number of rows in the column (including missing values) :', total_count)
print('The number of entries in the column that have data is: ', non_missing_entries_count)
print('Number of missing entries: ', missing_entries_count)
# Out:
# The Total number of rows in the column (including missing values) : 6071
# The number of entries in the column that have data is:  5653
# Number of missing entries:  418

# %%
cols_to_show6 = [
    "host_star_name",
    "spectral_type",
    "star_number_per_system",
    "stellar_effective_temp_k",
    "stellar_mass_solar_mass",
    "stellar_rad_solar_rad",
    "stellar_luminosity_solar_lum",
    "stellar_mass_imputation_method"
]

# Finding the entries in the spectral_type column which contain \ or / or - or +
# r is known as raw string and it treats the backslashes inside the string literally and not as escape characters. Without the r, you'd need to double the backslashes (e.g., \\)
# na=False handles the missing entries
contains_dash_or_slash_df = new_exoplanets_filtered3[new_exoplanets_filtered3['spectral_type'].str.contains(r'[\/\\\-+]', na=False)][cols_to_show6]

# List out the filtered entries
print("Entries that contain '\' or /' or '-' or '+:")
print(contains_dash_or_slash_df)

# Get the count of such entries
count = len(contains_dash_or_slash_df)
print(f"Count of entries that contain '\' or '/' or '-' or '+': {count} entries")
# Out:
# Entries that contain '' or /' or '-' or '+:
#                  host_star_name spectral_type  star_number_per_system  \
# 12    2MASS J01033563-5515561 A       M5.5/M6                     2.0
# 76                   BD-06 1339       K7/M0 V                     1.0
# 77                   BD-06 1339       K7/M0 V                     1.0
# 90               Barnard's star      M3.5-4 V                     1.0
# 91               Barnard's star      M3.5-4 V                     1.0
# ...                         ...           ...                     ...
# 5884                   WASP-178       A1 IV-V                     1.0
# 5898                   WASP-190       F6 IV-V                     1.0
# 6036                    gam Cep     K1 III-IV                     2.0
# 6044                    kap CrB     K0 III-IV                     1.0
# 6052                    omi UMa     G4 II-III                     2.0
#
#       stellar_effective_temp_k  stellar_mass_solar_mass  \
# 12                         NaN                 0.190000
# 76                      4324.0                 0.700000
# 77                      4324.0                 0.700000
# 90                      3195.0                 0.162000
# 91                      3195.0                 0.162000
# ...                        ...                      ...
# 5884                    9000.0                 2.000000
# 5898                    6400.0                 1.350000
# 6036                    4831.5                 1.356667
# 6044                    4880.0                 1.452500
# 6052                    5158.5                 2.905000
#
#       stellar_rad_solar_rad  stellar_luminosity_solar_lum  \
# 12                      NaN                           NaN
# 76                      NaN                           NaN
# 77                      NaN                           NaN
# 90                 0.185000                      0.003200
# 91                 0.185000                      0.003200
# ...                     ...                           ...
# 5884               1.670000                     16.416963
# 5898               1.600000                      3.853450
# 6036               4.740000                     10.984353
# 6044               4.813347                     11.788632
# 6052              13.970000                    123.987071
#
#      stellar_mass_imputation_method
# 12                         observed
# 76                         observed
# 77                         observed
# 90                         observed
# 91                         observed
# ...                             ...
# 5884                       observed
# 5898                       observed
# 6036                       observed
# 6044                       observed
# 6052                       observed
#
# [114 rows x 8 columns]
# Count of entries that contain '' or '/' or '-' or '+': 114 entries

# %%
contains_dash_or_slash_df
# Out:
#                  host_star_name spectral_type  star_number_per_system  \
# 12    2MASS J01033563-5515561 A       M5.5/M6                     2.0
# 76                   BD-06 1339       K7/M0 V                     1.0
# 77                   BD-06 1339       K7/M0 V                     1.0
# 90               Barnard's star      M3.5-4 V                     1.0
# 91               Barnard's star      M3.5-4 V                     1.0
# ...                         ...           ...                     ...
# 5884                   WASP-178       A1 IV-V                     1.0
# 5898                   WASP-190       F6 IV-V                     1.0
# 6036                    gam Cep     K1 III-IV                     2.0
# 6044                    kap CrB     K0 III-IV                     1.0
# 6052                    omi UMa     G4 II-III                     2.0
#
#       stellar_effective_temp_k  stellar_mass_solar_mass  \
# 12                         NaN                 0.190000
# 76                      4324.0                 0.700000
# 77                      4324.0                 0.700000
# 90                      3195.0                 0.162000
# 91                      3195.0                 0.162000
# ...                        ...                      ...
# 5884                    9000.0                 2.000000
# 5898                    6400.0                 1.350000
# 6036                    4831.5                 1.356667
# 6044                    4880.0                 1.452500
# 6052                    5158.5                 2.905000
#
#       stellar_rad_solar_rad  stellar_luminosity_solar_lum  \
# 12                      NaN                           NaN
# 76                      NaN                           NaN
# 77                      NaN                           NaN
# 90                 0.185000                      0.003200
# 91                 0.185000                      0.003200
# ...                     ...                           ...
# 5884               1.670000                     16.416963
# 5898               1.600000                      3.853450
# 6036               4.740000                     10.984353
# 6044               4.813347                     11.788632
# 6052              13.970000                    123.987071
#
#      stellar_mass_imputation_method
# 12                         observed
# 76                         observed
# 77                         observed
# 90                         observed
# 91                         observed
# ...                             ...
# 5884                       observed
# 5898                       observed
# 6036                       observed
# 6044                       observed
# 6052                       observed
#
# [114 rows x 8 columns]

# %%
# Viewing the unique entries that are possible in the spectral type column
new_exoplanets_filtered3['spectral_type'].unique()
# Out:
# array(['G8 III', 'K4 III', 'K0 III', 'K0 V', 'G2.5 V', 'K3 III', 'G6 III',
#        'K7 V', 'G3 IV', 'KIV', 'M V', 'M5.5/M6', 'M3.5 V', 'M6', 'M6 V',
#        nan, 'M8.5', 'M8', 'sdB', 'M3', 'K1 III', 'G0 V', 'G1 V', 'GV',
#        'F0 IV', 'M4.5 V', 'G8 V', 'K0 IV', 'G5 V', 'G3 III', 'K0',
#        'G5 III', 'K2 V', 'F8 V', 'M1', 'KV', 'KIII', 'K V', 'K2 II',
#        'K5 III', 'G', 'K1', 'K3', 'K7/M0 V', 'K3 V', 'FIV', 'K5 V', 'FV',
#        'G3 V', 'M3.5-4 V', 'M5.0 V', 'M1 V', 'M9-L1', 'M3.5', 'M3 V',
#        'K1 V', 'F6 V', 'F9 V', 'G2 V', 'G9 V', 'F8 IV', 'F9', 'G5', 'G2',
#        'G8/9 IV', 'F3 V', 'G2 IV', 'G0 VI', 'L1.5', 'M0.5', 'F5 V',
#        'F5-F8 V', 'G6 V', 'MV', 'G0', 'G8 IV/V', 'M7.25', 'M5.5 V',
#        'M4.0 V', 'M2.5 V', 'M 4.5V', 'M4 V', 'M4.5 Ve', 'K4.5', 'M0 V',
#        'M2 V', 'M1/M2 V', 'M3.0 V', 'M0.5 V', 'M0', 'M0.0', 'M2.5', 'M4',
#        'M1.5', 'M1.0 V', 'M2.0 V', 'M1.5 V', 'M4.0', 'M3.5 Ve',
#        'M0.5-1.0 V', 'M2', 'M1.0', 'K7', 'K6 V', 'F2', 'K7e V', 'K4',
#        'G4', 'F', 'F8', 'K', 'K2', 'G3', 'G8', 'F4', 'A8 V', 'AV', 'G V',
#        'F V', 'B9 Vne', 'G9 III', 'G5 IV', 'K4/5 V', 'G4 V', 'K2 III',
#        'K0.0 V', 'M1 III', 'K9 V', 'G7 IV-V', 'G7 III', 'G4 IV', 'K4 V',
#        'GIV', 'A0 V', 'G3 IV/V', 'F7 V', 'G7 IV', 'G2/G3 V', 'G1 IV',
#        'G9 IV-V', 'F5', 'M0.0 V', 'K0 IV-V', 'G9', 'G6', 'F8 IV/V',
#        'K1 IV', 'G3 IV-V', 'G3/5 V', 'G5 IV/V', 'G8 IV', 'K2.5 V',
#        'G6 IV', 'K3 IV', 'K0 III-IV', 'M2.5 III', 'G0 IV', 'K0-2 V',
#        'G2/G3 IV/V', 'K3/4 IV', 'G0/1 V', 'M2 III', 'F8/G0 IV/V',
#        'G8 III/IV', 'F9.5 V', 'K5', 'G1 IV/V', 'K4.5 V', 'M0 III',
#        'G4 IV-V', 'G1.5 V', 'G8-K0', 'K1 IV-V', 'G7 V', 'F6 IV',
#        'G8/K0 III', 'K 1III', 'G1-1.5 V', 'K0.5 V', 'G2/G3', 'G3/G5 V',
#        'A8 III', 'Be9.5/AO', 'K0/1 III', 'A9/F0', 'M0.5 Ve', 'A5 V',
#        'A2 V', 'B9 V', 'M', 'K2 III/IV', 'A5-A6', 'A5', 'F9 IV', 'K5.5',
#        'M4.5', 'G7 IV/V', 'M(3.5+/-0.5) V', 'G1', 'G7', 'M5 V', 'K7.5 V',
#        'M3.0', 'A', 'F4 V', 'F7', 'B9.5-A0', 'WD', 'F9V', 'B',
#        'K2 III-IV', 'F7 IV', 'F5 IV', 'G9/K0', 'm3 V', 'M6.5', 'M5',
#        'M(6.1 +/- 0.7) V', 'M(6.1+/-0.7) V', 'A8', 'A7 V', 'A8Ve', 'M9',
#        'G9 IV', 'M6.5+/-0.5', 'K9 V/M0 V', 'M4.5V-M5V', 'K7/M0', 'G5V',
#        'Am C', 'M4 +/- 0.5 V', 'F0', 'M4.5+/-0.5', 'M5V', 'M0.5+/-0.5 V',
#        'M4 +/- 0.5', 'M2+/-0.5', 'K8 V', 'M5.0+0.5-0.5', 'K2V', 'F9-F9.5',
#        'K1.5+/-1', 'G1/2 V', 'M4+/-0.5', 'F7/F8V', 'M5.5+/-0.5',
#        'M1.0+/-0.5', 'M3.5+/-0.5', 'K1/2 V', 'G8/G9', 'M3+/-1',
#        'M3.5 +/- 1.0', 'G2 IV-V', 'M5.0', 'F2 V', 'M4.0+/-0.5', 'F5V-G0V',
#        'G0/F9 V', 'M8.0 V', 'M7.0 V', 'DC', 'M7', 'M7.5', 'F6', 'K6',
#        'F1 V', 'A1 IV-V', 'F6 IV-V', 'DQ', 'T8.5', 'K3.5 V', 'F5V',
#        'B2.5 V', 'K1 III-IV', 'B9 IV', 'B2 IV', 'G4 II-III'], dtype=object)

# %%
# saving a copy of the contains_dash_or_slash_df as a dataframe
# contains_dash_or_slash_df.to_csv('contains_dash_or_slash_df.csv', index=False)

# %% [markdown]
# #### Addressing Spectral Type which has '/' or '-' between Luminosity Classes
# These spectral type entries are for stars which have disputed luminsoty classes. For ex. based on the star lifetime sequence, if a Main Sequence star (V) is suspected to grow to a Sub Giant (IV), it has most likely have become a Sub Giant (IV) so change the luminosity class from 'IV/V' or 'IV-V' to 'IV"

# %%
# IV/V becomes IV
# IV-V becomes IV
# III-IV becomes III
# III/IV becomes III
# II-III becomes II

new_exoplanets_filtered3.loc[:, 'spectral_type'] = (
    new_exoplanets_filtered3['spectral_type']
    .str.replace(
        r'\b(VII|VI|IV|V|III|II|I)(?:[\/-](VII|VI|IV|V|III|II|I))\b',
        r'\1',
        regex=True
    )
)

# %%
# checking if these changes were made to the spectral type column
new_exoplanets_filtered3['spectral_type'].unique()
# Out:
# array(['G8 III', 'K4 III', 'K0 III', 'K0 V', 'G2.5 V', 'K3 III', 'G6 III',
#        'K7 V', 'G3 IV', 'KIV', 'M V', 'M5.5/M6', 'M3.5 V', 'M6', 'M6 V',
#        nan, 'M8.5', 'M8', 'sdB', 'M3', 'K1 III', 'G0 V', 'G1 V', 'GV',
#        'F0 IV', 'M4.5 V', 'G8 V', 'K0 IV', 'G5 V', 'G3 III', 'K0',
#        'G5 III', 'K2 V', 'F8 V', 'M1', 'KV', 'KIII', 'K V', 'K2 II',
#        'K5 III', 'G', 'K1', 'K3', 'K7/M0 V', 'K3 V', 'FIV', 'K5 V', 'FV',
#        'G3 V', 'M3.5-4 V', 'M5.0 V', 'M1 V', 'M9-L1', 'M3.5', 'M3 V',
#        'K1 V', 'F6 V', 'F9 V', 'G2 V', 'G9 V', 'F8 IV', 'F9', 'G5', 'G2',
#        'G8/9 IV', 'F3 V', 'G2 IV', 'G0 VI', 'L1.5', 'M0.5', 'F5 V',
#        'F5-F8 V', 'G6 V', 'MV', 'G0', 'G8 IV', 'M7.25', 'M5.5 V',
#        'M4.0 V', 'M2.5 V', 'M 4.5V', 'M4 V', 'M4.5 Ve', 'K4.5', 'M0 V',
#        'M2 V', 'M1/M2 V', 'M3.0 V', 'M0.5 V', 'M0', 'M0.0', 'M2.5', 'M4',
#        'M1.5', 'M1.0 V', 'M2.0 V', 'M1.5 V', 'M4.0', 'M3.5 Ve',
#        'M0.5-1.0 V', 'M2', 'M1.0', 'K7', 'K6 V', 'F2', 'K7e V', 'K4',
#        'G4', 'F', 'F8', 'K', 'K2', 'G3', 'G8', 'F4', 'A8 V', 'AV', 'G V',
#        'F V', 'B9 Vne', 'G9 III', 'G5 IV', 'K4/5 V', 'G4 V', 'K2 III',
#        'K0.0 V', 'M1 III', 'K9 V', 'G7 IV', 'G7 III', 'G4 IV', 'K4 V',
#        'GIV', 'A0 V', 'F7 V', 'G2/G3 V', 'G1 IV', 'G9 IV', 'F5', 'M0.0 V',
#        'G9', 'G6', 'K1 IV', 'G3/5 V', 'K2.5 V', 'G6 IV', 'K3 IV',
#        'M2.5 III', 'G0 IV', 'K0-2 V', 'G2/G3 IV', 'K3/4 IV', 'G0/1 V',
#        'M2 III', 'F8/G0 IV', 'F9.5 V', 'K5', 'K4.5 V', 'M0 III', 'G1.5 V',
#        'G8-K0', 'G7 V', 'F6 IV', 'G8/K0 III', 'K 1III', 'G1-1.5 V',
#        'K0.5 V', 'G2/G3', 'G3/G5 V', 'A8 III', 'Be9.5/AO', 'K0/1 III',
#        'A9/F0', 'M0.5 Ve', 'A5 V', 'A2 V', 'B9 V', 'M', 'A5-A6', 'A5',
#        'F9 IV', 'K5.5', 'M4.5', 'M(3.5+/-0.5) V', 'G1', 'G7', 'M5 V',
#        'K7.5 V', 'M3.0', 'A', 'F4 V', 'F7', 'B9.5-A0', 'WD', 'F9V', 'B',
#        'F7 IV', 'F5 IV', 'G9/K0', 'm3 V', 'M6.5', 'M5',
#        'M(6.1 +/- 0.7) V', 'M(6.1+/-0.7) V', 'A8', 'A7 V', 'A8Ve', 'M9',
#        'M6.5+/-0.5', 'K9 V/M0 V', 'M4.5V-M5V', 'K7/M0', 'G5V', 'Am C',
#        'M4 +/- 0.5 V', 'F0', 'M4.5+/-0.5', 'M5V', 'M0.5+/-0.5 V',
#        'M4 +/- 0.5', 'M2+/-0.5', 'K8 V', 'M5.0+0.5-0.5', 'K2V', 'F9-F9.5',
#        'K1.5+/-1', 'G1/2 V', 'M4+/-0.5', 'F7/F8V', 'M5.5+/-0.5',
#        'M1.0+/-0.5', 'M3.5+/-0.5', 'K1/2 V', 'G8/G9', 'M3+/-1',
#        'M3.5 +/- 1.0', 'M5.0', 'F2 V', 'M4.0+/-0.5', 'F5V-G0V', 'G0/F9 V',
#        'M8.0 V', 'M7.0 V', 'DC', 'M7', 'M7.5', 'F6', 'K6', 'F1 V',
#        'A1 IV', 'DQ', 'T8.5', 'K3.5 V', 'F5V', 'B2.5 V', 'B9 IV', 'B2 IV',
#        'G4 II'], dtype=object)

# %% [markdown]
# #### Ensuring Spectral Type Consistency for White Dwarf
# * If a spectral type contains the luminosity class of 'VII', this is a White Dawrf, this must become 'WD'
# * If a spectral type contains the star type of 'DC', this is a specific type of white drawf, this must become 'WD'
# * If a spectral type contains the star type of 'DQ', this is a specific type of white drawf, this must become 'WD'

# %%
# checking which spectral type contains 'VII'
new_exoplanets_filtered3[new_exoplanets_filtered3["spectral_type"].str.contains("VII") == True][cols_to_show6]
# There are no white dwwrfs with VII, only WD. So, no correction needed
# Out:
# Empty DataFrame
# Columns: [host_star_name, spectral_type, star_number_per_system, stellar_effective_temp_k, stellar_mass_solar_mass, stellar_rad_solar_rad, stellar_luminosity_solar_lum, stellar_mass_imputation_method]
# Index: []

# %%
# checking which spectral type contains 'DC'
new_exoplanets_filtered3[new_exoplanets_filtered3["spectral_type"].str.contains("DC") == True][cols_to_show6]
# Out:
#         host_star_name spectral_type  star_number_per_system  \
# 5789  UCAC4 328-061594            DC                     1.0
#
#       stellar_effective_temp_k  stellar_mass_solar_mass  \
# 5789                       NaN                     1.19
#
#       stellar_rad_solar_rad  stellar_luminosity_solar_lum  \
# 5789                    NaN                           NaN
#
#      stellar_mass_imputation_method
# 5789                       observed

# %%
# checking which spectral type contains 'DQ'
new_exoplanets_filtered3[new_exoplanets_filtered3["spectral_type"].str.contains("DQ") == True][cols_to_show6]
# Out:
#      host_star_name spectral_type  star_number_per_system  \
# 5994    WD 0806-661            DQ                     1.0
#
#       stellar_effective_temp_k  stellar_mass_solar_mass  \
# 5994                       NaN                     0.62
#
#       stellar_rad_solar_rad  stellar_luminosity_solar_lum  \
# 5994                    NaN                           NaN
#
#      stellar_mass_imputation_method
# 5994                       observed

# %%
# Replace star type DC or DQ with WD (white dwarf)
new_exoplanets_filtered3.loc[:, "spectral_type"] = (
    new_exoplanets_filtered3["spectral_type"]
    .str.replace(r'DC|DQ', 'WD', regex=True)
)

# %%
# checking if these changes were made to the spectral type column
new_exoplanets_filtered3['spectral_type'].unique()
# Out:
# array(['G8 III', 'K4 III', 'K0 III', 'K0 V', 'G2.5 V', 'K3 III', 'G6 III',
#        'K7 V', 'G3 IV', 'KIV', 'M V', 'M5.5/M6', 'M3.5 V', 'M6', 'M6 V',
#        nan, 'M8.5', 'M8', 'sdB', 'M3', 'K1 III', 'G0 V', 'G1 V', 'GV',
#        'F0 IV', 'M4.5 V', 'G8 V', 'K0 IV', 'G5 V', 'G3 III', 'K0',
#        'G5 III', 'K2 V', 'F8 V', 'M1', 'KV', 'KIII', 'K V', 'K2 II',
#        'K5 III', 'G', 'K1', 'K3', 'K7/M0 V', 'K3 V', 'FIV', 'K5 V', 'FV',
#        'G3 V', 'M3.5-4 V', 'M5.0 V', 'M1 V', 'M9-L1', 'M3.5', 'M3 V',
#        'K1 V', 'F6 V', 'F9 V', 'G2 V', 'G9 V', 'F8 IV', 'F9', 'G5', 'G2',
#        'G8/9 IV', 'F3 V', 'G2 IV', 'G0 VI', 'L1.5', 'M0.5', 'F5 V',
#        'F5-F8 V', 'G6 V', 'MV', 'G0', 'G8 IV', 'M7.25', 'M5.5 V',
#        'M4.0 V', 'M2.5 V', 'M 4.5V', 'M4 V', 'M4.5 Ve', 'K4.5', 'M0 V',
#        'M2 V', 'M1/M2 V', 'M3.0 V', 'M0.5 V', 'M0', 'M0.0', 'M2.5', 'M4',
#        'M1.5', 'M1.0 V', 'M2.0 V', 'M1.5 V', 'M4.0', 'M3.5 Ve',
#        'M0.5-1.0 V', 'M2', 'M1.0', 'K7', 'K6 V', 'F2', 'K7e V', 'K4',
#        'G4', 'F', 'F8', 'K', 'K2', 'G3', 'G8', 'F4', 'A8 V', 'AV', 'G V',
#        'F V', 'B9 Vne', 'G9 III', 'G5 IV', 'K4/5 V', 'G4 V', 'K2 III',
#        'K0.0 V', 'M1 III', 'K9 V', 'G7 IV', 'G7 III', 'G4 IV', 'K4 V',
#        'GIV', 'A0 V', 'F7 V', 'G2/G3 V', 'G1 IV', 'G9 IV', 'F5', 'M0.0 V',
#        'G9', 'G6', 'K1 IV', 'G3/5 V', 'K2.5 V', 'G6 IV', 'K3 IV',
#        'M2.5 III', 'G0 IV', 'K0-2 V', 'G2/G3 IV', 'K3/4 IV', 'G0/1 V',
#        'M2 III', 'F8/G0 IV', 'F9.5 V', 'K5', 'K4.5 V', 'M0 III', 'G1.5 V',
#        'G8-K0', 'G7 V', 'F6 IV', 'G8/K0 III', 'K 1III', 'G1-1.5 V',
#        'K0.5 V', 'G2/G3', 'G3/G5 V', 'A8 III', 'Be9.5/AO', 'K0/1 III',
#        'A9/F0', 'M0.5 Ve', 'A5 V', 'A2 V', 'B9 V', 'M', 'A5-A6', 'A5',
#        'F9 IV', 'K5.5', 'M4.5', 'M(3.5+/-0.5) V', 'G1', 'G7', 'M5 V',
#        'K7.5 V', 'M3.0', 'A', 'F4 V', 'F7', 'B9.5-A0', 'WD', 'F9V', 'B',
#        'F7 IV', 'F5 IV', 'G9/K0', 'm3 V', 'M6.5', 'M5',
#        'M(6.1 +/- 0.7) V', 'M(6.1+/-0.7) V', 'A8', 'A7 V', 'A8Ve', 'M9',
#        'M6.5+/-0.5', 'K9 V/M0 V', 'M4.5V-M5V', 'K7/M0', 'G5V', 'Am C',
#        'M4 +/- 0.5 V', 'F0', 'M4.5+/-0.5', 'M5V', 'M0.5+/-0.5 V',
#        'M4 +/- 0.5', 'M2+/-0.5', 'K8 V', 'M5.0+0.5-0.5', 'K2V', 'F9-F9.5',
#        'K1.5+/-1', 'G1/2 V', 'M4+/-0.5', 'F7/F8V', 'M5.5+/-0.5',
#        'M1.0+/-0.5', 'M3.5+/-0.5', 'K1/2 V', 'G8/G9', 'M3+/-1',
#        'M3.5 +/- 1.0', 'M5.0', 'F2 V', 'M4.0+/-0.5', 'F5V-G0V', 'G0/F9 V',
#        'M8.0 V', 'M7.0 V', 'M7', 'M7.5', 'F6', 'K6', 'F1 V', 'A1 IV',
#        'T8.5', 'K3.5 V', 'F5V', 'B2.5 V', 'B9 IV', 'B2 IV', 'G4 II'],
#       dtype=object)

# %% [markdown]
# #### Ensuring Spectral Type Consistency for Sub Dwarf
# If a spectral type contains the luminosity class of 'VI' is a Sub Dawrf, this must become 'SD'

# %%
# checking which spectral type contains 'VI'
new_exoplanets_filtered3[new_exoplanets_filtered3["spectral_type"].str.contains("VI") == True][cols_to_show6]
# Out:
#     host_star_name spectral_type  star_number_per_system  \
# 128       CoRoT-32         G0 VI                     1.0
#
#      stellar_effective_temp_k  stellar_mass_solar_mass  stellar_rad_solar_rad  \
# 128                    5970.0                     1.08                   0.79
#
#      stellar_luminosity_solar_lum stellar_mass_imputation_method
# 128                      0.711281                       observed

# %%
# Replace luminosity class VI with SD (subdwarf)
new_exoplanets_filtered3.loc[:, "spectral_type"] = (
    new_exoplanets_filtered3["spectral_type"]
    .str.replace(r'.*VI.*', 'SD', regex=True)
)

# %%
# checking if change was made
new_exoplanets_filtered3[new_exoplanets_filtered3["host_star_name"] == "CoRoT-32"][cols_to_show6]
# Out:
#     host_star_name spectral_type  star_number_per_system  \
# 128       CoRoT-32            SD                     1.0
#
#      stellar_effective_temp_k  stellar_mass_solar_mass  stellar_rad_solar_rad  \
# 128                    5970.0                     1.08                   0.79
#
#      stellar_luminosity_solar_lum stellar_mass_imputation_method
# 128                      0.711281                       observed

# %% [markdown]
# #### Ensuring Spectral Type Consistency for Type B Main Sequence (V) - BV
# If a spectral type contains the luminosity class of 'Bne' this is a Type B Main Sequence Star (V). So, this must become 'V'

# %%
# checking which spectral type contains 'Vne'
new_exoplanets_filtered3[new_exoplanets_filtered3["spectral_type"].str.contains("Vne") == True][cols_to_show6]
# Out:
#     host_star_name spectral_type  star_number_per_system  \
# 506      HD 100546        B9 Vne                     1.0
#
#      stellar_effective_temp_k  stellar_mass_solar_mass  stellar_rad_solar_rad  \
# 506                   10500.0                      2.4                    NaN
#
#      stellar_luminosity_solar_lum stellar_mass_imputation_method
# 506                           NaN                       observed

# %%
# Replace luminosity class Vne with V (main sequence)
new_exoplanets_filtered3.loc[:, "spectral_type"] = (
    new_exoplanets_filtered3["spectral_type"]
    .str.replace(r'\bVne\b', 'V', regex=True)
)

# %%
# checking if change was made
new_exoplanets_filtered3[new_exoplanets_filtered3["host_star_name"] == "HD 100546"][cols_to_show6]
# Out:
#     host_star_name spectral_type  star_number_per_system  \
# 506      HD 100546          B9 V                     1.0
#
#      stellar_effective_temp_k  stellar_mass_solar_mass  stellar_rad_solar_rad  \
# 506                   10500.0                      2.4                    NaN
#
#      stellar_luminosity_solar_lum stellar_mass_imputation_method
# 506                           NaN                       observed

# %% [markdown]
# #### Ensuring Spectral Type Consistency for Main Sequence (V)
# If a spectral type contains the luminosity class of 'Ve' this is a typo which must be written as 'V'

# %%
# checking which spectral type contains 'Ve'
new_exoplanets_filtered3[new_exoplanets_filtered3["spectral_type"].str.contains("Ve") == True][cols_to_show6]
# Out:
#      host_star_name spectral_type  star_number_per_system  \
# 216         GJ 1289       M4.5 Ve                     1.0
# 291          GJ 480       M3.5 Ve                     1.0
# 1349      HIP 48714       M0.5 Ve                     1.0
# 4922        MWC 758          A8Ve                     1.0
#
#       stellar_effective_temp_k  stellar_mass_solar_mass  \
# 216                     3296.0                     0.21
# 291                        NaN                     0.45
# 1349                       NaN                     0.58
# 4922                       NaN                     1.50
#
#       stellar_rad_solar_rad  stellar_luminosity_solar_lum  \
# 216                     NaN                           NaN
# 291                     NaN                           NaN
# 1349                    NaN                           NaN
# 4922                    NaN                           NaN
#
#      stellar_mass_imputation_method
# 216                        observed
# 291                        observed
# 1349                       observed
# 4922                       observed

# %%
# Replace luminosity class Ve with V (main sequence)
new_exoplanets_filtered3.loc[:, "spectral_type"] = (
    new_exoplanets_filtered3["spectral_type"]
    .str.replace(r'Ve', 'V', regex=True)
)

# %%
# checking if changes were made
new_exoplanets_filtered3[new_exoplanets_filtered3["host_star_name"] == "HIP 48714"][cols_to_show6]
# Out:
#      host_star_name spectral_type  star_number_per_system  \
# 1349      HIP 48714        M0.5 V                     1.0
#
#       stellar_effective_temp_k  stellar_mass_solar_mass  \
# 1349                       NaN                     0.58
#
#       stellar_rad_solar_rad  stellar_luminosity_solar_lum  \
# 1349                    NaN                           NaN
#
#      stellar_mass_imputation_method
# 1349                       observed

# %%
# checking if changes were made
new_exoplanets_filtered3[new_exoplanets_filtered3["host_star_name"] == "MWC 758"][cols_to_show6]
# Out:
#      host_star_name spectral_type  star_number_per_system  \
# 4922        MWC 758           A8V                     1.0
#
#       stellar_effective_temp_k  stellar_mass_solar_mass  \
# 4922                       NaN                      1.5
#
#       stellar_rad_solar_rad  stellar_luminosity_solar_lum  \
# 4922                    NaN                           NaN
#
#      stellar_mass_imputation_method
# 4922                       observed

# %% [markdown]
# #### Ensuring Spectral Type Consistency for Type A Main Sequence (V) - AV
# If a spectral type entry is 'Am C', these are Type A Main Sequence (V) stars which display unusualy metalicity, for simplicity, these will be redefined as simple 'AV'

# %%
# checking which spectral type contains 'Am C'
new_exoplanets_filtered3[new_exoplanets_filtered3["spectral_type"].str.contains("Am C") == True][cols_to_show6]
# Out:
#      host_star_name spectral_type  star_number_per_system  \
# 5231       TOI-1431          Am C                     1.0
#
#       stellar_effective_temp_k  stellar_mass_solar_mass  \
# 5231                    7690.0                      1.9
#
#       stellar_rad_solar_rad  stellar_luminosity_solar_lum  \
# 5231                   1.92                     11.566386
#
#      stellar_mass_imputation_method
# 5231                       observed

# %%
# Replace luminosity class Am C with AV (Type A main sequence)
new_exoplanets_filtered3.loc[:, "spectral_type"] = (
    new_exoplanets_filtered3["spectral_type"]
    .str.replace(r'Am C', 'AV', regex=True)
)

# %%
# checking if changes were made
new_exoplanets_filtered3[new_exoplanets_filtered3["host_star_name"] == "TOI-1431"][cols_to_show6]
# Out:
#      host_star_name spectral_type  star_number_per_system  \
# 5231       TOI-1431            AV                     1.0
#
#       stellar_effective_temp_k  stellar_mass_solar_mass  \
# 5231                    7690.0                      1.9
#
#       stellar_rad_solar_rad  stellar_luminosity_solar_lum  \
# 5231                   1.92                     11.566386
#
#      stellar_mass_imputation_method
# 5231                       observed

# %%
# checking if these changes were made to the spectral type column
new_exoplanets_filtered3['spectral_type'].unique()
# Out:
# array(['G8 III', 'K4 III', 'K0 III', 'K0 V', 'G2.5 V', 'K3 III', 'G6 III',
#        'K7 V', 'G3 IV', 'KIV', 'M V', 'M5.5/M6', 'M3.5 V', 'M6', 'M6 V',
#        nan, 'M8.5', 'M8', 'sdB', 'M3', 'K1 III', 'G0 V', 'G1 V', 'GV',
#        'F0 IV', 'M4.5 V', 'G8 V', 'K0 IV', 'G5 V', 'G3 III', 'K0',
#        'G5 III', 'K2 V', 'F8 V', 'M1', 'KV', 'KIII', 'K V', 'K2 II',
#        'K5 III', 'G', 'K1', 'K3', 'K7/M0 V', 'K3 V', 'FIV', 'K5 V', 'FV',
#        'G3 V', 'M3.5-4 V', 'M5.0 V', 'M1 V', 'M9-L1', 'M3.5', 'M3 V',
#        'K1 V', 'F6 V', 'F9 V', 'G2 V', 'G9 V', 'F8 IV', 'F9', 'G5', 'G2',
#        'G8/9 IV', 'F3 V', 'G2 IV', 'SD', 'L1.5', 'M0.5', 'F5 V',
#        'F5-F8 V', 'G6 V', 'MV', 'G0', 'G8 IV', 'M7.25', 'M5.5 V',
#        'M4.0 V', 'M2.5 V', 'M 4.5V', 'M4 V', 'K4.5', 'M0 V', 'M2 V',
#        'M1/M2 V', 'M3.0 V', 'M0.5 V', 'M0', 'M0.0', 'M2.5', 'M4', 'M1.5',
#        'M1.0 V', 'M2.0 V', 'M1.5 V', 'M4.0', 'M0.5-1.0 V', 'M2', 'M1.0',
#        'K7', 'K6 V', 'F2', 'K7e V', 'K4', 'G4', 'F', 'F8', 'K', 'K2',
#        'G3', 'G8', 'F4', 'A8 V', 'AV', 'G V', 'F V', 'B9 V', 'G9 III',
#        'G5 IV', 'K4/5 V', 'G4 V', 'K2 III', 'K0.0 V', 'M1 III', 'K9 V',
#        'G7 IV', 'G7 III', 'G4 IV', 'K4 V', 'GIV', 'A0 V', 'F7 V',
#        'G2/G3 V', 'G1 IV', 'G9 IV', 'F5', 'M0.0 V', 'G9', 'G6', 'K1 IV',
#        'G3/5 V', 'K2.5 V', 'G6 IV', 'K3 IV', 'M2.5 III', 'G0 IV',
#        'K0-2 V', 'G2/G3 IV', 'K3/4 IV', 'G0/1 V', 'M2 III', 'F8/G0 IV',
#        'F9.5 V', 'K5', 'K4.5 V', 'M0 III', 'G1.5 V', 'G8-K0', 'G7 V',
#        'F6 IV', 'G8/K0 III', 'K 1III', 'G1-1.5 V', 'K0.5 V', 'G2/G3',
#        'G3/G5 V', 'A8 III', 'Be9.5/AO', 'K0/1 III', 'A9/F0', 'A5 V',
#        'A2 V', 'M', 'A5-A6', 'A5', 'F9 IV', 'K5.5', 'M4.5',
#        'M(3.5+/-0.5) V', 'G1', 'G7', 'M5 V', 'K7.5 V', 'M3.0', 'A',
#        'F4 V', 'F7', 'B9.5-A0', 'WD', 'F9V', 'B', 'F7 IV', 'F5 IV',
#        'G9/K0', 'm3 V', 'M6.5', 'M5', 'M(6.1 +/- 0.7) V',
#        'M(6.1+/-0.7) V', 'A8', 'A7 V', 'A8V', 'M9', 'M6.5+/-0.5',
#        'K9 V/M0 V', 'M4.5V-M5V', 'K7/M0', 'G5V', 'M4 +/- 0.5 V', 'F0',
#        'M4.5+/-0.5', 'M5V', 'M0.5+/-0.5 V', 'M4 +/- 0.5', 'M2+/-0.5',
#        'K8 V', 'M5.0+0.5-0.5', 'K2V', 'F9-F9.5', 'K1.5+/-1', 'G1/2 V',
#        'M4+/-0.5', 'F7/F8V', 'M5.5+/-0.5', 'M1.0+/-0.5', 'M3.5+/-0.5',
#        'K1/2 V', 'G8/G9', 'M3+/-1', 'M3.5 +/- 1.0', 'M5.0', 'F2 V',
#        'M4.0+/-0.5', 'F5V-G0V', 'G0/F9 V', 'M8.0 V', 'M7.0 V', 'M7',
#        'M7.5', 'F6', 'K6', 'F1 V', 'A1 IV', 'T8.5', 'K3.5 V', 'F5V',
#        'B2.5 V', 'B9 IV', 'B2 IV', 'G4 II'], dtype=object)

# %% [markdown]
# #### Removing White Space from Entries in Spectral Type Column

# %%
# removing all white space in spectral type column
new_exoplanets_filtered3["spectral_type"] = new_exoplanets_filtered3["spectral_type"].str.replace(r'\s+', '', regex=True)

# %%
# checking if these changes were made to the spectral type column
new_exoplanets_filtered3['spectral_type'].unique()
# Out:
# array(['G8III', 'K4III', 'K0III', 'K0V', 'G2.5V', 'K3III', 'G6III', 'K7V',
#        'G3IV', 'KIV', 'MV', 'M5.5/M6', 'M3.5V', 'M6', 'M6V', nan, 'M8.5',
#        'M8', 'sdB', 'M3', 'K1III', 'G0V', 'G1V', 'GV', 'F0IV', 'M4.5V',
#        'G8V', 'K0IV', 'G5V', 'G3III', 'K0', 'G5III', 'K2V', 'F8V', 'M1',
#        'KV', 'KIII', 'K2II', 'K5III', 'G', 'K1', 'K3', 'K7/M0V', 'K3V',
#        'FIV', 'K5V', 'FV', 'G3V', 'M3.5-4V', 'M5.0V', 'M1V', 'M9-L1',
#        'M3.5', 'M3V', 'K1V', 'F6V', 'F9V', 'G2V', 'G9V', 'F8IV', 'F9',
#        'G5', 'G2', 'G8/9IV', 'F3V', 'G2IV', 'SD', 'L1.5', 'M0.5', 'F5V',
#        'F5-F8V', 'G6V', 'G0', 'G8IV', 'M7.25', 'M5.5V', 'M4.0V', 'M2.5V',
#        'M4V', 'K4.5', 'M0V', 'M2V', 'M1/M2V', 'M3.0V', 'M0.5V', 'M0',
#        'M0.0', 'M2.5', 'M4', 'M1.5', 'M1.0V', 'M2.0V', 'M1.5V', 'M4.0',
#        'M0.5-1.0V', 'M2', 'M1.0', 'K7', 'K6V', 'F2', 'K7eV', 'K4', 'G4',
#        'F', 'F8', 'K', 'K2', 'G3', 'G8', 'F4', 'A8V', 'AV', 'B9V',
#        'G9III', 'G5IV', 'K4/5V', 'G4V', 'K2III', 'K0.0V', 'M1III', 'K9V',
#        'G7IV', 'G7III', 'G4IV', 'K4V', 'GIV', 'A0V', 'F7V', 'G2/G3V',
#        'G1IV', 'G9IV', 'F5', 'M0.0V', 'G9', 'G6', 'K1IV', 'G3/5V',
#        'K2.5V', 'G6IV', 'K3IV', 'M2.5III', 'G0IV', 'K0-2V', 'G2/G3IV',
#        'K3/4IV', 'G0/1V', 'M2III', 'F8/G0IV', 'F9.5V', 'K5', 'K4.5V',
#        'M0III', 'G1.5V', 'G8-K0', 'G7V', 'F6IV', 'G8/K0III', 'G1-1.5V',
#        'K0.5V', 'G2/G3', 'G3/G5V', 'A8III', 'Be9.5/AO', 'K0/1III',
#        'A9/F0', 'A5V', 'A2V', 'M', 'A5-A6', 'A5', 'F9IV', 'K5.5', 'M4.5',
#        'M(3.5+/-0.5)V', 'G1', 'G7', 'M5V', 'K7.5V', 'M3.0', 'A', 'F4V',
#        'F7', 'B9.5-A0', 'WD', 'B', 'F7IV', 'F5IV', 'G9/K0', 'm3V', 'M6.5',
#        'M5', 'M(6.1+/-0.7)V', 'A8', 'A7V', 'M9', 'M6.5+/-0.5', 'K9V/M0V',
#        'M4.5V-M5V', 'K7/M0', 'M4+/-0.5V', 'F0', 'M4.5+/-0.5',
#        'M0.5+/-0.5V', 'M4+/-0.5', 'M2+/-0.5', 'K8V', 'M5.0+0.5-0.5',
#        'F9-F9.5', 'K1.5+/-1', 'G1/2V', 'F7/F8V', 'M5.5+/-0.5',
#        'M1.0+/-0.5', 'M3.5+/-0.5', 'K1/2V', 'G8/G9', 'M3+/-1',
#        'M3.5+/-1.0', 'M5.0', 'F2V', 'M4.0+/-0.5', 'F5V-G0V', 'G0/F9V',
#        'M8.0V', 'M7.0V', 'M7', 'M7.5', 'F6', 'K6', 'F1V', 'A1IV', 'T8.5',
#        'K3.5V', 'B2.5V', 'B9IV', 'B2IV', 'G4II'], dtype=object)

# %% [markdown]
# #### Removing all Numbers and Dots from Spectral Type column

# %%
# Remove all numbers and dots from spectral_type
new_exoplanets_filtered3["spectral_type"] = new_exoplanets_filtered3["spectral_type"].str.replace(r'[\d\.]+', '', regex=True)

# %%
# checking if these changes were made to the spectral type column
new_exoplanets_filtered3['spectral_type'].unique()
# Out:
# array(['GIII', 'KIII', 'KV', 'GV', 'GIV', 'KIV', 'MV', 'M/M', 'M', nan,
#        'sdB', 'FIV', 'K', 'FV', 'KII', 'G', 'K/MV', 'M-V', 'M-L', 'F',
#        'G/IV', 'SD', 'L', 'F-FV', 'M/MV', 'KeV', 'AV', 'BV', 'K/V',
#        'MIII', 'G/GV', 'G/V', 'K-V', 'G/GIV', 'K/IV', 'F/GIV', 'G-K',
#        'G/KIII', 'G-V', 'G/G', 'AIII', 'Be/AO', 'K/III', 'A/F', 'A-A',
#        'A', 'M(+/-)V', 'B-A', 'WD', 'B', 'G/K', 'mV', 'M+/-', 'KV/MV',
#        'MV-MV', 'K/M', 'M+/-V', 'M+-', 'F-F', 'K+/-', 'F/FV', 'FV-GV',
#        'G/FV', 'AIV', 'T', 'BIV', 'GII'], dtype=object)

# %% [markdown]
# #### Removing Special Characters from Spectral Type column

# %% [markdown]
# Removing the '+' Special Character

# %%
# remove the special characters '+' from the entries
new_exoplanets_filtered3.loc[:, 'spectral_type'] = (new_exoplanets_filtered3["spectral_type"].str.replace(r'[+]', '', regex=True))

# %%
# checking if column updated
new_exoplanets_filtered3['spectral_type'].unique()
# Out:
# array(['GIII', 'KIII', 'KV', 'GV', 'GIV', 'KIV', 'MV', 'M/M', 'M', nan,
#        'sdB', 'FIV', 'K', 'FV', 'KII', 'G', 'K/MV', 'M-V', 'M-L', 'F',
#        'G/IV', 'SD', 'L', 'F-FV', 'M/MV', 'KeV', 'AV', 'BV', 'K/V',
#        'MIII', 'G/GV', 'G/V', 'K-V', 'G/GIV', 'K/IV', 'F/GIV', 'G-K',
#        'G/KIII', 'G-V', 'G/G', 'AIII', 'Be/AO', 'K/III', 'A/F', 'A-A',
#        'A', 'M(/-)V', 'B-A', 'WD', 'B', 'G/K', 'mV', 'M/-', 'KV/MV',
#        'MV-MV', 'K/M', 'M/-V', 'M-', 'F-F', 'K/-', 'F/FV', 'FV-GV',
#        'G/FV', 'AIV', 'T', 'BIV', 'GII'], dtype=object)

# %% [markdown]
# Replacing common typos and disbuted star types based on known statisics of star abundance

# %%
# Mapping of patterns for replacement (based on known statisics of how abundant each star type is in the galaxy)
pattern_map = {
    r'M/M': 'M',
    r'K/M': 'M',
    r'M-L': 'M',
    r'F-F': 'F',
    r'F/F': 'F',
    r'G/G': 'G',
    r'F/G': 'G',
    r'G/F': 'G',
    r'G-K': 'G',
    r'G/K': 'G',
    r'A/F': 'F',
    r'A-A': 'A',
    r'B-A': 'A',
    r'KV/MV': 'MV',
    r'MV-MV': 'MV',
    r'FV-GV': 'GV',
    r'Be/AO': 'AV',
    r'KeV': 'KV',
    r'mV': 'MV'
}

# Function to apply replacements
def replace_spectral(match):
    matched_text = match.group(0)
    return pattern_map[matched_text]

# Create a regex pattern that matches any key in the dictionary
combined_pattern = '|'.join(pattern_map.keys())

# Apply the replacement
new_exoplanets_filtered3['spectral_type'] = new_exoplanets_filtered3['spectral_type'].str.replace(
    combined_pattern,
    lambda m: pattern_map[m.group(0)],
    regex=True
)

# %%
# checking if column updated
new_exoplanets_filtered3['spectral_type'].unique()
# Out:
# array(['GIII', 'KIII', 'KV', 'GV', 'GIV', 'KIV', 'MV', 'M', nan, 'sdB',
#        'FIV', 'K', 'FV', 'KII', 'G', 'M-V', 'F', 'G/IV', 'SD', 'L', 'AV',
#        'BV', 'K/V', 'MIII', 'G/V', 'K-V', 'K/IV', 'G-V', 'AIII', 'K/III',
#        'A', 'M(/-)V', 'WD', 'B', 'M/-', 'M/-V', 'M-', 'K/-', 'AIV', 'T',
#        'BIV', 'GII'], dtype=object)

# %% [markdown]
# Removing the '/' and '-' and '()' Special Character

# %%
# remove the special characters '/' and '-' and '()' from the entries
new_exoplanets_filtered3.loc[:, 'spectral_type'] = (new_exoplanets_filtered3["spectral_type"].str.replace(r'[\/\-()]', '', regex=True))

# %%
# checking if column updated
new_exoplanets_filtered3['spectral_type'].unique()
# Out:
# array(['GIII', 'KIII', 'KV', 'GV', 'GIV', 'KIV', 'MV', 'M', nan, 'sdB',
#        'FIV', 'K', 'FV', 'KII', 'G', 'F', 'SD', 'L', 'AV', 'BV', 'MIII',
#        'AIII', 'A', 'WD', 'B', 'AIV', 'T', 'BIV', 'GII'], dtype=object)

# %% [markdown]
# #### For entries in specteral type which do not have a star type, set them at main sequence (V) as default

# %%
# Identify the entrie of the dataset which do not end with sdb, WD, SD, L, T, II, III, IV, and V
no_III_IV_V_data = new_exoplanets_filtered3[new_exoplanets_filtered3['spectral_type'].notna() &
                                            ~new_exoplanets_filtered3["spectral_type"].str.contains(r'sdB|WD|SD|L|T', regex=True, na=False) &
                                            ~new_exoplanets_filtered3['spectral_type'].str.endswith(('V', 'IV', 'III', 'II'), na=False)]

no_III_IV_V_data[cols_to_show6]
# Out:
#                  host_star_name spectral_type  star_number_per_system  \
# 12    2MASS J01033563-5515561 A             M                     2.0
# 14      2MASS J02192210-3925225             M                     1.0
# 17      2MASS J04414489+2301513             M                     1.0
# 20      2MASS J12073346-3932539             M                     1.0
# 24      2MASS J22501512+2325342             M                     1.0
# ...                         ...           ...                     ...
# 5993                    WASP-99             F                     1.0
# 6005                  Wolf 1061             M                     1.0
# 6006                  Wolf 1061             M                     1.0
# 6007                  Wolf 1061             M                     1.0
# 6018                       XO-6             F                     1.0
#
#       stellar_effective_temp_k  stellar_mass_solar_mass  \
# 12                         NaN                    0.190
# 14                      3064.0                    0.108
# 17                         NaN                    0.019
# 20                      2825.0                    0.024
# 24                         NaN                      NaN
# ...                        ...                      ...
# 5993                    6162.0                    1.210
# 6005                    3367.5                    0.272
# 6006                    3367.5                    0.272
# 6007                    3367.5                    0.272
# 6018                    6720.0                    1.470
#
#       stellar_rad_solar_rad  stellar_luminosity_solar_lum  \
# 12                      NaN                           NaN
# 14                  0.28100                      0.006244
# 17                      NaN                           NaN
# 20                  0.21887                      0.002737
# 24                      NaN                           NaN
# ...                     ...                           ...
# 5993                1.73000                      3.871407
# 6005                0.30700                      0.010874
# 6006                0.30700                      0.010874
# 6007                0.30700                      0.010874
# 6018                1.93000                      6.815246
#
#      stellar_mass_imputation_method
# 12                         observed
# 14                         observed
# 17                         observed
# 20                         observed
# 24                          missing
# ...                             ...
# 5993                       observed
# 6005                       observed
# 6006                       observed
# 6007                       observed
# 6018                       observed
#
# [583 rows x 8 columns]

# %%
no_III_IV_V_data['spectral_type'].unique()
# Out:
# array(['M', 'K', 'G', 'F', 'A', 'B'], dtype=object)

# %%
# Append 'V' to the end of these entries
new_exoplanets_filtered3.loc[no_III_IV_V_data.index, 'spectral_type'] = no_III_IV_V_data['spectral_type'] + 'V'

# %%
# checking if column updated
new_exoplanets_filtered3['spectral_type'].unique()
# Out:
# array(['GIII', 'KIII', 'KV', 'GV', 'GIV', 'KIV', 'MV', nan, 'sdB', 'FIV',
#        'FV', 'KII', 'SD', 'L', 'AV', 'BV', 'MIII', 'AIII', 'WD', 'AIV',
#        'T', 'BIV', 'GII'], dtype=object)

# %% [markdown]
# ### Removing Rows (Exoplanets) With Significant Missing Data

# %%
new_exoplanets_filtered3.columns
# Out:
# Index(['planet_name', 'host_star_name', 'star_number_per_system',
#        'discovery_method', 'year_of_discovery', 'discovery_facility',
#        'spectral_type', 'orbital_period_day', 'orbit_semi_major_axis_au',
#        'planet_rad_earth_rad', 'planet_mass_earth_mass',
#        'planet_rad_jupiter_rad', 'planet_mass_jupiter_mass',
#        'orbital_eccentricity', 'planet_equil_temp_k',
#        'stellar_effective_temp_k', 'stellar_rad_solar_rad',
#        'stellar_mass_solar_mass', 'stellar_metallicity', 'stellar_surf_grav',
#        'distance_parsec', 'stellar_mass_imputation_method',
#        'stellar_luminosity_solar_lum', 'planet_orbital_velocity'],
#       dtype='object')

# %%
cols_to_show5 = [
    'planet_name',
    'host_star_name',
    'orbital_period_day',
    'orbit_semi_major_axis_au',
    'planet_rad_earth_rad',
    'planet_mass_earth_mass',
    'orbital_eccentricity',
    'planet_equil_temp_k',
    'spectral_type',
    'stellar_effective_temp_k',
    'stellar_rad_solar_rad',
    'stellar_mass_solar_mass',
    'stellar_surf_grav',
    'stellar_luminosity_solar_lum',
    'planet_orbital_velocity'
]

# %%
# Viewing rows where planet mass is still missing
new_exoplanets_filtered3[new_exoplanets_filtered3["planet_mass_earth_mass"].isna()][cols_to_show5]
# Out:
#          planet_name host_star_name  orbital_period_day  \
# 1922  KIC 10001893 b   KIC 10001893            0.219700
# 1923  KIC 10001893 c   KIC 10001893            0.325280
# 1924  KIC 10001893 d   KIC 10001893            0.811610
# 4881       LkCa 15 b        LkCa 15                 NaN
# 4882       LkCa 15 c        LkCa 15                 NaN
# 4922       MWC 758 c        MWC 758           87.358046
# 5262      TOI-1634 c       TOI-1634          103.000000
#
#       orbit_semi_major_axis_au  planet_rad_earth_rad  planet_mass_earth_mass  \
# 1922                       NaN                   NaN                     NaN
# 1923                       NaN                   NaN                     NaN
# 1924                       NaN                   NaN                     NaN
# 4881                 14.700000                   NaN                     NaN
# 4882                 18.600000                   NaN                     NaN
# 4922                100.000000                   NaN                     NaN
# 5262                  0.329779                   NaN                     NaN
#
#       orbital_eccentricity  planet_equil_temp_k spectral_type  \
# 1922                   NaN                  NaN           NaN
# 1923                   NaN                  NaN           NaN
# 1924                   NaN                  NaN           NaN
# 4881                   NaN            56.230056           NaN
# 4882                   NaN            49.988570           NaN
# 4922                   NaN           500.000000            AV
# 5262                   0.0           164.456170            MV
#
#       stellar_effective_temp_k  stellar_rad_solar_rad  \
# 1922                   27500.0                    NaN
# 1923                   27500.0                    NaN
# 1924                   27500.0                    NaN
# 4881                    4194.0                1.60711
# 4882                    4194.0                1.60711
# 4922                       NaN                    NaN
# 5262                    3472.0                0.45000
#
#       stellar_mass_solar_mass  stellar_surf_grav  \
# 1922                      NaN              5.350
# 1923                      NaN              5.350
# 1924                      NaN              5.350
# 4881                      NaN                NaN
# 4882                      NaN                NaN
# 4922                    1.500                NaN
# 5262                    0.451              4.787
#
#       stellar_luminosity_solar_lum  planet_orbital_velocity
# 1922                           NaN                      NaN
# 1923                           NaN                      NaN
# 1924                           NaN                      NaN
# 4881                      0.716960                      NaN
# 4882                      0.716960                      NaN
# 4922                           NaN                 0.122496
# 5262                      0.026402                 1.169638

# %%
# Viewing rows where planet radius is still missing
new_exoplanets_filtered3[new_exoplanets_filtered3["planet_rad_earth_rad"].isna()][cols_to_show5]
# Out:
#          planet_name host_star_name  orbital_period_day  \
# 1922  KIC 10001893 b   KIC 10001893            0.219700
# 1923  KIC 10001893 c   KIC 10001893            0.325280
# 1924  KIC 10001893 d   KIC 10001893            0.811610
# 4881       LkCa 15 b        LkCa 15                 NaN
# 4882       LkCa 15 c        LkCa 15                 NaN
# 4922       MWC 758 c        MWC 758           87.358046
# 5262      TOI-1634 c       TOI-1634          103.000000
#
#       orbit_semi_major_axis_au  planet_rad_earth_rad  planet_mass_earth_mass  \
# 1922                       NaN                   NaN                     NaN
# 1923                       NaN                   NaN                     NaN
# 1924                       NaN                   NaN                     NaN
# 4881                 14.700000                   NaN                     NaN
# 4882                 18.600000                   NaN                     NaN
# 4922                100.000000                   NaN                     NaN
# 5262                  0.329779                   NaN                     NaN
#
#       orbital_eccentricity  planet_equil_temp_k spectral_type  \
# 1922                   NaN                  NaN           NaN
# 1923                   NaN                  NaN           NaN
# 1924                   NaN                  NaN           NaN
# 4881                   NaN            56.230056           NaN
# 4882                   NaN            49.988570           NaN
# 4922                   NaN           500.000000            AV
# 5262                   0.0           164.456170            MV
#
#       stellar_effective_temp_k  stellar_rad_solar_rad  \
# 1922                   27500.0                    NaN
# 1923                   27500.0                    NaN
# 1924                   27500.0                    NaN
# 4881                    4194.0                1.60711
# 4882                    4194.0                1.60711
# 4922                       NaN                    NaN
# 5262                    3472.0                0.45000
#
#       stellar_mass_solar_mass  stellar_surf_grav  \
# 1922                      NaN              5.350
# 1923                      NaN              5.350
# 1924                      NaN              5.350
# 4881                      NaN                NaN
# 4882                      NaN                NaN
# 4922                    1.500                NaN
# 5262                    0.451              4.787
#
#       stellar_luminosity_solar_lum  planet_orbital_velocity
# 1922                           NaN                      NaN
# 1923                           NaN                      NaN
# 1924                           NaN                      NaN
# 4881                      0.716960                      NaN
# 4882                      0.716960                      NaN
# 4922                           NaN                 0.122496
# 5262                      0.026402                 1.169638

# %%
# Viewing rows where orbital semi major axis is stil missing
new_exoplanets_filtered3[new_exoplanets_filtered3["orbit_semi_major_axis_au"].isna()][cols_to_show5]
# Out:
#                 planet_name       host_star_name  orbital_period_day  \
# 1108           HD 41004 A b           HD 41004 A           963.00000
# 1922         KIC 10001893 b         KIC 10001893             0.21970
# 1923         KIC 10001893 c         KIC 10001893             0.32528
# 1924         KIC 10001893 d         KIC 10001893             0.81161
# 1989   KMT-2019-BLG-1953L b   KMT-2019-BLG-1953L                 NaN
# 1999   KMT-2021-BLG-0322L b   KMT-2021-BLG-0322L                 NaN
# 2044   KMT-2024-BLG-0404L c   KMT-2024-BLG-0404L                 NaN
# 2045   KMT-2024-BLG-1044L b   KMT-2024-BLG-1044L                 NaN
# 4913    MOA-2019-BLG-008L b    MOA-2019-BLG-008L                 NaN
# 5000  OGLE-2015-BLG-1609L b  OGLE-2015-BLG-1609L                 NaN
# 5116             SR 12 AB c             SR 12 AB                 NaN
#
#       orbit_semi_major_axis_au  planet_rad_earth_rad  planet_mass_earth_mass  \
# 1108                       NaN             24.598745              807.250000
# 1922                       NaN                   NaN                     NaN
# 1923                       NaN                   NaN                     NaN
# 1924                       NaN                   NaN                     NaN
# 1989                       NaN             12.617441              200.000000
# 1999                       NaN             38.278370             2034.101805
# 2044                       NaN              3.911709               17.300000
# 2045                       NaN              2.663810                7.750000
# 4913                       NaN             62.781292             5720.911326
# 5000                       NaN              7.955578               76.278818
# 5116                       NaN             53.728057             4131.620000
#
#       orbital_eccentricity  planet_equil_temp_k spectral_type  \
# 1108                  0.74                  NaN           NaN
# 1922                   NaN                  NaN           NaN
# 1923                   NaN                  NaN           NaN
# 1924                   NaN                  NaN           NaN
# 1989                   NaN                  NaN           NaN
# 1999                   NaN                  NaN           NaN
# 2044                   NaN                  NaN            MV
# 2045                   NaN                  NaN           NaN
# 4913                   NaN                  NaN           NaN
# 5000                   NaN                  NaN           NaN
# 5116                   NaN                  NaN           NaN
#
#       stellar_effective_temp_k  stellar_rad_solar_rad  \
# 1108                       NaN                    NaN
# 1922                   27500.0                    NaN
# 1923                   27500.0                    NaN
# 1924                   27500.0                    NaN
# 1989                       NaN                    NaN
# 1999                       NaN                    NaN
# 2044                       NaN                    NaN
# 2045                       NaN                    NaN
# 4913                       NaN                    NaN
# 5000                       NaN                    NaN
# 5116                       NaN                    NaN
#
#       stellar_mass_solar_mass  stellar_surf_grav  \
# 1108                      NaN                NaN
# 1922                      NaN               5.35
# 1923                      NaN               5.35
# 1924                      NaN               5.35
# 1989                    0.310                NaN
# 1999                    0.620                NaN
# 2044                    0.090                NaN
# 2045                    0.069                NaN
# 4913                    0.900                NaN
# 5000                    0.170                NaN
# 5116                      NaN                NaN
#
#       stellar_luminosity_solar_lum  planet_orbital_velocity
# 1108                           NaN                      NaN
# 1922                           NaN                      NaN
# 1923                           NaN                      NaN
# 1924                           NaN                      NaN
# 1989                           NaN                      NaN
# 1999                           NaN                      NaN
# 2044                           NaN                      NaN
# 2045                           NaN                      NaN
# 4913                           NaN                      NaN
# 5000                           NaN                      NaN
# 5116                           NaN                      NaN

# %%
# Viewing rows where stellar_mass_solar_mass is stil missing
new_exoplanets_filtered3[new_exoplanets_filtered3["stellar_mass_solar_mass"].isna()][cols_to_show5]
# Out:
#                     planet_name           host_star_name  orbital_period_day  \
# 16    2MASS J03590986+2009361 b  2MASS J03590986+2009361                 NaN
# 18    2MASS J11011926-7732383 b  2MASS J11011926-7732383                 NaN
# 19    2MASS J11550485-7919108 b  2MASS J11550485-7919108                 NaN
# 22    2MASS J21252752-8138278 b  2MASS J21252752-8138278                 NaN
# 24    2MASS J22501512+2325342 b  2MASS J22501512+2325342                 NaN
# 51                     AB Pic b                   AB Pic                 NaN
# 101                    CT Cha b                   CT Cha                 NaN
# 197                   G 196-3 b                  G 196-3                 NaN
# 658               HD 135344 A b              HD 135344 A                 NaN
# 887                 HD 203030 b                HD 203030                 NaN
# 1037             HD 284149 AB b              HD 284149 A                 NaN
# 1108               HD 41004 A b               HD 41004 A           963.00000
# 1378                HIP 77900 b                HIP 77900                 NaN
# 1398                   HN Peg b                   HN Peg                 NaN
# 1414                   ITG 15 b                 ITG 15 A                 NaN
# 1922             KIC 10001893 b             KIC 10001893             0.21970
# 1923             KIC 10001893 c             KIC 10001893             0.32528
# 1924             KIC 10001893 d             KIC 10001893             0.81161
# 4881                  LkCa 15 b                  LkCa 15                 NaN
# 4882                  LkCa 15 c                  LkCa 15                 NaN
# 5081                   PDS 70 c                   PDS 70                 NaN
# 5113                 Ross 458 c                 Ross 458                 NaN
# 5116                 SR 12 AB c                 SR 12 AB                 NaN
# 5998                 WISPIT 1 b                 WISPIT 1                 NaN
# 5999                 WISPIT 1 c                 WISPIT 1                 NaN
#
#       orbit_semi_major_axis_au  planet_rad_earth_rad  planet_mass_earth_mass  \
# 16                      572.00             62.781292             5720.911326
# 18                      266.00             77.560661             8899.195396
# 19                      587.00             66.027337             6356.568140
# 22                     7493.00             51.710181             3813.940884
# 24                      518.00             80.163741             9534.852210
# 51                      260.00             54.706894             4290.500000
# 101                     440.00             24.660000             5403.000000
# 197                     350.00             74.858675             8263.538582
# 658                      16.50             16.253022             3178.284070
# 887                     487.10             14.459585             3496.112477
# 1037                    431.16             76.586475             8667.180659
# 1108                       NaN             24.598745              807.250000
# 1378                   3319.00             67.586850             6674.396547
# 1398                    773.00             11.776800             6991.570000
# 1414                    435.00             67.586850             6674.396547
# 1922                       NaN                   NaN                     NaN
# 1923                       NaN                   NaN                     NaN
# 1924                       NaN                   NaN                     NaN
# 4881                     14.70                   NaN                     NaN
# 4882                     18.60                   NaN                     NaN
# 5081                     34.25             22.866360              635.660000
# 5113                   1100.00             14.011250             1906.980000
# 5116                       NaN             53.728057             4131.620000
# 5998                    338.00             48.288111             3305.415433
# 5999                    840.00             34.975576             1684.490557
#
#       orbital_eccentricity  planet_equil_temp_k spectral_type  \
# 16                     NaN          2369.000000           NaN
# 18                     NaN          2677.000000           NaN
# 19                     NaN          2506.000000           NaN
# 22                     NaN          1616.000000           NaN
# 24                     NaN          1600.000000            MV
# 51                     NaN                  NaN            KV
# 101                    NaN          2600.000000           NaN
# 197                    NaN          1670.000000           NaN
# 658                   0.50          1585.000000            AV
# 887                    NaN          1123.000000            GV
# 1037                   NaN          2448.500000           NaN
# 1108                  0.74                  NaN           NaN
# 1378                   NaN          2507.000000           NaN
# 1398                   NaN                  NaN            GV
# 1414                   NaN          2601.000000           NaN
# 1922                   NaN                  NaN           NaN
# 1923                   NaN                  NaN           NaN
# 1924                   NaN                  NaN           NaN
# 4881                   NaN            56.230056           NaN
# 4882                   NaN            49.988570           NaN
# 5081                  0.11           995.000000           NaN
# 5113                   NaN                  NaN           NaN
# 5116                   NaN                  NaN           NaN
# 5998                   NaN                  NaN            KV
# 5999                   NaN                  NaN            KV
#
#       stellar_effective_temp_k  stellar_rad_solar_rad  \
# 16                         NaN                    NaN
# 18                         NaN                    NaN
# 19                         NaN                    NaN
# 22                         NaN                    NaN
# 24                         NaN                    NaN
# 51                         NaN                    NaN
# 101                        NaN                    NaN
# 197                        NaN                    NaN
# 658                     9540.0                1.50000
# 887                        NaN                    NaN
# 1037                    6035.0                1.36000
# 1108                       NaN                    NaN
# 1378                       NaN                    NaN
# 1398                       NaN                    NaN
# 1414                       NaN                    NaN
# 1922                   27500.0                    NaN
# 1923                   27500.0                    NaN
# 1924                   27500.0                    NaN
# 4881                    4194.0                1.60711
# 4882                    4194.0                1.60711
# 5081                    3972.0                    NaN
# 5113                       NaN                    NaN
# 5116                       NaN                    NaN
# 5998                    4670.0                    NaN
# 5999                    4670.0                    NaN
#
#       stellar_mass_solar_mass  stellar_surf_grav  \
# 16                        NaN                NaN
# 18                        NaN                NaN
# 19                        NaN                NaN
# 22                        NaN                NaN
# 24                        NaN                NaN
# 51                        NaN                NaN
# 101                       NaN                NaN
# 197                       NaN                NaN
# 658                       NaN                NaN
# 887                       NaN                NaN
# 1037                      NaN                NaN
# 1108                      NaN                NaN
# 1378                      NaN                NaN
# 1398                      NaN                NaN
# 1414                      NaN                NaN
# 1922                      NaN               5.35
# 1923                      NaN               5.35
# 1924                      NaN               5.35
# 4881                      NaN                NaN
# 4882                      NaN                NaN
# 5081                      NaN                NaN
# 5113                      NaN                NaN
# 5116                      NaN                NaN
# 5998                      NaN                NaN
# 5999                      NaN                NaN
#
#       stellar_luminosity_solar_lum  planet_orbital_velocity
# 16                             NaN                      NaN
# 18                             NaN                      NaN
# 19                             NaN                      NaN
# 22                             NaN                      NaN
# 24                             NaN                      NaN
# 51                             NaN                      NaN
# 101                            NaN                      NaN
# 197                            NaN                      NaN
# 658                      16.721139                      NaN
# 887                            NaN                      NaN
# 1037                      2.201287                      NaN
# 1108                           NaN                      NaN
# 1378                           NaN                      NaN
# 1398                           NaN                      NaN
# 1414                           NaN                      NaN
# 1922                           NaN                      NaN
# 1923                           NaN                      NaN
# 1924                           NaN                      NaN
# 4881                      0.716960                      NaN
# 4882                      0.716960                      NaN
# 5081                           NaN                      NaN
# 5113                           NaN                      NaN
# 5116                           NaN                      NaN
# 5998                           NaN                      NaN
# 5999                           NaN                      NaN

# %%
# Viewing rows where orbital_period_day is stil missing
new_exoplanets_filtered3[new_exoplanets_filtered3["orbital_period_day"].isna()][cols_to_show5]
# Out:
#                     planet_name           host_star_name  orbital_period_day  \
# 16    2MASS J03590986+2009361 b  2MASS J03590986+2009361                 NaN
# 18    2MASS J11011926-7732383 b  2MASS J11011926-7732383                 NaN
# 19    2MASS J11550485-7919108 b  2MASS J11550485-7919108                 NaN
# 22    2MASS J21252752-8138278 b  2MASS J21252752-8138278                 NaN
# 24    2MASS J22501512+2325342 b  2MASS J22501512+2325342                 NaN
# 51                     AB Pic b                   AB Pic                 NaN
# 101                    CT Cha b                   CT Cha                 NaN
# 197                   G 196-3 b                  G 196-3                 NaN
# 658               HD 135344 A b              HD 135344 A                 NaN
# 887                 HD 203030 b                HD 203030                 NaN
# 1037             HD 284149 AB b              HD 284149 A                 NaN
# 1378                HIP 77900 b                HIP 77900                 NaN
# 1398                   HN Peg b                   HN Peg                 NaN
# 1414                   ITG 15 b                 ITG 15 A                 NaN
# 1989       KMT-2019-BLG-1953L b       KMT-2019-BLG-1953L                 NaN
# 1999       KMT-2021-BLG-0322L b       KMT-2021-BLG-0322L                 NaN
# 2044       KMT-2024-BLG-0404L c       KMT-2024-BLG-0404L                 NaN
# 2045       KMT-2024-BLG-1044L b       KMT-2024-BLG-1044L                 NaN
# 4881                  LkCa 15 b                  LkCa 15                 NaN
# 4882                  LkCa 15 c                  LkCa 15                 NaN
# 4913        MOA-2019-BLG-008L b        MOA-2019-BLG-008L                 NaN
# 5000      OGLE-2015-BLG-1609L b      OGLE-2015-BLG-1609L                 NaN
# 5081                   PDS 70 c                   PDS 70                 NaN
# 5113                 Ross 458 c                 Ross 458                 NaN
# 5116                 SR 12 AB c                 SR 12 AB                 NaN
# 5998                 WISPIT 1 b                 WISPIT 1                 NaN
# 5999                 WISPIT 1 c                 WISPIT 1                 NaN
#
#       orbit_semi_major_axis_au  planet_rad_earth_rad  planet_mass_earth_mass  \
# 16                      572.00             62.781292             5720.911326
# 18                      266.00             77.560661             8899.195396
# 19                      587.00             66.027337             6356.568140
# 22                     7493.00             51.710181             3813.940884
# 24                      518.00             80.163741             9534.852210
# 51                      260.00             54.706894             4290.500000
# 101                     440.00             24.660000             5403.000000
# 197                     350.00             74.858675             8263.538582
# 658                      16.50             16.253022             3178.284070
# 887                     487.10             14.459585             3496.112477
# 1037                    431.16             76.586475             8667.180659
# 1378                   3319.00             67.586850             6674.396547
# 1398                    773.00             11.776800             6991.570000
# 1414                    435.00             67.586850             6674.396547
# 1989                       NaN             12.617441              200.000000
# 1999                       NaN             38.278370             2034.101805
# 2044                       NaN              3.911709               17.300000
# 2045                       NaN              2.663810                7.750000
# 4881                     14.70                   NaN                     NaN
# 4882                     18.60                   NaN                     NaN
# 4913                       NaN             62.781292             5720.911326
# 5000                       NaN              7.955578               76.278818
# 5081                     34.25             22.866360              635.660000
# 5113                   1100.00             14.011250             1906.980000
# 5116                       NaN             53.728057             4131.620000
# 5998                    338.00             48.288111             3305.415433
# 5999                    840.00             34.975576             1684.490557
#
#       orbital_eccentricity  planet_equil_temp_k spectral_type  \
# 16                     NaN          2369.000000           NaN
# 18                     NaN          2677.000000           NaN
# 19                     NaN          2506.000000           NaN
# 22                     NaN          1616.000000           NaN
# 24                     NaN          1600.000000            MV
# 51                     NaN                  NaN            KV
# 101                    NaN          2600.000000           NaN
# 197                    NaN          1670.000000           NaN
# 658                   0.50          1585.000000            AV
# 887                    NaN          1123.000000            GV
# 1037                   NaN          2448.500000           NaN
# 1378                   NaN          2507.000000           NaN
# 1398                   NaN                  NaN            GV
# 1414                   NaN          2601.000000           NaN
# 1989                   NaN                  NaN           NaN
# 1999                   NaN                  NaN           NaN
# 2044                   NaN                  NaN            MV
# 2045                   NaN                  NaN           NaN
# 4881                   NaN            56.230056           NaN
# 4882                   NaN            49.988570           NaN
# 4913                   NaN                  NaN           NaN
# 5000                   NaN                  NaN           NaN
# 5081                  0.11           995.000000           NaN
# 5113                   NaN                  NaN           NaN
# 5116                   NaN                  NaN           NaN
# 5998                   NaN                  NaN            KV
# 5999                   NaN                  NaN            KV
#
#       stellar_effective_temp_k  stellar_rad_solar_rad  \
# 16                         NaN                    NaN
# 18                         NaN                    NaN
# 19                         NaN                    NaN
# 22                         NaN                    NaN
# 24                         NaN                    NaN
# 51                         NaN                    NaN
# 101                        NaN                    NaN
# 197                        NaN                    NaN
# 658                     9540.0                1.50000
# 887                        NaN                    NaN
# 1037                    6035.0                1.36000
# 1378                       NaN                    NaN
# 1398                       NaN                    NaN
# 1414                       NaN                    NaN
# 1989                       NaN                    NaN
# 1999                       NaN                    NaN
# 2044                       NaN                    NaN
# 2045                       NaN                    NaN
# 4881                    4194.0                1.60711
# 4882                    4194.0                1.60711
# 4913                       NaN                    NaN
# 5000                       NaN                    NaN
# 5081                    3972.0                    NaN
# 5113                       NaN                    NaN
# 5116                       NaN                    NaN
# 5998                    4670.0                    NaN
# 5999                    4670.0                    NaN
#
#       stellar_mass_solar_mass  stellar_surf_grav  \
# 16                        NaN                NaN
# 18                        NaN                NaN
# 19                        NaN                NaN
# 22                        NaN                NaN
# 24                        NaN                NaN
# 51                        NaN                NaN
# 101                       NaN                NaN
# 197                       NaN                NaN
# 658                       NaN                NaN
# 887                       NaN                NaN
# 1037                      NaN                NaN
# 1378                      NaN                NaN
# 1398                      NaN                NaN
# 1414                      NaN                NaN
# 1989                    0.310                NaN
# 1999                    0.620                NaN
# 2044                    0.090                NaN
# 2045                    0.069                NaN
# 4881                      NaN                NaN
# 4882                      NaN                NaN
# 4913                    0.900                NaN
# 5000                    0.170                NaN
# 5081                      NaN                NaN
# 5113                      NaN                NaN
# 5116                      NaN                NaN
# 5998                      NaN                NaN
# 5999                      NaN                NaN
#
#       stellar_luminosity_solar_lum  planet_orbital_velocity
# 16                             NaN                      NaN
# 18                             NaN                      NaN
# 19                             NaN                      NaN
# 22                             NaN                      NaN
# 24                             NaN                      NaN
# 51                             NaN                      NaN
# 101                            NaN                      NaN
# 197                            NaN                      NaN
# 658                      16.721139                      NaN
# 887                            NaN                      NaN
# 1037                      2.201287                      NaN
# 1378                           NaN                      NaN
# 1398                           NaN                      NaN
# 1414                           NaN                      NaN
# 1989                           NaN                      NaN
# 1999                           NaN                      NaN
# 2044                           NaN                      NaN
# 2045                           NaN                      NaN
# 4881                      0.716960                      NaN
# 4882                      0.716960                      NaN
# 4913                           NaN                      NaN
# 5000                           NaN                      NaN
# 5081                           NaN                      NaN
# 5113                           NaN                      NaN
# 5116                           NaN                      NaN
# 5998                           NaN                      NaN
# 5999                           NaN                      NaN

# %%
# Viewing rows where orbital_period_day is stil missing
new_exoplanets_filtered3[new_exoplanets_filtered3["spectral_type"].isna()][cols_to_show5]
# Out:
#                     planet_name           host_star_name  orbital_period_day  \
# 16    2MASS J03590986+2009361 b  2MASS J03590986+2009361                 NaN
# 18    2MASS J11011926-7732383 b  2MASS J11011926-7732383                 NaN
# 19    2MASS J11550485-7919108 b  2MASS J11550485-7919108                 NaN
# 22    2MASS J21252752-8138278 b  2MASS J21252752-8138278                 NaN
# 50                     AB Aur b                   AB Aur           70.133984
# ...                         ...                      ...                 ...
# 6030                  bet Pic c                  bet Pic         1207.593170
# 6061                  tau Cet e                  tau Cet          162.870000
# 6062                  tau Cet f                  tau Cet          636.130000
# 6063                  tau Cet g                  tau Cet           20.000000
# 6064                  tau Cet h                  tau Cet           49.410000
#
#       orbit_semi_major_axis_au  planet_rad_earth_rad  planet_mass_earth_mass  \
# 16                     572.000             62.781292             5720.911326
# 18                     266.000             77.560661             8899.195396
# 19                     587.000             66.027337             6356.568140
# 22                    7493.000             51.710181             3813.940884
# 50                      93.900             45.060578             2860.455663
# ...                        ...                   ...                     ...
# 6030                     2.700             45.330432             2896.375052
# 6061                     0.538              1.924856                3.930000
# 6062                     1.334              1.924856                3.930000
# 6063                     0.133              1.307032                1.750000
# 6064                     0.243              1.335287                1.830000
#
#       orbital_eccentricity  planet_equil_temp_k spectral_type  \
# 16                     NaN               2369.0           NaN
# 18                     NaN               2677.0           NaN
# 19                     NaN               2506.0           NaN
# 22                     NaN               1616.0           NaN
# 50                   0.400                  NaN           NaN
# ...                    ...                  ...           ...
# 6030                 0.308               1250.0           NaN
# 6061                 0.180                  NaN           NaN
# 6062                 0.160                  NaN           NaN
# 6063                 0.060                  NaN           NaN
# 6064                 0.230                  NaN           NaN
#
#       stellar_effective_temp_k  stellar_rad_solar_rad  \
# 16                         NaN                    NaN
# 18                         NaN                    NaN
# 19                         NaN                    NaN
# 22                         NaN                    NaN
# 50                      9770.0                    NaN
# ...                        ...                    ...
# 6030                       NaN                    NaN
# 6061                       NaN                    NaN
# 6062                       NaN                    NaN
# 6063                       NaN                    NaN
# 6064                       NaN                    NaN
#
#       stellar_mass_solar_mass  stellar_surf_grav  \
# 16                        NaN                NaN
# 18                        NaN                NaN
# 19                        NaN                NaN
# 22                        NaN                NaN
# 50                      2.400                NaN
# ...                       ...                ...
# 6030                    1.795                NaN
# 6061                    0.783                NaN
# 6062                    0.783                NaN
# 6063                    0.783                NaN
# 6064                    0.783                NaN
#
#       stellar_luminosity_solar_lum  planet_orbital_velocity
# 16                             NaN                      NaN
# 18                             NaN                      NaN
# 19                             NaN                      NaN
# 22                             NaN                      NaN
# 50                             NaN                 0.159900
# ...                            ...                      ...
# 6030                           NaN                 0.815503
# 6061                           NaN                 1.206604
# 6062                           NaN                 0.766263
# 6063                           NaN                 2.426778
# 6064                           NaN                 1.795365
#
# [418 rows x 15 columns]

# %%
# Viewing rows where stellar luminosity is stil missing
new_exoplanets_filtered3[new_exoplanets_filtered3["stellar_luminosity_solar_lum"].isna()][cols_to_show5]
# Out:
#                        planet_name             host_star_name  \
# 12    2MASS J01033563-5515561 AB b  2MASS J01033563-5515561 A
# 15              2MASS J0249-0557 c         2MASS J0249-0557 A
# 16       2MASS J03590986+2009361 b    2MASS J03590986+2009361
# 17       2MASS J04414489+2301513 b    2MASS J04414489+2301513
# 18       2MASS J11011926-7732383 b    2MASS J11011926-7732383
# ...                            ...                        ...
# 6055                  psi1 Dra B b                 psi1 Dra B
# 6061                     tau Cet e                    tau Cet
# 6062                     tau Cet f                    tau Cet
# 6063                     tau Cet g                    tau Cet
# 6064                     tau Cet h                    tau Cet
#
#       orbital_period_day  orbit_semi_major_axis_au  planet_rad_earth_rad  \
# 12            146.114983                    84.000             53.729115
# 15           5442.294019                  1950.000             50.878165
# 16                   NaN                   572.000             62.781292
# 17             56.213427                    15.000             41.295349
# 18                   NaN                   266.000             77.560661
# ...                  ...                       ...                   ...
# 6055         3117.000000                     4.430             19.301521
# 6061          162.870000                     0.538              1.924856
# 6062          636.130000                     1.334              1.924856
# 6063           20.000000                     0.133              1.307032
# 6064           49.410000                     0.243              1.335287
#
#       planet_mass_earth_mass  orbital_eccentricity  planet_equil_temp_k  \
# 12               4131.790000                   NaN                  NaN
# 15               3686.809521                   NaN                  NaN
# 16               5720.911326                   NaN               2369.0
# 17               2383.600000                   NaN                  NaN
# 18               8899.195396                   NaN               2677.0
# ...                      ...                   ...                  ...
# 6055              486.279900                  0.40                  NaN
# 6061                3.930000                  0.18                  NaN
# 6062                3.930000                  0.16                  NaN
# 6063                1.750000                  0.06                  NaN
# 6064                1.830000                  0.23                  NaN
#
#      spectral_type  stellar_effective_temp_k  stellar_rad_solar_rad  \
# 12              MV                       NaN                    NaN
# 15              MV                       NaN                    NaN
# 16             NaN                       NaN                    NaN
# 17              MV                       NaN                    NaN
# 18             NaN                       NaN                    NaN
# ...            ...                       ...                    ...
# 6055            GV                    6212.0                    NaN
# 6061           NaN                       NaN                    NaN
# 6062           NaN                       NaN                    NaN
# 6063           NaN                       NaN                    NaN
# 6064           NaN                       NaN                    NaN
#
#       stellar_mass_solar_mass  stellar_surf_grav  \
# 12                      0.190                NaN
# 15                      0.046                NaN
# 16                        NaN                NaN
# 17                      0.019                NaN
# 18                        NaN                NaN
# ...                       ...                ...
# 6055                    1.190                4.2
# 6061                    0.783                NaN
# 6062                    0.783                NaN
# 6063                    0.783                NaN
# 6064                    0.783                NaN
#
#       stellar_luminosity_solar_lum  planet_orbital_velocity
# 12                             NaN                 0.047568
# 15                             NaN                 0.004858
# 16                             NaN                      NaN
# 17                             NaN                 0.035596
# 18                             NaN                      NaN
# ...                            ...                      ...
# 6055                           NaN                 0.518378
# 6061                           NaN                 1.206604
# 6062                           NaN                 0.766263
# 6063                           NaN                 2.426778
# 6064                           NaN                 1.795365
#
# [630 rows x 15 columns]

# %%
# removing rows where planet mass is still missing
new_exoplanets_filtered3 = new_exoplanets_filtered3[~new_exoplanets_filtered3["planet_mass_earth_mass"].isna()]

# %%
new_exoplanets_filtered3.shape
# Out:
# (6064, 24)

# %%
# removing rows where planet radius is still missing
new_exoplanets_filtered3 = new_exoplanets_filtered3[~new_exoplanets_filtered3["planet_rad_earth_rad"].isna()]

# %%
new_exoplanets_filtered3.shape
# Out:
# (6064, 24)

# %%
# removing rows where orbit_semi_major_axis_au is still missing
new_exoplanets_filtered3 = new_exoplanets_filtered3[~new_exoplanets_filtered3["orbit_semi_major_axis_au"].isna()]

# %%
new_exoplanets_filtered3.shape
# Out:
# (6056, 24)

# %%
# removing rows where stellar_mass_solar_mass is still missing
new_exoplanets_filtered3 = new_exoplanets_filtered3[~new_exoplanets_filtered3["stellar_mass_solar_mass"].isna()]

# %%
new_exoplanets_filtered3.shape
# Out:
# (6038, 24)

# %%
# removing rows where orbital_period_day is still missing
new_exoplanets_filtered3 = new_exoplanets_filtered3[~new_exoplanets_filtered3["orbital_period_day"].isna()]

# %%
new_exoplanets_filtered3.shape
# Out:
# (6038, 24)

# %%
# removing rows where planet_orbital_velocity is still missing
new_exoplanets_filtered3 = new_exoplanets_filtered3[~new_exoplanets_filtered3["planet_orbital_velocity"].isna()]

# %%
new_exoplanets_filtered3.shape
# Out:
# (6038, 24)

# %%
# removing rows where spectral type is still missing
new_exoplanets_filtered3 = new_exoplanets_filtered3[~new_exoplanets_filtered3["spectral_type"].isna()]

# %%
new_exoplanets_filtered3.shape
# Out:
# (5643, 24)

# %%
# removing rows where spectral type is still missing
new_exoplanets_filtered3 = new_exoplanets_filtered3[~new_exoplanets_filtered3["stellar_luminosity_solar_lum"].isna()]

# %%
new_exoplanets_filtered3.shape
# Out:
# (5419, 24)

# %%
# checking how much missing data currently present in data
missing_percentage2 = (new_exoplanets_filtered3.isnull().sum() / len(new_exoplanets_filtered3))
((missing_percentage2 * 100).sort_values(ascending=False)).map(lambda x: f"{x:.2f}%")
# Out:
# planet_mass_jupiter_mass          52.98%
# planet_rad_jupiter_rad            16.76%
# orbital_eccentricity              10.52%
# stellar_metallicity                3.60%
# distance_parsec                    1.81%
# planet_name                        0.00%
# star_number_per_system             0.00%
# host_star_name                     0.00%
# orbital_period_day                 0.00%
# spectral_type                      0.00%
# discovery_facility                 0.00%
# year_of_discovery                  0.00%
# discovery_method                   0.00%
# planet_rad_earth_rad               0.00%
# planet_mass_earth_mass             0.00%
# orbit_semi_major_axis_au           0.00%
# stellar_effective_temp_k           0.00%
# planet_equil_temp_k                0.00%
# stellar_mass_solar_mass            0.00%
# stellar_rad_solar_rad              0.00%
# stellar_surf_grav                  0.00%
# stellar_mass_imputation_method     0.00%
# stellar_luminosity_solar_lum       0.00%
# planet_orbital_velocity            0.00%
# dtype: object

# %% [markdown]
# Approximately 10.74% of original cleaned data were removed. The orignal cleaned data contained 6,071 exoplanets, after removing 10.71% of the rows, 5,419 exoplanets remain.

# %% [markdown]
# ### Removing Columns With Significant Missing Data and Uneeded Columns

# %%
# deleting the jupiter radius and juptier mass columns
new_exoplanets_filtered3 = new_exoplanets_filtered3.drop(columns=['planet_rad_jupiter_rad', 'planet_mass_jupiter_mass', 'orbital_eccentricity', 'stellar_metallicity', 'distance_parsec'])

# %%
new_exoplanets_filtered3.shape
# Out:
# (5419, 19)

# %%
# checking how much missing data currently present in data
missing_percentage2 = (new_exoplanets_filtered3.isnull().sum() / len(new_exoplanets_filtered3))
((missing_percentage2 * 100).sort_values(ascending=False)).map(lambda x: f"{x:.2f}%")
# Out:
# planet_name                       0.00%
# host_star_name                    0.00%
# star_number_per_system            0.00%
# discovery_method                  0.00%
# year_of_discovery                 0.00%
# discovery_facility                0.00%
# spectral_type                     0.00%
# orbital_period_day                0.00%
# orbit_semi_major_axis_au          0.00%
# planet_rad_earth_rad              0.00%
# planet_mass_earth_mass            0.00%
# planet_equil_temp_k               0.00%
# stellar_effective_temp_k          0.00%
# stellar_rad_solar_rad             0.00%
# stellar_mass_solar_mass           0.00%
# stellar_surf_grav                 0.00%
# stellar_mass_imputation_method    0.00%
# stellar_luminosity_solar_lum      0.00%
# planet_orbital_velocity           0.00%
# dtype: object

# %% [markdown]
# ### Creating a Habitable Zone Binary Column

# %%
# create a binary column called "habitable_zone_main_seq" for exoplanets which have a main sequence stars and a temperature range of 235K <= Teq 330K where:
# if the planet is within the habitable zone and has a main sequence luminsoty class then has value of 1
# if the planet is not within the habitable zone and has another luminosity class then has value of 0

# Precompute sqrt(Ls)
sqrt_Ls = np.sqrt(new_exoplanets_filtered3['stellar_luminosity_solar_lum'])

# Habitable zone boundaries with scaled inner and outer limits where a is the orbital semi major axis and Ls is the stellar luminosity class:
# For a Type MV star (0.07K sqrt(Ls) <= a <= 0.2K sqrt(Ls))
hz_inner_MV = 0.07 * sqrt_Ls
hz_outer_MV = 0.2 * sqrt_Ls
# For a Type KV star (0.1K sqrt(Ls) <= a <= 1.3K sqrt(Ls))
hz_inner_KV = 0.1 * sqrt_Ls
hz_outer_KV = 1.3 * sqrt_Ls
# For a Type GV star (0.8K sqrt(Ls) <= a <= 1.7K sqrt(Ls))
hz_inner_GV = 0.8 * sqrt_Ls
hz_outer_GV = 1.7 * sqrt_Ls
# For a Type FV star (1.5K sqrt(Ls) <= a <= 3.5K sqrt(Ls))
hz_inner_FV = 1.5 * sqrt_Ls
hz_outer_FV = 3.5 * sqrt_Ls

tolerance = 0.001

# Temperature condition
temp_condition = (
    (new_exoplanets_filtered3['planet_equil_temp_k'] >= 235) &
    (new_exoplanets_filtered3['planet_equil_temp_k'] <= 330)
)

# Individual spectral-type HZ conditions
condition_MV = (
    (new_exoplanets_filtered3['spectral_type'] == 'MV') &
    (new_exoplanets_filtered3['orbit_semi_major_axis_au'] >= hz_inner_MV - tolerance) &
    (new_exoplanets_filtered3['orbit_semi_major_axis_au'] <= hz_outer_MV + tolerance)
)
condition_KV = (
    (new_exoplanets_filtered3['spectral_type'] == 'KV') &
    (new_exoplanets_filtered3['orbit_semi_major_axis_au'] >= hz_inner_KV - tolerance) &
    (new_exoplanets_filtered3['orbit_semi_major_axis_au'] <= hz_outer_KV + tolerance)
)
condition_GV = (
    (new_exoplanets_filtered3['spectral_type'] == 'GV') &
    (new_exoplanets_filtered3['orbit_semi_major_axis_au'] >= hz_inner_GV - tolerance) &
    (new_exoplanets_filtered3['orbit_semi_major_axis_au'] <= hz_outer_GV + tolerance)
)
condition_FV = (
    (new_exoplanets_filtered3['spectral_type'] == 'FV') &
    (new_exoplanets_filtered3['orbit_semi_major_axis_au'] >= hz_inner_FV - tolerance) &
    (new_exoplanets_filtered3['orbit_semi_major_axis_au'] <= hz_outer_FV + tolerance)
)

# Combine everything
new_exoplanets_filtered3['habitable_zone_main_seq'] = (
    temp_condition &
    (condition_MV | condition_KV | condition_GV | condition_FV)
).astype(int)

# %%
# checking is column was successfully added
new_exoplanets_filtered3['habitable_zone_main_seq'].unique()
# Out:
# array([0, 1])

# %%
# viewing all rows which are within the habitable zone of its star
new_exoplanets_filtered3[new_exoplanets_filtered3['habitable_zone_main_seq'] == 1]
# Out:
#            planet_name  host_star_name  star_number_per_system  \
# 37            55 Cnc f          55 Cnc                     2.0
# 57            AU Mic e          AU Mic                     1.0
# 72         BD+49 828 b       BD+49 828                     1.0
# 82        BD-11 4672 c      BD-11 4672                     1.0
# 182   EPIC 212737443 c  EPIC 212737443                     1.0
# ...                ...             ...                     ...
# 5582        TOI-4633 c        TOI-4633                     2.0
# 5599         TOI-500 e         TOI-500                     1.0
# 5637         TOI-544 c         TOI-544                     1.0
# 5718         TOI-712 d         TOI-712                     1.0
# 5926         WASP-41 c         WASP-41                     1.0
#
#      discovery_method  year_of_discovery  \
# 37    Radial Velocity             2007.0
# 57    Radial Velocity             2025.0
# 72    Radial Velocity             2015.0
# 82    Radial Velocity             2020.0
# 182           Transit             2019.0
# ...               ...                ...
# 5582          Transit             2024.0
# 5599  Radial Velocity             2022.0
# 5637  Radial Velocity             2023.0
# 5718          Transit             2022.0
# 5926  Radial Velocity             2015.0
#
#                                 discovery_facility spectral_type  \
# 37                          Multiple Observatories            GV
# 57                           Mauna Kea Observatory            KV
# 72                            McDonald Observatory            KV
# 82              Roque de los Muchachos Observatory            KV
# 182                                             K2            KV
# ...                                            ...           ...
# 5582  Transiting Exoplanet Survey Satellite (TESS)            GV
# 5599                          La Silla Observatory            KV
# 5637                          La Silla Observatory            KV
# 5718  Transiting Exoplanet Survey Satellite (TESS)            KV
# 5926                          La Silla Observatory            GV
#
#       orbital_period_day  orbit_semi_major_axis_au  planet_rad_earth_rad  \
# 37             260.78125                  0.781513              6.344191
# 57              33.25000                  0.170681              4.301580
# 72            2590.00000                  4.200000             19.718599
# 82              74.20000                  0.300000              3.696464
# 182             65.55000                  0.280000              2.690000
# ...                  ...                       ...                   ...
# 5582           271.94450                  0.847000              3.200000
# 5599            61.30000                  0.275206              3.659440
# 5637            50.08900                  0.228093              4.340406
# 5718            84.83960                  0.340500              2.474000
# 5926           421.00000                  1.070000             27.391649
#
#       planet_mass_earth_mass  planet_equil_temp_k  stellar_effective_temp_k  \
# 37                 47.529849           235.917959               5241.127143
# 57                 21.100000           325.735064               3665.000000
# 72                508.500000           269.617897               4943.000000
# 82                 15.370000           269.263294               4550.000000
# 182                 6.554346           316.000000               4684.000000
# ...                      ...                  ...                       ...
# 5582              123.000000           261.852602               5800.000000
# 5599               15.050000           282.582374               4440.000000
# 5637               21.500000           279.380615               4169.000000
# 5718                5.590613           313.600000               4622.000000
# 5926             1010.699400           241.000000               5545.000000
#
#       stellar_rad_solar_rad  stellar_mass_solar_mass  stellar_surf_grav  \
# 37                 0.963067                 0.924286           4.412356
# 57                 0.820000                 0.600000           4.520000
# 72                 7.600000                 1.520000           2.850000
# 82                 0.639000                 0.651000           4.642000
# 182                0.673000                 0.690000           4.622000
# ...                     ...                      ...                ...
# 5582               1.050000                 1.100000           4.436836
# 5599               0.678000                 0.740000           4.618000
# 5637               0.623000                 0.631000           4.680000
# 5718               0.674000                 0.732000           4.645000
# 5926               0.870000                 0.930000           4.530000
#
#      stellar_mass_imputation_method  stellar_luminosity_solar_lum  \
# 37                         observed                      0.627916
# 57                         observed                      0.108846
# 72                         observed                     30.937091
# 82                         observed                      0.157014
# 182                        observed                      0.195608
# ...                             ...                           ...
# 5582                       observed                      1.119387
# 5599                       observed                      0.160281
# 5637                       observed                      0.105195
# 5718                       observed                      0.186007
# 5926                       observed                      0.641999
#
#       planet_orbital_velocity  habitable_zone_main_seq
# 37                   1.087703                        1
# 57                   1.875246                        1
# 72                   0.601689                        1
# 82                   1.473346                        1
# 182                  1.570075                        1
# ...                       ...                      ...
# 5582                 1.139803                        1
# 5599                 1.640069                        1
# 5637                 1.663543                        1
# 5718                 1.466466                        1
# 5926                 0.932448                        1
#
# [107 rows x 20 columns]

# %% [markdown]
# ## **Exploratory Data Analysis**

# %% [markdown]
# #### 1) What percentage of data still remain missing?

# %%
# checking how much missing data currently present in data
missing_percentage = (new_exoplanets_filtered3.isnull().sum() / len(new_exoplanets_filtered3))
((missing_percentage * 100).sort_values(ascending=False)).map(lambda x: f"{x:.2f}%")
# Out:
# planet_name                       0.00%
# host_star_name                    0.00%
# star_number_per_system            0.00%
# discovery_method                  0.00%
# year_of_discovery                 0.00%
# discovery_facility                0.00%
# spectral_type                     0.00%
# orbital_period_day                0.00%
# orbit_semi_major_axis_au          0.00%
# planet_rad_earth_rad              0.00%
# planet_mass_earth_mass            0.00%
# planet_equil_temp_k               0.00%
# stellar_effective_temp_k          0.00%
# stellar_rad_solar_rad             0.00%
# stellar_mass_solar_mass           0.00%
# stellar_surf_grav                 0.00%
# stellar_mass_imputation_method    0.00%
# stellar_luminosity_solar_lum      0.00%
# planet_orbital_velocity           0.00%
# habitable_zone_main_seq           0.00%
# dtype: object

# %%
new_exoplanets_filtered3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5419 entries, 0 to 6070
# Data columns (total 20 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   planet_name                     5419 non-null   object
#  1   host_star_name                  5419 non-null   object
#  2   star_number_per_system          5419 non-null   float64
#  3   discovery_method                5419 non-null   object
#  4   year_of_discovery               5419 non-null   float64
#  5   discovery_facility              5419 non-null   object
#  6   spectral_type                   5419 non-null   object
#  7   orbital_period_day              5419 non-null   float64
#  8   orbit_semi_major_axis_au        5419 non-null   float64
#  9   planet_rad_earth_rad            5419 non-null   float64
#  10  planet_mass_earth_mass          5419 non-null   float64
#  11  planet_equil_temp_k             5419 non-null   float64
#  12  stellar_effective_temp_k        5419 non-null   float64
#  13  stellar_rad_solar_rad           5419 non-null   float64
#  14  stellar_mass_solar_mass         5419 non-null   float64
#  15  stellar_surf_grav               5419 non-null   float64
#  16  stellar_mass_imputation_method  5419 non-null   object
#  17  stellar_luminosity_solar_lum    5419 non-null   float64
#  18  planet_orbital_velocity         5419 non-null   float64
#  19  habitable_zone_main_seq         5419 non-null   int64
# dtypes: float64(13), int64(1), object(6)
# memory usage: 889.1+ KB

# %% [markdown]
# #### 2) How many exoplanets are currently in the dataset?

# %%
# viewing the shape of the dataset
new_exoplanets_filtered3.shape # There are 5,419 exoplanets and 20 features
# Out:
# (5419, 20)

# %% [markdown]
# #### 3) Describe the statistics for all numerical columns

# %%
# view summary statisics of the data
new_exoplanets_filtered3.describe()
# Out:
#        star_number_per_system  year_of_discovery  orbital_period_day  \
# count             5419.000000        5419.000000        5.419000e+03
# mean                 1.095774        2016.687950        7.593898e+04
# std                  0.328675           4.789271        5.461997e+06
# min                  1.000000        1995.000000        1.120067e-01
# 25%                  1.000000        2014.000000        4.242077e+00
# 50%                  1.000000        2016.000000        1.035080e+01
# 75%                  1.000000        2021.000000        3.319877e+01
# max                  4.000000        2025.000000        4.020000e+08
#
#        orbit_semi_major_axis_au  planet_rad_earth_rad  planet_mass_earth_mass  \
# count               5419.000000           5419.000000             5419.000000
# mean                   2.842451              6.993976              277.828944
# std                  105.769021              9.956195              843.128061
# min                    0.003857              0.296555                0.070000
# 25%                    0.049900              1.726938                3.887098
# 50%                    0.088600              2.633500                7.178370
# 75%                    0.195822              9.644862              127.060338
# max                 7506.000000             78.167741             9045.396463
#
#        planet_equil_temp_k  stellar_effective_temp_k  stellar_rad_solar_rad  \
# count          5419.000000               5419.000000            5419.000000
# mean            830.303783               5378.916481               1.499147
# std             475.033378               1297.070027               3.896793
# min               5.272973                575.000000               0.012300
# 25%             491.800000               4925.500000               0.773015
# 50%             751.200000               5562.130000               0.952000
# 75%            1079.400000               5905.167778               1.240000
# max            6540.308280              32780.000000              88.475000
#
#        stellar_mass_solar_mass  stellar_surf_grav  \
# count              5419.000000        5419.000000
# mean                  0.957963           4.377543
# std                   0.384770           0.438593
# min                   0.014700           0.541000
# 25%                   0.801900           4.289923
# 50%                   0.957200           4.444564
# 75%                   1.088268           4.569494
# max                  10.940000           8.070000
#
#        stellar_luminosity_solar_lum  planet_orbital_velocity  \
# count                  5.419000e+03              5419.000000
# mean                   6.963584e+00                 3.227197
# std                    1.005093e+02                 1.618808
# min                    8.121645e-07                 0.007022
# 25%                    3.564069e-01                 2.097888
# 50%                    8.458098e-01                 3.099159
# 75%                    1.800537e+00                 4.260858
# max                    6.238854e+03                12.578639
#
#        habitable_zone_main_seq
# count              5419.000000
# mean                  0.019745
# std                   0.139137
# min                   0.000000
# 25%                   0.000000
# 50%                   0.000000
# 75%                   0.000000
# max                   1.000000

# %% [markdown]
# #### 4) Look at the Distribtuion for all numerical columns

# %%
# create histograms for all numerical columns
new_exoplanets_filtered3.hist(figsize=(14, 12), bins=50)
plt.show()

# %%
# create histograms for all parameters which display unqiue distribtuions
planet_feature3 = [
    'planet_orbital_velocity',
    'stellar_mass_solar_mass',
    'stellar_surf_grav'
]

new_exoplanets_filtered3[planet_feature3].hist(
    figsize=(12, 10),
    bins=40
)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 5) Are there major correlations between numerical features in the dataset?

# %%
# checking for any correlations between the variables in the dataset
# creating a correlation heatmap
plt.figure(figsize=(12, 9))
correlation_matrix = new_exoplanets_filtered3.select_dtypes(include=[np.number]).corr()
sns.heatmap(correlation_matrix, annot=True, cmap='YlGnBu', fmt=".2f")
# Out:
# <Axes: >

# %% [markdown]
# #### 6) What is the Distribution of Star Types for all Host Stars?

# %%
new_exoplanets_filtered3['spectral_type'].value_counts()
# Out:
# spectral_type
# GV      2413
# KV      1242
# FV       895
# MV       468
# KIII     112
# KIV       83
# GIV       69
# FIV       64
# AV        26
# GIII      21
# sdB        6
# MIII       6
# BV         3
# WD         3
# KII        2
# SD         1
# AIII       1
# AIV        1
# T          1
# BIV        1
# GII        1
# Name: count, dtype: int64

# %%
# Count all entries in the dataset that are sdB, WD, SD, L, T
other_count_all = len(new_exoplanets_filtered3[new_exoplanets_filtered3["spectral_type"].str.contains(r'sdB|WD|SD|L|T', regex=True, na=False)])
print(f"The count of host stars in the other category: {other_count_all}")

# Count all entries in the dataset that are Type O (including Main Sequence V, Sub Giant IV, Giant III, and Bright Giant II)
type_O_count_all = len(new_exoplanets_filtered3[(new_exoplanets_filtered3["spectral_type"].str.contains('O') == True) & (~new_exoplanets_filtered3["spectral_type"].str.contains('sdB'))])
print(f"The count of host stars in the Type O category: {type_O_count_all}")

# Count all entries in the dataset that are Type B (including Main Sequence V, Sub Giant IV, Giant III, and Bright Giant II)
type_B_count_all = len(new_exoplanets_filtered3[(new_exoplanets_filtered3["spectral_type"].str.contains('B') == True) & (~new_exoplanets_filtered3["spectral_type"].str.contains('sdB'))])
print(f"The count of host stars in the Type B category: {type_B_count_all}")

# Count all entries in the dataset that are Type A (including Main Sequence V, Sub Giant IV, Giant III, and Bright Giant II)
type_A_count_all = len(new_exoplanets_filtered3[new_exoplanets_filtered3["spectral_type"].str.contains('A') == True])
print(f"The count of host stars in the Type A category: {type_A_count_all}")

# Count all entries in the dataset that are Type F (including Main Sequence V, Sub Giant IV, Giant III, and Bright Giant II)
type_F_count_all = len(new_exoplanets_filtered3[new_exoplanets_filtered3["spectral_type"].str.contains('F') == True])
print(f"The count of host stars in the Type F category: {type_F_count_all}")

# Count all entries in the dataset that are Type G (including Main Sequence V, Sub Giant IV, Giant III, and Bright Giant II)
type_G_count_all = len(new_exoplanets_filtered3[new_exoplanets_filtered3["spectral_type"].str.contains('G') == True])
print(f"The count of host stars in the Type G category: {type_G_count_all}")

# Count all entries in the dataset that are Type K (including Main Sequence V, Sub Giant IV, Giant III, and Bright Giant II)
type_K_count_all = len(new_exoplanets_filtered3[new_exoplanets_filtered3["spectral_type"].str.contains('K') == True])
print(f"The count of host stars in the Type K category: {type_K_count_all}")

# Count all entries in the dataset that are Type M (including Main Sequence V, Sub Giant IV, Giant III, and Bright Giant II)
type_M_count_all = len(new_exoplanets_filtered3[new_exoplanets_filtered3["spectral_type"].str.contains('M') == True])
print(f"The count of host stars in the Type M category: {type_M_count_all}")
# Out:
# The count of host stars in the other category: 11
# The count of host stars in the Type O category: 0
# The count of host stars in the Type B category: 4
# The count of host stars in the Type A category: 28
# The count of host stars in the Type F category: 959
# The count of host stars in the Type G category: 2504
# The count of host stars in the Type K category: 1439
# The count of host stars in the Type M category: 474

# %%
total_star_count = other_count_all + type_O_count_all + type_B_count_all + type_A_count_all + type_F_count_all + type_G_count_all + type_K_count_all + type_M_count_all
total_star_count
# Out:
# 5419

# %%
# Store categories and counts
star_type_categories = [
    "Type M\n(Red Dwarf)\n2800K-3900K",
    "Type K\n3900K-5000K",
    "Type G\n5000K-6000K",
    "Type F\n6000K-7000K",
    "Type A\n7000K-10000K",
    "Type B\n10000K-30000K",
    "Type O\n>30000K",
    "Other"
]

counts = [
    type_M_count_all,
    type_K_count_all,
    type_G_count_all,
    type_F_count_all,
    type_A_count_all,
    type_B_count_all,
    type_O_count_all,
    other_count_all
]

# Create DataFrame for plotting
star_counts_df = pd.DataFrame({
    "Star Type": star_type_categories,
    "# of Host Stars": counts
})

plt.figure(figsize=(12, 9))
ax = sns.barplot(
    data=star_counts_df,
    x="Star Type",
    y="# of Host Stars",
    palette=[
        "red",   # Type M
        "orange",   # Type K
        "yellow",   # Type G
        "tan",   # Type F
        "lightblue",   # Type A
        "blue",   # Type B
        "darkblue",    # Type O
        "purple", # Other
    ]
)

plt.title("Distribution of all 5,419 Extrasolar Stars")

# Add counts and percentages on tope of each bar
total = star_counts_df["# of Host Stars"].sum()

for i, bar in enumerate(ax.patches):
    height = bar.get_height()
    percentage = (height / total) * 100

    ax.text(
        bar.get_x() + bar.get_width()/2,
        height,
        f'{int(height)}\n({percentage:.1f}%)',
        ha='center',
        va='bottom',
        fontsize=10
    )

plt.xticks(rotation=0, ha='center')
plt.tight_layout()
plt.show()

# %%
# Store categories and counts
star_type_categories = [
    "Type M\n(Red Dwarf)\n2800K-3900K",
    "Type K\n3900K-5000K",
    "Type G\n5000K-6000K",
    "Type F\n6000K-7000K",
    "Type A\n7000K-10000K",
    "Type B\n10000K-30000K",
    "Type O\n>30000K",
    "Other"
]

counts = [
    type_M_count_all,
    type_K_count_all,
    type_G_count_all,
    type_F_count_all,
    type_A_count_all,
    type_B_count_all,
    type_O_count_all,
    other_count_all
]

# Create DataFrame for plotting
star_counts_df = pd.DataFrame({
    "Star Type": star_type_categories,
    "# of Host Stars": counts
})

plt.figure(figsize=(12, 10), facecolor='black')
ax = sns.barplot(
    data=star_counts_df,
    x="Star Type",
    y="# of Host Stars",
    palette=[
        "red",        # Type M
        "orange",     # Type K
        "yellow",     # Type G
        "tan",        # Type F
        "lightblue",  # Type A
        "blue",       # Type B
        "darkblue",   # Type O
        "purple",     # Other
    ]
)
ax.set_facecolor('black')

plt.title("Distribution of all 5,419 Extrasolar Stars", color='white', fontweight='bold', fontsize=15)

# Add counts and percentages on tope of each bar
total = star_counts_df["# of Host Stars"].sum()

for i, bar in enumerate(ax.patches):
    height = bar.get_height()
    percentage = (height / total) * 100

    ax.text(
        bar.get_x() + bar.get_width()/2,
        height,
        f'{int(height)}\n({percentage:.1f}%)',
        ha='center',
        va='bottom',
        fontsize=11.5,
        color='white',
        fontweight='bold'
    )

plt.xticks(rotation=0, ha='center', fontweight='bold')
ax.tick_params(colors='white')

plt.xlabel("Star Type", color="white", fontweight='bold', fontsize=13)
plt.ylabel("# of Host Stars", color="white", fontweight='bold', fontsize=13)

for spine in ax.spines.values():
    spine.set_color('white')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### 7) What is the Distribution of Star Types for all Main Sequence (V), Sub Giant (IV), Giant (III), and Bright Giant (II) Host Stars?

# %%
# Store categories and counts
star_type_categories = [
    "Type M\n(Red Dwarf)\n2800K-3900K",
    "Type K\n3900K-5000K",
    "Type G\n5000K-6000K",
    "Type F\n6000K-7000K",
    "Type A\n7000K-10000K",
    "Type B\n10000K-30000K",
    "Type O\n>30000K"
]

counts = [
    type_M_count_all,
    type_K_count_all,
    type_G_count_all,
    type_F_count_all,
    type_A_count_all,
    type_B_count_all,
    type_O_count_all
]

# Create DataFrame for plotting
star_counts_df = pd.DataFrame({
    "Star Type": star_type_categories,
    "# of Host Stars": counts
})

plt.figure(figsize=(11, 9))
ax = sns.barplot(
    data=star_counts_df,
    x="Star Type",
    y="# of Host Stars",
    palette=[
        "red",   # Type M
        "orange",   # Type K
        "yellow",   # Type G
        "tan",   # Type F
        "lightblue",   # Type A
        "blue",   # Type B
        "darkblue"    # Type O
    ]
)

plt.title("Distribution of all 5,408 Main Sequence (V), Sub Giant (IV), Giant (III), and Bright Giant (II) Extrasolar Stars")

# Add counts and percentages on tope of each bar
total = star_counts_df["# of Host Stars"].sum()

for i, bar in enumerate(ax.patches):
    height = bar.get_height()
    percentage = (height / total) * 100

    ax.text(
        bar.get_x() + bar.get_width()/2,
        height,
        f'{int(height)}\n({percentage:.1f}%)',
        ha='center',
        va='bottom',
        fontsize=10
    )

plt.xticks(rotation=0, ha='center')
plt.tight_layout()
plt.show()

# %%
# Store categories and counts
star_type_categories = [
    "Type M\n(Red Dwarf)\n2800K-3900K",
    "Type K\n3900K-5000K",
    "Type G\n5000K-6000K",
    "Type F\n6000K-7000K",
    "Type A\n7000K-10000K",
    "Type B\n10000K-30000K",
    "Type O\n>30000K"
]

counts = [
    type_M_count_all,
    type_K_count_all,
    type_G_count_all,
    type_F_count_all,
    type_A_count_all,
    type_B_count_all,
    type_O_count_all
]

# Create DataFrame for plotting
star_counts_df = pd.DataFrame({
    "Star Type": star_type_categories,
    "# of Host Stars": counts
})

plt.figure(figsize=(12, 10), facecolor='black')
ax = sns.barplot(
    data=star_counts_df,
    x="Star Type",
    y="# of Host Stars",
    palette=[
        "red",        # Type M
        "orange",     # Type K
        "yellow",     # Type G
        "tan",        # Type F
        "lightblue",  # Type A
        "blue",       # Type B
        "darkblue"    # Type O
    ]
)
ax.set_facecolor('black')

plt.title("Distribution of all 5,408 Main Sequence (V), Sub Giant (IV), Giant (III), and Bright Giant (II) Extrasolar Stars", color='white', fontweight='bold', fontsize=14)

# Add counts and percentages on tope of each bar
total = star_counts_df["# of Host Stars"].sum()

for i, bar in enumerate(ax.patches):
    height = bar.get_height()
    percentage = (height / total) * 100

    ax.text(
        bar.get_x() + bar.get_width()/2,
        height,
        f'{int(height)}\n({percentage:.1f}%)',
        ha='center',
        va='bottom',
        fontsize=11.5,
        color='white',
        fontweight='bold'
    )

plt.xticks(rotation=0, ha='center', fontweight='bold')
ax.tick_params(colors='white')

plt.xlabel("Star Type", color="white", fontweight='bold', fontsize=13)
plt.ylabel("# of Host Stars", color="white", fontweight='bold', fontsize=13)

for spine in ax.spines.values():
    spine.set_color('white')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### 8) What is the Distribution of Star Types for all Main Sequence (V) Host Stars?

# %%
main_sequence_stars = new_exoplanets_filtered3[~new_exoplanets_filtered3["spectral_type"].str.contains(r'sdB|WD|SD|L|T', regex=True, na=False) &
                                              (new_exoplanets_filtered3["spectral_type"].str.contains('V') == True) &
                                              (~new_exoplanets_filtered3["spectral_type"].str.contains('IV') == True) &
                                              (~new_exoplanets_filtered3["spectral_type"].str.contains('III') == True) &
                                              (~new_exoplanets_filtered3["spectral_type"].str.contains('II') == True)]

# %%
main_sequence_stars['spectral_type'].value_counts()
# Out:
# spectral_type
# GV    2413
# KV    1242
# FV     895
# MV     468
# AV      26
# BV       3
# Name: count, dtype: int64

# %%
main_sequence_stars.shape
# Out:
# (5047, 20)

# %%
# Count all entries in the dataset that are Type O (including Main Sequence V, Sub Giant IV, Giant III, and Bright Giant II)
type_O_count_ms = len(main_sequence_stars[(main_sequence_stars["spectral_type"].str.contains('O') == True) & (~main_sequence_stars["spectral_type"].str.contains('sdB'))])
print(f"The count of host stars in the Type O category: {type_O_count_all}")

# Count all entries in the dataset that are Type B (including Main Sequence V, Sub Giant IV, Giant III, and Bright Giant II)
type_B_count_ms = len(main_sequence_stars[(main_sequence_stars["spectral_type"].str.contains('B') == True) & (~main_sequence_stars["spectral_type"].str.contains('sdB'))])
print(f"The count of host stars in the Type B category: {type_B_count_all}")

# Count all entries in the dataset that are Type A (including Main Sequence V, Sub Giant IV, Giant III, and Bright Giant II)
type_A_count_ms = len(main_sequence_stars[main_sequence_stars["spectral_type"].str.contains('A') == True])
print(f"The count of host stars in the Type A category: {type_A_count_all}")

# Count all entries in the dataset that are Type F (including Main Sequence V, Sub Giant IV, Giant III, and Bright Giant II)
type_F_count_ms = len(main_sequence_stars[main_sequence_stars["spectral_type"].str.contains('F') == True])
print(f"The count of host stars in the Type F category: {type_F_count_all}")

# Count all entries in the dataset that are Type G (including Main Sequence V, Sub Giant IV, Giant III, and Bright Giant II)
type_G_count_ms = len(main_sequence_stars[main_sequence_stars["spectral_type"].str.contains('G') == True])
print(f"The count of host stars in the Type G category: {type_G_count_all}")

# Count all entries in the dataset that are Type K (including Main Sequence V, Sub Giant IV, Giant III, and Bright Giant II)
type_K_count_ms = len(main_sequence_stars[main_sequence_stars["spectral_type"].str.contains('K') == True])
print(f"The count of host stars in the Type K category: {type_K_count_all}")

# Count all entries in the dataset that are Type M (including Main Sequence V, Sub Giant IV, Giant III, and Bright Giant II)
type_M_count_ms = len(main_sequence_stars[main_sequence_stars["spectral_type"].str.contains('M') == True])
print(f"The count of host stars in the Type M category: {type_M_count_all}")
# Out:
# The count of host stars in the Type O category: 0
# The count of host stars in the Type B category: 4
# The count of host stars in the Type A category: 28
# The count of host stars in the Type F category: 959
# The count of host stars in the Type G category: 2504
# The count of host stars in the Type K category: 1439
# The count of host stars in the Type M category: 474

# %%
total_star_count_ms = type_O_count_ms + type_B_count_ms + type_A_count_ms + type_F_count_ms + type_G_count_ms + type_K_count_ms + type_M_count_ms
total_star_count_ms
# Out:
# 5047

# %%
# Store categories and counts
star_type_categories = [
    "Type M\n(Red Dwarf)\n2800K-3900K",
    "Type K\n3900K-5000K",
    "Type G\n5000K-6000K",
    "Type F\n6000K-7000K",
    "Type A\n7000K-10000K",
    "Type B\n10000K-30000K",
    "Type O\n>30000K"
]

counts = [
    type_M_count_ms,
    type_K_count_ms,
    type_G_count_ms,
    type_F_count_ms,
    type_A_count_ms,
    type_B_count_ms,
    type_O_count_ms
]

# Create DataFrame for plotting
star_counts_df = pd.DataFrame({
    "Star Type": star_type_categories,
    "# of Host Stars": counts
})

plt.figure(figsize=(11, 9))
ax = sns.barplot(
    data=star_counts_df,
    x="Star Type",
    y="# of Host Stars",
    palette=[
        "red",   # Type M
        "orange",   # Type K
        "yellow",   # Type G
        "tan",   # Type F
        "lightblue",   # Type A
        "blue",   # Type B
        "darkblue"    # Type O
    ]
)

plt.title("Distribution of all 5,047 Main Sequence (V) Extrasolar Stars")

# Add counts and percentages on tope of each bar
total = star_counts_df["# of Host Stars"].sum()

for i, bar in enumerate(ax.patches):
    height = bar.get_height()
    percentage = (height / total) * 100

    ax.text(
        bar.get_x() + bar.get_width()/2,
        height,
        f'{int(height)}\n({percentage:.1f}%)',
        ha='center',
        va='bottom',
        fontsize=10
    )

plt.xticks(rotation=0, ha='center')
plt.tight_layout()
plt.show()

# %%
# Store categories and counts
star_type_categories = [
    "Type M\n(Red Dwarf)\n2800K-3900K",
    "Type K\n3900K-5000K",
    "Type G\n5000K-6000K",
    "Type F\n6000K-7000K",
    "Type A\n7000K-10000K",
    "Type B\n10000K-30000K",
    "Type O\n>30000K"
]

counts = [
    type_M_count_ms,
    type_K_count_ms,
    type_G_count_ms,
    type_F_count_ms,
    type_A_count_ms,
    type_B_count_ms,
    type_O_count_ms
]

# Create DataFrame for plotting
star_counts_df = pd.DataFrame({
    "Star Type": star_type_categories,
    "# of Host Stars": counts
})

plt.figure(figsize=(12, 10), facecolor='black')
ax = sns.barplot(
    data=star_counts_df,
    x="Star Type",
    y="# of Host Stars",
    palette=[
        "red",   # Type M
        "orange",   # Type K
        "yellow",   # Type G
        "tan",   # Type F
        "lightblue",   # Type A
        "blue",   # Type B
        "darkblue"    # Type O
    ]
)
ax.set_facecolor('black')

plt.title("Distribution of all 5,047 Main Sequence (V) Extrasolar Stars", color='white', fontweight='bold', fontsize=15)

# Add counts and percentages on tope of each bar
total = star_counts_df["# of Host Stars"].sum()

for i, bar in enumerate(ax.patches):
    height = bar.get_height()
    percentage = (height / total) * 100

    ax.text(
        bar.get_x() + bar.get_width()/2,
        height,
        f'{int(height)}\n({percentage:.1f}%)',
        ha='center',
        va='bottom',
        fontsize=11.5,
        color='white',
        fontweight='bold'
    )

plt.xticks(rotation=0, ha='center', fontweight='bold')
ax.tick_params(colors='white')

plt.xlabel("Star Type", color="white", fontweight='bold', fontsize=13)
plt.ylabel("# of Host Stars", color="white", fontweight='bold', fontsize=13)

for spine in ax.spines.values():
    spine.set_color('white')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### 9) Which Telescope Mission and/or Observatory discovered the greatest number of exoplanets?

# %%
new_exoplanets_filtered3['discovery_facility'].value_counts()
# Out:
# discovery_facility
# Kepler                                            2773
# Transiting Exoplanet Survey Satellite (TESS)       721
# K2                                                 536
# La Silla Observatory                               227
# Multiple Observatories                             208
# W. M. Keck Observatory                             178
# SuperWASP                                          116
# HATSouth                                            73
# HATNet                                              64
# Haute-Provence Observatory                          42
# Okayama Astrophysical Observatory                   36
# Roque de los Muchachos Observatory                  36
# CoRoT                                               35
# Lick Observatory                                    35
# SuperWASP-South                                     32
# Anglo-Australian Telescope                          29
# McDonald Observatory                                28
# Bohyunsan Optical Astronomical Observatory          26
# Calar Alto Observatory                              25
# Next-Generation Transit Survey (NGTS)               22
# Paranal Observatory                                 20
# WASP-South                                          11
# Multiple Facilities                                 11
# Gemini Observatory                                  10
# Qatar                                               10
# Las Campanas Observatory                             9
# KELT                                                 9
# Subaru Telescope                                     8
# OGLE                                                 8
# KELT-North                                           7
# XO                                                   6
# European Space Agency (ESA) Gaia Satellite           6
# Fred Lawrence Whipple Observatory                    6
# Thueringer Landessternwarte Tautenburg               6
# TrES                                                 5
# SuperWASP-North                                      5
# Mauna Kea Observatory                                4
# CHaracterising ExOPlanets Satellite (CHEOPS)         3
# Lowell Observatory                                   3
# KELT-South                                           3
# Cerro Tololo Inter-American Observatory              2
# Xinglong Station                                     2
# MEarth Project                                       2
# Zwicky Transient Facility                            2
# Acton Sky Portal Observatory                         2
# SPECULOOS Southern Observatory                       2
# Haleakala Observatory                                2
# United Kingdom Infrared Telescope                    2
# NASA Infrared Telescope Facility (IRTF)              1
# Wide-field Infrared Survey Explorer (WISE) Sat       1
# Hubble Space Telescope                               1
# Spitzer Space Telescope                              1
# Atacama Large Millimeter Array (ALMA)                1
# Apache Point Observatory                             1
# Kitt Peak National Observatory                       1
# Palomar Observatory                                  1
# European Southern Observatory                        1
# Winer Observatory                                    1
# University of Canterbury Mt John Observatory         1
# Name: count, dtype: int64

# %% [markdown]
# #### 10) What is the Distribution of Exoplanet Mass?

# %%
# viewing the total number of planets that are Dwarf Like in mass (1 > Mp)
dwarf_like_count = len(new_exoplanets_filtered3[(new_exoplanets_filtered3["planet_mass_earth_mass"] < 1)])
print("Number of Earth-like planets:", dwarf_like_count)

# viewing the total number of planets that are Earth Like in mass (1 <= Mp < 2)
earth_like_count = len(new_exoplanets_filtered3[(new_exoplanets_filtered3["planet_mass_earth_mass"] >= 1) &
 (new_exoplanets_filtered3["planet_mass_earth_mass"] < 2)])
print("Number of Earth-like planets:", earth_like_count)

# viewing the total number of planets that are Super-Earth Like in mass (2 <= Mp < 8)
super_earth_like_count = len(new_exoplanets_filtered3[(new_exoplanets_filtered3["planet_mass_earth_mass"] >= 2) &
 (new_exoplanets_filtered3["planet_mass_earth_mass"] < 8)])
print("Number of Super-Earth like planets:", super_earth_like_count)

# viewing the total number of planets that are Neptune Like in mass (8 <= Mp <= 40)
neptune_like_count = len(new_exoplanets_filtered3[(new_exoplanets_filtered3["planet_mass_earth_mass"] >= 8) &
 (new_exoplanets_filtered3["planet_mass_earth_mass"] <= 40)])
print("Number of Neptune like planets:", neptune_like_count)

# viewing the total number of planets that are Super-Neptune Like in mass (40 < Mp <= 80)
super_neptune_like_count = len(new_exoplanets_filtered3[(new_exoplanets_filtered3["planet_mass_earth_mass"] > 40) &
 (new_exoplanets_filtered3["planet_mass_earth_mass"] <= 80)])
print("Number of Super-Neptune like planets:", super_neptune_like_count)

# viewing the total number of planets that are Saturn Like in mass (80 < Mp <= 150)
saturn_like_count = len(new_exoplanets_filtered3[(new_exoplanets_filtered3["planet_mass_earth_mass"] > 80) &
 (new_exoplanets_filtered3["planet_mass_earth_mass"] <= 150)])
print("Number of Saturn like planets:", saturn_like_count)

# viewing the total number of planets that are Super-Saturn Like in mass (150 < Mp < 318)
super_saturn_like_count = len(new_exoplanets_filtered3[(new_exoplanets_filtered3["planet_mass_earth_mass"] > 150) &
 (new_exoplanets_filtered3["planet_mass_earth_mass"] < 318)])
print("Number of Super-Saturn like planets:", super_saturn_like_count)

# viewing the total number of planets that are Jupiter Like in mass (318 <= Mp <= 3180)
jupiter_like_count = len(new_exoplanets_filtered3[(new_exoplanets_filtered3["planet_mass_earth_mass"] >= 318) &
 (new_exoplanets_filtered3["planet_mass_earth_mass"] <= 3180)])
print("Number of Jupiter like planets:", jupiter_like_count)

# viewing the total number of planets that are Super-Jupiter Like in mass (Mp > 3180)
super_jupiter_like_count = len(new_exoplanets_filtered3[(new_exoplanets_filtered3["planet_mass_earth_mass"] > 3180)])
print("Number of Super-Jupiter like planets:", super_jupiter_like_count)
# Out:
# Number of Earth-like planets: 206
# Number of Earth-like planets: 650
# Number of Super-Earth like planets: 2015
# Number of Neptune like planets: 794
# Number of Super-Neptune like planets: 235
# Number of Saturn like planets: 224
# Number of Super-Saturn like planets: 370
# Number of Jupiter like planets: 819
# Number of Super-Jupiter like planets: 106

# %%
total_mass = dwarf_like_count + earth_like_count + super_earth_like_count + neptune_like_count + super_neptune_like_count + saturn_like_count + super_saturn_like_count + jupiter_like_count + super_jupiter_like_count
total_mass
# Out:
# 5419

# %%
total_mass2 = earth_like_count + super_earth_like_count + neptune_like_count + super_neptune_like_count + saturn_like_count + super_saturn_like_count + jupiter_like_count + super_jupiter_like_count
total_mass2
# Out:
# 5213

# %%
# Store categories and counts
categories = [
    "Earth-like\n(1 <= Mp < 2)",
    "Super-Earth-like\n(2 <= Mp < 8)",
    "Neptune-like\n(8 <= Mp <= 40)",
    "Super-Neptune-like\n(40 < Mp <= 80)",
    "Saturn-like\n(80 < Mp <= 150)",
    "Super-Saturn-like\n(150 < Mp < 318)",
    "Jupiter-like\n(318 <= Mp <= 3180)",
    "Super-Jupiter-like\n(Mp > 3180)"
]

counts = [
    earth_like_count,
    super_earth_like_count,
    neptune_like_count,
    super_neptune_like_count,
    saturn_like_count,
    super_saturn_like_count,
    jupiter_like_count,
    super_jupiter_like_count
]

# Create DataFrame for plotting
planet_counts_df = pd.DataFrame({
    "Mass of Exoplanet in Earth Mass": categories,
    "# of Exoplanets": counts
})

plt.figure(figsize=(9, 9))
ax = sns.barplot(
    data=planet_counts_df,
    x="Mass of Exoplanet in Earth Mass",
    y="# of Exoplanets",
    palette=[
        "#03A9F4",   # Earth-like
        "darkblue",   # Super-Earth
        "yellowgreen",   # Neptune-like
        "green",   # Super-Neptune-like
        "orange",   # Saturn-like
        "orangered",   # Super-Saturn
        "palevioletred",   # Jupiter-like
        "maroon"    # Super-Jupiter
    ]
)

plt.xticks(rotation=45, ha="right")
plt.title("Distribution of 5,213 of All 5,419 Confirmed Exoplanets by Mass Category")

# Add counts and percentages on tope of each bar
total = planet_counts_df["# of Exoplanets"].sum()

for i, bar in enumerate(ax.patches):
    height = bar.get_height()
    percentage = (height / total) * 100

    ax.text(
        bar.get_x() + bar.get_width()/2,
        height,
        f'{int(height)}\n({percentage:.1f}%)',
        ha='center',
        va='bottom',
        fontsize=10
    )

plt.tight_layout()
plt.show()

# %%
# Store categories and counts
categories = [
    "Dwarf-like\n(1 > Mp)",
    "Earth-like\n(1 <= Mp < 2)",
    "Super-Earth-like\n(2 <= Mp < 8)",
    "Neptune-like\n(8 <= Mp <= 40)",
    "Super-Neptune-like\n(40 < Mp <= 80)",
    "Saturn-like\n(80 < Mp <= 150)",
    "Super-Saturn-like\n(150 < Mp < 318)",
    "Jupiter-like\n(318 <= Mp <= 3180)",
    "Super-Jupiter-like\n(Mp > 3180)"
]

counts = [
    dwarf_like_count,
    earth_like_count,
    super_earth_like_count,
    neptune_like_count,
    super_neptune_like_count,
    saturn_like_count,
    super_saturn_like_count,
    jupiter_like_count,
    super_jupiter_like_count
]

# Create DataFrame for plotting
planet_counts_df = pd.DataFrame({
    "Mass of Exoplanet in Earth Mass": categories,
    "# of Exoplanets": counts
})

plt.figure(figsize=(9, 9))
ax = sns.barplot(
    data=planet_counts_df,
    x="Mass of Exoplanet in Earth Mass",
    y="# of Exoplanets",
    palette=[
        "indigo",  # Dwarf-like
        "#03A9F4",   # Earth-like
        "darkblue",   # Super-Earth
        "yellowgreen",   # Neptune-like
        "green",   # Super-Neptune-like
        "orange",   # Saturn-like
        "orangered",   # Super-Saturn
        "palevioletred",   # Jupiter-like
        "maroon"    # Super-Jupiter
    ]
)

plt.xticks(rotation=45, ha="right")
plt.title("Distribution of All 5,419 Confirmed Exoplanets by Mass Category")

# Add counts and percentages on tope of each bar
total = planet_counts_df["# of Exoplanets"].sum()

for i, bar in enumerate(ax.patches):
    height = bar.get_height()
    percentage = (height / total) * 100

    ax.text(
        bar.get_x() + bar.get_width()/2,
        height,
        f'{int(height)}\n({percentage:.1f}%)',
        ha='center',
        va='bottom',
        fontsize=10
    )

plt.tight_layout()
plt.show()

# %%
# Store categories and counts
categories = [
    "Dwarf-like\n(1 > Mp)",
    "Earth-like\n(1 <= Mp < 2)",
    "Super-Earth-like\n(2 <= Mp < 8)",
    "Neptune-like\n(8 <= Mp <= 40)",
    "Super-Neptune-like\n(40 < Mp <= 80)",
    "Saturn-like\n(80 < Mp <= 150)",
    "Super-Saturn-like\n(150 < Mp < 318)",
    "Jupiter-like\n(318 <= Mp <= 3180)",
    "Super-Jupiter-like\n(Mp > 3180)"
]

counts = [
    dwarf_like_count,
    earth_like_count,
    super_earth_like_count,
    neptune_like_count,
    super_neptune_like_count,
    saturn_like_count,
    super_saturn_like_count,
    jupiter_like_count,
    super_jupiter_like_count
]

# Create DataFrame for plotting
planet_counts_df = pd.DataFrame({
    "Mass of Exoplanet in Earth Mass": categories,
    "# of Exoplanets": counts
})

plt.figure(figsize=(9.5, 9.5), facecolor='black')
ax = sns.barplot(
    data=planet_counts_df,
    x="Mass of Exoplanet in Earth Mass",
    y="# of Exoplanets",
    palette=[
        "indigo",  # Dwarf-like
        "#03A9F4",   # Earth-like
        "darkblue",   # Super-Earth
        "yellowgreen",   # Neptune-like
        "green",   # Super-Neptune-like
        "orange",   # Saturn-like
        "orangered",   # Super-Saturn
        "palevioletred",   # Jupiter-like
        "maroon"    # Super-Jupiter
    ]
)
ax.set_facecolor('black')

plt.title("Distribution of All 5,419 Confirmed Exoplanets by Mass Category", color='white', fontweight='bold', fontsize=13)

# Add counts and percentages on tope of each bar
total = planet_counts_df["# of Exoplanets"].sum()

for i, bar in enumerate(ax.patches):
    height = bar.get_height()
    percentage = (height / total) * 100

    ax.text(
        bar.get_x() + bar.get_width()/2,
        height,
        f'{int(height)}\n({percentage:.1f}%)',
        ha='center',
        va='bottom',
        fontsize=10.5,
        color='white',
        fontweight='bold'
    )

plt.xticks(rotation=35, ha="right", fontweight='bold')
ax.tick_params(colors='white')

plt.xlabel("Mass of Exoplanet in Earth Mass", color="white", fontweight='bold', fontsize=13)
plt.ylabel("# of Exoplanets", color="white", fontweight='bold', fontsize=13)

for spine in ax.spines.values():
    spine.set_color('white')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### 11) What is the Distribution of Exoplanet Radius?

# %%
# viewing the total number of planets that are Earth Like in radius (Rp <= 1.5)
earth_like_count_rad = len(new_exoplanets_filtered3[(new_exoplanets_filtered3["planet_rad_earth_rad"] <= 1.5)])
print("Number of Earth-like planets:", earth_like_count_rad)

# viewing the total number of planets that are Super-Earth Like in radius (1.5 < Rp <= 2)
super_earth_like_count_rad = len(new_exoplanets_filtered3[(new_exoplanets_filtered3["planet_rad_earth_rad"] > 1.5) &
 (new_exoplanets_filtered3["planet_rad_earth_rad"] <= 2)])
print("Number of Super-Earth like planets:", super_earth_like_count_rad)

# viewing the total number of planets that are Neptune Like in radius (2 < Rp <= 4)
neptune_like_count_rad = len(new_exoplanets_filtered3[(new_exoplanets_filtered3["planet_rad_earth_rad"] > 2) &
 (new_exoplanets_filtered3["planet_rad_earth_rad"] <= 4)])
print("Number of Neptune like planets:", neptune_like_count_rad)

# viewing the total number of planets that are Neptune Like in radius (4 < Rp <= 6)
super_neptune_like_count_rad = len(new_exoplanets_filtered3[(new_exoplanets_filtered3["planet_rad_earth_rad"] > 4) &
 (new_exoplanets_filtered3["planet_rad_earth_rad"] <= 6)])
print("Number of Super-Neptune like planets:", super_neptune_like_count_rad)

# viewing the total number of planets that are Saturn Like in radius (6 < Rp <= 9)
saturn_like_count_rad = len(new_exoplanets_filtered3[(new_exoplanets_filtered3["planet_rad_earth_rad"] > 6) &
 (new_exoplanets_filtered3["planet_rad_earth_rad"] <= 9)])
print("Number of Saturn like planets:", saturn_like_count_rad)

# viewing the total number of planets that are Super-Saturn Like in radius (9 < Rp <= 11)
super_saturn_like_count_rad = len(new_exoplanets_filtered3[(new_exoplanets_filtered3["planet_rad_earth_rad"] > 9) &
 (new_exoplanets_filtered3["planet_rad_earth_rad"] <= 11)])
print("Number of Super-Saturn like planets:", super_saturn_like_count_rad)

# viewing the total number of planets that are Jupiter Like in radius (11 < Rp <= 15)
jupiter_like_count_rad = len(new_exoplanets_filtered3[(new_exoplanets_filtered3["planet_rad_earth_rad"] > 11) &
 (new_exoplanets_filtered3["planet_rad_earth_rad"] <= 15)])
print("Number of Jupiter like planets:", jupiter_like_count_rad)

# viewing the total number of planets that are Super-Jupiter Like in radius (Rp > 15)
super_jupiter_like_count_rad = len(new_exoplanets_filtered3[(new_exoplanets_filtered3["planet_rad_earth_rad"] > 15)])
print("Number of Super-Jupiter like planets:", super_jupiter_like_count_rad)
# Out:
# Number of Earth-like planets: 962
# Number of Super-Earth like planets: 750
# Number of Neptune like planets: 1881
# Number of Super-Neptune like planets: 240
# Number of Saturn like planets: 184
# Number of Super-Saturn like planets: 176
# Number of Jupiter like planets: 527
# Number of Super-Jupiter like planets: 699

# %%
total_rad = earth_like_count_rad + super_earth_like_count_rad + neptune_like_count_rad + super_neptune_like_count_rad + saturn_like_count_rad + super_saturn_like_count_rad + jupiter_like_count_rad + super_jupiter_like_count_rad
total_rad
# Out:
# 5419

# %%
# Store categories and counts
categories = [
    "Earth-like\n(Rp <= 1.5)",
    "Super-Earth-like\n(1.5 < Rp <= 2)",
    "Neptune-like\n(2 < Rp <= 4)",
    "Super-Neptune-like\n(4 < Rp <= 6)",
    "Saturn-like\n(6 < Rp <= 9)",
    "Super-Saturn-like\n(9 < Rp <= 11)",
    "Jupiter-like\n(11 < Rp <= 15)",
    "Super-Jupiter-like\n(Rp > 15)"
]

counts = [
    earth_like_count_rad,
    super_earth_like_count_rad,
    neptune_like_count_rad,
    super_neptune_like_count_rad,
    saturn_like_count_rad,
    super_saturn_like_count_rad,
    jupiter_like_count_rad,
    super_jupiter_like_count_rad
]

# Create DataFrame for plotting
planet_counts_df = pd.DataFrame({
    "Radius of Exoplanet in Earth Radius": categories,
    "# of Exoplanets": counts
})

plt.figure(figsize=(9, 9))
ax = sns.barplot(
    data=planet_counts_df,
    x="Radius of Exoplanet in Earth Radius",
    y="# of Exoplanets",
    palette=[
        "#03A9F4",   # Earth-like
        "darkblue",   # Super-Earth
        "yellowgreen",   # Neptune-like
        "green",   # Super-Neptune-like
        "orange",   # Saturn-like
        "orangered",   # Super-Saturn
        "palevioletred",   # Jupiter-like
        "maroon"    # Super-Jupiter
    ]
)

plt.xticks(rotation=45, ha="right")
plt.title("Distribution of All 5.419 Confirmed Exoplanets by Radius Category")

# Add counts and percentages on tope of each bar
total = planet_counts_df["# of Exoplanets"].sum()

for i, bar in enumerate(ax.patches):
    height = bar.get_height()
    percentage = (height / total) * 100

    ax.text(
        bar.get_x() + bar.get_width()/2,
        height,
        f'{int(height)}\n({percentage:.1f}%)',
        ha='center',
        va='bottom',
        fontsize=10
    )

plt.tight_layout()
plt.show()

# %%
# Store categories and counts
categories = [
    "Earth-like\n(Rp <= 1.5)",
    "Super-Earth-like\n(1.5 < Rp <= 2)",
    "Neptune-like\n(2 < Rp <= 4)",
    "Super-Neptune-like\n(4 < Rp <= 6)",
    "Saturn-like\n(6 < Rp <= 9)",
    "Super-Saturn-like\n(9 < Rp <= 11)",
    "Jupiter-like\n(11 < Rp <= 15)",
    "Super-Jupiter-like\n(Rp > 15)"
]

counts = [
    earth_like_count_rad,
    super_earth_like_count_rad,
    neptune_like_count_rad,
    super_neptune_like_count_rad,
    saturn_like_count_rad,
    super_saturn_like_count_rad,
    jupiter_like_count_rad,
    super_jupiter_like_count_rad
]

# Create DataFrame for plotting
planet_counts_df = pd.DataFrame({
    "Radius of Exoplanet in Earth Radius": categories,
    "# of Exoplanets": counts
})

plt.figure(figsize=(9.5, 9.5), facecolor='black')
ax = sns.barplot(
    data=planet_counts_df,
    x="Radius of Exoplanet in Earth Radius",
    y="# of Exoplanets",
    palette=[
        "#03A9F4",   # Earth-like
        "darkblue",   # Super-Earth
        "yellowgreen",   # Neptune-like
        "green",   # Super-Neptune-like
        "orange",   # Saturn-like
        "orangered",   # Super-Saturn
        "palevioletred",   # Jupiter-like
        "maroon"    # Super-Jupiter
    ]
)
ax.set_facecolor('black')

plt.title("Distribution of All 5.419 Confirmed Exoplanets by Radius Category", color='white', fontweight='bold', fontsize=15)

# Add counts and percentages on tope of each bar
total = planet_counts_df["# of Exoplanets"].sum()

for i, bar in enumerate(ax.patches):
    height = bar.get_height()
    percentage = (height / total) * 100

    ax.text(
        bar.get_x() + bar.get_width()/2,
        height,
        f'{int(height)}\n({percentage:.1f}%)',
        ha='center',
        va='bottom',
        fontsize=10.5,
        color='white',
        fontweight='bold'
    )

plt.xticks(rotation=35, ha="right", fontweight='bold')
ax.tick_params(colors='white')

plt.xlabel("Radius of Exoplanet in Earth Radius", color="white", fontweight='bold', fontsize=13)
plt.ylabel("# of Exoplanets", color="white", fontweight='bold', fontsize=13)

for spine in ax.spines.values():
    spine.set_color('white')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### 12) What is the Distribution of Exoplanet Orbital Period in Earth Days?

# %%
bins = list(range(0, 1400, 100))
bins.append(float("inf"))

labels = [f"{i}-{i+100}" for i in range(0, 1300, 100)]
labels.append(">1300")

new_exoplanets_filtered3["period_bin"] = pd.cut(
    new_exoplanets_filtered3["orbital_period_day"],
    bins=bins,
    labels=labels,
    right=False
)

period_counts = new_exoplanets_filtered3["period_bin"].value_counts().sort_index()

# Create color list
colors = ["#e31eeb"] * len(period_counts)

# Find index of the 300-400 bin
highlight_index = period_counts.index.get_loc("300-400")

# Change that one to blue
colors[highlight_index] = "#03A9F4"

plt.figure(figsize=(13, 9), facecolor='black')

period_counts.plot(
    kind="bar",
    color=colors,
    edgecolor=colors
)

plt.xlabel("Orbital Period in Earth Days", fontsize=13, fontweight='bold', color='white')
plt.ylabel("# of Exoplanets", fontsize=13, fontweight='bold', color='white')
plt.title("Distribution of Orbital Periods for all 5,419 Confirmed Exoplanets", fontsize=15, fontweight='bold', color='white')

# Add labels
total = period_counts.sum()
ax = plt.gca()
ax.set_facecolor('black')

for bar in ax.patches:
    height = bar.get_height()
    percentage = (height / total) * 100

    ax.text(
        bar.get_x() + bar.get_width()/2,
        height,
        f'{int(height)}\n({percentage:.1f}%)',
        ha='center',
        va='bottom',
        fontsize=10,
        color='white',
        fontweight='bold'
    )

for spine in ax.spines.values():
    spine.set_color('white')

plt.xticks(rotation=45, fontsize=10, color='white', fontweight='bold')
plt.yticks(fontsize=10, color='white')
plt.tight_layout()
plt.show()

# %%
period_counts = new_exoplanets_filtered3["period_bin"].value_counts().sort_index()
period_counts
# Out:
# period_bin
# 0-100        4623
# 100-200       186
# 200-300        88
# 300-400        63
# 400-500        59
# 500-600        40
# 600-700        40
# 700-800        18
# 800-900        29
# 900-1000       30
# 1000-1100      19
# 1100-1200      16
# 1200-1300      13
# >1300         195
# Name: count, dtype: int64

# %% [markdown]
# #### 13) What is the Distribution of Distance between Exoplanet and its Host Star in AU?

# %%
bins = list(range(0, 8, 1))
bins.append(float("inf"))

labels = [f"{i}-{i+1}" for i in range(0, 7, 1)]
labels.append(">7")

new_exoplanets_filtered3["distance_bin"] = pd.cut(
    new_exoplanets_filtered3["orbit_semi_major_axis_au"],
    bins=bins,
    labels=labels,
    right=False
)

distance_counts = new_exoplanets_filtered3["distance_bin"].value_counts().sort_index()

# Create color list
colors = ["#e31eeb"] * len(distance_counts)

# Find index of the 0-1 bin
highlight_index = distance_counts.index.get_loc("0-1")

# Change that one to blue
colors[highlight_index] = "#03A9F4"

plt.figure(figsize=(13, 9), facecolor='black')

distance_counts.plot(
    kind="bar",
    color=colors,
    edgecolor=colors
)

plt.xlabel("Distance Between Exoplanets and their Host Stars in AU", fontsize=13, fontweight='bold', color='white')
plt.ylabel("# of Exoplanets", fontsize=13, fontweight='bold', color='white')
plt.title("Distribution of Distance Between Exoplanets and their Host Stars for all 5,419 Confirmed Exoplanets", fontsize=15, fontweight='bold', color='white')

# Add labels
total = distance_counts.sum()
ax = plt.gca()
ax.set_facecolor('black')

for bar in ax.patches:
    height = bar.get_height()
    percentage = (height / total) * 100

    ax.text(
        bar.get_x() + bar.get_width()/2,
        height,
        f'{int(height)}\n({percentage:.1f}%)',
        ha='center',
        va='bottom',
        fontsize=10,
        color='white',
        fontweight='bold'
    )

for spine in ax.spines.values():
    spine.set_color('white')

plt.xticks(rotation=0, fontsize=10, color='white', fontweight='bold')
plt.yticks(fontsize=10, color='white')
plt.tight_layout()
plt.show()

# %%
distance_counts = new_exoplanets_filtered3["distance_bin"].value_counts().sort_index()
distance_counts
# Out:
# distance_bin
# 0-1    4908
# 1-2     229
# 2-3     113
# 3-4      53
# 4-5      31
# 5-6      22
# 6-7      11
# >7       52
# Name: count, dtype: int64

# %% [markdown]
# #### 14) What is the Distribution of Exoplanet Equilibrium Temperature in Kelvin?

# %%
bins = list(range(0, 2400, 200))
bins.append(float("inf"))

labels = [f"{i}-{i+200}" for i in range(0, 2200, 200)]
labels.append(">2400")

new_exoplanets_filtered3["planet_temp_bin"] = pd.cut(
    new_exoplanets_filtered3["planet_equil_temp_k"],
    bins=bins,
    labels=labels,
    right=False
)

planet_temp_counts = new_exoplanets_filtered3["planet_temp_bin"].value_counts().sort_index()

# Create color list
colors = ["#e31eeb"] * len(planet_temp_counts)

# Find index of the 200-400 bin
highlight_index = planet_temp_counts.index.get_loc("200-400")

# Change that one to blue
colors[highlight_index] = "#03A9F4"

plt.figure(figsize=(14, 9), facecolor='black')

planet_temp_counts.plot(
    kind="bar",
    color=colors,
    edgecolor=colors
)

plt.xlabel("Planet Equilibrium Temperature in Kelvin (K)", fontsize=13, fontweight='bold', color='white')
plt.ylabel("# of Exoplanets", fontsize=13, fontweight='bold', color='white')
plt.title("Distribution of Equilibrium Temperature for 5,419 Confirmed Exoplanets", fontsize=15, fontweight='bold', color='white')

# Add labels
total = distance_counts.sum()
ax = plt.gca()
ax.set_facecolor('black')

for bar in ax.patches:
    height = bar.get_height()
    percentage = (height / total) * 100

    ax.text(
        bar.get_x() + bar.get_width()/2,
        height,
        f'{int(height)}\n({percentage:.1f}%)',
        ha='center',
        va='bottom',
        fontsize=10,
        color='white',
        fontweight='bold'
    )

for spine in ax.spines.values():
    spine.set_color('white')

plt.xticks(rotation=0, fontsize=10, color='white', fontweight='bold')
plt.yticks(fontsize=10, color='white')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 15) What is the Distribution of Discovery Methods?

# %%
plt.figure(figsize=(10, 9))

method_counts = new_exoplanets_filtered3['discovery_method'].value_counts()

method_counts.plot(
    kind='bar',
    color = [
    "#4CAF50",   # Transit
    "#03A9F4",   # Radial Velocity
    "#FF9800",   # Microlensing
    "#9C27B0",   # Imaging
    "#F44336",   # Transit Timing Variations
    "#795548",   # Astrometry
    "#607D8B"    # Other (if present)
]
)

plt.xlabel("Discovery Method")
plt.ylabel("Number of Exoplanets")
plt.title("Distribution of All 5,419 Exoplanet Discovery Methods")

# Add labels
total = method_counts.sum()
ax = plt.gca()

for bar in ax.patches:
    height = bar.get_height()
    percentage = (height / total) * 100

    ax.text(
        bar.get_x() + bar.get_width()/2,
        height,
        f'{int(height)}\n({percentage:.1f}%)',
        ha='center',
        va='bottom',
        fontsize=8
    )

plt.xticks(rotation=45, ha='right')
plt.ylim(0, max(method_counts) * 1.15)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 16) What is the Distribution of Discovery Years?

# %%
new_exoplanets_filtered3['year_of_discovery'] = (new_exoplanets_filtered3['year_of_discovery'].astype(int))

plt.figure(figsize=(13, 8), facecolor='black')

# Sort by year chronological
year_counts = (
    new_exoplanets_filtered3['year_of_discovery']
    .value_counts()
    .sort_index()
)

ax = plt.gca()
ax.set_facecolor('black')

year_counts.plot(
    kind='bar',
    color = '#c4260e'
)

plt.xlabel("Year of Discovery", fontsize=13, fontweight='bold', color='white')
plt.ylabel("Number of Exoplanets", fontsize=13, fontweight='bold', color='white')
plt.title("Distribution of All 5,419 Exoplanet Discovery Year", fontsize=15, fontweight='bold', color='white')

for spine in ax.spines.values():
    spine.set_color('white')

plt.xticks(rotation=45, ha='right', fontsize=10, color='white', fontweight='bold')
plt.yticks(fontsize=10, color='white')
plt.ylim(0, max(year_counts) * 1.15)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##**Key Feature Selection for Modeling**

# %%
new_exoplanets_filtered3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5419 entries, 0 to 6070
# Data columns (total 23 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   planet_name                     5419 non-null   object
#  1   host_star_name                  5419 non-null   object
#  2   star_number_per_system          5419 non-null   float64
#  3   discovery_method                5419 non-null   object
#  4   year_of_discovery               5419 non-null   int64
#  5   discovery_facility              5419 non-null   object
#  6   spectral_type                   5419 non-null   object
#  7   orbital_period_day              5419 non-null   float64
#  8   orbit_semi_major_axis_au        5419 non-null   float64
#  9   planet_rad_earth_rad            5419 non-null   float64
#  10  planet_mass_earth_mass          5419 non-null   float64
#  11  planet_equil_temp_k             5419 non-null   float64
#  12  stellar_effective_temp_k        5419 non-null   float64
#  13  stellar_rad_solar_rad           5419 non-null   float64
#  14  stellar_mass_solar_mass         5419 non-null   float64
#  15  stellar_surf_grav               5419 non-null   float64
#  16  stellar_mass_imputation_method  5419 non-null   object
#  17  stellar_luminosity_solar_lum    5419 non-null   float64
#  18  planet_orbital_velocity         5419 non-null   float64
#  19  habitable_zone_main_seq         5419 non-null   int64
#  20  period_bin                      5419 non-null   category
#  21  distance_bin                    5419 non-null   category
#  22  planet_temp_bin                 5419 non-null   category
# dtypes: category(3), float64(12), int64(2), object(6)
# memory usage: 906.3+ KB

# %%
# creating copy of dataset
new_exoplanets_filtered4 = new_exoplanets_filtered3.copy()

# %%
# conducting key feature selection by removing uneeded columns
new_exoplanets_filtered4 = new_exoplanets_filtered4.drop(columns=['planet_temp_bin',
                                                                  'distance_bin',
                                                                  'period_bin',
                                                                  'stellar_mass_imputation_method',
                                                                  'discovery_facility',
                                                                  'year_of_discovery',
                                                                  'discovery_method',
                                                                  'host_star_name'])

# %%
new_exoplanets_filtered4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5419 entries, 0 to 6070
# Data columns (total 15 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   planet_name                   5419 non-null   object
#  1   star_number_per_system        5419 non-null   float64
#  2   spectral_type                 5419 non-null   object
#  3   orbital_period_day            5419 non-null   float64
#  4   orbit_semi_major_axis_au      5419 non-null   float64
#  5   planet_rad_earth_rad          5419 non-null   float64
#  6   planet_mass_earth_mass        5419 non-null   float64
#  7   planet_equil_temp_k           5419 non-null   float64
#  8   stellar_effective_temp_k      5419 non-null   float64
#  9   stellar_rad_solar_rad         5419 non-null   float64
#  10  stellar_mass_solar_mass       5419 non-null   float64
#  11  stellar_surf_grav             5419 non-null   float64
#  12  stellar_luminosity_solar_lum  5419 non-null   float64
#  13  planet_orbital_velocity       5419 non-null   float64
#  14  habitable_zone_main_seq       5419 non-null   int64
# dtypes: float64(12), int64(1), object(2)
# memory usage: 677.4+ KB

# %% [markdown]
# There are 15 features where 14 are key features and 1 is the planet_name which is the observation.

# %%
# save this dataframe
#new_exoplanets_filtered4.to_csv('filtered_2026_dataset_new_final3.csv', index=False)
