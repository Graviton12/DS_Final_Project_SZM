# %% [markdown]
# # **Exoplanet Habitablity Prediction Exploratory Data Analysis**

# %%
# Importing
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## **Initial Data Preprocessing**

# %%
# loading dataset
df = pd.read_excel('/content/drive/MyDrive/Exoplanet /exoplanet_habitability_data.xlsx')

# %%
# Viewing the first 5 rows of the dataset
df.head()
# Out:
#     pl_name hostname  default_flag  sy_snum  sy_pnum  discoverymethod  \
# 0  11 Com b   11 Com             1        2        1  Radial Velocity
# 1  11 Com b   11 Com             0        2        1  Radial Velocity
# 2  11 Com b   11 Com             0        2        1  Radial Velocity
# 3  11 UMi b   11 UMi             0        1        1  Radial Velocity
# 4  11 UMi b   11 UMi             1        1        1  Radial Velocity
#
#    disc_year                           disc_facility              soltype  \
# 0       2007                        Xinglong Station  Published Confirmed
# 1       2007                        Xinglong Station  Published Confirmed
# 2       2007                        Xinglong Station  Published Confirmed
# 3       2009  Thueringer Landessternwarte Tautenburg  Published Confirmed
# 4       2009  Thueringer Landessternwarte Tautenburg  Published Confirmed
#
#    pl_controv_flag  ... sy_vmagerr2  sy_kmag  sy_kmagerr1  sy_kmagerr2  \
# 0                0  ...      -0.023    2.282        0.346       -0.346
# 1                0  ...      -0.023    2.282        0.346       -0.346
# 2                0  ...      -0.023    2.282        0.346       -0.346
# 3                0  ...      -0.005    1.939        0.270       -0.270
# 4                0  ...      -0.005    1.939        0.270       -0.270
#
#    sy_gaiamag  sy_gaiamagerr1  sy_gaiamagerr2  rowupdate  pl_pubdate  \
# 0     4.44038        0.003848       -0.003848 2023-09-19     2023-08
# 1     4.44038        0.003848       -0.003848 2014-05-14     2008-01
# 2     4.44038        0.003848       -0.003848 2014-07-23     2011-08
# 3     4.56216        0.003903       -0.003903 2018-04-25     2009-10
# 4     4.56216        0.003903       -0.003903 2018-09-04     2017-03
#
#    releasedate
# 0   2023-09-19
# 1   2014-05-14
# 2   2014-07-23
# 3   2014-05-14
# 4   2018-09-06
#
# [5 rows x 92 columns]

# %%
# viewing dataset information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39235 entries, 0 to 39234
# Data columns (total 92 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pl_name          39235 non-null  object
#  1   hostname         39235 non-null  object
#  2   default_flag     39235 non-null  int64
#  3   sy_snum          39235 non-null  int64
#  4   sy_pnum          39235 non-null  int64
#  5   discoverymethod  39235 non-null  object
#  6   disc_year        39235 non-null  int64
#  7   disc_facility    39235 non-null  object
#  8   soltype          39235 non-null  object
#  9   pl_controv_flag  39235 non-null  int64
#  10  pl_refname       39235 non-null  object
#  11  pl_orbper        35942 non-null  float64
#  12  pl_orbpererr1    34256 non-null  float64
#  13  pl_orbpererr2    34255 non-null  float64
#  14  pl_orbperlim     35942 non-null  float64
#  15  pl_orbsmax       21968 non-null  float64
#  16  pl_orbsmaxerr1   7499 non-null   float64
#  17  pl_orbsmaxerr2   7498 non-null   float64
#  18  pl_orbsmaxlim    24754 non-null  float64
#  19  pl_rade          27053 non-null  float64
#  20  pl_radeerr1      26323 non-null  float64
#  21  pl_radeerr2      26323 non-null  float64
#  22  pl_radelim       29798 non-null  float64
#  23  pl_radj          27053 non-null  float64
#  24  pl_radjerr1      26323 non-null  float64
#  25  pl_radjerr2      26323 non-null  float64
#  26  pl_radjlim       27053 non-null  float64
#  27  pl_bmasse        7112 non-null   float64
#  28  pl_bmasseerr1    6452 non-null   float64
#  29  pl_bmasseerr2    6452 non-null   float64
#  30  pl_bmasselim     7112 non-null   float64
#  31  pl_bmassj        7111 non-null   float64
#  32  pl_bmassjerr1    6446 non-null   float64
#  33  pl_bmassjerr2    6446 non-null   float64
#  34  pl_bmassjlim     7111 non-null   float64
#  35  pl_bmassprov     7112 non-null   object
#  36  pl_orbeccen      18729 non-null  float64
#  37  pl_orbeccenerr1  3732 non-null   float64
#  38  pl_orbeccenerr2  3731 non-null   float64
#  39  pl_orbeccenlim   21472 non-null  float64
#  40  pl_insol         17124 non-null  float64
#  41  pl_insolerr1     15787 non-null  float64
#  42  pl_insolerr2     15787 non-null  float64
#  43  pl_insollim      22182 non-null  float64
#  44  pl_eqt           17215 non-null  float64
#  45  pl_eqterr1       2548 non-null   float64
#  46  pl_eqterr2       2548 non-null   float64
#  47  pl_eqtlim        19958 non-null  float64
#  48  ttv_flag         39235 non-null  int64
#  49  st_refname       38834 non-null  object
#  50  st_spectype      2901 non-null   object
#  51  st_teff          35743 non-null  float64
#  52  st_tefferr1      34981 non-null  float64
#  53  st_tefferr2      34721 non-null  float64
#  54  st_tefflim       35743 non-null  float64
#  55  st_rad           35978 non-null  float64
#  56  st_raderr1       30430 non-null  float64
#  57  st_raderr2       30277 non-null  float64
#  58  st_radlim        35978 non-null  float64
#  59  st_mass          33126 non-null  float64
#  60  st_masserr1      27704 non-null  float64
#  61  st_masserr2      27549 non-null  float64
#  62  st_masslim       33133 non-null  float64
#  63  st_met           24786 non-null  float64
#  64  st_meterr1       24113 non-null  float64
#  65  st_meterr2       24113 non-null  float64
#  66  st_metlim        27097 non-null  float64
#  67  st_metratio      24589 non-null  object
#  68  st_logg          30455 non-null  float64
#  69  st_loggerr1      25151 non-null  float64
#  70  st_loggerr2      25150 non-null  float64
#  71  st_logglim       30455 non-null  float64
#  72  sy_refname       39235 non-null  object
#  73  rastr            39235 non-null  object
#  74  ra               39235 non-null  float64
#  75  decstr           39235 non-null  object
#  76  dec              39235 non-null  float64
#  77  sy_dist          38389 non-null  float64
#  78  sy_disterr1      37532 non-null  float64
#  79  sy_disterr2      37532 non-null  float64
#  80  sy_vmag          38433 non-null  float64
#  81  sy_vmagerr1      38420 non-null  float64
#  82  sy_vmagerr2      38419 non-null  float64
#  83  sy_kmag          38424 non-null  float64
#  84  sy_kmagerr1      38182 non-null  float64
#  85  sy_kmagerr2      38182 non-null  float64
#  86  sy_gaiamag       38134 non-null  float64
#  87  sy_gaiamagerr1   38134 non-null  float64
#  88  sy_gaiamagerr2   38134 non-null  float64
#  89  rowupdate        39234 non-null  datetime64[ns]
#  90  pl_pubdate       39235 non-null  object
#  91  releasedate      39235 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), float64(70), int64(6), object(14)
# memory usage: 27.5+ MB

# %%
# looking at statistics of dataset
df.describe()
# Out:
#        default_flag       sy_snum       sy_pnum     disc_year  \
# count  39235.000000  39235.000000  39235.000000  39235.000000
# mean       0.154734      1.085281      1.918389   2015.536281
# min        0.000000      1.000000      1.000000   1992.000000
# 25%        0.000000      1.000000      1.000000   2014.000000
# 50%        0.000000      1.000000      1.000000   2016.000000
# 75%        0.000000      1.000000      2.000000   2016.000000
# max        1.000000      4.000000      8.000000   2026.000000
# std        0.361656      0.308527      1.238380      4.006345
#
#        pl_controv_flag     pl_orbper  pl_orbpererr1  pl_orbpererr2  \
# count     39235.000000  3.594200e+04   3.425600e+04   3.425500e+04
# mean          0.003109  1.217103e+04   1.408216e+04  -3.318888e+03
# min           0.000000  9.070629e-02   0.000000e+00  -1.000000e+08
# 25%           0.000000  4.385364e+00   8.000000e-06  -2.000000e-04
# 50%           0.000000  1.033116e+01   3.812000e-05  -3.817000e-05
# 75%           0.000000  2.662946e+01   2.000000e-04  -8.000000e-06
# max           1.000000  4.020000e+08   4.700000e+08   0.000000e+00
# std           0.055677  2.121667e+06   2.539574e+06   5.415493e+05
#
#        pl_orbperlim    pl_orbsmax  ...   sy_vmagerr1   sy_vmagerr2  \
# count  35942.000000  21968.000000  ...  38420.000000  38419.000000
# mean      -0.000250      4.727418  ...      0.115940     -0.116524
# min       -1.000000      0.004400  ...      0.001000    -12.270000
# 25%        0.000000      0.054500  ...      0.046000     -0.137000
# 50%        0.000000      0.100735  ...      0.092000     -0.092000
# 75%        0.000000      0.219012  ...      0.137000     -0.046000
# max        1.000000  19000.000000  ...     11.000000     -0.001000
# std        0.020428    180.936826  ...      0.150125      0.179291
#
#             sy_kmag   sy_kmagerr1   sy_kmagerr2    sy_gaiamag  sy_gaiamagerr1  \
# count  38424.000000  38182.000000  38182.000000  38134.000000    38134.000000
# mean      11.529683      0.034920     -0.034440     13.319203        0.000520
# min       -3.044000      0.011000    -11.140000      2.364310        0.000112
# 25%       10.649000      0.020000     -0.033000     12.303100        0.000253
# 50%       12.234000      0.024000     -0.024000     13.951700        0.000353
# 75%       13.145000      0.033000     -0.020000     15.027600        0.000507
# max       35.330000      9.995000     -0.011000     20.186100        0.063232
# std        2.332455      0.185057      0.176456      2.364615        0.001092
#
#        sy_gaiamagerr2                      rowupdate  \
# count    38134.000000                          39234
# mean        -0.000520  2018-04-08 01:13:22.141000192
# min         -0.063232            2013-10-28 00:00:00
# 25%         -0.000507            2015-08-25 00:00:00
# 50%         -0.000353            2017-05-08 00:00:00
# 75%         -0.000253            2019-06-24 00:00:00
# max         -0.000112            2026-01-08 00:00:00
# std          0.001092                            NaN
#
#                          releasedate
# count                          39235
# mean   2018-02-20 05:57:30.715534592
# min              2013-10-28 00:00:00
# 25%              2015-02-26 00:00:00
# 50%              2017-05-08 00:00:00
# 75%              2019-04-18 00:00:00
# max              2026-01-08 00:00:00
# std                              NaN
#
# [8 rows x 78 columns]

# %%
# Viewing the number of rows and columns
df.shape # 39,235 rows and 92 columns
# Out:
# (39235, 92)

# %% [markdown]
# ### Deleting and Renaming Columns

# %%
# Viewing columns
df.columns
# Out:
# Index(['pl_name', 'hostname', 'default_flag', 'sy_snum', 'sy_pnum',
#        'discoverymethod', 'disc_year', 'disc_facility', 'soltype',
#        'pl_controv_flag', 'pl_refname', 'pl_orbper', 'pl_orbpererr1',
#        'pl_orbpererr2', 'pl_orbperlim', 'pl_orbsmax', 'pl_orbsmaxerr1',
#        'pl_orbsmaxerr2', 'pl_orbsmaxlim', 'pl_rade', 'pl_radeerr1',
#        'pl_radeerr2', 'pl_radelim', 'pl_radj', 'pl_radjerr1', 'pl_radjerr2',
#        'pl_radjlim', 'pl_bmasse', 'pl_bmasseerr1', 'pl_bmasseerr2',
#        'pl_bmasselim', 'pl_bmassj', 'pl_bmassjerr1', 'pl_bmassjerr2',
#        'pl_bmassjlim', 'pl_bmassprov', 'pl_orbeccen', 'pl_orbeccenerr1',
#        'pl_orbeccenerr2', 'pl_orbeccenlim', 'pl_insol', 'pl_insolerr1',
#        'pl_insolerr2', 'pl_insollim', 'pl_eqt', 'pl_eqterr1', 'pl_eqterr2',
#        'pl_eqtlim', 'ttv_flag', 'st_refname', 'st_spectype', 'st_teff',
#        'st_tefferr1', 'st_tefferr2', 'st_tefflim', 'st_rad', 'st_raderr1',
#        'st_raderr2', 'st_radlim', 'st_mass', 'st_masserr1', 'st_masserr2',
#        'st_masslim', 'st_met', 'st_meterr1', 'st_meterr2', 'st_metlim',
#        'st_metratio', 'st_logg', 'st_loggerr1', 'st_loggerr2', 'st_logglim',
#        'sy_refname', 'rastr', 'ra', 'decstr', 'dec', 'sy_dist', 'sy_disterr1',
#        'sy_disterr2', 'sy_vmag', 'sy_vmagerr1', 'sy_vmagerr2', 'sy_kmag',
#        'sy_kmagerr1', 'sy_kmagerr2', 'sy_gaiamag', 'sy_gaiamagerr1',
#        'sy_gaiamagerr2', 'rowupdate', 'pl_pubdate', 'releasedate'],
#       dtype='object')

# %%
# dropping uneeded columns
df.drop(['sy_pnum', 'pl_refname', 'pl_orbpererr1', 'pl_orbpererr2', 'pl_orbperlim', 'pl_orbsmaxerr1', 'pl_orbsmaxerr2', 'pl_orbsmaxlim',
         'pl_radeerr1', 'pl_radeerr2', 'pl_radelim', 'pl_radj', 'pl_radjerr1', 'pl_radjerr2', 'pl_radjlim', 'pl_bmasseerr1', 'pl_bmasseerr2',
         'pl_bmasselim', 'pl_bmassj', 'pl_bmassjerr1', 'pl_bmassjerr2', 'pl_bmassjlim', 'pl_bmassprov', 'pl_orbeccenerr1', 'pl_orbeccenerr2',
         'pl_orbeccenlim', 'pl_insol', 'pl_insolerr1', 'pl_insolerr2', 'pl_insollim', 'pl_eqterr1', 'pl_eqterr2', 'pl_eqtlim', 'ttv_flag', 'st_refname',
         'st_tefferr1', 'st_tefferr2', 'st_tefflim', 'st_raderr1', 'st_raderr2', 'st_radlim', 'st_masserr1', 'st_masserr2', 'st_masslim',
         'st_meterr1', 'st_meterr2', 'st_metlim', 'st_metratio', 'st_loggerr1', 'st_loggerr2', 'st_logglim', 'sy_refname', 'rastr', 'ra', 'decstr', 'dec',
         'sy_disterr1', 'sy_disterr2', 'sy_vmagerr1', 'sy_vmagerr2', 'sy_kmagerr1', 'sy_kmagerr2', 'sy_gaiamagerr1', 'sy_gaiamagerr2', 'rowupdate', 'pl_pubdate',
         'releasedate', 'sy_vmag', 'sy_kmag', 'sy_gaiamag'], axis=1, inplace=True)

# %%
# Checking if the columns were dropped
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39235 entries, 0 to 39234
# Data columns (total 22 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pl_name          39235 non-null  object
#  1   hostname         39235 non-null  object
#  2   default_flag     39235 non-null  int64
#  3   sy_snum          39235 non-null  int64
#  4   discoverymethod  39235 non-null  object
#  5   disc_year        39235 non-null  int64
#  6   disc_facility    39235 non-null  object
#  7   soltype          39235 non-null  object
#  8   pl_controv_flag  39235 non-null  int64
#  9   pl_orbper        35942 non-null  float64
#  10  pl_orbsmax       21968 non-null  float64
#  11  pl_rade          27053 non-null  float64
#  12  pl_bmasse        7112 non-null   float64
#  13  pl_orbeccen      18729 non-null  float64
#  14  pl_eqt           17215 non-null  float64
#  15  st_spectype      2901 non-null   object
#  16  st_teff          35743 non-null  float64
#  17  st_rad           35978 non-null  float64
#  18  st_mass          33126 non-null  float64
#  19  st_met           24786 non-null  float64
#  20  st_logg          30455 non-null  float64
#  21  sy_dist          38389 non-null  float64
# dtypes: float64(12), int64(4), object(6)
# memory usage: 6.6+ MB

# %%
# renaming columns
df = df.rename(columns={
    'pl_name': 'planet_name',
    'hostname': 'host_star_name',
    'st_spectype': 'spectral_type',
    'sy_snum': 'star_number_per_system',
    'discoverymethod': 'discovery_method',
    'disc_year': 'year_of_discovery',
    'disc_facility': 'discovery_facility',
    'soltype': 'solution_type',
    'pl_orbper': 'orbital_period_day',
    'pl_orbsmax': 'orbit_semi_major_axis_au',
    'pl_rade': 'planet_rad_earth_rad',
    'pl_bmasse': 'planet_mass_earth_mass',
    'pl_orbeccen': 'orbital_eccentricity',
    'pl_eqt': 'planet_equil_temp_k',
    'st_teff': 'stellar_effective_temp_k',
    'st_rad': 'stellar_rad_solar_rad',
    'st_mass': 'stellar_mass_solar_mass',
    'st_met': 'stellar_metallicity',
    'st_logg': 'stellar_surf_grav',
    'sy_dist': 'distance_parsec'
})

# %%
# checking if columns were renamed
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39235 entries, 0 to 39234
# Data columns (total 22 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   planet_name               39235 non-null  object
#  1   host_star_name            39235 non-null  object
#  2   default_flag              39235 non-null  int64
#  3   star_number_per_system    39235 non-null  int64
#  4   discovery_method          39235 non-null  object
#  5   year_of_discovery         39235 non-null  int64
#  6   discovery_facility        39235 non-null  object
#  7   solution_type             39235 non-null  object
#  8   pl_controv_flag           39235 non-null  int64
#  9   orbital_period_day        35942 non-null  float64
#  10  orbit_semi_major_axis_au  21968 non-null  float64
#  11  planet_rad_earth_rad      27053 non-null  float64
#  12  planet_mass_earth_mass    7112 non-null   float64
#  13  orbital_eccentricity      18729 non-null  float64
#  14  planet_equil_temp_k       17215 non-null  float64
#  15  spectral_type             2901 non-null   object
#  16  stellar_effective_temp_k  35743 non-null  float64
#  17  stellar_rad_solar_rad     35978 non-null  float64
#  18  stellar_mass_solar_mass   33126 non-null  float64
#  19  stellar_metallicity       24786 non-null  float64
#  20  stellar_surf_grav         30455 non-null  float64
#  21  distance_parsec           38389 non-null  float64
# dtypes: float64(12), int64(4), object(6)
# memory usage: 6.6+ MB

# %% [markdown]
# ### Checking for outliers

# %%
# Determining all numerical columns in DataFrame
numerical_columns = df.select_dtypes(include=[np.number]).columns
numerical_columns
# Out:
# Index(['default_flag', 'star_number_per_system', 'year_of_discovery',
#        'pl_controv_flag', 'orbital_period_day', 'orbit_semi_major_axis_au',
#        'planet_rad_earth_rad', 'planet_mass_earth_mass',
#        'orbital_eccentricity', 'planet_equil_temp_k',
#        'stellar_effective_temp_k', 'stellar_rad_solar_rad',
#        'stellar_mass_solar_mass', 'stellar_metallicity', 'stellar_surf_grav',
#        'distance_parsec'],
#       dtype='object')

# %% [markdown]
# #### Outlier Detection Algorithm
# * Creating an outlier detection algorithm to identify which entries are potential outliers for a given exoplanet per column

# %%
# Creating copy of DataFrame
exoplanets = df.copy()

# Function to determine the z-score using Population Standard Deviation (ddof=0)
def flag_outliers_zscore(series, threshold=3):
    # Calculate mean and population std dev (ddof=0)
    # We use dropna() to ensure missing values don't interfere with the calculation
    clean_series = series.dropna()
    if len(clean_series) < 3:
        return pd.Series([False] * len(series), index=series.index)

    mean = clean_series.mean()
    # population standard deviation
    std_dev = clean_series.std(ddof=0)

    # Lowered guard to 0.01 so stellar parameters aren't skipped
    if std_dev <= 0.01:
        return pd.Series([False] * len(series), index=series.index)

    # Compute the z-score
    z_scores = (series - mean) / std_dev
    return abs(z_scores) > threshold

# Function to flag outliers
def flag_outliers_for_column_zscore(df, column_name, threshold=3):
    # Group by planet name (ensure this matches your column name, e.g., 'pl_name')
    grouped = df.groupby("planet_name")

    for group_name, group_data in grouped:
        outlier_flags = flag_outliers_zscore(group_data[column_name], threshold)
        df.loc[group_data.index, column_name + '_outlier'] = outlier_flags

# Get numerical columns
numerical_columns = exoplanets.select_dtypes(include=[np.number]).columns

# Define sensitive columns that need a lower threshold to catch outliers
sensitive_columns = ['stellar_mass_solar_mass', 'stellar_rad_solar_rad']

# Apply the detection
for column_name in numerical_columns:
    if column_name in sensitive_columns:
        # Use threshold=1.0 for stellar mass and radius
        flag_outliers_for_column_zscore(exoplanets, column_name, threshold=1.0)
    else:
        # Use threshold=3.0 for all other numerical columns
        flag_outliers_for_column_zscore(exoplanets, column_name, threshold=3.0)

# Verification check for Kepler-452 b
print(exoplanets[exoplanets['planet_name'] == 'Kepler-452 b'][['default_flag', 'planet_name', 'stellar_mass_solar_mass', 'stellar_mass_solar_mass_outlier']])
# Out:
#        default_flag   planet_name  stellar_mass_solar_mass  \
# 27463             0  Kepler-452 b                      NaN
# 27464             0  Kepler-452 b                    1.022
# 27465             0  Kepler-452 b                    0.892
# 27466             0  Kepler-452 b                    1.030
# 27467             1  Kepler-452 b                    1.037
# 27468             0  Kepler-452 b                    0.870
#
#       stellar_mass_solar_mass_outlier
# 27463                           False
# 27464                           False
# 27465                            True
# 27466                           False
# 27467                           False
# 27468                            True

# %%
# Create an empty list to store outlier dictionaries
all_outliers_data = []

# Loop over all outlier columns (which are all numerical columns)
for column in numerical_columns:
    outlier_col = column + "_outlier"

    # Filter rows where the outlier flag is True
    outliers = exoplanets[exoplanets[outlier_col] == True]

    # For each outlier, create a dictionary and add it to the list
    for idx, row in outliers.iterrows():
        all_outliers_data.append({
            "planet_name": row["planet_name"],
            "column": column,
            "value": row[column]
        })

# Create the DataFrame from the list of dictionaries after the loop
outlier_summary = pd.DataFrame(all_outliers_data)

# Display all outliers
print(outlier_summary)
# Out:
#         planet_name             column  value
# 0          55 Cnc b       default_flag   1.00
# 1          55 Cnc d       default_flag   1.00
# 2          55 Cnc e       default_flag   1.00
# 3          AU Mic b       default_flag   1.00
# 4         CoRoT-2 b       default_flag   1.00
# ...             ...                ...    ...
# 23132   Kepler-23 d  stellar_surf_grav   3.97
# 23133  Kepler-428 b  stellar_surf_grav   4.67
# 23134   Kepler-43 b  stellar_surf_grav   4.54
# 23135   Kepler-44 b  stellar_surf_grav   4.48
# 23136    Kepler-6 b  stellar_surf_grav   4.42
#
# [23137 rows x 3 columns]

# %% [markdown]
# 21,137 rows contains at least one entry flagged as an outlier

# %%
# If a row with default_flag == 1 has entry flagged as outlier (true), this entry should still be kept and thus, will be changed to false
outlier_cols = [col for col in exoplanets.columns if col.endswith('_outlier')]

rows_with_outliers = exoplanets[
    (exoplanets["default_flag"] == 1) &
    (exoplanets[outlier_cols].any(axis=1))
]

print(
    rows_with_outliers[
        ["default_flag", "planet_name"] + outlier_cols
    ]
)
# Out:
#        default_flag planet_name default_flag_outlier  \
# 0                 1    11 Com b                False
# 4                 1    11 UMi b                False
# 17                1  16 Cyg B b                False
# 85                1    55 Cnc b                 True
# 91                1    55 Cnc c                False
# ...             ...         ...                  ...
# 39196             1   rho CrB c                False
# 39201             1   tau Boo b                False
# 39215             1   ups And b                False
# 39221             1   ups And c                False
# 39227             1   ups And d                False
#
#       star_number_per_system_outlier year_of_discovery_outlier  \
# 0                              False                     False
# 4                              False                     False
# 17                             False                     False
# 85                             False                     False
# 91                             False                     False
# ...                              ...                       ...
# 39196                          False                     False
# 39201                          False                     False
# 39215                          False                     False
# 39221                          False                     False
# 39227                          False                     False
#
#       pl_controv_flag_outlier orbital_period_day_outlier  \
# 0                       False                      False
# 4                       False                      False
# 17                      False                      False
# 85                      False                      False
# 91                      False                      False
# ...                       ...                        ...
# 39196                   False                      False
# 39201                   False                      False
# 39215                   False                      False
# 39221                   False                      False
# 39227                   False                      False
#
#       orbit_semi_major_axis_au_outlier planet_rad_earth_rad_outlier  \
# 0                                False                        False
# 4                                False                        False
# 17                               False                        False
# 85                               False                        False
# 91                               False                        False
# ...                                ...                          ...
# 39196                            False                        False
# 39201                            False                        False
# 39215                            False                        False
# 39221                            False                        False
# 39227                            False                        False
#
#       planet_mass_earth_mass_outlier orbital_eccentricity_outlier  \
# 0                              False                        False
# 4                              False                        False
# 17                             False                        False
# 85                             False                        False
# 91                             False                        False
# ...                              ...                          ...
# 39196                          False                        False
# 39201                          False                        False
# 39215                          False                        False
# 39221                          False                        False
# 39227                          False                        False
#
#       planet_equil_temp_k_outlier stellar_effective_temp_k_outlier  \
# 0                           False                            False
# 4                           False                            False
# 17                          False                            False
# 85                          False                            False
# 91                          False                            False
# ...                           ...                              ...
# 39196                       False                            False
# 39201                       False                            False
# 39215                       False                            False
# 39221                       False                            False
# 39227                       False                            False
#
#       stellar_rad_solar_rad_outlier stellar_mass_solar_mass_outlier  \
# 0                             False                            True
# 4                             False                            True
# 17                            False                            True
# 85                            False                            True
# 91                            False                            True
# ...                             ...                             ...
# 39196                         False                            True
# 39201                          True                           False
# 39215                          True                           False
# 39221                          True                           False
# 39227                          True                           False
#
#       stellar_metallicity_outlier stellar_surf_grav_outlier  \
# 0                           False                     False
# 4                           False                     False
# 17                          False                     False
# 85                          False                     False
# 91                          False                     False
# ...                           ...                       ...
# 39196                       False                     False
# 39201                       False                     False
# 39215                       False                     False
# 39221                       False                     False
# 39227                       False                     False
#
#       distance_parsec_outlier
# 0                       False
# 4                       False
# 17                      False
# 85                      False
# 91                      False
# ...                       ...
# 39196                   False
# 39201                   False
# 39215                   False
# 39221                   False
# 39227                   False
#
# [2594 rows x 18 columns]

# %% [markdown]
# 2,549 rows which contain at least one flagged outlier are defautl flag rows. These must be overidden

# %%
# Manually overiding the entries within default flag == 1 rows to be False
exoplanets.loc[
    exoplanets["default_flag"] == 1,
    outlier_cols
] = False

# %%
# Cheaking if these entries were successfully overidden
print(
    exoplanets[
        (exoplanets["default_flag"] == 1) &
        (exoplanets["stellar_mass_solar_mass_outlier"] == True)
    ][
        [
            "default_flag",
            "planet_name",
            "stellar_mass_solar_mass",
            "stellar_mass_solar_mass_outlier"
        ]
    ]
)
# Out:
# Empty DataFrame
# Columns: [default_flag, planet_name, stellar_mass_solar_mass, stellar_mass_solar_mass_outlier]
# Index: []

# %% [markdown]
# #### Outlier Visualizer
# * Automatically diplaying the entries flagged as outliers for a given exoplanet per column

# %%
# Create an empty list to store outlier dictionaries
all_outliers_data = []

# Loop over all outlier columns (which are all numerical columns)
for column in numerical_columns:
    outlier_col = column + "_outlier"

    # Filter rows where the outlier flag is True
    outliers = exoplanets[exoplanets[outlier_col] == True]

    # For each outlier, create a dictionary and add it to the list
    for idx, row in outliers.iterrows():
        all_outliers_data.append({
            "planet_name": row["planet_name"],
            "column": column,
            "value": row[column]
        })

# Create the DataFrame from the list of dictionaries after the loop
outlier_summary = pd.DataFrame(all_outliers_data)

# Display all outliers
print(outlier_summary)
# Out:
#         planet_name              column        value
# 0          55 Cnc b  orbital_period_day    14.465314
# 1       HD 106315 c  orbital_period_day  1221.270977
# 2           K2-19 c  orbital_period_day    23.814860
# 3           K2-32 b  orbital_period_day    17.975860
# 4      Kepler-117 b  orbital_period_day    50.790364
# ...             ...                 ...          ...
# 19550   Kepler-23 d   stellar_surf_grav     3.970000
# 19551  Kepler-428 b   stellar_surf_grav     4.670000
# 19552   Kepler-43 b   stellar_surf_grav     4.540000
# 19553   Kepler-44 b   stellar_surf_grav     4.480000
# 19554    Kepler-6 b   stellar_surf_grav     4.420000
#
# [19555 rows x 3 columns]

# %% [markdown]
# 19,555 rows have at least one entry flagged as an outlier

# %%
# List of planets we want to visualize
selected_planets = ["HD 106315 c"]

# Loop over each outlier in the summary
for _, outlier in outlier_summary.iterrows():
    planet = outlier["planet_name"]
    column = outlier["column"]

    # Only process if the planet is in your selected list
    if planet in selected_planets:
        print(f"\nAll entries for planet '{planet}' in column '{column}':")

        # Filter the DataFrame for this planet
        planet_data = exoplanets[exoplanets["planet_name"] == planet].copy()

        # Keep only the planet_name and the column with the outlier
        planet_data = planet_data[["default_flag", "planet_name", column]]

        # Style function to highlight the outlier
        def highlight_outlier(val):
            if val == outlier["value"]:
                return 'background-color: yellow; font-weight: bold'
            else:
                return ''

        # Display with styling
        display(planet_data.style.applymap(highlight_outlier, subset=[column]))
# Out:
# All entries for planet 'HD 106315 c' in column 'orbital_period_day':
# <style type="text/css">
# #T_4d62d_row0_col2 {
#   background-color: yellow;
#   font-weight: bold;
# }
# </style>
# <table id="T_4d62d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4d62d_level0_col0" class="col_heading level0 col0" >default_flag</th>
#       <th id="T_4d62d_level0_col1" class="col_heading level0 col1" >planet_name</th>
#       <th id="T_4d62d_level0_col2" class="col_heading level0 col2" >orbital_period_day</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4d62d_level0_row0" class="row_heading level0 row0" >1958</th>
#       <td id="T_4d62d_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_4d62d_row0_col1" class="data row0 col1" >HD 106315 c</td>
#       <td id="T_4d62d_row0_col2" class="data row0 col2" >1221.270977</td>
#     </tr>
#     <tr>
#       <th id="T_4d62d_level0_row1" class="row_heading level0 row1" >1959</th>
#       <td id="T_4d62d_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_4d62d_row1_col1" class="data row1 col1" >HD 106315 c</td>
#       <td id="T_4d62d_row1_col2" class="data row1 col2" >21.056520</td>
#     </tr>
#     <tr>
#       <th id="T_4d62d_level0_row2" class="row_heading level0 row2" >1960</th>
#       <td id="T_4d62d_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_4d62d_row2_col1" class="data row2 col1" >HD 106315 c</td>
#       <td id="T_4d62d_row2_col2" class="data row2 col2" >21.057600</td>
#     </tr>
#     <tr>
#       <th id="T_4d62d_level0_row3" class="row_heading level0 row3" >1961</th>
#       <td id="T_4d62d_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_4d62d_row3_col1" class="data row3 col1" >HD 106315 c</td>
#       <td id="T_4d62d_row3_col2" class="data row3 col2" >21.057880</td>
#     </tr>
#     <tr>
#       <th id="T_4d62d_level0_row4" class="row_heading level0 row4" >1962</th>
#       <td id="T_4d62d_row4_col0" class="data row4 col0" >1</td>
#       <td id="T_4d62d_row4_col1" class="data row4 col1" >HD 106315 c</td>
#       <td id="T_4d62d_row4_col2" class="data row4 col2" >21.057040</td>
#     </tr>
#     <tr>
#       <th id="T_4d62d_level0_row5" class="row_heading level0 row5" >1963</th>
#       <td id="T_4d62d_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_4d62d_row5_col1" class="data row5 col1" >HD 106315 c</td>
#       <td id="T_4d62d_row5_col2" class="data row5 col2" >21.056030</td>
#     </tr>
#     <tr>
#       <th id="T_4d62d_level0_row6" class="row_heading level0 row6" >1964</th>
#       <td id="T_4d62d_row6_col0" class="data row6 col0" >0</td>
#       <td id="T_4d62d_row6_col1" class="data row6 col1" >HD 106315 c</td>
#       <td id="T_4d62d_row6_col2" class="data row6 col2" >21.056614</td>
#     </tr>
#     <tr>
#       <th id="T_4d62d_level0_row7" class="row_heading level0 row7" >1965</th>
#       <td id="T_4d62d_row7_col0" class="data row7 col0" >0</td>
#       <td id="T_4d62d_row7_col1" class="data row7 col1" >HD 106315 c</td>
#       <td id="T_4d62d_row7_col2" class="data row7 col2" >21.057504</td>
#     </tr>
#     <tr>
#       <th id="T_4d62d_level0_row8" class="row_heading level0 row8" >1966</th>
#       <td id="T_4d62d_row8_col0" class="data row8 col0" >0</td>
#       <td id="T_4d62d_row8_col1" class="data row8 col1" >HD 106315 c</td>
#       <td id="T_4d62d_row8_col2" class="data row8 col2" >21.056520</td>
#     </tr>
#     <tr>
#       <th id="T_4d62d_level0_row9" class="row_heading level0 row9" >1967</th>
#       <td id="T_4d62d_row9_col0" class="data row9 col0" >0</td>
#       <td id="T_4d62d_row9_col1" class="data row9 col1" >HD 106315 c</td>
#       <td id="T_4d62d_row9_col2" class="data row9 col2" >21.056830</td>
#     </tr>
#     <tr>
#       <th id="T_4d62d_level0_row10" class="row_heading level0 row10" >1968</th>
#       <td id="T_4d62d_row10_col0" class="data row10 col0" >0</td>
#       <td id="T_4d62d_row10_col1" class="data row10 col1" >HD 106315 c</td>
#       <td id="T_4d62d_row10_col2" class="data row10 col2" >21.057310</td>
#     </tr>
#     <tr>
#       <th id="T_4d62d_level0_row11" class="row_heading level0 row11" >1969</th>
#       <td id="T_4d62d_row11_col0" class="data row11 col0" >0</td>
#       <td id="T_4d62d_row11_col1" class="data row11 col1" >HD 106315 c</td>
#       <td id="T_4d62d_row11_col2" class="data row11 col2" >21.058000</td>
#     </tr>
#   </tbody>
# </table>
# All entries for planet 'HD 106315 c' in column 'stellar_rad_solar_rad':
# <style type="text/css">
# #T_56308_row2_col2, #T_56308_row6_col2 {
#   background-color: yellow;
#   font-weight: bold;
# }
# </style>
# <table id="T_56308" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_56308_level0_col0" class="col_heading level0 col0" >default_flag</th>
#       <th id="T_56308_level0_col1" class="col_heading level0 col1" >planet_name</th>
#       <th id="T_56308_level0_col2" class="col_heading level0 col2" >stellar_rad_solar_rad</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_56308_level0_row0" class="row_heading level0 row0" >1958</th>
#       <td id="T_56308_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_56308_row0_col1" class="data row0 col1" >HD 106315 c</td>
#       <td id="T_56308_row0_col2" class="data row0 col2" >1.242700</td>
#     </tr>
#     <tr>
#       <th id="T_56308_level0_row1" class="row_heading level0 row1" >1959</th>
#       <td id="T_56308_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_56308_row1_col1" class="data row1 col1" >HD 106315 c</td>
#       <td id="T_56308_row1_col2" class="data row1 col2" >1.269000</td>
#     </tr>
#     <tr>
#       <th id="T_56308_level0_row2" class="row_heading level0 row2" >1960</th>
#       <td id="T_56308_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_56308_row2_col1" class="data row2 col1" >HD 106315 c</td>
#       <td id="T_56308_row2_col2" class="data row2 col2" >1.180000</td>
#     </tr>
#     <tr>
#       <th id="T_56308_level0_row3" class="row_heading level0 row3" >1961</th>
#       <td id="T_56308_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_56308_row3_col1" class="data row3 col1" >HD 106315 c</td>
#       <td id="T_56308_row3_col2" class="data row3 col2" >1.290000</td>
#     </tr>
#     <tr>
#       <th id="T_56308_level0_row4" class="row_heading level0 row4" >1962</th>
#       <td id="T_56308_row4_col0" class="data row4 col0" >1</td>
#       <td id="T_56308_row4_col1" class="data row4 col1" >HD 106315 c</td>
#       <td id="T_56308_row4_col2" class="data row4 col2" >1.296000</td>
#     </tr>
#     <tr>
#       <th id="T_56308_level0_row5" class="row_heading level0 row5" >1963</th>
#       <td id="T_56308_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_56308_row5_col1" class="data row5 col1" >HD 106315 c</td>
#       <td id="T_56308_row5_col2" class="data row5 col2" >1.299000</td>
#     </tr>
#     <tr>
#       <th id="T_56308_level0_row6" class="row_heading level0 row6" >1964</th>
#       <td id="T_56308_row6_col0" class="data row6 col0" >0</td>
#       <td id="T_56308_row6_col1" class="data row6 col1" >HD 106315 c</td>
#       <td id="T_56308_row6_col2" class="data row6 col2" >1.180000</td>
#     </tr>
#     <tr>
#       <th id="T_56308_level0_row7" class="row_heading level0 row7" >1965</th>
#       <td id="T_56308_row7_col0" class="data row7 col0" >0</td>
#       <td id="T_56308_row7_col1" class="data row7 col1" >HD 106315 c</td>
#       <td id="T_56308_row7_col2" class="data row7 col2" >1.273595</td>
#     </tr>
#     <tr>
#       <th id="T_56308_level0_row8" class="row_heading level0 row8" >1966</th>
#       <td id="T_56308_row8_col0" class="data row8 col0" >0</td>
#       <td id="T_56308_row8_col1" class="data row8 col1" >HD 106315 c</td>
#       <td id="T_56308_row8_col2" class="data row8 col2" >1.269000</td>
#     </tr>
#     <tr>
#       <th id="T_56308_level0_row9" class="row_heading level0 row9" >1967</th>
#       <td id="T_56308_row9_col0" class="data row9 col0" >0</td>
#       <td id="T_56308_row9_col1" class="data row9 col1" >HD 106315 c</td>
#       <td id="T_56308_row9_col2" class="data row9 col2" >1.242700</td>
#     </tr>
#     <tr>
#       <th id="T_56308_level0_row10" class="row_heading level0 row10" >1968</th>
#       <td id="T_56308_row10_col0" class="data row10 col0" >0</td>
#       <td id="T_56308_row10_col1" class="data row10 col1" >HD 106315 c</td>
#       <td id="T_56308_row10_col2" class="data row10 col2" >1.310000</td>
#     </tr>
#     <tr>
#       <th id="T_56308_level0_row11" class="row_heading level0 row11" >1969</th>
#       <td id="T_56308_row11_col0" class="data row11 col0" >0</td>
#       <td id="T_56308_row11_col1" class="data row11 col1" >HD 106315 c</td>
#       <td id="T_56308_row11_col2" class="data row11 col2" >1.281000</td>
#     </tr>
#   </tbody>
# </table>
# All entries for planet 'HD 106315 c' in column 'stellar_rad_solar_rad':
# <style type="text/css">
# #T_1be09_row2_col2, #T_1be09_row6_col2 {
#   background-color: yellow;
#   font-weight: bold;
# }
# </style>
# <table id="T_1be09" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1be09_level0_col0" class="col_heading level0 col0" >default_flag</th>
#       <th id="T_1be09_level0_col1" class="col_heading level0 col1" >planet_name</th>
#       <th id="T_1be09_level0_col2" class="col_heading level0 col2" >stellar_rad_solar_rad</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1be09_level0_row0" class="row_heading level0 row0" >1958</th>
#       <td id="T_1be09_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_1be09_row0_col1" class="data row0 col1" >HD 106315 c</td>
#       <td id="T_1be09_row0_col2" class="data row0 col2" >1.242700</td>
#     </tr>
#     <tr>
#       <th id="T_1be09_level0_row1" class="row_heading level0 row1" >1959</th>
#       <td id="T_1be09_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_1be09_row1_col1" class="data row1 col1" >HD 106315 c</td>
#       <td id="T_1be09_row1_col2" class="data row1 col2" >1.269000</td>
#     </tr>
#     <tr>
#       <th id="T_1be09_level0_row2" class="row_heading level0 row2" >1960</th>
#       <td id="T_1be09_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_1be09_row2_col1" class="data row2 col1" >HD 106315 c</td>
#       <td id="T_1be09_row2_col2" class="data row2 col2" >1.180000</td>
#     </tr>
#     <tr>
#       <th id="T_1be09_level0_row3" class="row_heading level0 row3" >1961</th>
#       <td id="T_1be09_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_1be09_row3_col1" class="data row3 col1" >HD 106315 c</td>
#       <td id="T_1be09_row3_col2" class="data row3 col2" >1.290000</td>
#     </tr>
#     <tr>
#       <th id="T_1be09_level0_row4" class="row_heading level0 row4" >1962</th>
#       <td id="T_1be09_row4_col0" class="data row4 col0" >1</td>
#       <td id="T_1be09_row4_col1" class="data row4 col1" >HD 106315 c</td>
#       <td id="T_1be09_row4_col2" class="data row4 col2" >1.296000</td>
#     </tr>
#     <tr>
#       <th id="T_1be09_level0_row5" class="row_heading level0 row5" >1963</th>
#       <td id="T_1be09_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_1be09_row5_col1" class="data row5 col1" >HD 106315 c</td>
#       <td id="T_1be09_row5_col2" class="data row5 col2" >1.299000</td>
#     </tr>
#     <tr>
#       <th id="T_1be09_level0_row6" class="row_heading level0 row6" >1964</th>
#       <td id="T_1be09_row6_col0" class="data row6 col0" >0</td>
#       <td id="T_1be09_row6_col1" class="data row6 col1" >HD 106315 c</td>
#       <td id="T_1be09_row6_col2" class="data row6 col2" >1.180000</td>
#     </tr>
#     <tr>
#       <th id="T_1be09_level0_row7" class="row_heading level0 row7" >1965</th>
#       <td id="T_1be09_row7_col0" class="data row7 col0" >0</td>
#       <td id="T_1be09_row7_col1" class="data row7 col1" >HD 106315 c</td>
#       <td id="T_1be09_row7_col2" class="data row7 col2" >1.273595</td>
#     </tr>
#     <tr>
#       <th id="T_1be09_level0_row8" class="row_heading level0 row8" >1966</th>
#       <td id="T_1be09_row8_col0" class="data row8 col0" >0</td>
#       <td id="T_1be09_row8_col1" class="data row8 col1" >HD 106315 c</td>
#       <td id="T_1be09_row8_col2" class="data row8 col2" >1.269000</td>
#     </tr>
#     <tr>
#       <th id="T_1be09_level0_row9" class="row_heading level0 row9" >1967</th>
#       <td id="T_1be09_row9_col0" class="data row9 col0" >0</td>
#       <td id="T_1be09_row9_col1" class="data row9 col1" >HD 106315 c</td>
#       <td id="T_1be09_row9_col2" class="data row9 col2" >1.242700</td>
#     </tr>
#     <tr>
#       <th id="T_1be09_level0_row10" class="row_heading level0 row10" >1968</th>
#       <td id="T_1be09_row10_col0" class="data row10 col0" >0</td>
#       <td id="T_1be09_row10_col1" class="data row10 col1" >HD 106315 c</td>
#       <td id="T_1be09_row10_col2" class="data row10 col2" >1.310000</td>
#     </tr>
#     <tr>
#       <th id="T_1be09_level0_row11" class="row_heading level0 row11" >1969</th>
#       <td id="T_1be09_row11_col0" class="data row11 col0" >0</td>
#       <td id="T_1be09_row11_col1" class="data row11 col1" >HD 106315 c</td>
#       <td id="T_1be09_row11_col2" class="data row11 col2" >1.281000</td>
#     </tr>
#   </tbody>
# </table>
# All entries for planet 'HD 106315 c' in column 'stellar_rad_solar_rad':
# <style type="text/css">
# #T_db042_row10_col2 {
#   background-color: yellow;
#   font-weight: bold;
# }
# </style>
# <table id="T_db042" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_db042_level0_col0" class="col_heading level0 col0" >default_flag</th>
#       <th id="T_db042_level0_col1" class="col_heading level0 col1" >planet_name</th>
#       <th id="T_db042_level0_col2" class="col_heading level0 col2" >stellar_rad_solar_rad</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_db042_level0_row0" class="row_heading level0 row0" >1958</th>
#       <td id="T_db042_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_db042_row0_col1" class="data row0 col1" >HD 106315 c</td>
#       <td id="T_db042_row0_col2" class="data row0 col2" >1.242700</td>
#     </tr>
#     <tr>
#       <th id="T_db042_level0_row1" class="row_heading level0 row1" >1959</th>
#       <td id="T_db042_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_db042_row1_col1" class="data row1 col1" >HD 106315 c</td>
#       <td id="T_db042_row1_col2" class="data row1 col2" >1.269000</td>
#     </tr>
#     <tr>
#       <th id="T_db042_level0_row2" class="row_heading level0 row2" >1960</th>
#       <td id="T_db042_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_db042_row2_col1" class="data row2 col1" >HD 106315 c</td>
#       <td id="T_db042_row2_col2" class="data row2 col2" >1.180000</td>
#     </tr>
#     <tr>
#       <th id="T_db042_level0_row3" class="row_heading level0 row3" >1961</th>
#       <td id="T_db042_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_db042_row3_col1" class="data row3 col1" >HD 106315 c</td>
#       <td id="T_db042_row3_col2" class="data row3 col2" >1.290000</td>
#     </tr>
#     <tr>
#       <th id="T_db042_level0_row4" class="row_heading level0 row4" >1962</th>
#       <td id="T_db042_row4_col0" class="data row4 col0" >1</td>
#       <td id="T_db042_row4_col1" class="data row4 col1" >HD 106315 c</td>
#       <td id="T_db042_row4_col2" class="data row4 col2" >1.296000</td>
#     </tr>
#     <tr>
#       <th id="T_db042_level0_row5" class="row_heading level0 row5" >1963</th>
#       <td id="T_db042_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_db042_row5_col1" class="data row5 col1" >HD 106315 c</td>
#       <td id="T_db042_row5_col2" class="data row5 col2" >1.299000</td>
#     </tr>
#     <tr>
#       <th id="T_db042_level0_row6" class="row_heading level0 row6" >1964</th>
#       <td id="T_db042_row6_col0" class="data row6 col0" >0</td>
#       <td id="T_db042_row6_col1" class="data row6 col1" >HD 106315 c</td>
#       <td id="T_db042_row6_col2" class="data row6 col2" >1.180000</td>
#     </tr>
#     <tr>
#       <th id="T_db042_level0_row7" class="row_heading level0 row7" >1965</th>
#       <td id="T_db042_row7_col0" class="data row7 col0" >0</td>
#       <td id="T_db042_row7_col1" class="data row7 col1" >HD 106315 c</td>
#       <td id="T_db042_row7_col2" class="data row7 col2" >1.273595</td>
#     </tr>
#     <tr>
#       <th id="T_db042_level0_row8" class="row_heading level0 row8" >1966</th>
#       <td id="T_db042_row8_col0" class="data row8 col0" >0</td>
#       <td id="T_db042_row8_col1" class="data row8 col1" >HD 106315 c</td>
#       <td id="T_db042_row8_col2" class="data row8 col2" >1.269000</td>
#     </tr>
#     <tr>
#       <th id="T_db042_level0_row9" class="row_heading level0 row9" >1967</th>
#       <td id="T_db042_row9_col0" class="data row9 col0" >0</td>
#       <td id="T_db042_row9_col1" class="data row9 col1" >HD 106315 c</td>
#       <td id="T_db042_row9_col2" class="data row9 col2" >1.242700</td>
#     </tr>
#     <tr>
#       <th id="T_db042_level0_row10" class="row_heading level0 row10" >1968</th>
#       <td id="T_db042_row10_col0" class="data row10 col0" >0</td>
#       <td id="T_db042_row10_col1" class="data row10 col1" >HD 106315 c</td>
#       <td id="T_db042_row10_col2" class="data row10 col2" >1.310000</td>
#     </tr>
#     <tr>
#       <th id="T_db042_level0_row11" class="row_heading level0 row11" >1969</th>
#       <td id="T_db042_row11_col0" class="data row11 col0" >0</td>
#       <td id="T_db042_row11_col1" class="data row11 col1" >HD 106315 c</td>
#       <td id="T_db042_row11_col2" class="data row11 col2" >1.281000</td>
#     </tr>
#   </tbody>
# </table>
# All entries for planet 'HD 106315 c' in column 'stellar_mass_solar_mass':
# <style type="text/css">
# #T_16b11_row9_col2 {
#   background-color: yellow;
#   font-weight: bold;
# }
# </style>
# <table id="T_16b11" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_16b11_level0_col0" class="col_heading level0 col0" >default_flag</th>
#       <th id="T_16b11_level0_col1" class="col_heading level0 col1" >planet_name</th>
#       <th id="T_16b11_level0_col2" class="col_heading level0 col2" >stellar_mass_solar_mass</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_16b11_level0_row0" class="row_heading level0 row0" >1958</th>
#       <td id="T_16b11_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_16b11_row0_col1" class="data row0 col1" >HD 106315 c</td>
#       <td id="T_16b11_row0_col2" class="data row0 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_16b11_level0_row1" class="row_heading level0 row1" >1959</th>
#       <td id="T_16b11_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_16b11_row1_col1" class="data row1 col1" >HD 106315 c</td>
#       <td id="T_16b11_row1_col2" class="data row1 col2" >1.154000</td>
#     </tr>
#     <tr>
#       <th id="T_16b11_level0_row2" class="row_heading level0 row2" >1960</th>
#       <td id="T_16b11_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_16b11_row2_col1" class="data row2 col1" >HD 106315 c</td>
#       <td id="T_16b11_row2_col2" class="data row2 col2" >1.070000</td>
#     </tr>
#     <tr>
#       <th id="T_16b11_level0_row3" class="row_heading level0 row3" >1961</th>
#       <td id="T_16b11_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_16b11_row3_col1" class="data row3 col1" >HD 106315 c</td>
#       <td id="T_16b11_row3_col2" class="data row3 col2" >1.080000</td>
#     </tr>
#     <tr>
#       <th id="T_16b11_level0_row4" class="row_heading level0 row4" >1962</th>
#       <td id="T_16b11_row4_col0" class="data row4 col0" >1</td>
#       <td id="T_16b11_row4_col1" class="data row4 col1" >HD 106315 c</td>
#       <td id="T_16b11_row4_col2" class="data row4 col2" >1.091000</td>
#     </tr>
#     <tr>
#       <th id="T_16b11_level0_row5" class="row_heading level0 row5" >1963</th>
#       <td id="T_16b11_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_16b11_row5_col1" class="data row5 col1" >HD 106315 c</td>
#       <td id="T_16b11_row5_col2" class="data row5 col2" >1.024000</td>
#     </tr>
#     <tr>
#       <th id="T_16b11_level0_row6" class="row_heading level0 row6" >1964</th>
#       <td id="T_16b11_row6_col0" class="data row6 col0" >0</td>
#       <td id="T_16b11_row6_col1" class="data row6 col1" >HD 106315 c</td>
#       <td id="T_16b11_row6_col2" class="data row6 col2" >1.070000</td>
#     </tr>
#     <tr>
#       <th id="T_16b11_level0_row7" class="row_heading level0 row7" >1965</th>
#       <td id="T_16b11_row7_col0" class="data row7 col0" >0</td>
#       <td id="T_16b11_row7_col1" class="data row7 col1" >HD 106315 c</td>
#       <td id="T_16b11_row7_col2" class="data row7 col2" >1.119172</td>
#     </tr>
#     <tr>
#       <th id="T_16b11_level0_row8" class="row_heading level0 row8" >1966</th>
#       <td id="T_16b11_row8_col0" class="data row8 col0" >0</td>
#       <td id="T_16b11_row8_col1" class="data row8 col1" >HD 106315 c</td>
#       <td id="T_16b11_row8_col2" class="data row8 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_16b11_level0_row9" class="row_heading level0 row9" >1967</th>
#       <td id="T_16b11_row9_col0" class="data row9 col0" >0</td>
#       <td id="T_16b11_row9_col1" class="data row9 col1" >HD 106315 c</td>
#       <td id="T_16b11_row9_col2" class="data row9 col2" >1.330000</td>
#     </tr>
#     <tr>
#       <th id="T_16b11_level0_row10" class="row_heading level0 row10" >1968</th>
#       <td id="T_16b11_row10_col0" class="data row10 col0" >0</td>
#       <td id="T_16b11_row10_col1" class="data row10 col1" >HD 106315 c</td>
#       <td id="T_16b11_row10_col2" class="data row10 col2" >1.079000</td>
#     </tr>
#     <tr>
#       <th id="T_16b11_level0_row11" class="row_heading level0 row11" >1969</th>
#       <td id="T_16b11_row11_col0" class="data row11 col0" >0</td>
#       <td id="T_16b11_row11_col1" class="data row11 col1" >HD 106315 c</td>
#       <td id="T_16b11_row11_col2" class="data row11 col2" >1.027000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Outlier Removal Algorithm
# * Automatically remove the entries flagged as outliers

# %%
# Make a copy of the DataFrame
exoplanets_cleaned = exoplanets.copy()

# Loop over all outlier columns (which are numerical columns)
for column in numerical_columns:
    outlier_col = column + "_outlier"

    # Set the outlier entries to NaN (remove the entry) but do not remove the row
    exoplanets_cleaned.loc[exoplanets_cleaned[outlier_col] == True, column] = pd.NA

# Drop the '_outlier' columns now that they are no longer needed
outlier_cols = [col + "_outlier" for col in numerical_columns]
exoplanets_cleaned = exoplanets_cleaned.drop(columns=outlier_cols)

# Display the cleaned DataFrame
print(exoplanets_cleaned)
# Out:
#       planet_name host_star_name  default_flag  star_number_per_system  \
# 0        11 Com b         11 Com           1.0                     2.0
# 1        11 Com b         11 Com           0.0                     2.0
# 2        11 Com b         11 Com           0.0                     2.0
# 3        11 UMi b         11 UMi           0.0                     1.0
# 4        11 UMi b         11 UMi           1.0                     1.0
# ...           ...            ...           ...                     ...
# 39230   ups And d        ups And           0.0                     2.0
# 39231   ups Leo b        ups Leo           1.0                     1.0
# 39232    xi Aql b         xi Aql           0.0                     1.0
# 39233    xi Aql b         xi Aql           0.0                     1.0
# 39234    xi Aql b         xi Aql           1.0                     1.0
#
#       discovery_method  year_of_discovery  \
# 0      Radial Velocity             2007.0
# 1      Radial Velocity             2007.0
# 2      Radial Velocity             2007.0
# 3      Radial Velocity             2009.0
# 4      Radial Velocity             2009.0
# ...                ...                ...
# 39230  Radial Velocity             1999.0
# 39231  Radial Velocity             2021.0
# 39232  Radial Velocity             2007.0
# 39233  Radial Velocity             2007.0
# 39234  Radial Velocity             2007.0
#
#                            discovery_facility        solution_type  \
# 0                            Xinglong Station  Published Confirmed
# 1                            Xinglong Station  Published Confirmed
# 2                            Xinglong Station  Published Confirmed
# 3      Thueringer Landessternwarte Tautenburg  Published Confirmed
# 4      Thueringer Landessternwarte Tautenburg  Published Confirmed
# ...                                       ...                  ...
# 39230                  Multiple Observatories  Published Confirmed
# 39231       Okayama Astrophysical Observatory  Published Confirmed
# 39232       Okayama Astrophysical Observatory  Published Confirmed
# 39233       Okayama Astrophysical Observatory  Published Confirmed
# 39234       Okayama Astrophysical Observatory  Published Confirmed
#
#        pl_controv_flag  orbital_period_day  ...  planet_mass_earth_mass  \
# 0                  0.0           323.21000  ...             4914.898486
# 1                  0.0           326.03000  ...             6165.600000
# 2                  0.0                 NaN  ...             5434.700000
# 3                  0.0           516.22000  ...             3337.070000
# 4                  0.0           516.21997  ...             4684.814200
# ...                ...                 ...  ...                     ...
# 39230              0.0          1278.10000  ...             1312.637900
# 39231              0.0           385.20000  ...              162.092488
# 39232              0.0                 NaN  ...              642.000000
# 39233              0.0           136.75000  ...              890.000000
# 39234              0.0           136.97000  ...              616.904938
#
#        orbital_eccentricity  planet_equil_temp_k  spectral_type  \
# 0                     0.238                  NaN         G8 III
# 1                     0.231                  NaN         G8 III
# 2                       NaN                  NaN            NaN
# 3                     0.080                  NaN         K4 III
# 4                     0.080                  NaN            NaN
# ...                     ...                  ...            ...
# 39230                 0.267                  NaN            NaN
# 39231                 0.320                  NaN         G9 III
# 39232                   NaN                  NaN            NaN
# 39233                 0.000                  NaN            NaN
# 39234                 0.059                  NaN         K0 III
#
#        stellar_effective_temp_k stellar_rad_solar_rad  \
# 0                       4874.00              13.76000
# 1                       4742.00              19.00000
# 2                           NaN                   NaN
# 3                       4340.00              24.08000
# 4                       4213.00              29.79000
# ...                         ...                   ...
# 39230                   6105.51               1.63649
# 39231                   4836.00              11.22000
# 39232                       NaN                   NaN
# 39233                   4780.00              12.00000
# 39234                   4841.00              10.86000
#
#        stellar_mass_solar_mass  stellar_metallicity  stellar_surf_grav  \
# 0                         2.09              -0.2600            2.45000
# 1                         2.70              -0.3500            2.31000
# 2                         2.60                  NaN                NaN
# 3                         1.80               0.0400            1.60000
# 4                         2.78              -0.0200            1.93000
# ...                        ...                  ...                ...
# 39230                      NaN               0.1014            4.07094
# 39231                     1.48              -0.2000            2.46000
# 39232                      NaN                  NaN                NaN
# 39233                      NaN              -0.2050            2.66000
# 39234                     1.74              -0.1100            2.61000
#
#        distance_parsec
# 0              93.1846
# 1              93.1846
# 2              93.1846
# 3             125.3210
# 4             125.3210
# ...                ...
# 39230          13.4054
# 39231          52.5973
# 39232          56.1858
# 39233          56.1858
# 39234          56.1858
#
# [39235 rows x 22 columns]

# %%
exoplanets_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39235 entries, 0 to 39234
# Data columns (total 22 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   planet_name               39235 non-null  object
#  1   host_star_name            39235 non-null  object
#  2   default_flag              39235 non-null  float64
#  3   star_number_per_system    39235 non-null  float64
#  4   discovery_method          39235 non-null  object
#  5   year_of_discovery         39235 non-null  float64
#  6   discovery_facility        39235 non-null  object
#  7   solution_type             39235 non-null  object
#  8   pl_controv_flag           39235 non-null  float64
#  9   orbital_period_day        35927 non-null  float64
#  10  orbit_semi_major_axis_au  21968 non-null  float64
#  11  planet_rad_earth_rad      27037 non-null  float64
#  12  planet_mass_earth_mass    7110 non-null   float64
#  13  orbital_eccentricity      18727 non-null  float64
#  14  planet_equil_temp_k       17215 non-null  float64
#  15  spectral_type             2901 non-null   object
#  16  stellar_effective_temp_k  35700 non-null  float64
#  17  stellar_rad_solar_rad     25413 non-null  float64
#  18  stellar_mass_solar_mass   24229 non-null  float64
#  19  stellar_metallicity       24783 non-null  float64
#  20  stellar_surf_grav         30443 non-null  float64
#  21  distance_parsec           38389 non-null  float64
# dtypes: float64(16), object(6)
# memory usage: 6.6+ MB

# %% [markdown]
# ### Uncomfirmed Exoplanet Removal

# %%
# filtering our uncomfirmed exoplanets
exoplanets_filtered = exoplanets_cleaned[exoplanets_cleaned['solution_type'] != 'TESS Project Candidate']
exoplanets_filtered
# Out:
#       planet_name host_star_name  default_flag  star_number_per_system  \
# 0        11 Com b         11 Com           1.0                     2.0
# 1        11 Com b         11 Com           0.0                     2.0
# 2        11 Com b         11 Com           0.0                     2.0
# 3        11 UMi b         11 UMi           0.0                     1.0
# 4        11 UMi b         11 UMi           1.0                     1.0
# ...           ...            ...           ...                     ...
# 39230   ups And d        ups And           0.0                     2.0
# 39231   ups Leo b        ups Leo           1.0                     1.0
# 39232    xi Aql b         xi Aql           0.0                     1.0
# 39233    xi Aql b         xi Aql           0.0                     1.0
# 39234    xi Aql b         xi Aql           1.0                     1.0
#
#       discovery_method  year_of_discovery  \
# 0      Radial Velocity             2007.0
# 1      Radial Velocity             2007.0
# 2      Radial Velocity             2007.0
# 3      Radial Velocity             2009.0
# 4      Radial Velocity             2009.0
# ...                ...                ...
# 39230  Radial Velocity             1999.0
# 39231  Radial Velocity             2021.0
# 39232  Radial Velocity             2007.0
# 39233  Radial Velocity             2007.0
# 39234  Radial Velocity             2007.0
#
#                            discovery_facility        solution_type  \
# 0                            Xinglong Station  Published Confirmed
# 1                            Xinglong Station  Published Confirmed
# 2                            Xinglong Station  Published Confirmed
# 3      Thueringer Landessternwarte Tautenburg  Published Confirmed
# 4      Thueringer Landessternwarte Tautenburg  Published Confirmed
# ...                                       ...                  ...
# 39230                  Multiple Observatories  Published Confirmed
# 39231       Okayama Astrophysical Observatory  Published Confirmed
# 39232       Okayama Astrophysical Observatory  Published Confirmed
# 39233       Okayama Astrophysical Observatory  Published Confirmed
# 39234       Okayama Astrophysical Observatory  Published Confirmed
#
#        pl_controv_flag  orbital_period_day  ...  planet_mass_earth_mass  \
# 0                  0.0           323.21000  ...             4914.898486
# 1                  0.0           326.03000  ...             6165.600000
# 2                  0.0                 NaN  ...             5434.700000
# 3                  0.0           516.22000  ...             3337.070000
# 4                  0.0           516.21997  ...             4684.814200
# ...                ...                 ...  ...                     ...
# 39230              0.0          1278.10000  ...             1312.637900
# 39231              0.0           385.20000  ...              162.092488
# 39232              0.0                 NaN  ...              642.000000
# 39233              0.0           136.75000  ...              890.000000
# 39234              0.0           136.97000  ...              616.904938
#
#        orbital_eccentricity  planet_equil_temp_k  spectral_type  \
# 0                     0.238                  NaN         G8 III
# 1                     0.231                  NaN         G8 III
# 2                       NaN                  NaN            NaN
# 3                     0.080                  NaN         K4 III
# 4                     0.080                  NaN            NaN
# ...                     ...                  ...            ...
# 39230                 0.267                  NaN            NaN
# 39231                 0.320                  NaN         G9 III
# 39232                   NaN                  NaN            NaN
# 39233                 0.000                  NaN            NaN
# 39234                 0.059                  NaN         K0 III
#
#        stellar_effective_temp_k stellar_rad_solar_rad  \
# 0                       4874.00              13.76000
# 1                       4742.00              19.00000
# 2                           NaN                   NaN
# 3                       4340.00              24.08000
# 4                       4213.00              29.79000
# ...                         ...                   ...
# 39230                   6105.51               1.63649
# 39231                   4836.00              11.22000
# 39232                       NaN                   NaN
# 39233                   4780.00              12.00000
# 39234                   4841.00              10.86000
#
#        stellar_mass_solar_mass  stellar_metallicity  stellar_surf_grav  \
# 0                         2.09              -0.2600            2.45000
# 1                         2.70              -0.3500            2.31000
# 2                         2.60                  NaN                NaN
# 3                         1.80               0.0400            1.60000
# 4                         2.78              -0.0200            1.93000
# ...                        ...                  ...                ...
# 39230                      NaN               0.1014            4.07094
# 39231                     1.48              -0.2000            2.46000
# 39232                      NaN                  NaN                NaN
# 39233                      NaN              -0.2050            2.66000
# 39234                     1.74              -0.1100            2.61000
#
#        distance_parsec
# 0              93.1846
# 1              93.1846
# 2              93.1846
# 3             125.3210
# 4             125.3210
# ...                ...
# 39230          13.4054
# 39231          52.5973
# 39232          56.1858
# 39233          56.1858
# 39234          56.1858
#
# [37943 rows x 22 columns]

# %%
# checking if rows were filtered out
print(f'orignal dataset dimensions: {exoplanets_cleaned.shape}')
print(f'filtered dataset dimesions: {exoplanets_filtered.shape}')
# Out:
# orignal dataset dimensions: (39235, 22)
# filtered dataset dimesions: (37943, 22)

# %%
# deleting solution_type column
del exoplanets_filtered['solution_type']
# deleting default_flag column
del exoplanets_filtered['pl_controv_flag']

# %%
# deleting default_flag column
del exoplanets_filtered['default_flag']

# %% [markdown]
# ### Duplicate Row Reduction Algorithm

# %%
# import stats from scipy to calculate mode
from scipy import stats

# creating function to get the mode of a series
# this custom mode function can help avoid a KeyError: 0
# this error can occur if the serires that is passed in the mode function is empty or there is is an isue accessing the mode_value
def mode(series):
    # handling a series if it is empty (contains null values)
    if series.empty:
        # return a null value if the series is empty
        return np.nan
    # compute mode result which is the most frequent value (mode) of the series
    mode_value = series.mode()
    # checking if mode result is empty
    if mode_value.empty:
        # return a null value if mode result result is empty
        return np.nan
    # if there are multple modes, ensuring first element is picked and if there is only one mode, then only that mode is picked
    return mode_value.iloc[0]

# %%
# Creating copy of dataset
new_exoplanets_filtered = exoplanets_filtered.copy()

# Creating a custom aggregration which uses the mean for numerical columns and the custom mode function for non-numerical columns
custom_aggregation = {
    'host_star_name': mode,
    'star_number_per_system': mode,
    'discovery_method': mode,
    'year_of_discovery': mode,
    'discovery_facility': mode,
    'orbital_period_day': 'mean',
    'orbit_semi_major_axis_au': 'mean',
    'planet_rad_earth_rad': 'mean',
    'planet_mass_earth_mass': 'mean',
    'orbital_eccentricity': 'mean',
    'planet_equil_temp_k': 'mean',
    'spectral_type': mode,
    'stellar_effective_temp_k': 'mean',
    'stellar_rad_solar_rad': 'mean',
    'stellar_mass_solar_mass': 'mean',
    'stellar_surf_grav': 'mean',
    'distance_parsec': 'mean'
}

# Ensuring all columns are present in the dataset
# For the columns present in the keys of custom_aggression
for column in custom_aggregation.keys():
    # If the column is not in new_exoplanets_filtered
    if column not in new_exoplanets_filtered.columns:
        # Then raise a KeyError that the "column is not found in the dataset"
        raise KeyError(f"Column '{column}' not found in DataFrame")

# group by the name of exoplanet (group the values in the column by the planet_name)
# .agg(custom_aggregation) performs the spefic aggreagtion function within custom_aggregation for each column
# using .reset_index() to reset the index of new_exoplanets_filtered2
# planet_name is converted to the index of the new_exoplanets_filtered2 so .reset_index() coverts planet_name back into a column, creating default integer index
new_exoplanets_filtered2 = new_exoplanets_filtered.groupby('planet_name').agg(custom_aggregation).reset_index()

# %%
# Checking if rows were successfully reduced
print(f'New filtered dataset dimensions: {new_exoplanets_filtered2.shape}')
# Out:
# New filtered dataset dimensions: (6071, 21)

# %%
# Saving this new DataFrame
#new_exoplanets_filtered2.to_csv('filtered_2026_dataset_new.csv', index=False)

# %% [markdown]
# ## **Data Preprocessing for Filtered Dataset**

# %%
# Importing
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# loading dataset
new_exoplanets_filtered2 = pd.read_csv('/content/drive/MyDrive/Exoplanet /filtered_2026_dataset_new.csv')

# %%
# Viewing the statistics of the dataset
new_exoplanets_filtered2.describe()
# Out:
#        star_number_per_system  year_of_discovery  orbital_period_day  \
# count             6071.000000        6071.000000        5.753000e+03
# mean                 1.103772        2016.878109        7.440323e+04
# std                  0.342638           4.900489        5.302515e+06
# min                  1.000000        1992.000000        9.070629e-02
# 25%                  1.000000        2014.000000        4.347403e+00
# 50%                  1.000000        2016.000000        1.109432e+01
# 75%                  1.000000        2021.000000        3.979446e+01
# max                  4.000000        2026.000000        4.020000e+08
#
#        orbit_semi_major_axis_au  planet_rad_earth_rad  planet_mass_earth_mass  \
# count               5762.000000           4559.000000             3180.000000
# mean                  15.673251              6.084308              756.691216
# std                  351.042366             48.307448             1516.613794
# min                    0.004400              0.296555                0.017500
# 25%                    0.052310              1.649139               13.187500
# 50%                    0.101554              2.454374              173.945797
# 75%                    0.304015              4.323714              696.441594
# max                19000.000000           1899.339625            13256.622856
#
#        orbital_eccentricity  planet_equil_temp_k  stellar_effective_temp_k  \
# count           5168.000000          4438.000000               5605.000000
# mean               0.076404           907.554282               5411.592671
# std                0.146754           460.637865               1764.079064
# min                0.000000            50.000000                415.000000
# 25%                0.000000           567.187500               4920.000000
# 50%                0.000000           811.425000               5561.700000
# 75%                0.090000          1166.475000               5908.050000
# max                0.948000          4050.000000              57000.000000
#
#        stellar_rad_solar_rad  stellar_mass_solar_mass  stellar_surf_grav  \
# count            5465.000000              6031.000000        5422.000000
# mean                1.496930                 0.934069           4.370181
# std                 3.822314                 0.382083           0.438790
# min                 0.012300                 0.012617           0.541000
# 25%                 0.774528                 0.774100           4.287104
# 50%                 0.956497                 0.947571           4.439732
# 75%                 1.252000                 1.083000           4.565054
# max                88.475000                 9.100000           8.070000
#
#        distance_parsec
# count      5948.000000
# mean        708.228107
# std        1187.183726
# min           1.301190
# 25%         102.144000
# 50%         384.757000
# 75%         839.274250
# max        8240.000000

# %% [markdown]
# ### Assessing Null Values

# %%
# Viewing the percentage of missing value for each column
missing_percentage = (new_exoplanets_filtered2.isnull().sum() / len(new_exoplanets_filtered2))
((missing_percentage * 100).sort_values(ascending=False)).map(lambda x: f"{x:.2f}%")
# Out:
# spectral_type               68.57%
# planet_mass_earth_mass      47.62%
# planet_equil_temp_k         26.90%
# planet_rad_earth_rad        24.91%
# orbital_eccentricity        14.87%
# stellar_surf_grav           10.69%
# stellar_rad_solar_rad        9.98%
# stellar_effective_temp_k     7.68%
# orbital_period_day           5.24%
# orbit_semi_major_axis_au     5.09%
# distance_parsec              2.03%
# stellar_mass_solar_mass      0.66%
# host_star_name               0.00%
# planet_name                  0.00%
# star_number_per_system       0.00%
# discovery_method             0.00%
# year_of_discovery            0.00%
# discovery_facility           0.00%
# dtype: object

# %%
# Viewing the information of the new DataFrame
new_exoplanets_filtered2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6071 entries, 0 to 6070
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   planet_name               6071 non-null   object
#  1   host_star_name            6071 non-null   object
#  2   star_number_per_system    6071 non-null   float64
#  3   discovery_method          6071 non-null   object
#  4   year_of_discovery         6071 non-null   float64
#  5   discovery_facility        6071 non-null   object
#  6   orbital_period_day        5753 non-null   float64
#  7   orbit_semi_major_axis_au  5762 non-null   float64
#  8   planet_rad_earth_rad      4559 non-null   float64
#  9   planet_mass_earth_mass    3180 non-null   float64
#  10  orbital_eccentricity      5168 non-null   float64
#  11  planet_equil_temp_k       4438 non-null   float64
#  12  spectral_type             1908 non-null   object
#  13  stellar_effective_temp_k  5605 non-null   float64
#  14  stellar_rad_solar_rad     5465 non-null   float64
#  15  stellar_mass_solar_mass   6031 non-null   float64
#  16  stellar_surf_grav         5422 non-null   float64
#  17  distance_parsec           5948 non-null   float64
# dtypes: float64(13), object(5)
# memory usage: 853.9+ KB

# %% [markdown]
# #### Missing Stellar Mass Imputation (Kepler's Third Law Method)
# * Imputing the missing value for stellar mass using Kepler's Third Law Equations

# %%
# viewing a row which has missing stellar mass but the orbital semi major axis and orbital period is known
new_exoplanets_filtered2[new_exoplanets_filtered2["stellar_mass_solar_mass"].isna() & new_exoplanets_filtered2["orbit_semi_major_axis_au"].notna() & new_exoplanets_filtered2["orbital_period_day"].notna()]
# Out:
#          planet_name host_star_name  star_number_per_system  \
# 99          CI Tau c         CI Tau                     1.0
# 221         GJ 163 b         GJ 163                     1.0
# 222         GJ 163 c         GJ 163                     1.0
# 223         GJ 163 d         GJ 163                     1.0
# 1132      HD 47186 c       HD 47186                     1.0
# 2923    Kepler-160 d     Kepler-160                     1.0
# 4923  MXB 1658-298 b   MXB 1658-298                     2.0
# 5230      TOI-1422 c       TOI-1422                     1.0
#
#                discovery_method  year_of_discovery  \
# 99              Radial Velocity             2024.0
# 221             Radial Velocity             2013.0
# 222             Radial Velocity             2013.0
# 223             Radial Velocity             2013.0
# 1132            Radial Velocity             2008.0
# 2923  Transit Timing Variations             2020.0
# 4923  Eclipse Timing Variations             2017.0
# 5230            Radial Velocity             2025.0
#
#                       discovery_facility  orbital_period_day  \
# 99                Multiple Observatories            25.20000
# 221                 La Silla Observatory             8.63182
# 222                 La Silla Observatory            25.63058
# 223                 La Silla Observatory           603.95116
# 1132                La Silla Observatory          1353.60000
# 2923                              Kepler            30.00000
# 4923              Multiple Observatories           760.00000
# 5230  Roque de los Muchachos Observatory            34.56330
#
#       orbit_semi_major_axis_au  planet_rad_earth_rad  planet_mass_earth_mass  \
# 99                      0.1700                   NaN             1144.182265
# 221                     0.0607                   NaN               10.600000
# 222                     0.1254                   NaN                6.800000
# 223                     1.0304                   NaN               29.400000
# 1132                    2.3950                   NaN              111.420000
# 2923                    0.1700                   NaN              100.000000
# 4923                    1.6130                   NaN             7532.571000
# 5230                    0.2050                  2.61               14.000000
#
#       orbital_eccentricity  planet_equil_temp_k spectral_type  \
# 99                   0.580                  NaN           NaN
# 221                  0.073                  NaN           NaN
# 222                  0.099                  NaN           NaN
# 223                  0.373                  NaN           NaN
# 1132                 0.249                  NaN           NaN
# 2923                   NaN                  NaN           NaN
# 4923                   NaN                  NaN           NaN
# 5230                 0.200                628.0          G2 V
#
#       stellar_effective_temp_k  stellar_rad_solar_rad  \
# 99                         NaN                    NaN
# 221                        NaN                    NaN
# 222                        NaN                    NaN
# 223                        NaN                    NaN
# 1132                       NaN                    NaN
# 2923                    5471.0                  1.118
# 4923                       NaN                    NaN
# 5230                       NaN                    NaN
#
#       stellar_mass_solar_mass  stellar_surf_grav  distance_parsec
# 99                        NaN                NaN         157.9980
# 221                       NaN                NaN          15.1285
# 222                       NaN                NaN          15.1285
# 223                       NaN                NaN          15.1285
# 1132                      NaN                NaN          37.4574
# 2923                      NaN                NaN         937.0130
# 4923                      NaN                NaN              NaN
# 5230                      NaN                NaN         155.1410

# %%
# focusing on specfiic rows for futher viewing: planet name, host star name, spectral tyoe, stellar mass, obirtal semi major axis, and orbtial period
cols_to_show = [
    "planet_name",
    "host_star_name",
    "spectral_type",
    "stellar_mass_solar_mass",
    "orbit_semi_major_axis_au",
    "orbital_period_day"
]

filtered_rows = new_exoplanets_filtered2[
    new_exoplanets_filtered2["stellar_mass_solar_mass"].isna() &
    new_exoplanets_filtered2["orbit_semi_major_axis_au"].notna() &
    new_exoplanets_filtered2["orbital_period_day"].notna()
][cols_to_show]

filtered_rows
# Out:
#          planet_name host_star_name spectral_type  stellar_mass_solar_mass  \
# 99          CI Tau c         CI Tau           NaN                      NaN
# 221         GJ 163 b         GJ 163           NaN                      NaN
# 222         GJ 163 c         GJ 163           NaN                      NaN
# 223         GJ 163 d         GJ 163           NaN                      NaN
# 1132      HD 47186 c       HD 47186           NaN                      NaN
# 2923    Kepler-160 d     Kepler-160           NaN                      NaN
# 4923  MXB 1658-298 b   MXB 1658-298           NaN                      NaN
# 5230      TOI-1422 c       TOI-1422          G2 V                      NaN
#
#       orbit_semi_major_axis_au  orbital_period_day
# 99                      0.1700            25.20000
# 221                     0.0607             8.63182
# 222                     0.1254            25.63058
# 223                     1.0304           603.95116
# 1132                    2.3950          1353.60000
# 2923                    0.1700            30.00000
# 4923                    1.6130           760.00000
# 5230                    0.2050            34.56330

# %%
# For: Ms = (a^3)/(T^2) where a is the orbital semi major axis, T is the orbital period, and Ms is the stellar mass in terms of the Sun's mass (normalized)

# Constants and convertion factors
# the orbital_period will be converted from earth days to earth years
days_to_years = 1 / 365.25

# Create a boolean mask (series of TRUE and FALSE per row) to avoid division by zero or missing inputs
# Each row must be TRUE for all (no missing orbital semi major axis data, no missing orbital period data, all orbital period data greater than zero)
valid_inputs = (
    # For all orbital semi major axis (distance between star and planet) entries not missing and
    new_exoplanets_filtered2["orbit_semi_major_axis_au"].notna() &
    # For all orbital period (time it takes the planet to orbit its star) entries not missing and
    new_exoplanets_filtered2["orbital_period_day"].notna() &
    # For all orbital period entries greater than (but never equal to) zero
    (new_exoplanets_filtered2["orbital_period_day"] > 0)
)

# Mask of rows to be modified for the stellar mass column where the stellar mass entry is missing TRUE and satisfies the valid inputs TRUE
mask = new_exoplanets_filtered2["stellar_mass_solar_mass"].isna() & valid_inputs

# For the specific rows in stellar mass with missing mass entry, apply the mask
new_exoplanets_filtered2.loc[mask, "stellar_mass_solar_mass"] = (
    new_exoplanets_filtered2.loc[mask, "orbit_semi_major_axis_au"]**3
    / (new_exoplanets_filtered2.loc[mask, "orbital_period_day"]*days_to_years)**2
)

# %%
# checking if the number of missing values decreased
missing_percentage = (new_exoplanets_filtered2.isnull().sum() / len(new_exoplanets_filtered2))
((missing_percentage * 100).sort_values(ascending=False)).map(lambda x: f"{x:.2f}%")
# Out:
# spectral_type               68.57%
# planet_mass_earth_mass      47.62%
# planet_equil_temp_k         26.90%
# planet_rad_earth_rad        24.91%
# orbital_eccentricity        14.87%
# stellar_surf_grav           10.69%
# stellar_rad_solar_rad        9.98%
# stellar_effective_temp_k     7.68%
# orbital_period_day           5.24%
# orbit_semi_major_axis_au     5.09%
# distance_parsec              2.03%
# stellar_mass_solar_mass      0.53%
# host_star_name               0.00%
# planet_name                  0.00%
# star_number_per_system       0.00%
# discovery_method             0.00%
# year_of_discovery            0.00%
# discovery_facility           0.00%
# dtype: object

# %%
# viewing planet TOI-1422 c to verify imputation values align with physical theory
new_exoplanets_filtered2[new_exoplanets_filtered2["planet_name"] == "TOI-1422 c"][cols_to_show]
# Out:
#      planet_name host_star_name spectral_type  stellar_mass_solar_mass  \
# 5230  TOI-1422 c       TOI-1422          G2 V                 0.962081
#
#       orbit_semi_major_axis_au  orbital_period_day
# 5230                     0.205             34.5633

# %% [markdown]
# #### Missing Stellar Mass Imputation (Law of Universal Gravitation Method)
# * Imputing the missing value for stellar mass using the Law of Universal Gravitaion

# %%
# viewing a row which has missing stellar mass but stellar surface gravity is known and stellar radius is known
new_exoplanets_filtered2[new_exoplanets_filtered2["stellar_mass_solar_mass"].isna() & new_exoplanets_filtered2["stellar_surf_grav"].notna() & new_exoplanets_filtered2["stellar_rad_solar_rad"].notna()]
# Out:
#           planet_name  host_star_name  star_number_per_system  \
# 153  EPIC 201427007 b  EPIC 201427007                     1.0
# 163  EPIC 206024342 c  EPIC 206024342                     1.0
# 164  EPIC 206024342 d  EPIC 206024342                     1.0
# 167  EPIC 206042996 c  EPIC 206042996                     1.0
# 179  EPIC 212624936 b  EPIC 212624936                     1.0
# 180  EPIC 212624936 c  EPIC 212624936                     1.0
# 183  EPIC 220492298 b  EPIC 220492298                     1.0
#
#     discovery_method  year_of_discovery discovery_facility  \
# 153          Transit             2021.0                 K2
# 163          Transit             2021.0                 K2
# 164          Transit             2021.0                 K2
# 167          Transit             2021.0                 K2
# 179          Transit             2021.0                 K2
# 180          Transit             2021.0                 K2
# 183          Transit             2021.0                 K2
#
#      orbital_period_day  orbit_semi_major_axis_au  planet_rad_earth_rad  \
# 153            0.720910                       NaN              1.500000
# 163            0.911666                       NaN              1.303333
# 164           14.642393                       NaN              3.015000
# 167            0.354897                       NaN              1.325000
# 179            0.578657                       NaN              1.200000
# 180           11.812653                       NaN              2.485000
# 183            0.762406                       NaN              0.990000
#
#      planet_mass_earth_mass  orbital_eccentricity  planet_equil_temp_k  \
# 153                     NaN                   NaN                  NaN
# 163                     NaN                   NaN                  NaN
# 164                     NaN                   NaN                  NaN
# 167                     NaN                   NaN                  NaN
# 179                     NaN                   NaN                  NaN
# 180                     NaN                   NaN                  NaN
# 183                     NaN                   NaN                  NaN
#
#     spectral_type  stellar_effective_temp_k  stellar_rad_solar_rad  \
# 153           NaN               5633.000000                  0.940
# 163           NaN               5686.000000                  1.020
# 164           NaN               5936.666667                  1.020
# 167           NaN               4003.500000                  0.535
# 179           NaN               5765.000000                  0.930
# 180           NaN               5765.000000                  0.939
# 183           NaN               5620.000000                  0.890
#
#      stellar_mass_solar_mass  stellar_surf_grav  distance_parsec
# 153                      NaN               4.40          706.391
# 163                      NaN               4.50          369.888
# 164                      NaN               4.35          369.888
# 167                      NaN               4.80          451.769
# 179                      NaN               4.40          561.929
# 180                      NaN               4.40          561.929
# 183                      NaN               4.50          624.512

# %%
# focusing on specfiic rows for futher viewing: planet name, host star name, spectral type, stellar mass, stellar radius, stellar surface gravity,
# orbital semi major axis, and orbtial period
cols_to_show2 = [
    "planet_name",
    "host_star_name",
    "spectral_type",
    "stellar_mass_solar_mass",
    "stellar_rad_solar_rad",
    "stellar_surf_grav",
    "orbit_semi_major_axis_au",
    "orbital_period_day"
]

filtered_rows = new_exoplanets_filtered2[
    new_exoplanets_filtered2["stellar_mass_solar_mass"].isna() &
    new_exoplanets_filtered2["stellar_rad_solar_rad"].notna() &
    new_exoplanets_filtered2["stellar_surf_grav"].notna()
][cols_to_show2]

filtered_rows
# Out:
#           planet_name  host_star_name spectral_type  stellar_mass_solar_mass  \
# 153  EPIC 201427007 b  EPIC 201427007           NaN                      NaN
# 163  EPIC 206024342 c  EPIC 206024342           NaN                      NaN
# 164  EPIC 206024342 d  EPIC 206024342           NaN                      NaN
# 167  EPIC 206042996 c  EPIC 206042996           NaN                      NaN
# 179  EPIC 212624936 b  EPIC 212624936           NaN                      NaN
# 180  EPIC 212624936 c  EPIC 212624936           NaN                      NaN
# 183  EPIC 220492298 b  EPIC 220492298           NaN                      NaN
#
#      stellar_rad_solar_rad  stellar_surf_grav  orbit_semi_major_axis_au  \
# 153                  0.940               4.40                       NaN
# 163                  1.020               4.50                       NaN
# 164                  1.020               4.35                       NaN
# 167                  0.535               4.80                       NaN
# 179                  0.930               4.40                       NaN
# 180                  0.939               4.40                       NaN
# 183                  0.890               4.50                       NaN
#
#      orbital_period_day
# 153            0.720910
# 163            0.911666
# 164           14.642393
# 167            0.354897
# 179            0.578657
# 180           11.812653
# 183            0.762406

# %%
# For: Ms = (g Rs^(2))/G where g is the stellar surface gravity, Rs is the stellar radius and and G is the gravitational constant

# Constants and conversion factors
G = 6.67430e-11    # m^3 kg^-1 s^-2
M_sun = 1.989e30   # kg
R_sun = 6.96e8     # m

# Valid inputs: stellar radius and surface gravity (log g) known
valid_inputs = (
    new_exoplanets_filtered2["stellar_rad_solar_rad"].notna() &
    new_exoplanets_filtered2["stellar_surf_grav"].notna()
)

# Mask of rows to be modified for the stellar mass column where the stellar mass entry is missing TRUE and satisfies the valid inputs TRUE
mask2 = new_exoplanets_filtered2["stellar_mass_solar_mass"].isna() & valid_inputs

# Convert log(g) [cgs] to g [m/s^2]
g_m_s2 = 10 ** new_exoplanets_filtered2.loc[mask2, "stellar_surf_grav"] / 100

# Convert stellar radius from sun radius to meters
R_m = new_exoplanets_filtered2.loc[mask2, "stellar_rad_solar_rad"] * R_sun

# Compute stellar mass in sun masses
new_exoplanets_filtered2.loc[mask2, "stellar_mass_solar_mass"] = ((g_m_s2 * R_m**2) / G) / M_sun

# %%
# checking if the number of missing values decreased
missing_percentage = (new_exoplanets_filtered2.isnull().sum() / len(new_exoplanets_filtered2))
((missing_percentage * 100).sort_values(ascending=False)).map(lambda x: f"{x:.2f}%")
# Out:
# spectral_type               68.57%
# planet_mass_earth_mass      47.62%
# planet_equil_temp_k         26.90%
# planet_rad_earth_rad        24.91%
# orbital_eccentricity        14.87%
# stellar_surf_grav           10.69%
# stellar_rad_solar_rad        9.98%
# stellar_effective_temp_k     7.68%
# orbital_period_day           5.24%
# orbit_semi_major_axis_au     5.09%
# distance_parsec              2.03%
# stellar_mass_solar_mass      0.41%
# host_star_name               0.00%
# planet_name                  0.00%
# star_number_per_system       0.00%
# discovery_method             0.00%
# year_of_discovery            0.00%
# discovery_facility           0.00%
# dtype: object

# %%
# viewing planet EPIC 201427007 b to verify imputation values align with physical theory
new_exoplanets_filtered2[new_exoplanets_filtered2["planet_name"] == "EPIC 201427007 b"][cols_to_show2]
# Out:
#           planet_name  host_star_name spectral_type  stellar_mass_solar_mass  \
# 153  EPIC 201427007 b  EPIC 201427007           NaN                 0.809904
#
#      stellar_rad_solar_rad  stellar_surf_grav  orbit_semi_major_axis_au  \
# 153                   0.94                4.4                       NaN
#
#      orbital_period_day
# 153             0.72091

# %%
# Creating a flag column since multiple methods were used to impute stellar mass

# Tf stellar mass exists and was never imputed. it’s labeled as observed
new_exoplanets_filtered2["stellar_mass_imputation_method"] = "observed"
# If the orbital period and semi major axis was not missing and used to impute stellar mass. It's labeled as kepler_third_law_method_orb_per_orb_semi_major_axis
new_exoplanets_filtered2.loc[mask, "stellar_mass_imputation_method"] = "kepler_third_law_method_orb_per_orb_semi_major_axis"
# If the stellar radius and stellar surface gravity was not missing and used to impute stellar mass. It's labeled as law_of_gravition_stellar_rad_surf_grav
new_exoplanets_filtered2.loc[mask2, "stellar_mass_imputation_method"] = "law_of_gravition_stellar_rad_surf_grav"
# If missing values for stellar mass still missing. It's labeled as missing
new_exoplanets_filtered2.loc[
    new_exoplanets_filtered2["stellar_mass_solar_mass"].isna(),
    "stellar_mass_imputation_method"
] = "missing"

# %%
# Check how many times a specifc method was used for imputing missing stellar mass
new_exoplanets_filtered2["stellar_mass_imputation_method"].value_counts()
# Out:
# stellar_mass_imputation_method
# observed                                               6031
# missing                                                  25
# kepler_third_law_method_orb_per_orb_semi_major_axis       8
# law_of_gravition_stellar_rad_surf_grav                    7
# Name: count, dtype: int64

# %%
# Viewing the rows which still have a missing stellar mass
filtered_rows2 = new_exoplanets_filtered2[
    new_exoplanets_filtered2["stellar_mass_solar_mass"].isna()][cols_to_show2]

filtered_rows2 # These rows will most likely be removed as they have substantial missing data in key feature columns
# Out:
#                     planet_name           host_star_name spectral_type  \
# 16    2MASS J03590986+2009361 b  2MASS J03590986+2009361           NaN
# 18    2MASS J11011926-7732383 b  2MASS J11011926-7732383           NaN
# 19    2MASS J11550485-7919108 b  2MASS J11550485-7919108           NaN
# 22    2MASS J21252752-8138278 b  2MASS J21252752-8138278           NaN
# 24    2MASS J22501512+2325342 b  2MASS J22501512+2325342            M3
# 51                     AB Pic b                   AB Pic          K2 V
# 101                    CT Cha b                   CT Cha           NaN
# 197                   G 196-3 b                  G 196-3           NaN
# 658               HD 135344 A b              HD 135344 A          A0 V
# 887                 HD 203030 b                HD 203030          G8 V
# 1037             HD 284149 AB b              HD 284149 A           NaN
# 1108               HD 41004 A b               HD 41004 A           NaN
# 1378                HIP 77900 b                HIP 77900           NaN
# 1398                   HN Peg b                   HN Peg          G0 V
# 1414                   ITG 15 b                 ITG 15 A           NaN
# 1922             KIC 10001893 b             KIC 10001893           NaN
# 1923             KIC 10001893 c             KIC 10001893           NaN
# 1924             KIC 10001893 d             KIC 10001893           NaN
# 4881                  LkCa 15 b                  LkCa 15           NaN
# 4882                  LkCa 15 c                  LkCa 15           NaN
# 5081                   PDS 70 c                   PDS 70           NaN
# 5113                 Ross 458 c                 Ross 458           NaN
# 5116                 SR 12 AB c                 SR 12 AB           NaN
# 5998                 WISPIT 1 b                 WISPIT 1          K4 V
# 5999                 WISPIT 1 c                 WISPIT 1          K4 V
#
#       stellar_mass_solar_mass  stellar_rad_solar_rad  stellar_surf_grav  \
# 16                        NaN                    NaN                NaN
# 18                        NaN                    NaN                NaN
# 19                        NaN                    NaN                NaN
# 22                        NaN                    NaN                NaN
# 24                        NaN                    NaN                NaN
# 51                        NaN                    NaN                NaN
# 101                       NaN                    NaN                NaN
# 197                       NaN                    NaN                NaN
# 658                       NaN                1.50000                NaN
# 887                       NaN                    NaN                NaN
# 1037                      NaN                1.36000                NaN
# 1108                      NaN                    NaN                NaN
# 1378                      NaN                    NaN                NaN
# 1398                      NaN                    NaN                NaN
# 1414                      NaN                    NaN                NaN
# 1922                      NaN                    NaN               5.35
# 1923                      NaN                    NaN               5.35
# 1924                      NaN                    NaN               5.35
# 4881                      NaN                1.60711                NaN
# 4882                      NaN                1.60711                NaN
# 5081                      NaN                    NaN                NaN
# 5113                      NaN                    NaN                NaN
# 5116                      NaN                    NaN                NaN
# 5998                      NaN                    NaN                NaN
# 5999                      NaN                    NaN                NaN
#
#       orbit_semi_major_axis_au  orbital_period_day
# 16                      572.00                 NaN
# 18                      266.00                 NaN
# 19                      587.00                 NaN
# 22                     7493.00                 NaN
# 24                      518.00                 NaN
# 51                      260.00                 NaN
# 101                     440.00                 NaN
# 197                     350.00                 NaN
# 658                      16.50                 NaN
# 887                     487.10                 NaN
# 1037                    431.16                 NaN
# 1108                       NaN           963.00000
# 1378                   3319.00                 NaN
# 1398                    773.00                 NaN
# 1414                    435.00                 NaN
# 1922                       NaN             0.21970
# 1923                       NaN             0.32528
# 1924                       NaN             0.81161
# 4881                     14.70                 NaN
# 4882                     18.60                 NaN
# 5081                     34.25                 NaN
# 5113                   1100.00                 NaN
# 5116                       NaN                 NaN
# 5998                    338.00                 NaN
# 5999                    840.00                 NaN

# %% [markdown]
# #### Missing Orbital Semi Major Axis Imputation
# * Imputing the missing value for stellar mass using Kepler's Third Law Equations

# %%
# focusing on specfiic rows for futher viewing: planet name, host star name, spectral tyoe, stellar mass, obirtal semi major axis, and orbtial period
cols_to_show = [
    "planet_name",
    "host_star_name",
    "spectral_type",
    "stellar_mass_solar_mass",
    "orbit_semi_major_axis_au",
    "orbital_period_day"
]

filtered_rows = new_exoplanets_filtered2[
    new_exoplanets_filtered2["orbit_semi_major_axis_au"].isna() &
    new_exoplanets_filtered2["stellar_mass_solar_mass"].notna() &
    new_exoplanets_filtered2["orbital_period_day"].notna()
][cols_to_show]

filtered_rows
# Out:
#            planet_name  host_star_name spectral_type  stellar_mass_solar_mass  \
# 56            AU Mic d          AU Mic           NaN                   0.5100
# 57            AU Mic e          AU Mic           NaN                   0.6000
# 136          CoRoT-7 d         CoRoT-7          G9 V                   0.9150
# 150         DS Tuc A b        DS Tuc A          G6 V                   0.9845
# 152   EPIC 201238110 b  EPIC 201238110           NaN                   0.4100
# ...                ...             ...           ...                      ...
# 5817        WASP-110 b        WASP-110            G9                   0.8140
# 5830        WASP-126 c        WASP-126           NaN                   1.1200
# 6023  ZTF J1230-2655 b  ZTF J1230-2655           NaN                   0.6460
# 6024  ZTF J1828+2308 b  ZTF J1828+2308           NaN                   0.6100
# 6054          pi Men d        HD 39091           NaN                   1.0700
#
#       orbit_semi_major_axis_au  orbital_period_day
# 56                         NaN           12.735960
# 57                         NaN           33.250000
# 136                        NaN            8.966000
# 150                        NaN            8.138484
# 152                        NaN           28.167600
# ...                        ...                 ...
# 5817                       NaN            3.778401
# 5830                       NaN            7.630000
# 6023                       NaN            0.235978
# 6024                       NaN            0.112007
# 6054                       NaN          124.640000
#
# [298 rows x 6 columns]

# %%
# For: a = (T^2 * Ms)^(1/3) where a is the orbital semi major axis, T is the orbital period, and Ms is the stellar mass in terms of the Sun's mass (normalized)

# Constants and conversion factors
# the orbital_period will be converted from earth days to earth years
days_to_years = 1 / 365.25

# Create a boolean mask (series of TRUE and FALSE per row) to avoid division by zero or missing inputs
# Each row must be TRUE for all (no missing orbital semi major axis data, no missing orbital period data, all orbital period data greater than zero)
valid_inputs = (
    # For all orbital period (time it takes the planet to orbit its star) entries not missing and
    new_exoplanets_filtered2["orbital_period_day"].notna() &
    # For all stellar mass entries not missing
    new_exoplanets_filtered2["stellar_mass_solar_mass"].notna()
)

# Mask of rows to be modified for the stellar mass column where the orbital semi major axis entry is missing TRUE and satisfys the valid inputs TRUE
mask = new_exoplanets_filtered2["orbit_semi_major_axis_au"].isna() & valid_inputs

# For the specific rows in orbital semi major axis with missing mass entry, apply the mask
new_exoplanets_filtered2.loc[mask, "orbit_semi_major_axis_au"] = (
    new_exoplanets_filtered2.loc[mask, "stellar_mass_solar_mass"] * (new_exoplanets_filtered2.loc[mask, "orbital_period_day"] * days_to_years)**2)**(1/3)

# %%
# checking if the number of missing values decreased
missing_percentage = (new_exoplanets_filtered2.isnull().sum() / len(new_exoplanets_filtered2))
((missing_percentage * 100).sort_values(ascending=False)).map(lambda x: f"{x:.2f}%")
# Out:
# spectral_type                     68.57%
# planet_mass_earth_mass            47.62%
# planet_equil_temp_k               26.90%
# planet_rad_earth_rad              24.91%
# orbital_eccentricity              14.87%
# stellar_surf_grav                 10.69%
# stellar_rad_solar_rad              9.98%
# stellar_effective_temp_k           7.68%
# orbital_period_day                 5.24%
# distance_parsec                    2.03%
# stellar_mass_solar_mass            0.41%
# orbit_semi_major_axis_au           0.18%
# star_number_per_system             0.00%
# planet_name                        0.00%
# host_star_name                     0.00%
# year_of_discovery                  0.00%
# discovery_method                   0.00%
# discovery_facility                 0.00%
# stellar_mass_imputation_method     0.00%
# dtype: object

# %%
# viewing planet EPIC 201427007 b to verify imputation values align with physical theory
new_exoplanets_filtered2[new_exoplanets_filtered2["planet_name"] == "EPIC 201427007 b"][cols_to_show2]
# Out:
#           planet_name  host_star_name spectral_type  stellar_mass_solar_mass  \
# 153  EPIC 201427007 b  EPIC 201427007           NaN                 0.809904
#
#      stellar_rad_solar_rad  stellar_surf_grav  orbit_semi_major_axis_au  \
# 153                   0.94                4.4                  0.014667
#
#      orbital_period_day
# 153             0.72091

# %% [markdown]
# #### Missing Orbital Period Imputation
# * Imputing the missing value for stellar mass using Kepler's Third Law Equations

# %%
# focusing on specfiic rows for futher viewing: planet name, host star name, spectral tyoe, stellar mass, orbital semi major axis, and orbtial period
cols_to_show = [
    "planet_name",
    "host_star_name",
    "spectral_type",
    "stellar_mass_solar_mass",
    "orbit_semi_major_axis_au",
    "orbital_period_day"
]

filtered_rows = new_exoplanets_filtered2[
    new_exoplanets_filtered2["orbital_period_day"].isna() &
    new_exoplanets_filtered2["orbit_semi_major_axis_au"].notna() &
    new_exoplanets_filtered2["stellar_mass_solar_mass"].notna()
][cols_to_show]

filtered_rows
# Out:
#                         planet_name               host_star_name  \
# 7           1RXS J160929.1-210524 b        1RXS J160929.1-210524
# 11                         2M0437 b      2MASS J04372171+2651014
# 12     2MASS J01033563-5515561 AB b    2MASS J01033563-5515561 A
# 13        2MASS J01225093-2439505 b      2MASS J01225093-2439505
# 14        2MASS J02192210-3925225 b      2MASS J02192210-3925225
# ...                             ...                          ...
# 5994                  WD 0806-661 b                  WD 0806-661
# 5997  WISEP J121756.91+162640.2 A b  WISEP J121756.91+162640.2 A
# 6000                     WISPIT 2 b                     WISPIT 2
# 6043                      kap And b                      kap And
# 6046                      mu2 Sco b                      mu2 Sco
#
#      spectral_type  stellar_mass_solar_mass  orbit_semi_major_axis_au  \
# 7             K7 V                 0.850000                     330.0
# 11             M V                 0.170000                     118.0
# 12         M5.5/M6                 0.190000                      84.0
# 13          M3.5 V                 0.376592                      52.0
# 14              M6                 0.108000                     156.0
# ...            ...                      ...                       ...
# 5994            DQ                 0.620000                    2500.0
# 5997          T8.5                 0.029000                       8.0
# 6000           NaN                 1.080000                      55.5
# 6043         B9 IV                 2.525000                      58.0
# 6046         B2 IV                 9.100000                     242.4
#
#       orbital_period_day
# 7                    NaN
# 11                   NaN
# 12                   NaN
# 13                   NaN
# 14                   NaN
# ...                  ...
# 5994                 NaN
# 5997                 NaN
# 6000                 NaN
# 6043                 NaN
# 6046                 NaN
#
# [291 rows x 6 columns]

# %%
# For: T = (a^3 * Ms)^(1/2) where a is the orbital semi major axis, T is the orbital period, and Ms is the stellar mass in terms of the Sun's mass (normalized)

# Constants and conversion factors
# the orbital_period will be converted from earth years to earth days
years_to_days = 365.25

# Create a boolean mask (series of TRUE and FALSE per row) to avoid division by zero or missing inputs
# Each row must be TRUE for all (no missing orbital semi major axis data, no missing orbital period data, all orbital period data greater than zero)
valid_inputs = (
    # For all orbital period (time it takes the planet to orbit its star) entries not missing and
    new_exoplanets_filtered2["orbit_semi_major_axis_au"].notna() &
    # For all stellar mass entries not missing and
    new_exoplanets_filtered2["stellar_mass_solar_mass"].notna() &
    # For all stelar mass entries greater than (but never equal to) zero
    (new_exoplanets_filtered2["stellar_mass_solar_mass"] > 0)
)

# Mask of rows to be modified for the stellar mass column where the orbital semi major axis entry is missing TRUE and satisfys the valid inputs TRUE
mask = new_exoplanets_filtered2["orbital_period_day"].isna() & valid_inputs

# Create a boolean mask (series of TRUE and FALSE per row) to avoid division by zero or missing inputs
# Each row must be TRUE for all (no missing orbital semi major axis data, no missing orbital period data, all orbital period data greater than zero)
valid_inputs = (
    # For all orbital semi major axis (distance between planet and its star) entries not missing and
    new_exoplanets_filtered2["orbit_semi_major_axis_au"].notna() &
    # For all stellar mass entries not missing and
    new_exoplanets_filtered2["stellar_mass_solar_mass"].notna() &
    # For all stelar mass entries greater than (but never equal to) zero
    (new_exoplanets_filtered2["stellar_mass_solar_mass"] > 0)
)

# Mask of rows to be modified for the orbital period column where the orbital period entry is missing TRUE and satisfies the valid inputs TRUE
mask = new_exoplanets_filtered2["orbital_period_day"].isna() & valid_inputs

# For the specific rows in orbital period with missing mass entry, apply the mask
new_exoplanets_filtered2.loc[mask, "orbital_period_day"] = (
    (new_exoplanets_filtered2.loc[mask, "orbit_semi_major_axis_au"])**3 / new_exoplanets_filtered2.loc[mask, "stellar_mass_solar_mass"])**(1/3)

# %%
# checking if number of missing values decreased
missing_percentage = (new_exoplanets_filtered2.isnull().sum() / len(new_exoplanets_filtered2))
((missing_percentage * 100).sort_values(ascending=False)).map(lambda x: f"{x:.2f}%")
# Out:
# spectral_type                     68.57%
# planet_mass_earth_mass            47.62%
# planet_equil_temp_k               26.90%
# planet_rad_earth_rad              24.91%
# orbital_eccentricity              14.87%
# stellar_surf_grav                 10.69%
# stellar_rad_solar_rad              9.98%
# stellar_effective_temp_k           7.68%
# distance_parsec                    2.03%
# orbital_period_day                 0.44%
# stellar_mass_solar_mass            0.41%
# orbit_semi_major_axis_au           0.18%
# star_number_per_system             0.00%
# planet_name                        0.00%
# host_star_name                     0.00%
# year_of_discovery                  0.00%
# discovery_method                   0.00%
# discovery_facility                 0.00%
# stellar_mass_imputation_method     0.00%
# dtype: object

# %%
# viewing planet 2MASS J01033563-5515561 AB b to verify imputation values align with physical theory
new_exoplanets_filtered2[new_exoplanets_filtered2["planet_name"] == "2MASS J01033563-5515561 AB b"][cols_to_show2]
# Out:
#                      planet_name             host_star_name spectral_type  \
# 12  2MASS J01033563-5515561 AB b  2MASS J01033563-5515561 A       M5.5/M6
#
#     stellar_mass_solar_mass  stellar_rad_solar_rad  stellar_surf_grav  \
# 12                     0.19                    NaN                NaN
#
#     orbit_semi_major_axis_au  orbital_period_day
# 12                      84.0          146.114983

# %% [markdown]
# #### Missing Stellar Surface Gravity Imputation
# * Imputing the missing value for stellar mass using the Law of Universal Gravitation

# %%
# For: g = (GMs)/(Rs^(2)) where g is the stellar surface gravity, Rs is the stellar radius and and G is the gravitational constant

# Constants and conversion factors
G = 6.67430e-11    # m^3 kg^-1 s^-2
M_sun = 1.989e30   # kg
R_sun = 6.96e8     # m

# Valid inputs: stellar mass and stellar radius known
valid_inputs = (
    new_exoplanets_filtered2["stellar_mass_solar_mass"].notna() &
    new_exoplanets_filtered2["stellar_rad_solar_rad"].notna() &
    (new_exoplanets_filtered2["stellar_mass_solar_mass"] > 0) &
    (new_exoplanets_filtered2["stellar_rad_solar_rad"] > 0)
)

# Mask of rows to be modified for the stellar surface gravity log(g) [cgs] column where the stellar surface entry is missing TRUE and satisfies the valid inputs TRUE
mask = new_exoplanets_filtered2["stellar_surf_grav"].isna() & valid_inputs

# Convert stellar mass from solar masses to kg
M_kg = new_exoplanets_filtered2.loc[mask, "stellar_mass_solar_mass"] * M_sun

# Convert stellar radius from solar radii to meters
R_m = new_exoplanets_filtered2.loc[mask, "stellar_rad_solar_rad"] * R_sun

# Compute surface gravity in m/s^2
g_m_s2 = G * M_kg / (R_m ** 2)

# Convert m/s^2 → cm/s^2
g_cgs = g_m_s2 * 100

# Store log10(g) (cgs)
new_exoplanets_filtered2.loc[mask, "stellar_surf_grav"] = np.log10(g_cgs)

# %%
# checking if number of missing values decreased
missing_percentage = (new_exoplanets_filtered2.isnull().sum() / len(new_exoplanets_filtered2))
((missing_percentage * 100).sort_values(ascending=False)).map(lambda x: f"{x:.2f}%")
# Out:
# spectral_type                     68.57%
# planet_mass_earth_mass            47.62%
# planet_equil_temp_k               26.90%
# planet_rad_earth_rad              24.91%
# orbital_eccentricity              14.87%
# stellar_rad_solar_rad              9.98%
# stellar_surf_grav                  8.17%
# stellar_effective_temp_k           7.68%
# distance_parsec                    2.03%
# orbital_period_day                 0.44%
# stellar_mass_solar_mass            0.41%
# orbit_semi_major_axis_au           0.18%
# star_number_per_system             0.00%
# planet_name                        0.00%
# host_star_name                     0.00%
# year_of_discovery                  0.00%
# discovery_method                   0.00%
# discovery_facility                 0.00%
# stellar_mass_imputation_method     0.00%
# dtype: object

# %%
# Viewing the rows which still have a missing stellar surface gravity
filtered_rows3 = new_exoplanets_filtered2[
    new_exoplanets_filtered2["stellar_surf_grav"].isna()][cols_to_show2]

filtered_rows3
# Out:
#                        planet_name             host_star_name spectral_type  \
# 12    2MASS J01033563-5515561 AB b  2MASS J01033563-5515561 A       M5.5/M6
# 15              2MASS J0249-0557 c         2MASS J0249-0557 A          M6 V
# 16       2MASS J03590986+2009361 b    2MASS J03590986+2009361           NaN
# 17       2MASS J04414489+2301513 b    2MASS J04414489+2301513          M8.5
# 18       2MASS J11011926-7732383 b    2MASS J11011926-7732383           NaN
# ...                            ...                        ...           ...
# 6030                     bet Pic c                    bet Pic           NaN
# 6061                     tau Cet e                    tau Cet           NaN
# 6062                     tau Cet f                    tau Cet           NaN
# 6063                     tau Cet g                    tau Cet           NaN
# 6064                     tau Cet h                    tau Cet           NaN
#
#       stellar_mass_solar_mass  stellar_rad_solar_rad  stellar_surf_grav  \
# 12                      0.190                    NaN                NaN
# 15                      0.046                    NaN                NaN
# 16                        NaN                    NaN                NaN
# 17                      0.019                    NaN                NaN
# 18                        NaN                    NaN                NaN
# ...                       ...                    ...                ...
# 6030                    1.795                    NaN                NaN
# 6061                    0.783                    NaN                NaN
# 6062                    0.783                    NaN                NaN
# 6063                    0.783                    NaN                NaN
# 6064                    0.783                    NaN                NaN
#
#       orbit_semi_major_axis_au  orbital_period_day
# 12                      84.000          146.114983
# 15                    1950.000         5442.294019
# 16                     572.000                 NaN
# 17                      15.000           56.213427
# 18                     266.000                 NaN
# ...                        ...                 ...
# 6030                     2.700         1207.593170
# 6061                     0.538          162.870000
# 6062                     1.334          636.130000
# 6063                     0.133           20.000000
# 6064                     0.243           49.410000
#
# [496 rows x 8 columns]

# %% [markdown]
# #### Missing Stellar Effective Temperature Imputation
# * Imputing the missing value for stellar mass using Zero-Greenhouse Equilibrium Temperature of Exoplanet Equation

# %%
# Viewing the rows which still have a missing stellar effective temperature
filtered_rows4 = new_exoplanets_filtered2[
    new_exoplanets_filtered2["stellar_effective_temp_k"].isna()]

filtered_rows4
# Out:
#                        planet_name             host_star_name  \
# 12    2MASS J01033563-5515561 AB b  2MASS J01033563-5515561 A
# 15              2MASS J0249-0557 c         2MASS J0249-0557 A
# 16       2MASS J03590986+2009361 b    2MASS J03590986+2009361
# 17       2MASS J04414489+2301513 b    2MASS J04414489+2301513
# 18       2MASS J11011926-7732383 b    2MASS J11011926-7732383
# ...                            ...                        ...
# 6030                     bet Pic c                    bet Pic
# 6061                     tau Cet e                    tau Cet
# 6062                     tau Cet f                    tau Cet
# 6063                     tau Cet g                    tau Cet
# 6064                     tau Cet h                    tau Cet
#
#       star_number_per_system discovery_method  year_of_discovery  \
# 12                       2.0          Imaging             2013.0
# 15                       2.0          Imaging             2018.0
# 16                       1.0          Imaging             2024.0
# 17                       1.0          Imaging             2010.0
# 18                       1.0          Imaging             2024.0
# ...                      ...              ...                ...
# 6030                     1.0  Radial Velocity             2019.0
# 6061                     1.0  Radial Velocity             2017.0
# 6062                     1.0  Radial Velocity             2017.0
# 6063                     1.0  Radial Velocity             2017.0
# 6064                     1.0  Radial Velocity             2017.0
#
#                               discovery_facility  orbital_period_day  \
# 12                           Paranal Observatory          146.114983
# 15                         Mauna Kea Observatory         5442.294019
# 16    European Space Agency (ESA) Gaia Satellite                 NaN
# 17                        Hubble Space Telescope           56.213427
# 18    European Space Agency (ESA) Gaia Satellite                 NaN
# ...                                          ...                 ...
# 6030                        La Silla Observatory         1207.593170
# 6061                      Multiple Observatories          162.870000
# 6062                      Multiple Observatories          636.130000
# 6063                      Multiple Observatories           20.000000
# 6064                      Multiple Observatories           49.410000
#
#       orbit_semi_major_axis_au  planet_rad_earth_rad  planet_mass_earth_mass  \
# 12                      84.000                   NaN             4131.790000
# 15                    1950.000                   NaN             3686.809521
# 16                     572.000                   NaN             5720.911326
# 17                      15.000                   NaN             2383.600000
# 18                     266.000                   NaN             8899.195396
# ...                        ...                   ...                     ...
# 6030                     2.700                   NaN             2896.375052
# 6061                     0.538                   NaN                3.930000
# 6062                     1.334                   NaN                3.930000
# 6063                     0.133                   NaN                1.750000
# 6064                     0.243                   NaN                1.830000
#
#       orbital_eccentricity  planet_equil_temp_k spectral_type  \
# 12                     NaN                  NaN       M5.5/M6
# 15                     NaN                  NaN          M6 V
# 16                     NaN               2369.0           NaN
# 17                     NaN                  NaN          M8.5
# 18                     NaN               2677.0           NaN
# ...                    ...                  ...           ...
# 6030                 0.308               1250.0           NaN
# 6061                 0.180                  NaN           NaN
# 6062                 0.160                  NaN           NaN
# 6063                 0.060                  NaN           NaN
# 6064                 0.230                  NaN           NaN
#
#       stellar_effective_temp_k  stellar_rad_solar_rad  \
# 12                         NaN                    NaN
# 15                         NaN                    NaN
# 16                         NaN                    NaN
# 17                         NaN                    NaN
# 18                         NaN                    NaN
# ...                        ...                    ...
# 6030                       NaN                    NaN
# 6061                       NaN                    NaN
# 6062                       NaN                    NaN
# 6063                       NaN                    NaN
# 6064                       NaN                    NaN
#
#       stellar_mass_solar_mass  stellar_surf_grav  distance_parsec  \
# 12                      0.190                NaN              NaN
# 15                      0.046                NaN         66.06130
# 16                        NaN                NaN        117.43500
# 17                      0.019                NaN              NaN
# 18                        NaN                NaN              NaN
# ...                       ...                ...              ...
# 6030                    1.795                NaN         19.74420
# 6061                    0.783                NaN          3.60304
# 6062                    0.783                NaN          3.60304
# 6063                    0.783                NaN          3.60304
# 6064                    0.783                NaN          3.60304
#
#      stellar_mass_imputation_method
# 12                         observed
# 15                         observed
# 16                          missing
# 17                         observed
# 18                          missing
# ...                             ...
# 6030                       observed
# 6061                       observed
# 6062                       observed
# 6063                       observed
# 6064                       observed
#
# [466 rows x 19 columns]

# %%
# For: T_eff = (T_eq/(1 - A)^(1/4)) * sqrt((2a)/Rs) where Rs is the stellar radius in sun radius and a is the orbital semi major axis (coverted from AU to Solar Radius)
# and T_eff is the stellar effective temperature

# Constants
AU_to_Rsun = 215.032    # 1 AU = 215.032 solar radii
A = 0.5                 # Bond albedo (assumed A = 0.5 neither hihgly reflective nor completely dark)

# Valid inputs: stellar temperature [K], stellar radius [R_sun], semi-major axis [AU]
valid_inputs = (
    new_exoplanets_filtered2["planet_equil_temp_k"].notna() &
    new_exoplanets_filtered2["orbit_semi_major_axis_au"].notna() &
    new_exoplanets_filtered2["stellar_rad_solar_rad"].notna() &
    (new_exoplanets_filtered2["stellar_rad_solar_rad"] > 0) &
    (new_exoplanets_filtered2["orbit_semi_major_axis_au"] > 0)
)

# Mask rows where stellar effective temperature is missing
mask = new_exoplanets_filtered2["stellar_effective_temp_k"].isna() & valid_inputs

# Planetary equilibrium effective temperature already in Kelvin
T_eq = new_exoplanets_filtered2.loc[mask, "planet_equil_temp_k"]

# Convert semi-major axis from AU to sun radius since a/Rs must be dimensionless
a_Rsun = (
    new_exoplanets_filtered2.loc[mask, "orbit_semi_major_axis_au"] * AU_to_Rsun
)

# Stellar radius already in sun radius
Rs = new_exoplanets_filtered2.loc[mask, "stellar_rad_solar_rad"]

# Compute planetary equilibrium temperature [K]
T_eff = (
    T_eq / (1-A)**0.25 * np.sqrt(2 * a_Rsun / Rs)
)

# Store result in Kelvin
T_eff = new_exoplanets_filtered2.loc[mask, "stellar_effective_temp_k"]

# %%
# checking if number of missing values decreased
missing_percentage = (new_exoplanets_filtered2.isnull().sum() / len(new_exoplanets_filtered2))
((missing_percentage * 100).sort_values(ascending=False)).map(lambda x: f"{x:.2f}%")
# Out:
# spectral_type                     68.57%
# planet_mass_earth_mass            47.62%
# planet_equil_temp_k               26.90%
# planet_rad_earth_rad              24.91%
# orbital_eccentricity              14.87%
# stellar_rad_solar_rad              9.98%
# stellar_surf_grav                  8.17%
# stellar_effective_temp_k           7.68%
# distance_parsec                    2.03%
# orbital_period_day                 0.44%
# stellar_mass_solar_mass            0.41%
# orbit_semi_major_axis_au           0.18%
# star_number_per_system             0.00%
# planet_name                        0.00%
# host_star_name                     0.00%
# year_of_discovery                  0.00%
# discovery_method                   0.00%
# discovery_facility                 0.00%
# stellar_mass_imputation_method     0.00%
# dtype: object

# %% [markdown]
# #### Missing Planet Effective Temperature Imputation
# * Imputing the missing value for stellar mass using Zero-Greenhouse Equilibrium Temperature of Exoplanet Equation

# %%
# Viewing the rows which still have a missing planet equilibrium temperature
filtered_rows5 = new_exoplanets_filtered2[
    new_exoplanets_filtered2["planet_equil_temp_k"].isna()]

filtered_rows5
# Out:
#      planet_name host_star_name  star_number_per_system discovery_method  \
# 0       11 Com b         11 Com                     2.0  Radial Velocity
# 1       11 UMi b         11 UMi                     1.0  Radial Velocity
# 2       14 And b         14 And                     1.0  Radial Velocity
# 3       14 Her b         14 Her                     1.0  Radial Velocity
# 4     16 Cyg B b       16 Cyg B                     3.0  Radial Velocity
# ...          ...            ...                     ...              ...
# 6066   ups And b        ups And                     2.0  Radial Velocity
# 6067   ups And c        ups And                     2.0  Radial Velocity
# 6068   ups And d        ups And                     2.0  Radial Velocity
# 6069   ups Leo b        ups Leo                     1.0  Radial Velocity
# 6070    xi Aql b         xi Aql                     1.0  Radial Velocity
#
#       year_of_discovery                      discovery_facility  \
# 0                2007.0                        Xinglong Station
# 1                2009.0  Thueringer Landessternwarte Tautenburg
# 2                2008.0       Okayama Astrophysical Observatory
# 3                2002.0                  W. M. Keck Observatory
# 4                1996.0                  Multiple Observatories
# ...                 ...                                     ...
# 6066             1996.0                        Lick Observatory
# 6067             1999.0                  Multiple Observatories
# 6068             1999.0                  Multiple Observatories
# 6069             2021.0       Okayama Astrophysical Observatory
# 6070             2007.0       Okayama Astrophysical Observatory
#
#       orbital_period_day  orbit_semi_major_axis_au  planet_rad_earth_rad  \
# 0             324.620000                  1.226000                   NaN
# 1             516.219985                  1.526667                   NaN
# 2             186.300000                  0.761667                   NaN
# 3            1766.378417                  2.814750                   NaN
# 4             799.375000                  1.662833                   NaN
# ...                  ...                       ...                   ...
# 6066            4.616229                  0.058895                   NaN
# 6067          240.728533                  0.827712                   NaN
# 6068         1285.346167                  2.528382                   NaN
# 6069          385.200000                  1.180000                   NaN
# 6070          136.860000                  0.628333                   NaN
#
#       planet_mass_earth_mass  orbital_eccentricity  planet_equil_temp_k  \
# 0                5505.066162              0.234500                  NaN
# 1                3818.094733              0.080000                  NaN
# 2                1224.550434              0.000000                  NaN
# 3                1642.383592              0.362925                  NaN
# 4                 533.514528              0.676033                  NaN
# ...                      ...                   ...                  ...
# 6066              219.960419              0.030200                  NaN
# 6067             1275.328758              0.238933                  NaN
# 6068             1616.242590              0.281117                  NaN
# 6069              162.092488              0.320000                  NaN
# 6070              716.301646              0.029500                  NaN
#
#      spectral_type  stellar_effective_temp_k  stellar_rad_solar_rad  \
# 0           G8 III               4808.000000              16.380000
# 1           K4 III               4276.500000              26.935000
# 2           K0 III               4850.500000              11.275000
# 3             K0 V               5296.985000               0.999085
# 4           G2.5 V               5728.594000               1.129135
# ...            ...                       ...                    ...
# 6066          F8 V               6137.820000               1.614742
# 6067          F8 V               6117.093333               1.614742
# 6068          F8 V               6117.093333               1.614742
# 6069        G9 III               4836.000000              11.220000
# 6070        K0 III               4810.500000              11.430000
#
#       stellar_mass_solar_mass  stellar_surf_grav  distance_parsec  \
# 0                    2.463333           2.380000          93.1846
# 1                    2.093333           1.765000         125.3210
# 2                    1.780000           2.590000          75.4392
# 3                    0.904000           4.418006          17.9323
# 4                    1.016599           4.342293          21.1397
# ...                       ...                ...              ...
# 6066                 1.276049           4.161529          13.4054
# 6067                 1.301399           4.148705          13.4054
# 6068                 1.301399           4.148705          13.4054
# 6069                 1.480000           2.460000          52.5973
# 6070                 1.740000           2.635000          56.1858
#
#      stellar_mass_imputation_method
# 0                          observed
# 1                          observed
# 2                          observed
# 3                          observed
# 4                          observed
# ...                             ...
# 6066                       observed
# 6067                       observed
# 6068                       observed
# 6069                       observed
# 6070                       observed
#
# [1633 rows x 19 columns]

# %%
# For: T_eq = T_eff * (1 - A)^(1/4) * sqrt(Rs/(2a)) where Rs is the stellar radius in sun radius and a is the orbital semi major axis (coverted from AU to Solar Radius)
# and T_eff is the stellar effective temperature

# Constants
AU_to_Rsun = 215.032    # 1 AU = 215.032 solar radii
A = 0.5                 # Bond albedo (assumed A = 0.5 neither hihgly reflective nor completely dark)

# Valid inputs: stellar temperature [K], stellar radius [R_sun], semi-major axis [AU]
valid_inputs = (
    new_exoplanets_filtered2["stellar_effective_temp_k"].notna() &
    new_exoplanets_filtered2["stellar_rad_solar_rad"].notna() &
    new_exoplanets_filtered2["orbit_semi_major_axis_au"].notna() &
    (new_exoplanets_filtered2["stellar_effective_temp_k"] > 0) &
    (new_exoplanets_filtered2["stellar_rad_solar_rad"] > 0) &
    (new_exoplanets_filtered2["orbit_semi_major_axis_au"] > 0)
)

# Mask rows where planetary equilibrium temperature is missing
mask = new_exoplanets_filtered2["planet_equil_temp_k"].isna() & valid_inputs

# Stellar effective temperature already in Kelvin
T_eff = new_exoplanets_filtered2.loc[mask, "stellar_effective_temp_k"]

# Convert semi-major axis from AU to sun radius since Rs/a must be dimensionless
a_Rsun = (
    new_exoplanets_filtered2.loc[mask, "orbit_semi_major_axis_au"] * AU_to_Rsun
)

# Stellar radius already in sun radius
Rs = new_exoplanets_filtered2.loc[mask, "stellar_rad_solar_rad"]

# Compute planetary equilibrium temperature [K]
T_eq = (
    T_eff *
    (1 - A) ** 0.25 *
    np.sqrt(Rs / (2 * a_Rsun))
)

# Store result in Kelvin
new_exoplanets_filtered2.loc[mask, "planet_equil_temp_k"] = T_eq

# %%
# checking if number of missing values decreased
missing_percentage = (new_exoplanets_filtered2.isnull().sum() / len(new_exoplanets_filtered2))
((missing_percentage * 100).sort_values(ascending=False)).map(lambda x: f"{x:.2f}%")
# Out:
# spectral_type                     68.57%
# planet_mass_earth_mass            47.62%
# planet_rad_earth_rad              24.91%
# orbital_eccentricity              14.87%
# stellar_rad_solar_rad              9.98%
# planet_equil_temp_k                9.55%
# stellar_surf_grav                  8.17%
# stellar_effective_temp_k           7.68%
# distance_parsec                    2.03%
# orbital_period_day                 0.44%
# stellar_mass_solar_mass            0.41%
# orbit_semi_major_axis_au           0.18%
# star_number_per_system             0.00%
# planet_name                        0.00%
# host_star_name                     0.00%
# year_of_discovery                  0.00%
# discovery_method                   0.00%
# discovery_facility                 0.00%
# stellar_mass_imputation_method     0.00%
# dtype: object

# %%
# viewing planet 11 Com b to verify imputation values align with physical theory
new_exoplanets_filtered2[new_exoplanets_filtered2["planet_name"] == "11 Com b"]
# Out:
#   planet_name host_star_name  star_number_per_system discovery_method  \
# 0    11 Com b         11 Com                     2.0  Radial Velocity
#
#    year_of_discovery discovery_facility  orbital_period_day  \
# 0             2007.0   Xinglong Station              324.62
#
#    orbit_semi_major_axis_au  planet_rad_earth_rad  planet_mass_earth_mass  \
# 0                     1.226                   NaN             5505.066162
#
#    orbital_eccentricity  planet_equil_temp_k spectral_type  \
# 0                0.2345           712.610355        G8 III
#
#    stellar_effective_temp_k  stellar_rad_solar_rad  stellar_mass_solar_mass  \
# 0                    4808.0                  16.38                 2.463333
#
#    stellar_surf_grav  distance_parsec stellar_mass_imputation_method
# 0               2.38          93.1846                       observed

# %% [markdown]
# #### Missing Planet Mass Imputation
# * Imputing the missing value for planetary mass using Transit Method Mass-Radius Estimation

# %%
# Viewing the rows which still have a missing planet mass
filtered_rows6 = new_exoplanets_filtered2[
    new_exoplanets_filtered2["planet_mass_earth_mass"].isna()]

filtered_rows6
# Out:
#             planet_name  host_star_name  star_number_per_system  \
# 151   EPIC 201170410.02  EPIC 201170410                     1.0
# 152    EPIC 201238110 b  EPIC 201238110                     1.0
# 153    EPIC 201427007 b  EPIC 201427007                     1.0
# 154    EPIC 201497682 b  EPIC 201497682                     1.0
# 156    EPIC 201615463 c          K2-166                     1.0
# ...                 ...             ...                     ...
# 5750         TOI-880.02         TOI-880                     1.0
# 5752          TOI-904 b         TOI-904                     1.0
# 5753          TOI-904 c         TOI-904                     1.0
# 5755         TOI-907.01         TOI-907                     1.0
# 5758          TOI-913 b         TOI-913                     1.0
#
#      discovery_method  year_of_discovery  \
# 151           Transit             2020.0
# 152           Transit             2019.0
# 153           Transit             2021.0
# 154           Transit             2019.0
# 156           Transit             2019.0
# ...               ...                ...
# 5750          Transit             2024.0
# 5752          Transit             2023.0
# 5753          Transit             2023.0
# 5755          Transit             2024.0
# 5758          Transit             2023.0
#
#                                 discovery_facility  orbital_period_day  \
# 151                                             K2            6.798700
# 152                                             K2           28.167600
# 153                                             K2            0.720910
# 154                                             K2            2.131740
# 156                                             K2            3.804640
# ...                                            ...                 ...
# 5750  Transiting Exoplanet Survey Satellite (TESS)            2.574652
# 5752  Transiting Exoplanet Survey Satellite (TESS)           10.877200
# 5753  Transiting Exoplanet Survey Satellite (TESS)           83.999700
# 5755  Transiting Exoplanet Survey Satellite (TESS)            4.584913
# 5758  Transiting Exoplanet Survey Satellite (TESS)           11.098644
#
#       orbit_semi_major_axis_au  planet_rad_earth_rad  planet_mass_earth_mass  \
# 151                   0.034900              1.047000                     NaN
# 152                   0.134597              2.035000                     NaN
# 153                   0.014667              1.500000                     NaN
# 154                   0.029840              0.692000                     NaN
# 156                   0.048829              1.220000                     NaN
# ...                        ...                   ...                     ...
# 5750                  0.034545              2.483961                     NaN
# 5752                  0.056000              2.426000                     NaN
# 5753                  0.312000              2.167000                     NaN
# 5755                  0.055225              9.615885                     NaN
# 5758                  0.091143              2.452800                     NaN
#
#       orbital_eccentricity  planet_equil_temp_k spectral_type  \
# 151                    0.0           420.477369           NaN
# 152                    NaN                  NaN           NaN
# 153                    NaN          1828.565041           NaN
# 154                    NaN                  NaN           NaN
# 156                    NaN                  NaN           NaN
# ...                    ...                  ...           ...
# 5750                   NaN          1123.985000             K
# 5752                   NaN           429.430000           NaN
# 5753                   NaN           217.260000           NaN
# 5755                   NaN          1846.600000           NaN
# 5758                   NaN           712.010000           NaN
#
#       stellar_effective_temp_k  stellar_rad_solar_rad  \
# 151                     3648.0               0.282000
# 152                        NaN               0.374000
# 153                     5633.0               0.940000
# 154                        NaN                    NaN
# 156                        NaN                    NaN
# ...                        ...                    ...
# 5750                    4992.5               0.823500
# 5752                    3770.2               0.527000
# 5753                    3770.2               0.527000
# 5755                    6272.0               2.059789
# 5758                    4969.0               0.732500
#
#       stellar_mass_solar_mass  stellar_surf_grav  distance_parsec  \
# 151                  0.287000           4.999000              NaN
# 152                  0.410000           4.904863         159.2590
# 153                  0.809904           4.400000         706.3910
# 154                  0.780000                NaN         253.0260
# 156                  1.073000                NaN         476.8820
# ...                       ...                ...              ...
# 5750                 0.837708           4.525000          60.6679
# 5752                 0.557000           4.740056          46.0891
# 5753                 0.557000           4.740056          46.0891
# 5755                 1.069357           3.839900         312.5290
# 5758                 0.820000           4.622000          65.1769
#
#               stellar_mass_imputation_method
# 151                                 observed
# 152                                 observed
# 153   law_of_gravition_stellar_rad_surf_grav
# 154                                 observed
# 156                                 observed
# ...                                      ...
# 5750                                observed
# 5752                                observed
# 5753                                observed
# 5755                                observed
# 5758                                observed
#
# [2891 rows x 19 columns]

# %%
# viewing planets with missing mass but known planet radius

cols_to_show3 = [
    "planet_name",
    "planet_mass_earth_mass",
    "planet_rad_earth_rad",
]

filtered_row6 = new_exoplanets_filtered2[
    new_exoplanets_filtered2["planet_mass_earth_mass"].isna() &
    new_exoplanets_filtered2["planet_rad_earth_rad"].notna()
][cols_to_show3]

filtered_row6
# Out:
#             planet_name  planet_mass_earth_mass  planet_rad_earth_rad
# 151   EPIC 201170410.02                     NaN              1.047000
# 152    EPIC 201238110 b                     NaN              2.035000
# 153    EPIC 201427007 b                     NaN              1.500000
# 154    EPIC 201497682 b                     NaN              0.692000
# 156    EPIC 201615463 c                     NaN              1.220000
# ...                 ...                     ...                   ...
# 5750         TOI-880.02                     NaN              2.483961
# 5752          TOI-904 b                     NaN              2.426000
# 5753          TOI-904 c                     NaN              2.167000
# 5755         TOI-907.01                     NaN              9.615885
# 5758          TOI-913 b                     NaN              2.452800
#
# [2884 rows x 3 columns]

# %%
# imputing the planet mass for kepler-452 b which is known to be Mp = 3.29
idx = new_exoplanets_filtered2.index[new_exoplanets_filtered2["planet_name"] == "Kepler-452 b"][0]

new_exoplanets_filtered2.at[idx, "planet_mass_earth_mass"] = 3.29

# %%
# viewing the row for kepler-452 b
new_exoplanets_filtered2[new_exoplanets_filtered2["planet_name"] == "Kepler-452 b"]
# Out:
#        planet_name host_star_name  star_number_per_system discovery_method  \
# 4115  Kepler-452 b     Kepler-452                     1.0          Transit
#
#       year_of_discovery discovery_facility  orbital_period_day  \
# 4115             2015.0             Kepler          384.844831
#
#       orbit_semi_major_axis_au  planet_rad_earth_rad  planet_mass_earth_mass  \
# 4115                  1.009733                1.3722                    3.29
#
#       orbital_eccentricity  planet_equil_temp_k spectral_type  \
# 4115                   0.0                235.0            G2
#
#       stellar_effective_temp_k  stellar_rad_solar_rad  \
# 4115               5687.166667               1.099285
#
#       stellar_mass_solar_mass  stellar_surf_grav  distance_parsec  \
# 4115                 1.029667            4.44555          551.727
#
#      stellar_mass_imputation_method
# 4115                       observed

# %%
# For Mp = Rp^(0.52) where Rp is the planet radius and Mp is the planet

# Valid inputs
valid_inputs = (
    new_exoplanets_filtered2["planet_rad_earth_rad"].notna() &
    (new_exoplanets_filtered2["planet_rad_earth_rad"] > 0)
)

# Mask rows where planet mass is missing
mask = new_exoplanets_filtered2["planet_mass_earth_mass"].isna() & valid_inputs

# imputing missing planet mass
new_exoplanets_filtered2.loc[mask, "planet_mass_earth_mass"] = new_exoplanets_filtered2.loc[mask, "planet_rad_earth_rad"]**0.52

# %%
# checking if number of missing values decreased
missing_percentage = (new_exoplanets_filtered2.isnull().sum() / len(new_exoplanets_filtered2))
((missing_percentage * 100).sort_values(ascending=False)).map(lambda x: f"{x:.2f}%")
# Out:
# spectral_type                     68.57%
# planet_rad_earth_rad              24.91%
# orbital_eccentricity              14.87%
# stellar_rad_solar_rad              9.98%
# planet_equil_temp_k                9.55%
# stellar_surf_grav                  8.17%
# stellar_effective_temp_k           7.68%
# distance_parsec                    2.03%
# orbital_period_day                 0.44%
# stellar_mass_solar_mass            0.41%
# orbit_semi_major_axis_au           0.18%
# planet_mass_earth_mass             0.12%
# star_number_per_system             0.00%
# planet_name                        0.00%
# host_star_name                     0.00%
# year_of_discovery                  0.00%
# discovery_method                   0.00%
# discovery_facility                 0.00%
# stellar_mass_imputation_method     0.00%
# dtype: object

# %% [markdown]
# #### Missing Planet Radius Imputation
# * Imputing the missing value for planet radius using mputing the missing value for planetary mass using Transit Method Mass-Radius Estimation

# %%
# viewing planets with missing mass but known planet radius

cols_to_show4 = [
    "planet_name",
    "planet_mass_earth_mass",
    "planet_rad_earth_rad",
]

filtered_row6 = new_exoplanets_filtered2[
    new_exoplanets_filtered2["planet_rad_earth_rad"].isna() &
    new_exoplanets_filtered2["planet_mass_earth_mass"].notna()
][cols_to_show4]

filtered_row6
# Out:
#      planet_name  planet_mass_earth_mass  planet_rad_earth_rad
# 0       11 Com b             5505.066162                   NaN
# 1       11 UMi b             3818.094733                   NaN
# 2       14 And b             1224.550434                   NaN
# 3       14 Her b             1642.383592                   NaN
# 4     16 Cyg B b              533.514528                   NaN
# ...          ...                     ...                   ...
# 6066   ups And b              219.960419                   NaN
# 6067   ups And c             1275.328758                   NaN
# 6068   ups And d             1616.242590                   NaN
# 6069   ups Leo b              162.092488                   NaN
# 6070    xi Aql b              716.301646                   NaN
#
# [1505 rows x 3 columns]

# %%
# For Rp = Mp^(1/2.09) where Rp is the planet radius and Mp is the planet mass

# Valid inputs
valid_inputs = (
    new_exoplanets_filtered2["planet_mass_earth_mass"].notna() &
    (new_exoplanets_filtered2["planet_mass_earth_mass"] > 0)
)

# Mask rows where planet rad is missing
mask = new_exoplanets_filtered2["planet_rad_earth_rad"].isna() & valid_inputs

# imputing missing planet rad
new_exoplanets_filtered2.loc[mask, "planet_rad_earth_rad"] = new_exoplanets_filtered2.loc[mask, "planet_mass_earth_mass"]**(1/2.09)

# %%
# checking if number of missing values decreased
missing_percentage = (new_exoplanets_filtered2.isnull().sum() / len(new_exoplanets_filtered2))
((missing_percentage * 100).sort_values(ascending=False)).map(lambda x: f"{x:.2f}%")
# Out:
# spectral_type                     68.57%
# orbital_eccentricity              14.87%
# stellar_rad_solar_rad              9.98%
# planet_equil_temp_k                9.55%
# stellar_surf_grav                  8.17%
# stellar_effective_temp_k           7.68%
# distance_parsec                    2.03%
# orbital_period_day                 0.44%
# stellar_mass_solar_mass            0.41%
# orbit_semi_major_axis_au           0.18%
# planet_rad_earth_rad               0.12%
# planet_mass_earth_mass             0.12%
# star_number_per_system             0.00%
# planet_name                        0.00%
# host_star_name                     0.00%
# year_of_discovery                  0.00%
# discovery_method                   0.00%
# discovery_facility                 0.00%
# stellar_mass_imputation_method     0.00%
# dtype: object

# %%
# viewing planet 11 Com b to verify imputation values align with physical theory
new_exoplanets_filtered2[new_exoplanets_filtered2["planet_name"] == "11 Com b"]
# Out:
#   planet_name host_star_name  star_number_per_system discovery_method  \
# 0    11 Com b         11 Com                     2.0  Radial Velocity
#
#    year_of_discovery discovery_facility  orbital_period_day  \
# 0             2007.0   Xinglong Station              324.62
#
#    orbit_semi_major_axis_au  planet_rad_earth_rad  planet_mass_earth_mass  \
# 0                     1.226             61.636581             5505.066162
#
#    orbital_eccentricity  planet_equil_temp_k spectral_type  \
# 0                0.2345           712.610355        G8 III
#
#    stellar_effective_temp_k  stellar_rad_solar_rad  stellar_mass_solar_mass  \
# 0                    4808.0                  16.38                 2.463333
#
#    stellar_surf_grav  distance_parsec stellar_mass_imputation_method
# 0               2.38          93.1846                       observed

# %% [markdown]
# ### Computing Columns Relavent for Analysis

# %% [markdown]
# #### Creating Stellar Luminosity Column
# * Using the Stefan-Boltzmann Formula

# %%
# For Ls = Rs^(2) * Teff_s^(4) where Ls is the stellar luminosity (in terms of sun's luminosity), Rs is the stellar radius (in terms of sun;s radius), and
# Ts is the stellar effective surface temperature (in terms of sun's effective surface temperature)

# Constants and conversion factors
# sun's effective surface temperature in Kelvin [K]
Teff_sun = 5778 #K

# valid calculation if stellar radius and stellar effective temperature is known
mask_lum = (
    new_exoplanets_filtered2["stellar_rad_solar_rad"].notna() &
    new_exoplanets_filtered2["stellar_effective_temp_k"].notna()
)

# converting the stellar effective surface temperature in Kelvin to Sun's effective surface temperature in Kelvin
Teff_s = new_exoplanets_filtered2.loc[mask, "stellar_effective_temp_k"] / Teff_sun

new_exoplanets_filtered2.loc[mask_lum, "stellar_luminosity_solar_lum"] = (
    new_exoplanets_filtered2.loc[mask_lum, "stellar_rad_solar_rad"]**2 *
    (new_exoplanets_filtered2.loc[mask_lum, "stellar_effective_temp_k"] / Teff_sun)**4
)

# fill remaining rows with NaN (pandas does this by default)
new_exoplanets_filtered2["stellar_luminosity_solar_lum"] = new_exoplanets_filtered2["stellar_luminosity_solar_lum"].astype(float)

# %%
# checking new column is added for kepler 452 b
new_exoplanets_filtered2[new_exoplanets_filtered2["planet_name"] == "Kepler-452 b"]
# Out:
#        planet_name host_star_name  star_number_per_system discovery_method  \
# 4115  Kepler-452 b     Kepler-452                     1.0          Transit
#
#       year_of_discovery discovery_facility  orbital_period_day  \
# 4115             2015.0             Kepler          384.844831
#
#       orbit_semi_major_axis_au  planet_rad_earth_rad  planet_mass_earth_mass  \
# 4115                  1.009733                1.3722                    3.29
#
#       orbital_eccentricity  planet_equil_temp_k spectral_type  \
# 4115                   0.0                235.0            G2
#
#       stellar_effective_temp_k  stellar_rad_solar_rad  \
# 4115               5687.166667               1.099285
#
#       stellar_mass_solar_mass  stellar_surf_grav  distance_parsec  \
# 4115                 1.029667            4.44555          551.727
#
#      stellar_mass_imputation_method  stellar_luminosity_solar_lum
# 4115                       observed                      1.134212

# %% [markdown]
# #### Creating Planet Radial Velocity Column
# * Using Planet Radial Velocity Formula

# %%
# For: v_orb = sqrt(G * Ms / a), expressed in units of Earth's orbital velocity
# Ms = stellar mass [M_sun], a = semi-major axis [AU]

# Constants
G = 6.67430e-11        # m^3 kg^-1 s^-2
M_sun = 1.98847e30     # kg
AU = 1.495978707e11    # m
v_earth_km_s = 29.78   # Earth's orbital velocity in km/s

# valid calculation if stellar mass and semi-major axis are known
mask_vel = (
    new_exoplanets_filtered2["stellar_mass_solar_mass"].notna() &
    new_exoplanets_filtered2["orbit_semi_major_axis_au"].notna()
)

# convert to SI units
M_star = new_exoplanets_filtered2.loc[mask_vel, "stellar_mass_solar_mass"] * M_sun
a_m = new_exoplanets_filtered2.loc[mask_vel, "orbit_semi_major_axis_au"] * AU

# compute orbital velocity [m/s]
v_orb_m_s = np.sqrt(G * M_star / a_m)

# convert to km/s
v_orb_km_s = v_orb_m_s / 1e3

# convert to Earth orbital velocity units
v_orb_earth_units = v_orb_km_s / v_earth_km_s

# store result in new column
new_exoplanets_filtered2.loc[mask_vel, "planet_orbital_velocity"] = v_orb_earth_units

# ensure column is float
new_exoplanets_filtered2["planet_orbital_velocity"] = new_exoplanets_filtered2["planet_orbital_velocity"].astype(float)

# %%
# checking new column is added for kepler 452 b
new_exoplanets_filtered2[new_exoplanets_filtered2["planet_name"] == "Kepler-452 b"]
# Out:
#        planet_name host_star_name  star_number_per_system discovery_method  \
# 4115  Kepler-452 b     Kepler-452                     1.0          Transit
#
#       year_of_discovery discovery_facility  orbital_period_day  \
# 4115             2015.0             Kepler          384.844831
#
#       orbit_semi_major_axis_au  planet_rad_earth_rad  planet_mass_earth_mass  \
# 4115                  1.009733                1.3722                    3.29
#
#       ...  planet_equil_temp_k  spectral_type stellar_effective_temp_k  \
# 4115  ...                235.0             G2              5687.166667
#
#       stellar_rad_solar_rad  stellar_mass_solar_mass  stellar_surf_grav  \
# 4115               1.099285                 1.029667            4.44555
#
#       distance_parsec  stellar_mass_imputation_method  \
# 4115          551.727                        observed
#
#      stellar_luminosity_solar_lum  planet_orbital_velocity
# 4115                     1.134212                 1.009997
#
# [1 rows x 21 columns]

# %% [markdown]
# ### Removing Rows (Exoplanets) With Significant Missing Data

# %%
new_exoplanets_filtered2.columns
# Out:
# Index(['planet_name', 'host_star_name', 'star_number_per_system',
#        'discovery_method', 'year_of_discovery', 'discovery_facility',
#        'orbital_period_day', 'orbit_semi_major_axis_au',
#        'planet_rad_earth_rad', 'planet_mass_earth_mass',
#        'orbital_eccentricity', 'planet_equil_temp_k', 'spectral_type',
#        'stellar_effective_temp_k', 'stellar_rad_solar_rad',
#        'stellar_mass_solar_mass', 'stellar_surf_grav', 'distance_parsec',
#        'stellar_mass_imputation_method', 'stellar_luminosity_solar_lum',
#        'planet_orbital_velocity'],
#       dtype='object')

# %%
cols_to_show5 = [
    'planet_name',
    'host_star_name',
    'orbital_period_day',
    'orbit_semi_major_axis_au',
    'planet_rad_earth_rad',
    'planet_mass_earth_mass',
    'orbital_eccentricity',
    'planet_equil_temp_k',
    'spectral_type',
    'stellar_effective_temp_k',
    'stellar_rad_solar_rad',
    'stellar_mass_solar_mass',
    'stellar_surf_grav',
    'stellar_luminosity_solar_lum',
    'planet_orbital_velocity'
]

# %%
# Viewing rows where planet mass is still missing
new_exoplanets_filtered2[new_exoplanets_filtered2["planet_mass_earth_mass"].isna()][cols_to_show5]
# Out:
#          planet_name host_star_name  orbital_period_day  \
# 1922  KIC 10001893 b   KIC 10001893            0.219700
# 1923  KIC 10001893 c   KIC 10001893            0.325280
# 1924  KIC 10001893 d   KIC 10001893            0.811610
# 4881       LkCa 15 b        LkCa 15                 NaN
# 4882       LkCa 15 c        LkCa 15                 NaN
# 4922       MWC 758 c        MWC 758           87.358046
# 5262      TOI-1634 c       TOI-1634          103.000000
#
#       orbit_semi_major_axis_au  planet_rad_earth_rad  planet_mass_earth_mass  \
# 1922                       NaN                   NaN                     NaN
# 1923                       NaN                   NaN                     NaN
# 1924                       NaN                   NaN                     NaN
# 4881                 14.700000                   NaN                     NaN
# 4882                 18.600000                   NaN                     NaN
# 4922                100.000000                   NaN                     NaN
# 5262                  0.329779                   NaN                     NaN
#
#       orbital_eccentricity  planet_equil_temp_k spectral_type  \
# 1922                   NaN                  NaN           NaN
# 1923                   NaN                  NaN           NaN
# 1924                   NaN                  NaN           NaN
# 4881                   NaN            56.230056           NaN
# 4882                   NaN            49.988570           NaN
# 4922                   NaN           500.000000          A8Ve
# 5262                   0.0           164.456170           NaN
#
#       stellar_effective_temp_k  stellar_rad_solar_rad  \
# 1922                   27500.0                    NaN
# 1923                   27500.0                    NaN
# 1924                   27500.0                    NaN
# 4881                    4194.0                1.60711
# 4882                    4194.0                1.60711
# 4922                       NaN                    NaN
# 5262                    3472.0                0.45000
#
#       stellar_mass_solar_mass  stellar_surf_grav  \
# 1922                      NaN              5.350
# 1923                      NaN              5.350
# 1924                      NaN              5.350
# 4881                      NaN                NaN
# 4882                      NaN                NaN
# 4922                    1.500                NaN
# 5262                    0.451              4.787
#
#       stellar_luminosity_solar_lum  planet_orbital_velocity
# 1922                           NaN                      NaN
# 1923                           NaN                      NaN
# 1924                           NaN                      NaN
# 4881                      0.716960                      NaN
# 4882                      0.716960                      NaN
# 4922                           NaN                 0.122496
# 5262                      0.026402                 1.169638

# %%
# Viewing rows where planet radius is still missing
new_exoplanets_filtered2[new_exoplanets_filtered2["planet_rad_earth_rad"].isna()][cols_to_show5]
# Out:
#          planet_name host_star_name  orbital_period_day  \
# 1922  KIC 10001893 b   KIC 10001893            0.219700
# 1923  KIC 10001893 c   KIC 10001893            0.325280
# 1924  KIC 10001893 d   KIC 10001893            0.811610
# 4881       LkCa 15 b        LkCa 15                 NaN
# 4882       LkCa 15 c        LkCa 15                 NaN
# 4922       MWC 758 c        MWC 758           87.358046
# 5262      TOI-1634 c       TOI-1634          103.000000
#
#       orbit_semi_major_axis_au  planet_rad_earth_rad  planet_mass_earth_mass  \
# 1922                       NaN                   NaN                     NaN
# 1923                       NaN                   NaN                     NaN
# 1924                       NaN                   NaN                     NaN
# 4881                 14.700000                   NaN                     NaN
# 4882                 18.600000                   NaN                     NaN
# 4922                100.000000                   NaN                     NaN
# 5262                  0.329779                   NaN                     NaN
#
#       orbital_eccentricity  planet_equil_temp_k spectral_type  \
# 1922                   NaN                  NaN           NaN
# 1923                   NaN                  NaN           NaN
# 1924                   NaN                  NaN           NaN
# 4881                   NaN            56.230056           NaN
# 4882                   NaN            49.988570           NaN
# 4922                   NaN           500.000000          A8Ve
# 5262                   0.0           164.456170           NaN
#
#       stellar_effective_temp_k  stellar_rad_solar_rad  \
# 1922                   27500.0                    NaN
# 1923                   27500.0                    NaN
# 1924                   27500.0                    NaN
# 4881                    4194.0                1.60711
# 4882                    4194.0                1.60711
# 4922                       NaN                    NaN
# 5262                    3472.0                0.45000
#
#       stellar_mass_solar_mass  stellar_surf_grav  \
# 1922                      NaN              5.350
# 1923                      NaN              5.350
# 1924                      NaN              5.350
# 4881                      NaN                NaN
# 4882                      NaN                NaN
# 4922                    1.500                NaN
# 5262                    0.451              4.787
#
#       stellar_luminosity_solar_lum  planet_orbital_velocity
# 1922                           NaN                      NaN
# 1923                           NaN                      NaN
# 1924                           NaN                      NaN
# 4881                      0.716960                      NaN
# 4882                      0.716960                      NaN
# 4922                           NaN                 0.122496
# 5262                      0.026402                 1.169638

# %%
# Viewing rows where orbital semi major axis is stil missing
new_exoplanets_filtered2[new_exoplanets_filtered2["orbit_semi_major_axis_au"].isna()][cols_to_show5]
# Out:
#                 planet_name       host_star_name  orbital_period_day  \
# 1108           HD 41004 A b           HD 41004 A           963.00000
# 1922         KIC 10001893 b         KIC 10001893             0.21970
# 1923         KIC 10001893 c         KIC 10001893             0.32528
# 1924         KIC 10001893 d         KIC 10001893             0.81161
# 1989   KMT-2019-BLG-1953L b   KMT-2019-BLG-1953L                 NaN
# 1999   KMT-2021-BLG-0322L b   KMT-2021-BLG-0322L                 NaN
# 2044   KMT-2024-BLG-0404L c   KMT-2024-BLG-0404L                 NaN
# 2045   KMT-2024-BLG-1044L b   KMT-2024-BLG-1044L                 NaN
# 4913    MOA-2019-BLG-008L b    MOA-2019-BLG-008L                 NaN
# 5000  OGLE-2015-BLG-1609L b  OGLE-2015-BLG-1609L                 NaN
# 5116             SR 12 AB c             SR 12 AB                 NaN
#
#       orbit_semi_major_axis_au  planet_rad_earth_rad  planet_mass_earth_mass  \
# 1108                       NaN             24.598745              807.250000
# 1922                       NaN                   NaN                     NaN
# 1923                       NaN                   NaN                     NaN
# 1924                       NaN                   NaN                     NaN
# 1989                       NaN             12.617441              200.000000
# 1999                       NaN             38.278370             2034.101805
# 2044                       NaN              3.911709               17.300000
# 2045                       NaN              3.110421               10.715000
# 4913                       NaN             68.731220             6912.767852
# 5000                       NaN              5.760443               38.846577
# 5116                       NaN             53.728057             4131.620000
#
#       orbital_eccentricity  planet_equil_temp_k spectral_type  \
# 1108                  0.74                  NaN           NaN
# 1922                   NaN                  NaN           NaN
# 1923                   NaN                  NaN           NaN
# 1924                   NaN                  NaN           NaN
# 1989                   NaN                  NaN           NaN
# 1999                   NaN                  NaN           NaN
# 2044                   NaN                  NaN             M
# 2045                   NaN                  NaN           NaN
# 4913                   NaN                  NaN           NaN
# 5000                   NaN                  NaN           NaN
# 5116                   NaN                  NaN           NaN
#
#       stellar_effective_temp_k  stellar_rad_solar_rad  \
# 1108                       NaN                    NaN
# 1922                   27500.0                    NaN
# 1923                   27500.0                    NaN
# 1924                   27500.0                    NaN
# 1989                       NaN                    NaN
# 1999                       NaN                    NaN
# 2044                       NaN                    NaN
# 2045                       NaN                    NaN
# 4913                       NaN                    NaN
# 5000                       NaN                    NaN
# 5116                       NaN                    NaN
#
#       stellar_mass_solar_mass  stellar_surf_grav  \
# 1108                      NaN                NaN
# 1922                      NaN               5.35
# 1923                      NaN               5.35
# 1924                      NaN               5.35
# 1989                 0.310000                NaN
# 1999                 0.620000                NaN
# 2044                 0.090000                NaN
# 2045                 0.100000                NaN
# 4913                 0.722222                NaN
# 5000                 0.122333                NaN
# 5116                      NaN                NaN
#
#       stellar_luminosity_solar_lum  planet_orbital_velocity
# 1108                           NaN                      NaN
# 1922                           NaN                      NaN
# 1923                           NaN                      NaN
# 1924                           NaN                      NaN
# 1989                           NaN                      NaN
# 1999                           NaN                      NaN
# 2044                           NaN                      NaN
# 2045                           NaN                      NaN
# 4913                           NaN                      NaN
# 5000                           NaN                      NaN
# 5116                           NaN                      NaN

# %%
# Viewing rows where stellar_mass_solar_mass is stil missing
new_exoplanets_filtered2[new_exoplanets_filtered2["stellar_mass_solar_mass"].isna()][cols_to_show5]
# Out:
#                     planet_name           host_star_name  orbital_period_day  \
# 16    2MASS J03590986+2009361 b  2MASS J03590986+2009361                 NaN
# 18    2MASS J11011926-7732383 b  2MASS J11011926-7732383                 NaN
# 19    2MASS J11550485-7919108 b  2MASS J11550485-7919108                 NaN
# 22    2MASS J21252752-8138278 b  2MASS J21252752-8138278                 NaN
# 24    2MASS J22501512+2325342 b  2MASS J22501512+2325342                 NaN
# 51                     AB Pic b                   AB Pic                 NaN
# 101                    CT Cha b                   CT Cha                 NaN
# 197                   G 196-3 b                  G 196-3                 NaN
# 658               HD 135344 A b              HD 135344 A                 NaN
# 887                 HD 203030 b                HD 203030                 NaN
# 1037             HD 284149 AB b              HD 284149 A                 NaN
# 1108               HD 41004 A b               HD 41004 A           963.00000
# 1378                HIP 77900 b                HIP 77900                 NaN
# 1398                   HN Peg b                   HN Peg                 NaN
# 1414                   ITG 15 b                 ITG 15 A                 NaN
# 1922             KIC 10001893 b             KIC 10001893             0.21970
# 1923             KIC 10001893 c             KIC 10001893             0.32528
# 1924             KIC 10001893 d             KIC 10001893             0.81161
# 4881                  LkCa 15 b                  LkCa 15                 NaN
# 4882                  LkCa 15 c                  LkCa 15                 NaN
# 5081                   PDS 70 c                   PDS 70                 NaN
# 5113                 Ross 458 c                 Ross 458                 NaN
# 5116                 SR 12 AB c                 SR 12 AB                 NaN
# 5998                 WISPIT 1 b                 WISPIT 1                 NaN
# 5999                 WISPIT 1 c                 WISPIT 1                 NaN
#
#       orbit_semi_major_axis_au  planet_rad_earth_rad  planet_mass_earth_mass  \
# 16                      572.00             62.781292             5720.911326
# 18                      266.00             77.560661             8899.195396
# 19                      587.00             66.027337             6356.568140
# 22                     7493.00             51.710181             3813.940884
# 24                      518.00             80.163741             9534.852210
# 51                      260.00             54.706894             4290.500000
# 101                     440.00             24.660000             5403.000000
# 197                     350.00             74.858675             8263.538582
# 658                      16.50             16.253022             3178.284070
# 887                     487.10             14.459585             5576.104739
# 1037                    431.16             76.586475             8667.180659
# 1108                       NaN             24.598745              807.250000
# 1378                   3319.00             67.586850             6674.396547
# 1398                    773.00             11.776800             6991.570000
# 1414                    435.00             67.586850             6674.396547
# 1922                       NaN                   NaN                     NaN
# 1923                       NaN                   NaN                     NaN
# 1924                       NaN                   NaN                     NaN
# 4881                     14.70                   NaN                     NaN
# 4882                     18.60                   NaN                     NaN
# 5081                     34.25             22.866360             1984.766925
# 5113                   1100.00             14.011250             1906.980000
# 5116                       NaN             53.728057             4131.620000
# 5998                    338.00             48.288111             3305.415433
# 5999                    840.00             34.975576             1684.490557
#
#       orbital_eccentricity  planet_equil_temp_k spectral_type  \
# 16                     NaN          2369.000000           NaN
# 18                     NaN          2677.000000           NaN
# 19                     NaN          2506.000000           NaN
# 22                     NaN          1616.000000           NaN
# 24                     NaN          1600.000000            M3
# 51                     NaN                  NaN          K2 V
# 101                    NaN          2600.000000           NaN
# 197                    NaN          1670.000000           NaN
# 658                   0.50          1585.000000          A0 V
# 887                    NaN          1123.000000          G8 V
# 1037                   NaN          2448.500000           NaN
# 1108                  0.74                  NaN           NaN
# 1378                   NaN          2507.000000           NaN
# 1398                   NaN                  NaN          G0 V
# 1414                   NaN          2601.000000           NaN
# 1922                   NaN                  NaN           NaN
# 1923                   NaN                  NaN           NaN
# 1924                   NaN                  NaN           NaN
# 4881                   NaN            56.230056           NaN
# 4882                   NaN            49.988570           NaN
# 5081                  0.11           995.000000           NaN
# 5113                   NaN                  NaN           NaN
# 5116                   NaN                  NaN           NaN
# 5998                   NaN                  NaN          K4 V
# 5999                   NaN                  NaN          K4 V
#
#       stellar_effective_temp_k  stellar_rad_solar_rad  \
# 16                         NaN                    NaN
# 18                         NaN                    NaN
# 19                         NaN                    NaN
# 22                         NaN                    NaN
# 24                         NaN                    NaN
# 51                         NaN                    NaN
# 101                        NaN                    NaN
# 197                        NaN                    NaN
# 658                     9540.0                1.50000
# 887                        NaN                    NaN
# 1037                    6035.0                1.36000
# 1108                       NaN                    NaN
# 1378                       NaN                    NaN
# 1398                       NaN                    NaN
# 1414                       NaN                    NaN
# 1922                   27500.0                    NaN
# 1923                   27500.0                    NaN
# 1924                   27500.0                    NaN
# 4881                    4194.0                1.60711
# 4882                    4194.0                1.60711
# 5081                    3972.0                    NaN
# 5113                       NaN                    NaN
# 5116                       NaN                    NaN
# 5998                    4670.0                    NaN
# 5999                    4670.0                    NaN
#
#       stellar_mass_solar_mass  stellar_surf_grav  \
# 16                        NaN                NaN
# 18                        NaN                NaN
# 19                        NaN                NaN
# 22                        NaN                NaN
# 24                        NaN                NaN
# 51                        NaN                NaN
# 101                       NaN                NaN
# 197                       NaN                NaN
# 658                       NaN                NaN
# 887                       NaN                NaN
# 1037                      NaN                NaN
# 1108                      NaN                NaN
# 1378                      NaN                NaN
# 1398                      NaN                NaN
# 1414                      NaN                NaN
# 1922                      NaN               5.35
# 1923                      NaN               5.35
# 1924                      NaN               5.35
# 4881                      NaN                NaN
# 4882                      NaN                NaN
# 5081                      NaN                NaN
# 5113                      NaN                NaN
# 5116                      NaN                NaN
# 5998                      NaN                NaN
# 5999                      NaN                NaN
#
#       stellar_luminosity_solar_lum  planet_orbital_velocity
# 16                             NaN                      NaN
# 18                             NaN                      NaN
# 19                             NaN                      NaN
# 22                             NaN                      NaN
# 24                             NaN                      NaN
# 51                             NaN                      NaN
# 101                            NaN                      NaN
# 197                            NaN                      NaN
# 658                      16.721139                      NaN
# 887                            NaN                      NaN
# 1037                      2.201287                      NaN
# 1108                           NaN                      NaN
# 1378                           NaN                      NaN
# 1398                           NaN                      NaN
# 1414                           NaN                      NaN
# 1922                           NaN                      NaN
# 1923                           NaN                      NaN
# 1924                           NaN                      NaN
# 4881                      0.716960                      NaN
# 4882                      0.716960                      NaN
# 5081                           NaN                      NaN
# 5113                           NaN                      NaN
# 5116                           NaN                      NaN
# 5998                           NaN                      NaN
# 5999                           NaN                      NaN

# %%
# Viewing rows where orbital_period_day is stil missing
new_exoplanets_filtered2[new_exoplanets_filtered2["orbital_period_day"].isna()][cols_to_show5]
# Out:
#                     planet_name           host_star_name  orbital_period_day  \
# 16    2MASS J03590986+2009361 b  2MASS J03590986+2009361                 NaN
# 18    2MASS J11011926-7732383 b  2MASS J11011926-7732383                 NaN
# 19    2MASS J11550485-7919108 b  2MASS J11550485-7919108                 NaN
# 22    2MASS J21252752-8138278 b  2MASS J21252752-8138278                 NaN
# 24    2MASS J22501512+2325342 b  2MASS J22501512+2325342                 NaN
# 51                     AB Pic b                   AB Pic                 NaN
# 101                    CT Cha b                   CT Cha                 NaN
# 197                   G 196-3 b                  G 196-3                 NaN
# 658               HD 135344 A b              HD 135344 A                 NaN
# 887                 HD 203030 b                HD 203030                 NaN
# 1037             HD 284149 AB b              HD 284149 A                 NaN
# 1378                HIP 77900 b                HIP 77900                 NaN
# 1398                   HN Peg b                   HN Peg                 NaN
# 1414                   ITG 15 b                 ITG 15 A                 NaN
# 1989       KMT-2019-BLG-1953L b       KMT-2019-BLG-1953L                 NaN
# 1999       KMT-2021-BLG-0322L b       KMT-2021-BLG-0322L                 NaN
# 2044       KMT-2024-BLG-0404L c       KMT-2024-BLG-0404L                 NaN
# 2045       KMT-2024-BLG-1044L b       KMT-2024-BLG-1044L                 NaN
# 4881                  LkCa 15 b                  LkCa 15                 NaN
# 4882                  LkCa 15 c                  LkCa 15                 NaN
# 4913        MOA-2019-BLG-008L b        MOA-2019-BLG-008L                 NaN
# 5000      OGLE-2015-BLG-1609L b      OGLE-2015-BLG-1609L                 NaN
# 5081                   PDS 70 c                   PDS 70                 NaN
# 5113                 Ross 458 c                 Ross 458                 NaN
# 5116                 SR 12 AB c                 SR 12 AB                 NaN
# 5998                 WISPIT 1 b                 WISPIT 1                 NaN
# 5999                 WISPIT 1 c                 WISPIT 1                 NaN
#
#       orbit_semi_major_axis_au  planet_rad_earth_rad  planet_mass_earth_mass  \
# 16                      572.00             62.781292             5720.911326
# 18                      266.00             77.560661             8899.195396
# 19                      587.00             66.027337             6356.568140
# 22                     7493.00             51.710181             3813.940884
# 24                      518.00             80.163741             9534.852210
# 51                      260.00             54.706894             4290.500000
# 101                     440.00             24.660000             5403.000000
# 197                     350.00             74.858675             8263.538582
# 658                      16.50             16.253022             3178.284070
# 887                     487.10             14.459585             5576.104739
# 1037                    431.16             76.586475             8667.180659
# 1378                   3319.00             67.586850             6674.396547
# 1398                    773.00             11.776800             6991.570000
# 1414                    435.00             67.586850             6674.396547
# 1989                       NaN             12.617441              200.000000
# 1999                       NaN             38.278370             2034.101805
# 2044                       NaN              3.911709               17.300000
# 2045                       NaN              3.110421               10.715000
# 4881                     14.70                   NaN                     NaN
# 4882                     18.60                   NaN                     NaN
# 4913                       NaN             68.731220             6912.767852
# 5000                       NaN              5.760443               38.846577
# 5081                     34.25             22.866360             1984.766925
# 5113                   1100.00             14.011250             1906.980000
# 5116                       NaN             53.728057             4131.620000
# 5998                    338.00             48.288111             3305.415433
# 5999                    840.00             34.975576             1684.490557
#
#       orbital_eccentricity  planet_equil_temp_k spectral_type  \
# 16                     NaN          2369.000000           NaN
# 18                     NaN          2677.000000           NaN
# 19                     NaN          2506.000000           NaN
# 22                     NaN          1616.000000           NaN
# 24                     NaN          1600.000000            M3
# 51                     NaN                  NaN          K2 V
# 101                    NaN          2600.000000           NaN
# 197                    NaN          1670.000000           NaN
# 658                   0.50          1585.000000          A0 V
# 887                    NaN          1123.000000          G8 V
# 1037                   NaN          2448.500000           NaN
# 1378                   NaN          2507.000000           NaN
# 1398                   NaN                  NaN          G0 V
# 1414                   NaN          2601.000000           NaN
# 1989                   NaN                  NaN           NaN
# 1999                   NaN                  NaN           NaN
# 2044                   NaN                  NaN             M
# 2045                   NaN                  NaN           NaN
# 4881                   NaN            56.230056           NaN
# 4882                   NaN            49.988570           NaN
# 4913                   NaN                  NaN           NaN
# 5000                   NaN                  NaN           NaN
# 5081                  0.11           995.000000           NaN
# 5113                   NaN                  NaN           NaN
# 5116                   NaN                  NaN           NaN
# 5998                   NaN                  NaN          K4 V
# 5999                   NaN                  NaN          K4 V
#
#       stellar_effective_temp_k  stellar_rad_solar_rad  \
# 16                         NaN                    NaN
# 18                         NaN                    NaN
# 19                         NaN                    NaN
# 22                         NaN                    NaN
# 24                         NaN                    NaN
# 51                         NaN                    NaN
# 101                        NaN                    NaN
# 197                        NaN                    NaN
# 658                     9540.0                1.50000
# 887                        NaN                    NaN
# 1037                    6035.0                1.36000
# 1378                       NaN                    NaN
# 1398                       NaN                    NaN
# 1414                       NaN                    NaN
# 1989                       NaN                    NaN
# 1999                       NaN                    NaN
# 2044                       NaN                    NaN
# 2045                       NaN                    NaN
# 4881                    4194.0                1.60711
# 4882                    4194.0                1.60711
# 4913                       NaN                    NaN
# 5000                       NaN                    NaN
# 5081                    3972.0                    NaN
# 5113                       NaN                    NaN
# 5116                       NaN                    NaN
# 5998                    4670.0                    NaN
# 5999                    4670.0                    NaN
#
#       stellar_mass_solar_mass  stellar_surf_grav  \
# 16                        NaN                NaN
# 18                        NaN                NaN
# 19                        NaN                NaN
# 22                        NaN                NaN
# 24                        NaN                NaN
# 51                        NaN                NaN
# 101                       NaN                NaN
# 197                       NaN                NaN
# 658                       NaN                NaN
# 887                       NaN                NaN
# 1037                      NaN                NaN
# 1378                      NaN                NaN
# 1398                      NaN                NaN
# 1414                      NaN                NaN
# 1989                 0.310000                NaN
# 1999                 0.620000                NaN
# 2044                 0.090000                NaN
# 2045                 0.100000                NaN
# 4881                      NaN                NaN
# 4882                      NaN                NaN
# 4913                 0.722222                NaN
# 5000                 0.122333                NaN
# 5081                      NaN                NaN
# 5113                      NaN                NaN
# 5116                      NaN                NaN
# 5998                      NaN                NaN
# 5999                      NaN                NaN
#
#       stellar_luminosity_solar_lum  planet_orbital_velocity
# 16                             NaN                      NaN
# 18                             NaN                      NaN
# 19                             NaN                      NaN
# 22                             NaN                      NaN
# 24                             NaN                      NaN
# 51                             NaN                      NaN
# 101                            NaN                      NaN
# 197                            NaN                      NaN
# 658                      16.721139                      NaN
# 887                            NaN                      NaN
# 1037                      2.201287                      NaN
# 1378                           NaN                      NaN
# 1398                           NaN                      NaN
# 1414                           NaN                      NaN
# 1989                           NaN                      NaN
# 1999                           NaN                      NaN
# 2044                           NaN                      NaN
# 2045                           NaN                      NaN
# 4881                      0.716960                      NaN
# 4882                      0.716960                      NaN
# 4913                           NaN                      NaN
# 5000                           NaN                      NaN
# 5081                           NaN                      NaN
# 5113                           NaN                      NaN
# 5116                           NaN                      NaN
# 5998                           NaN                      NaN
# 5999                           NaN                      NaN

# %%
# removing rows where planet mass is still missing
new_exoplanets_filtered2 = new_exoplanets_filtered2[~new_exoplanets_filtered2["planet_mass_earth_mass"].isna()]

# %%
new_exoplanets_filtered2.shape
# Out:
# (6064, 21)

# %%
# removing rows where planet radius is still missing
new_exoplanets_filtered2 = new_exoplanets_filtered2[~new_exoplanets_filtered2["planet_rad_earth_rad"].isna()]

# %%
new_exoplanets_filtered2.shape
# Out:
# (6064, 21)

# %%
# removing rows where orbit_semi_major_axis_au is still missing
new_exoplanets_filtered2 = new_exoplanets_filtered2[~new_exoplanets_filtered2["orbit_semi_major_axis_au"].isna()]

# %%
new_exoplanets_filtered2.shape
# Out:
# (6056, 21)

# %%
# removing rows where stellar_mass_solar_mass is still missing
new_exoplanets_filtered2 = new_exoplanets_filtered2[~new_exoplanets_filtered2["stellar_mass_solar_mass"].isna()]

# %%
new_exoplanets_filtered2.shape
# Out:
# (6038, 21)

# %%
# removing rows where orbital_period_day is still missing
new_exoplanets_filtered2 = new_exoplanets_filtered2[~new_exoplanets_filtered2["orbital_period_day"].isna()]

# %%
new_exoplanets_filtered2.shape
# Out:
# (6038, 21)

# %%
# removing rows where planet_orbital_velocity is still missing
new_exoplanets_filtered2 = new_exoplanets_filtered2[~new_exoplanets_filtered2["planet_orbital_velocity"].isna()]

# %%
new_exoplanets_filtered2.shape
# Out:
# (6038, 21)

# %%
# dropping the distance parsec column
new_exoplanets_filtered2 = new_exoplanets_filtered2.drop(columns=["distance_parsec"])

# %% [markdown]
# ## **Exploratory Data Analysis**

# %% [markdown]
# #### 1) What percentage of data still remain missing?

# %%
# checking how much missing data currently present in data
missing_percentage = (new_exoplanets_filtered2.isnull().sum() / len(new_exoplanets_filtered2))
((missing_percentage * 100).sort_values(ascending=False)).map(lambda x: f"{x:.2f}%")
# Out:
# spectral_type                     68.55%
# orbital_eccentricity              14.47%
# stellar_luminosity_solar_lum       9.97%
# stellar_rad_solar_rad              9.57%
# planet_equil_temp_k                9.34%
# stellar_surf_grav                  7.73%
# stellar_effective_temp_k           7.35%
# planet_name                        0.00%
# discovery_method                   0.00%
# star_number_per_system             0.00%
# host_star_name                     0.00%
# year_of_discovery                  0.00%
# planet_rad_earth_rad               0.00%
# planet_mass_earth_mass             0.00%
# orbital_period_day                 0.00%
# orbit_semi_major_axis_au           0.00%
# discovery_facility                 0.00%
# stellar_mass_solar_mass            0.00%
# stellar_mass_imputation_method     0.00%
# planet_orbital_velocity            0.00%
# dtype: object

# %% [markdown]
# #### 2) How many exoplanets are currently in the dataset?

# %%
# viewing the shape of the dataset
new_exoplanets_filtered2.shape # There are 6,038 exoplanets and 21 features
# Out:
# (6038, 20)

# %% [markdown]
# #### 3) Describe the statistics for all numerical columns

# %%
# view summary statisics of the data
new_exoplanets_filtered2.describe()
# Out:
#        star_number_per_system  year_of_discovery  orbital_period_day  \
# count             6038.000000        6038.000000        6.038000e+03
# mean                 1.102683        2016.871149        7.090274e+04
# std                  0.341570           4.886381        5.175862e+06
# min                  1.000000        1992.000000        9.070629e-02
# 25%                  1.000000        2014.000000        4.120169e+00
# 50%                  1.000000        2016.000000        1.036259e+01
# 75%                  1.000000        2021.000000        3.814035e+01
# max                  4.000000        2026.000000        4.020000e+08
#
#        orbit_semi_major_axis_au  planet_rad_earth_rad  planet_mass_earth_mass  \
# count               6038.000000           6038.000000             6038.000000
# mean                  11.923000              9.712176              380.552037
# std                  325.260941             43.418697             1117.532336
# min                    0.003857              0.144327                0.017500
# 25%                    0.051895              1.874218                1.483045
# 50%                    0.099670              2.833239                3.454195
# 75%                    0.279476             11.655954              190.458911
# max                19000.000000           1899.339625            13256.622856
#
#        orbital_eccentricity  planet_equil_temp_k  stellar_effective_temp_k  \
# count           5164.000000          5474.000000               5594.000000
# mean               0.076202           833.127985               5400.201988
# std                0.146397           479.672036               1688.602359
# min                0.000000             5.272973                415.000000
# 25%                0.000000           491.400000               4923.400000
# 50%                0.000000           753.100000               5561.713636
# 75%                0.090000          1087.900000               5906.875000
# max                0.948000          6540.308280              57000.000000
#
#        stellar_rad_solar_rad  stellar_mass_solar_mass  stellar_surf_grav  \
# count            5460.000000              6038.000000        5571.000000
# mean                1.497106                 0.934313           4.375051
# std                 3.824037                 0.381420           0.438840
# min                 0.012300                 0.012617           0.541000
# 25%                 0.774521                 0.775700           4.287805
# 50%                 0.956428                 0.947643           4.441140
# 75%                 1.251025                 1.082937           4.568030
# max                88.475000                 9.100000           8.070000
#
#        stellar_luminosity_solar_lum  planet_orbital_velocity
# count                  5.436000e+03              6038.000000
# mean                   6.856799e+00                 3.014856
# std                    9.937277e+01                 1.731583
# min                    8.121645e-07                 0.004858
# 25%                    3.577305e-01                 1.773136
# 50%                    8.542609e-01                 2.936925
# 75%                    1.818141e+00                 4.137818
# max                    6.238854e+03                17.840732

# %% [markdown]
# #### 4) Look at the Distribtuion for all numerical columns

# %%
# create histograms for all numerical columns
new_exoplanets_filtered2.hist(figsize=(14, 12), bins=50)
plt.show()

# %%
# create histograms for all parameters which display unqiue distribtuions
planet_feature2 = [
    'orbital_eccentricity',
    'planet_orbital_velocity',
    'stellar_mass_solar_mass',
    'stellar_surf_grav'
]

new_exoplanets_filtered2[planet_feature2].hist(
    figsize=(12, 10),
    bins=40
)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 5) Are there major correlations between numerical features in the dataset?

# %%
# checking for any correlations between the variables in the dataset
# creating a correlation heatmap
plt.figure(figsize=(12, 9))
correlation_matrix = new_exoplanets_filtered2.select_dtypes(include=[np.number]).corr()
sns.heatmap(correlation_matrix, annot=True, cmap='YlGnBu', fmt=".2f")
# Out:
# <Axes: >

# %% [markdown]
# #### 6) What is the Distribution of Exoplanet Mass?

# %%
# viewing the total number of planets that are Earth Like in mass (1 <= Mp < 2)
earth_like_count = len(new_exoplanets_filtered2[(new_exoplanets_filtered2["planet_mass_earth_mass"] >= 1) &
 (new_exoplanets_filtered2["planet_mass_earth_mass"] < 2)])
print("Number of Earth-like planets:", earth_like_count)

# viewing the total number of planets that are Super-Earth Like in mass (2 <= Mp < 8)
super_earth_like_count = len(new_exoplanets_filtered2[(new_exoplanets_filtered2["planet_mass_earth_mass"] >= 2) &
 (new_exoplanets_filtered2["planet_mass_earth_mass"] < 8)])
print("Number of Super-Earth like planets:", super_earth_like_count)

# viewing the total number of planets that are Neptune Like in mass (8 <= Mp <= 80)
neptune_like_count = len(new_exoplanets_filtered2[(new_exoplanets_filtered2["planet_mass_earth_mass"] >= 8) &
 (new_exoplanets_filtered2["planet_mass_earth_mass"] <= 80)])
print("Number of Neptune like planets:", neptune_like_count)

# viewing the total number of planets that are Saturn Like in mass (80 < Mp <= 150)
saturn_like_count = len(new_exoplanets_filtered2[(new_exoplanets_filtered2["planet_mass_earth_mass"] > 80) &
 (new_exoplanets_filtered2["planet_mass_earth_mass"] <= 150)])
print("Number of Saturn like planets:", saturn_like_count)

# viewing the total number of planets that are Super-Saturn Like in mass (150 < Mp < 318)
super_saturn_like_count = len(new_exoplanets_filtered2[(new_exoplanets_filtered2["planet_mass_earth_mass"] > 150) &
 (new_exoplanets_filtered2["planet_mass_earth_mass"] < 318)])
print("Number of Super-Saturn like planets:", super_saturn_like_count)

# viewing the total number of planets that are Jupiter Like in mass (318 <= Mp <= 3180)
jupiter_like_count = len(new_exoplanets_filtered2[(new_exoplanets_filtered2["planet_mass_earth_mass"] >= 318) &
 (new_exoplanets_filtered2["planet_mass_earth_mass"] <= 3180)])
print("Number of Jupiter like planets:", jupiter_like_count)

# viewing the total number of planets that are Super-Jupiter Like in mass (Mp > 3180)
super_jupiter_like_count = len(new_exoplanets_filtered2[(new_exoplanets_filtered2["planet_mass_earth_mass"] > 3180)])
print("Number of Super-Jupiter like planets:", super_jupiter_like_count)
# Out:
# Number of Earth-like planets: 2510
# Number of Super-Earth like planets: 696
# Number of Neptune like planets: 799
# Number of Saturn like planets: 207
# Number of Super-Saturn like planets: 422
# Number of Jupiter like planets: 1012
# Number of Super-Jupiter like planets: 193

# %%
total_mass = earth_like_count + super_earth_like_count + neptune_like_count + saturn_like_count + super_saturn_like_count + jupiter_like_count + super_jupiter_like_count
total_mass
# Out:
# 5839

# %%
# Store categories and counts
categories = [
    "Earth-like\n(1 <= Mp < 2)",
    "Super-Earth\n(2 <= Mp < 8)",
    "Neptune-like\n(8 <= Mp <= 80)",
    "Saturn-like\n(80 < Mp <= 150)",
    "Super-Saturn\n(150 < Mp < 318)",
    "Jupiter-like\n(318 <= Mp <= 3180)",
    "Super-Jupiter\n(Mp > 3180)"
]

counts = [
    earth_like_count,
    super_earth_like_count,
    neptune_like_count,
    saturn_like_count,
    super_saturn_like_count,
    jupiter_like_count,
    super_jupiter_like_count
]

# Create DataFrame for plotting
planet_counts_df = pd.DataFrame({
    "Mass of Exoplanet in Earth Mass": categories,
    "# of Exoplanets": counts
})

plt.figure(figsize=(9, 9))
ax = sns.barplot(
    data=planet_counts_df,
    x="Mass of Exoplanet in Earth Mass",
    y="# of Exoplanets",
    palette=[
        "#03A9F4",   # Earth-like
        "red",   # Super-Earth
        "darkgreen",   # Neptune-like
        "orange",   # Saturn-like
        "indigo",   # Super-Saturn
        "purple",   # Jupiter-like
        "maroon"    # Super-Jupiter
    ]
)

plt.xticks(rotation=45, ha="right")
plt.title("Distribution of 5,839 of All 6,038 Confirmed Exoplanets by Mass Category")

# Add counts and percentages on tope of each bar
total = planet_counts_df["# of Exoplanets"].sum()

for i, bar in enumerate(ax.patches):
    height = bar.get_height()
    percentage = (height / total) * 100

    ax.text(
        bar.get_x() + bar.get_width()/2,
        height,
        f'{int(height)}\n({percentage:.1f}%)',
        ha='center',
        va='bottom',
        fontsize=10
    )

plt.tight_layout()
plt.show()

# %% [markdown]
# #### 7) What is the Distribution of Exoplanet Radius?

# %%
# viewing the total number of planets that are Earth Like in radius (Rp <= 1.5)
earth_like_count_rad = len(new_exoplanets_filtered2[(new_exoplanets_filtered2["planet_rad_earth_rad"] <= 1.5)])
print("Number of Earth-like planets:", earth_like_count_rad)

# viewing the total number of planets that are Super-Earth Like in radius (1.5 < Rp <= 2)
super_earth_like_count_rad = len(new_exoplanets_filtered2[(new_exoplanets_filtered2["planet_rad_earth_rad"] > 1.5) &
 (new_exoplanets_filtered2["planet_rad_earth_rad"] <= 2)])
print("Number of Super-Earth like planets:", super_earth_like_count_rad)

# viewing the total number of planets that are Neptune Like in radius (2 < Rp <= 6)
neptune_like_count_rad = len(new_exoplanets_filtered2[(new_exoplanets_filtered2["planet_rad_earth_rad"] > 2) &
 (new_exoplanets_filtered2["planet_rad_earth_rad"] <= 6)])
print("Number of Neptune like planets:", neptune_like_count_rad)

# viewing the total number of planets that are Saturn Like in radius (6 < Rp <= 9)
saturn_like_count_rad = len(new_exoplanets_filtered2[(new_exoplanets_filtered2["planet_rad_earth_rad"] > 6) &
 (new_exoplanets_filtered2["planet_rad_earth_rad"] <= 9)])
print("Number of Saturn like planets:", saturn_like_count_rad)

# viewing the total number of planets that are Super-Saturn Like in radius (9 < Rp <= 11)
super_saturn_like_count_rad = len(new_exoplanets_filtered2[(new_exoplanets_filtered2["planet_rad_earth_rad"] > 9) &
 (new_exoplanets_filtered2["planet_rad_earth_rad"] <= 11)])
print("Number of Super-Saturn like planets:", super_saturn_like_count_rad)

# viewing the total number of planets that are Jupiter Like in radius (11 < Rp <= 15)
jupiter_like_count_rad = len(new_exoplanets_filtered2[(new_exoplanets_filtered2["planet_rad_earth_rad"] > 11) &
 (new_exoplanets_filtered2["planet_rad_earth_rad"] <= 15)])
print("Number of Jupiter like planets:", jupiter_like_count_rad)

# viewing the total number of planets that are Super-Jupiter Like in radius (Rp > 15)
super_jupiter_like_count_rad = len(new_exoplanets_filtered2[(new_exoplanets_filtered2["planet_rad_earth_rad"] > 15)])
print("Number of Super-Jupiter like planets:", super_jupiter_like_count_rad)
# Out:
# Number of Earth-like planets: 940
# Number of Super-Earth like planets: 748
# Number of Neptune like planets: 2306
# Number of Saturn like planets: 221
# Number of Super-Saturn like planets: 211
# Number of Jupiter like planets: 580
# Number of Super-Jupiter like planets: 1032

# %%
total_rad = earth_like_count_rad + super_earth_like_count_rad + neptune_like_count_rad + saturn_like_count_rad + super_saturn_like_count_rad + jupiter_like_count_rad + super_jupiter_like_count_rad
total_rad
# Out:
# 6038

# %%
# Store categories and counts
categories = [
    "Earth-like\n(Rp <= 1.5)",
    "Super-Earth\n(1.5 < Rp <= 2)",
    "Neptune-like\n(2 < Rp <= 6)",
    "Saturn-like\n(6 < Rp <= 9)",
    "Super-Saturn\n(9 < Rp <= 11)",
    "Jupiter-like\n(11 < Rp <= 15)",
    "Super-Jupiter\n(Rp > 15)"
]

counts = [
    earth_like_count_rad,
    super_earth_like_count_rad,
    neptune_like_count_rad,
    saturn_like_count_rad,
    super_saturn_like_count_rad,
    jupiter_like_count_rad,
    super_jupiter_like_count_rad
]

# Create DataFrame for plotting
planet_counts_df = pd.DataFrame({
    "Radius of Exoplanet in Earth Radius": categories,
    "# of Exoplanets": counts
})

plt.figure(figsize=(9, 9))
ax = sns.barplot(
    data=planet_counts_df,
    x="Radius of Exoplanet in Earth Radius",
    y="# of Exoplanets",
    palette=[
        "#03A9F4",   # Earth-like
        "red",   # Super-Earth
        "darkgreen",   # Neptune-like
        "orange",   # Saturn-like
        "indigo",   # Super-Saturn
        "purple",   # Jupiter-like
        "maroon"    # Super-Jupiter
    ]
)

plt.xticks(rotation=45, ha="right")
plt.title("Distribution of All 6,038 Confirmed Exoplanets by Radius Category")

# Add counts and percentages on tope of each bar
total = planet_counts_df["# of Exoplanets"].sum()

for i, bar in enumerate(ax.patches):
    height = bar.get_height()
    percentage = (height / total) * 100

    ax.text(
        bar.get_x() + bar.get_width()/2,
        height,
        f'{int(height)}\n({percentage:.1f}%)',
        ha='center',
        va='bottom',
        fontsize=10
    )

plt.tight_layout()
plt.show()

# %% [markdown]
# #### 8) What is the Distribution of Exoplanet Orbital Period in Earth Days?

# %%
bins = list(range(0, 1400, 100))
bins.append(float("inf"))

labels = [f"{i}-{i+100}" for i in range(0, 1300, 100)]
labels.append(">1300")

new_exoplanets_filtered2["period_bin"] = pd.cut(
    new_exoplanets_filtered2["orbital_period_day"],
    bins=bins,
    labels=labels,
    right=False
)

period_counts = new_exoplanets_filtered2["period_bin"].value_counts().sort_index()

# Create color list (default purple)
colors = ["purple"] * len(period_counts)

# Find index of the 300-400 bin
highlight_index = period_counts.index.get_loc("300-400")

# Change that one to blue
colors[highlight_index] = "#03A9F4"

plt.figure(figsize=(10, 8))

period_counts.plot(
    kind="bar",
    color=colors,
    edgecolor=colors
)

plt.xlabel("Orbital Period in Earth Days")
plt.ylabel("# of Exoplanets")
plt.title("Distribution of Orbital Periods for all 6,038 Confirmed Exoplanets")

# Add labels
total = period_counts.sum()
ax = plt.gca()

for bar in ax.patches:
    height = bar.get_height()
    percentage = (height / total) * 100

    ax.text(
        bar.get_x() + bar.get_width()/2,
        height,
        f'{int(height)}\n({percentage:.1f}%)',
        ha='center',
        va='bottom',
        fontsize=8
    )

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
period_counts = new_exoplanets_filtered2["period_bin"].value_counts().sort_index()
period_counts
# Out:
# period_bin
# 0-100        5031
# 100-200       207
# 200-300       102
# 300-400        70
# 400-500        65
# 500-600        51
# 600-700        46
# 700-800        21
# 800-900        30
# 900-1000       31
# 1000-1100      21
# 1100-1200      22
# 1200-1300      19
# >1300         322
# Name: count, dtype: int64

# %% [markdown]
# #### 9) What is the Distribution of Distance between Exoplanet and its Host Star in AU?

# %%
bins = list(range(0, 8, 1))
bins.append(float("inf"))

labels = [f"{i}-{i+1}" for i in range(0, 7, 1)]
labels.append(">7")

new_exoplanets_filtered2["distance_bin"] = pd.cut(
    new_exoplanets_filtered2["orbit_semi_major_axis_au"],
    bins=bins,
    labels=labels,
    right=False
)

distance_counts = new_exoplanets_filtered2["distance_bin"].value_counts().sort_index()

# Create color list (default purple)
colors = ["purple"] * len(distance_counts)

# Find index of the 0-1 bin
highlight_index = distance_counts.index.get_loc("0-1")

# Change that one to blue
colors[highlight_index] = "#03A9F4"

plt.figure(figsize=(10, 8))

distance_counts.plot(
    kind="bar",
    color=colors,
    edgecolor=colors
)

plt.xlabel("Distance Between Exoplanets and their Host Stars in AU")
plt.ylabel("# of Exoplanets")
plt.title("Distribution of Distance Between Exoplanets and their Host Stars for all 6,038 Confirmed Exoplanets")

# Add labels
total = distance_counts.sum()
ax = plt.gca()

for bar in ax.patches:
    height = bar.get_height()
    percentage = (height / total) * 100

    ax.text(
        bar.get_x() + bar.get_width()/2,
        height,
        f'{int(height)}\n({percentage:.1f}%)',
        ha='center',
        va='bottom',
        fontsize=8
    )

plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
distance_counts = new_exoplanets_filtered2["distance_bin"].value_counts().sort_index()
distance_counts
# Out:
# distance_bin
# 0-1    5126
# 1-2     322
# 2-3     209
# 3-4     116
# 4-5      62
# 5-6      39
# 6-7      17
# >7      147
# Name: count, dtype: int64

# %% [markdown]
# #### 10) What is the Distribution of Exoplanet Equilibrium Temperature in Kelvin?

# %%
bins = list(range(0, 2400, 200))
bins.append(float("inf"))

labels = [f"{i}-{i+200}" for i in range(0, 2200, 200)]
labels.append(">2400")

new_exoplanets_filtered2["planet_temp_bin"] = pd.cut(
    new_exoplanets_filtered2["planet_equil_temp_k"],
    bins=bins,
    labels=labels,
    right=False
)

planet_temp_counts = new_exoplanets_filtered2["planet_temp_bin"].value_counts().sort_index()

# Create color list (default purple)
colors = ["purple"] * len(planet_temp_counts)

# Find index of the 200-400 bin
highlight_index = planet_temp_counts.index.get_loc("200-400")

# Change that one to blue
colors[highlight_index] = "#03A9F4"

plt.figure(figsize=(14, 8))

planet_temp_counts.plot(
    kind="bar",
    color=colors,
    edgecolor=colors
)

plt.xlabel("Planet Equilibrium Temperature in Kelvin (K)")
plt.ylabel("# of Exoplanets")
plt.title("Distribution of Equilibrium Temperature for 5,449 of all 6,038 Confirmed Exoplanets")

# Add labels
total = distance_counts.sum()
ax = plt.gca()

for bar in ax.patches:
    height = bar.get_height()
    percentage = (height / total) * 100

    ax.text(
        bar.get_x() + bar.get_width()/2,
        height,
        f'{int(height)}\n({percentage:.1f}%)',
        ha='center',
        va='bottom',
        fontsize=8
    )

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 11) What is the Distribution of Discovery Methods?

# %%
plt.figure(figsize=(10, 8))

method_counts = new_exoplanets_filtered2['discovery_method'].value_counts()

method_counts.plot(
    kind='bar',
    color = [
    "#4CAF50",   # Transit
    "#03A9F4",   # Radial Velocity
    "#FF9800",   # Microlensing
    "#9C27B0",   # Imaging
    "#F44336",   # Transit Timing Variations
    "#795548",   # Astrometry
    "#607D8B"    # Other (if present)
]
)

plt.xlabel("Discovery Method")
plt.ylabel("Number of Exoplanets")
plt.title("Distribution of All 6,038 Exoplanet Discovery Methods")

# Add labels
total = method_counts.sum()
ax = plt.gca()

for bar in ax.patches:
    height = bar.get_height()
    percentage = (height / total) * 100

    ax.text(
        bar.get_x() + bar.get_width()/2,
        height,
        f'{int(height)}\n({percentage:.1f}%)',
        ha='center',
        va='bottom',
        fontsize=8
    )

plt.xticks(rotation=45, ha='right')
plt.ylim(0, max(method_counts) * 1.15)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 13) What is the Distribution of Discovery Years?

# %%
new_exoplanets_filtered2['year_of_discovery'] = (new_exoplanets_filtered2['year_of_discovery'].astype(int))

plt.figure(figsize=(13, 8))

# Sort by year chronological
year_counts = (
    new_exoplanets_filtered2['year_of_discovery']
    .value_counts()
    .sort_index()
)

year_counts.plot(
    kind='bar',
    color = 'maroon'
)

plt.xlabel("Year of Discovery")
plt.ylabel("Number of Exoplanets")
plt.title("Distribution of All 6,038 Exoplanet Discovery Year")

plt.xticks(rotation=45, ha='right')
plt.ylim(0, max(year_counts) * 1.15)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## **Next Steps**
# After conducitng feature selection:
# * 15 key planetary and stellar features:
#   * spectral_type
#   * orbital_eccentricity
#   * orbital_period_day
#   * orbit_semi_major_axis_au
#   * planet_equil_temp_k
#   * planet_mass_earth_mass
#   * planet_rad_earth_rad
#   * stellar_luminosity_solar_lum
#   * stellar_rad_solar_rad
#   * stellar_mass_solar_mass
#   * stellar_surf_grav
#   * stellar_effective_temp_k
#   * star_number_per_system
#   * host_star_name (observation)
#   * planet_name	(observation)
#
# Next Steps for Data Cleaning:
# * Categorize the Spectral Type Column
# * Utilize a valid formula or secondary formula for imputing missing:
#   * orbital_eccentricity
#   * stellar_luminosity_solar_lum
#   * stellar_rad_solar_rad
#   * planet_equil_temp_k
#   * stellar_surf_grav
#   * stellar_effective_temp_k
# * remove remaining missing rows
# * Using the Planet Habitbaility Word Catelog by Planetary Habitability Laboratory (PHL) at Puerto Rico
#   * Extract Earth Similarity Index Column for target variable
